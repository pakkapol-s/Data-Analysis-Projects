# %% [markdown]
# # Pandas Essential Training

# %% [markdown]
# The following cells has the year for the first olympics.

# %%
year = 1896
year + 4
# Out:
# 1900

# %% [markdown]
# ## Using pandas

# %%
# !pip install pandas==2.0.2 "numpy>=1.21.0,<2.0.0"
# Out:
# Requirement already satisfied: pandas==2.0.2 in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.0.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.0.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.0.2) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.2) (1.17.0)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/operations/check.py", line 42, in create_package_set_from_installed
#     dependencies = list(dist.iter_dependencies())
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/importlib/_dists.py", line 225, in iter_dependencies
#     elif not extras and req.marker.evaluate({"extra": ""}):
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/packaging/markers.py", line 325, in evaluate
#     return _evaluate_markers(self._markers, current_environment)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/packaging/markers.py", line 211, in _evaluate_markers
#     groups[-1].append(_evaluate_markers(marker, environment))
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/packaging/markers.py", line 225, in _evaluate_markers
#     groups[-1].append(_eval_op(lhs_value, op, rhs_value))
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/packaging/markers.py", line 183, in _eval_op
#     return spec.contains(lhs, prereleases=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/packaging/specifiers.py", line 563, in contains
#     return operator_callable(normalized_item, self.version)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/packaging/specifiers.py", line 424, in _compare_equal
#     prospective = Version(prospective.public)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/packaging/version.py", line 205, in __init__
#     self._version = _Version(
#                     ^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 215, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.11/logging/__init__.py", line 1526, in critical
#     def critical(self, msg, *args, **kwargs):
#
# KeyboardInterrupt
# ^C

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.2'

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
#  '_testing',
#  '_typing',
#  '_version',
#  'annotations',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'from_dummies',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'read_xml',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', *, sep: 'str | None | lib.NoDefault' = <no_default>, delimiter: 'str | None | lib.NoDefault' = None, header: "int | Sequence[int] | None | Literal['infer']" = 'infer', names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>, index_col: 'IndexLabel | Literal[False] | None' = None, usecols=None, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters=None, true_values=None, false_values=None, skipinitialspace: 'bool' = False, skiprows=None, skipfooter: 'int' = 0, nrows: 'int | None' = None, na_values=None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool' = False, skip_blank_lines: 'bool' = True, parse_dates: 'bool | Sequence[Hashable] | None' = None, infer_datetime_format: 'bool | lib.NoDefault' = <no_default>, keep_date_col: 'bool' = False, date_parser=<no_default>, date_format: 'str | None' = None, dayfirst: 'bool' = False, cache_dates: 'bool' = True, iterator: 'bool' = False, chunksize: 'int | None' = None, compression: 'CompressionOptions' = 'infer', thousands: 'str | None' = None, decimal: 'str' = '.', lineterminator: 'str | None' = None, quotechar: 'str' = '"', quoting: 'int' = 0, doublequote: 'bool' = True, escapechar: 'str | None' = None, comment: 'str | None' = None, encoding: 'str | None' = None, encoding_errors: 'str | None' = 'strict', dialect: 'str | csv.Dialect | None' = None, on_bad_lines: 'str' = 'error', delim_whitespace: 'bool' = False, low_memory=True, memory_map: 'bool' = False, float_precision: "Literal['high', 'legacy'] | None" = None, storage_options: 'StorageOptions' = None, dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>) -> 'DataFrame | TextFileReader'
#     Read a comma-separated values (csv) file into DataFrame.
#
#     Also supports optionally iterating or breaking of the file
#     into chunks.
#
#     Additional help can be found in the online docs for
#     `IO Tools <https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html>`_.
#
#     Parameters
#     ----------
#     filepath_or_buffer : str, path object or file-like object
#         Any valid string path is acceptable. The string could be a URL. Valid
#         URL schemes include http, ftp, s3, gs, and file. For file URLs, a host is
#         expected. A local file could be: file://localhost/path/to/table.csv.
#
#         If you want to pass in a path object, pandas accepts any ``os.PathLike``.
#
#         By file-like object, we refer to objects with a ``read()`` method, such as
#         a file handle (e.g. via builtin ``open`` function) or ``StringIO``.
#     sep : str, default ','
#         Delimiter to use. If sep is None, the C engine cannot automatically detect
#         the separator, but the Python parsing engine can, meaning the latter will
#         be used and automatically detect the separator by Python's builtin sniffer
#         tool, ``csv.Sniffer``. In addition, separators longer than 1 character and
#         different from ``'\s+'`` will be interpreted as regular expressions and
#         will also force the use of the Python parsing engine. Note that regex
#         delimiters are prone to ignoring quoted data. Regex example: ``'\r\t'``.
#     delimiter : str, default ``None``
#         Alias for sep.
#     header : int, list of int, None, default 'infer'
#         Row number(s) to use as the column names, and the start of the
#         data.  Default behavior is to infer the column names: if no names
#         are passed the behavior is identical to ``header=0`` and column
#         names are inferred from the first line of the file, if column
#         names are passed explicitly then the behavior is identical to
#         ``header=None``. Explicitly pass ``header=0`` to be able to
#         replace existing names. The header can be a list of integers that
#         specify row locations for a multi-index on the columns
#         e.g. [0,1,3]. Intervening rows that are not specified will be
#         skipped (e.g. 2 in this example is skipped). Note that this
#         parameter ignores commented lines and empty lines if
#         ``skip_blank_lines=True``, so ``header=0`` denotes the first line of
#         data rather than the first line of the file.
#     names : array-like, optional
#         List of column names to use. If the file contains a header row,
#         then you should explicitly pass ``header=0`` to override the column names.
#         Duplicates in this list are not allowed.
#     index_col : int, str, sequence of int / str, or False, optional, default ``None``
#       Column(s) to use as the row labels of the ``DataFrame``, either given as
#       string name or column index. If a sequence of int / str is given, a
#       MultiIndex is used.
#
#       Note: ``index_col=False`` can be used to force pandas to *not* use the first
#       column as the index, e.g. when you have a malformed file with delimiters at
#       the end of each line.
#     usecols : list-like or callable, optional
#         Return a subset of the columns. If list-like, all elements must either
#         be positional (i.e. integer indices into the document columns) or strings
#         that correspond to column names provided either by the user in `names` or
#         inferred from the document header row(s). If ``names`` are given, the document
#         header row(s) are not taken into account. For example, a valid list-like
#         `usecols` parameter would be ``[0, 1, 2]`` or ``['foo', 'bar', 'baz']``.
#         Element order is ignored, so ``usecols=[0, 1]`` is the same as ``[1, 0]``.
#         To instantiate a DataFrame from ``data`` with element order preserved use
#         ``pd.read_csv(data, usecols=['foo', 'bar'])[['foo', 'bar']]`` for columns
#         in ``['foo', 'bar']`` order or
#         ``pd.read_csv(data, usecols=['foo', 'bar'])[['bar', 'foo']]``
#         for ``['bar', 'foo']`` order.
#
#         If callable, the callable function will be evaluated against the column
#         names, returning names where the callable function evaluates to True. An
#         example of a valid callable argument would be ``lambda x: x.upper() in
#         ['AAA', 'BBB', 'DDD']``. Using this parameter results in much faster
#         parsing time and lower memory usage.
#     dtype : Type name or dict of column -> type, optional
#         Data type for data or columns. E.g. {'a': np.float64, 'b': np.int32,
#         'c': 'Int64'}
#         Use `str` or `object` together with suitable `na_values` settings
#         to preserve and not interpret dtype.
#         If converters are specified, they will be applied INSTEAD
#         of dtype conversion.
#
#         .. versionadded:: 1.5.0
#
#             Support for defaultdict was added. Specify a defaultdict as input where
#             the default determines the dtype of the columns which are not explicitly
#             listed.
#     engine : {'c', 'python', 'pyarrow'}, optional
#         Parser engine to use. The C and pyarrow engines are faster, while the python engine
#         is currently more feature-complete. Multithreading is currently only supported by
#         the pyarrow engine.
#
#         .. versionadded:: 1.4.0
#
#             The "pyarrow" engine was added as an *experimental* engine, and some features
#             are unsupported, or may not work correctly, with this engine.
#     converters : dict, optional
#         Dict of functions for converting values in certain columns. Keys can either
#         be integers or column labels.
#     true_values : list, optional
#         Values to consider as True in addition to case-insensitive variants of "True".
#     false_values : list, optional
#         Values to consider as False in addition to case-insensitive variants of "False".
#     skipinitialspace : bool, default False
#         Skip spaces after delimiter.
#     skiprows : list-like, int or callable, optional
#         Line numbers to skip (0-indexed) or number of lines to skip (int)
#         at the start of the file.
#
#         If callable, the callable function will be evaluated against the row
#         indices, returning True if the row should be skipped and False otherwise.
#         An example of a valid callable argument would be ``lambda x: x in [0, 2]``.
#     skipfooter : int, default 0
#         Number of lines at bottom of file to skip (Unsupported with engine='c').
#     nrows : int, optional
#         Number of rows of file to read. Useful for reading pieces of large files.
#     na_values : scalar, str, list-like, or dict, optional
#         Additional strings to recognize as NA/NaN. If dict passed, specific
#         per-column NA values.  By default the following values are interpreted as
#         NaN: '', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan',
#         '1.#IND', '1.#QNAN', '<NA>', 'N/A', 'NA', 'NULL', 'NaN', 'None',
#         'n/a', 'nan', 'null'.
#     keep_default_na : bool, default True
#         Whether or not to include the default NaN values when parsing the data.
#         Depending on whether `na_values` is passed in, the behavior is as follows:
#
#         * If `keep_default_na` is True, and `na_values` are specified, `na_values`
#           is appended to the default NaN values used for parsing.
#         * If `keep_default_na` is True, and `na_values` are not specified, only
#           the default NaN values are used for parsing.
#         * If `keep_default_na` is False, and `na_values` are specified, only
#           the NaN values specified `na_values` are used for parsing.
#         * If `keep_default_na` is False, and `na_values` are not specified, no
#           strings will be parsed as NaN.
#
#         Note that if `na_filter` is passed in as False, the `keep_default_na` and
#         `na_values` parameters will be ignored.
#     na_filter : bool, default True
#         Detect missing value markers (empty strings and the value of na_values). In
#         data without any NAs, passing na_filter=False can improve the performance
#         of reading a large file.
#     verbose : bool, default False
#         Indicate number of NA values placed in non-numeric columns.
#     skip_blank_lines : bool, default True
#         If True, skip over blank lines rather than interpreting as NaN values.
#     parse_dates : bool or list of int or names or list of lists or dict, default False
#         The behavior is as follows:
#
#         * boolean. If True -> try parsing the index.
#         * list of int or names. e.g. If [1, 2, 3] -> try parsing columns 1, 2, 3
#           each as a separate date column.
#         * list of lists. e.g.  If [[1, 3]] -> combine columns 1 and 3 and parse as
#           a single date column.
#         * dict, e.g. {'foo' : [1, 3]} -> parse columns 1, 3 as date and call
#           result 'foo'
#
#         If a column or index cannot be represented as an array of datetimes,
#         say because of an unparsable value or a mixture of timezones, the column
#         or index will be returned unaltered as an object data type. For
#         non-standard datetime parsing, use ``pd.to_datetime`` after
#         ``pd.read_csv``.
#
#         Note: A fast-path exists for iso8601-formatted dates.
#     infer_datetime_format : bool, default False
#         If True and `parse_dates` is enabled, pandas will attempt to infer the
#         format of the datetime strings in the columns, and if it can be inferred,
#         switch to a faster method of parsing them. In some cases this can increase
#         the parsing speed by 5-10x.
#
#         .. deprecated:: 2.0.0
#             A strict version of this argument is now the default, passing it has no effect.
#
#     keep_date_col : bool, default False
#         If True and `parse_dates` specifies combining multiple columns then
#         keep the original columns.
#     date_parser : function, optional
#         Function to use for converting a sequence of string columns to an array of
#         datetime instances. The default uses ``dateutil.parser.parser`` to do the
#         conversion. Pandas will try to call `date_parser` in three different ways,
#         advancing to the next if an exception occurs: 1) Pass one or more arrays
#         (as defined by `parse_dates`) as arguments; 2) concatenate (row-wise) the
#         string values from the columns defined by `parse_dates` into a single array
#         and pass that; and 3) call `date_parser` once for each row using one or
#         more strings (corresponding to the columns defined by `parse_dates`) as
#         arguments.
#
#         .. deprecated:: 2.0.0
#            Use ``date_format`` instead, or read in as ``object`` and then apply
#            :func:`to_datetime` as-needed.
#     date_format : str or dict of column -> format, default ``None``
#        If used in conjunction with ``parse_dates``, will parse dates according to this
#        format. For anything more complex,
#        please read in as ``object`` and then apply :func:`to_datetime` as-needed.
#
#        .. versionadded:: 2.0.0
#     dayfirst : bool, default False
#         DD/MM format dates, international and European format.
#     cache_dates : bool, default True
#         If True, use a cache of unique, converted dates to apply the datetime
#         conversion. May produce significant speed-up when parsing duplicate
#         date strings, especially ones with timezone offsets.
#
#     iterator : bool, default False
#         Return TextFileReader object for iteration or getting chunks with
#         ``get_chunk()``.
#
#         .. versionchanged:: 1.2
#
#            ``TextFileReader`` is a context manager.
#     chunksize : int, optional
#         Return TextFileReader object for iteration.
#         See the `IO Tools docs
#         <https://pandas.pydata.org/pandas-docs/stable/io.html#io-chunking>`_
#         for more information on ``iterator`` and ``chunksize``.
#
#         .. versionchanged:: 1.2
#
#            ``TextFileReader`` is a context manager.
#     compression : str or dict, default 'infer'
#         For on-the-fly decompression of on-disk data. If 'infer' and 'filepath_or_buffer' is
#         path-like, then detect compression from the following extensions: '.gz',
#         '.bz2', '.zip', '.xz', '.zst', '.tar', '.tar.gz', '.tar.xz' or '.tar.bz2'
#         (otherwise no compression).
#         If using 'zip' or 'tar', the ZIP file must contain only one data file to be read in.
#         Set to ``None`` for no decompression.
#         Can also be a dict with key ``'method'`` set
#         to one of {``'zip'``, ``'gzip'``, ``'bz2'``, ``'zstd'``, ``'tar'``} and other
#         key-value pairs are forwarded to
#         ``zipfile.ZipFile``, ``gzip.GzipFile``,
#         ``bz2.BZ2File``, ``zstandard.ZstdDecompressor`` or
#         ``tarfile.TarFile``, respectively.
#         As an example, the following could be passed for Zstandard decompression using a
#         custom compression dictionary:
#         ``compression={'method': 'zstd', 'dict_data': my_compression_dict}``.
#
#         .. versionadded:: 1.5.0
#             Added support for `.tar` files.
#
#         .. versionchanged:: 1.4.0 Zstandard support.
#
#     thousands : str, optional
#         Thousands separator.
#     decimal : str, default '.'
#         Character to recognize as decimal point (e.g. use ',' for European data).
#     lineterminator : str (length 1), optional
#         Character to break file into lines. Only valid with C parser.
#     quotechar : str (length 1), optional
#         The character used to denote the start and end of a quoted item. Quoted
#         items can include the delimiter and it will be ignored.
#     quoting : int or csv.QUOTE_* instance, default 0
#         Control field quoting behavior per ``csv.QUOTE_*`` constants. Use one of
#         QUOTE_MINIMAL (0), QUOTE_ALL (1), QUOTE_NONNUMERIC (2) or QUOTE_NONE (3).
#     doublequote : bool, default ``True``
#        When quotechar is specified and quoting is not ``QUOTE_NONE``, indicate
#        whether or not to interpret two consecutive quotechar elements INSIDE a
#        field as a single ``quotechar`` element.
#     escapechar : str (length 1), optional
#         One-character string used to escape other characters.
#     comment : str, optional
#         Indicates remainder of line should not be parsed. If found at the beginning
#         of a line, the line will be ignored altogether. This parameter must be a
#         single character. Like empty lines (as long as ``skip_blank_lines=True``),
#         fully commented lines are ignored by the parameter `header` but not by
#         `skiprows`. For example, if ``comment='#'``, parsing
#         ``#empty\na,b,c\n1,2,3`` with ``header=0`` will result in 'a,b,c' being
#         treated as the header.
#     encoding : str, optional, default "utf-8"
#         Encoding to use for UTF when reading/writing (ex. 'utf-8'). `List of Python
#         standard encodings
#         <https://docs.python.org/3/library/codecs.html#standard-encodings>`_ .
#
#         .. versionchanged:: 1.2
#
#            When ``encoding`` is ``None``, ``errors="replace"`` is passed to
#            ``open()``. Otherwise, ``errors="strict"`` is passed to ``open()``.
#            This behavior was previously only the case for ``engine="python"``.
#
#         .. versionchanged:: 1.3.0
#
#            ``encoding_errors`` is a new argument. ``encoding`` has no longer an
#            influence on how encoding errors are handled.
#
#     encoding_errors : str, optional, default "strict"
#         How encoding errors are treated. `List of possible values
#         <https://docs.python.org/3/library/codecs.html#error-handlers>`_ .
#
#         .. versionadded:: 1.3.0
#
#     dialect : str or csv.Dialect, optional
#         If provided, this parameter will override values (default or not) for the
#         following parameters: `delimiter`, `doublequote`, `escapechar`,
#         `skipinitialspace`, `quotechar`, and `quoting`. If it is necessary to
#         override values, a ParserWarning will be issued. See csv.Dialect
#         documentation for more details.
#     on_bad_lines : {'error', 'warn', 'skip'} or callable, default 'error'
#         Specifies what to do upon encountering a bad line (a line with too many fields).
#         Allowed values are :
#
#             - 'error', raise an Exception when a bad line is encountered.
#             - 'warn', raise a warning when a bad line is encountered and skip that line.
#             - 'skip', skip bad lines without raising or warning when they are encountered.
#
#         .. versionadded:: 1.3.0
#
#         .. versionadded:: 1.4.0
#
#             - callable, function with signature
#               ``(bad_line: list[str]) -> list[str] | None`` that will process a single
#               bad line. ``bad_line`` is a list of strings split by the ``sep``.
#               If the function returns ``None``, the bad line will be ignored.
#               If the function returns a new list of strings with more elements than
#               expected, a ``ParserWarning`` will be emitted while dropping extra elements.
#               Only supported when ``engine="python"``
#
#     delim_whitespace : bool, default False
#         Specifies whether or not whitespace (e.g. ``' '`` or ``'    '``) will be
#         used as the sep. Equivalent to setting ``sep='\s+'``. If this option
#         is set to True, nothing should be passed in for the ``delimiter``
#         parameter.
#     low_memory : bool, default True
#         Internally process the file in chunks, resulting in lower memory use
#         while parsing, but possibly mixed type inference.  To ensure no mixed
#         types either set False, or specify the type with the `dtype` parameter.
#         Note that the entire file is read into a single DataFrame regardless,
#         use the `chunksize` or `iterator` parameter to return the data in chunks.
#         (Only valid with C parser).
#     memory_map : bool, default False
#         If a filepath is provided for `filepath_or_buffer`, map the file object
#         directly onto memory and access the data directly from there. Using this
#         option can improve performance because there is no longer any I/O overhead.
#     float_precision : str, optional
#         Specifies which converter the C engine should use for floating-point
#         values. The options are ``None`` or 'high' for the ordinary converter,
#         'legacy' for the original lower precision pandas converter, and
#         'round_trip' for the round-trip converter.
#
#         .. versionchanged:: 1.2
#
#     storage_options : dict, optional
#         Extra options that make sense for a particular storage connection, e.g.
#         host, port, username, password, etc. For HTTP(S) URLs the key-value pairs
#         are forwarded to ``urllib.request.Request`` as header options. For other
#         URLs (e.g. starting with "s3://", and "gcs://") the key-value pairs are
#         forwarded to ``fsspec.open``. Please see ``fsspec`` and ``urllib`` for more
#         details, and for more examples on storage options refer `here
#         <https://pandas.pydata.org/docs/user_guide/io.html?
#         highlight=storage_options#reading-writing-remote-files>`_.
#
#         .. versionadded:: 1.2
#
#     dtype_backend : {"numpy_nullable", "pyarrow"}, defaults to NumPy backed DataFrames
#         Which dtype_backend to use, e.g. whether a DataFrame should have NumPy
#         arrays, nullable dtypes are used for all dtypes that have a nullable
#         implementation when "numpy_nullable" is set, pyarrow is used for all
#         dtypes if "pyarrow" is set.
#
#         The dtype_backends are still experimential.
#
#         .. versionadded:: 2.0
#
#     Returns
#     -------
#     DataFrame or TextFileReader
#         A comma-separated values (csv) file is returned as two-dimensional
#         data structure with labeled axes.
#
#     See Also
#     --------
#     DataFrame.to_csv : Write DataFrame to a comma-separated values (csv) file.
#     read_csv : Read a comma-separated values (csv) file into DataFrame.
#     read_fwf : Read a table of fixed-width formatted lines into DataFrame.
#
#     Examples
#     --------
#     >>> pd.read_csv('data.csv')  # doctest: +SKIP

# %%
pd.read_csv?

# %% [markdown]
# Pandas documentation: https://pandas.pydata.org/docs/reference/index.html

# %% [markdown]
# ## Reading tabular data into pandas

# %%
# !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
# Out:
# --2025-06-15 02:10:57--  https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/jonfernandes/pandas_essential/main/olympics_1896_2004.csv [following]
# --2025-06-15 02:10:57--  https://raw.githubusercontent.com/jonfernandes/pandas_essential/main/olympics_1896_2004.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2398388 (2.3M) [text/plain]
# Saving to: ‘olympics_1896_2004.csv.2’
#
# olympics_1896_2004. 100%[===================>]   2.29M  --.-KB/s    in 0.08s
#
# 2025-06-15 02:10:57 (27.9 MB/s) - ‘olympics_1896_2004.csv.2’ saved [2398388/2398388]

# %%
#from google.colab import files
#files.upload()

# %%
# !ls -la
# Out:
# total 7048
# drwxr-xr-x 1 root root    4096 Jun 15 02:10 .
# drwxr-xr-x 1 root root    4096 Jun 15 02:00 ..
# drwxr-xr-x 4 root root    4096 Jun 12 13:35 .config
# -rw-r--r-- 1 root root 2398388 Jun 15 02:08 olympics_1896_2004.csv
# -rw-r--r-- 1 root root 2398388 Jun 15 02:10 olympics_1896_2004.csv.1
# -rw-r--r-- 1 root root 2398388 Jun 15 02:10 olympics_1896_2004.csv.2
# drwxr-xr-x 1 root root    4096 Jun 12 13:36 sample_data

# %%
pd.read_csv?

# %%
pd.read_csv('olympics_1896_2004.csv')
# Out:
#       This is a list of medallists at the Summer Olympic Games (1896-2004) with details of the year of the olympics, city, sport, discipline, athlete name, gender, event and medal  \
# 0                                                    NaN
# 1      DISCLAIMER: No guarantees, express or implied,...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                   Year
# ...                                                  ...
# 27174                                               2004
# 27175                                               2004
# 27176                                               2004
# 27177                                               2004
# 27178                                               2004
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3          Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN         NaN                 NaN        NaN
# 1            NaN        NaN         NaN                 NaN        NaN
# 2            NaN        NaN         NaN                 NaN        NaN
# 3            NaN        NaN         NaN                 NaN        NaN
# 4           City      Sport  Discipline        Athlete Name        NOC
# ...          ...        ...         ...                 ...        ...
# 27174     Athens    Fencing     Fencing  LOGOUNOVA, Tatiana        RUS
# 27175     Athens    Fencing     Fencing       SIVKOVA, Anna        RUS
# 27176     Athens    Fencing     Fencing      BOKEL, Claudia        GER
# 27177     Athens    Fencing     Fencing     DUPLITZER, Imke        GER
# 27178     Athens    Fencing     Fencing   HEIDEMANN, Britta        GER
#
#       Unnamed: 6 Unnamed: 7    Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0            NaN        NaN           NaN        NaN         NaN
# 1            NaN        NaN           NaN        NaN         NaN
# 2            NaN        NaN           NaN        NaN         NaN
# 3            NaN        NaN           NaN        NaN         NaN
# 4         Gender      Event  Event Gender      Medal    Position
# ...          ...        ...           ...        ...         ...
# 27174      Women  épée team             W       Gold           1
# 27175      Women  épée team             W       Gold           1
# 27176      Women  épée team             W     Silver           2
# 27177      Women  épée team             W     Silver           2
# 27178      Women  épée team             W     Silver           2
#
# [27179 rows x 11 columns]

# %%
pd.read_csv(filepath_or_buffer='olympics_1896_2004.csv')
# Out:
#       This is a list of medallists at the Summer Olympic Games (1896-2004) with details of the year of the olympics, city, sport, discipline, athlete name, gender, event and medal  \
# 0                                                    NaN
# 1      DISCLAIMER: No guarantees, express or implied,...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                   Year
# ...                                                  ...
# 27174                                               2004
# 27175                                               2004
# 27176                                               2004
# 27177                                               2004
# 27178                                               2004
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3          Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN         NaN                 NaN        NaN
# 1            NaN        NaN         NaN                 NaN        NaN
# 2            NaN        NaN         NaN                 NaN        NaN
# 3            NaN        NaN         NaN                 NaN        NaN
# 4           City      Sport  Discipline        Athlete Name        NOC
# ...          ...        ...         ...                 ...        ...
# 27174     Athens    Fencing     Fencing  LOGOUNOVA, Tatiana        RUS
# 27175     Athens    Fencing     Fencing       SIVKOVA, Anna        RUS
# 27176     Athens    Fencing     Fencing      BOKEL, Claudia        GER
# 27177     Athens    Fencing     Fencing     DUPLITZER, Imke        GER
# 27178     Athens    Fencing     Fencing   HEIDEMANN, Britta        GER
#
#       Unnamed: 6 Unnamed: 7    Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0            NaN        NaN           NaN        NaN         NaN
# 1            NaN        NaN           NaN        NaN         NaN
# 2            NaN        NaN           NaN        NaN         NaN
# 3            NaN        NaN           NaN        NaN         NaN
# 4         Gender      Event  Event Gender      Medal    Position
# ...          ...        ...           ...        ...         ...
# 27174      Women  épée team             W       Gold           1
# 27175      Women  épée team             W       Gold           1
# 27176      Women  épée team             W     Silver           2
# 27177      Women  épée team             W     Silver           2
# 27178      Women  épée team             W     Silver           2
#
# [27179 rows x 11 columns]

# %%
oo = pd.read_csv('olympics_1896_2004.csv')
oo
# Out:
#       This is a list of medallists at the Summer Olympic Games (1896-2004) with details of the year of the olympics, city, sport, discipline, athlete name, gender, event and medal  \
# 0                                                    NaN
# 1      DISCLAIMER: No guarantees, express or implied,...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                   Year
# ...                                                  ...
# 27174                                               2004
# 27175                                               2004
# 27176                                               2004
# 27177                                               2004
# 27178                                               2004
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3          Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN         NaN                 NaN        NaN
# 1            NaN        NaN         NaN                 NaN        NaN
# 2            NaN        NaN         NaN                 NaN        NaN
# 3            NaN        NaN         NaN                 NaN        NaN
# 4           City      Sport  Discipline        Athlete Name        NOC
# ...          ...        ...         ...                 ...        ...
# 27174     Athens    Fencing     Fencing  LOGOUNOVA, Tatiana        RUS
# 27175     Athens    Fencing     Fencing       SIVKOVA, Anna        RUS
# 27176     Athens    Fencing     Fencing      BOKEL, Claudia        GER
# 27177     Athens    Fencing     Fencing     DUPLITZER, Imke        GER
# 27178     Athens    Fencing     Fencing   HEIDEMANN, Britta        GER
#
#       Unnamed: 6 Unnamed: 7    Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0            NaN        NaN           NaN        NaN         NaN
# 1            NaN        NaN           NaN        NaN         NaN
# 2            NaN        NaN           NaN        NaN         NaN
# 3            NaN        NaN           NaN        NaN         NaN
# 4         Gender      Event  Event Gender      Medal    Position
# ...          ...        ...           ...        ...         ...
# 27174      Women  épée team             W       Gold           1
# 27175      Women  épée team             W       Gold           1
# 27176      Women  épée team             W     Silver           2
# 27177      Women  épée team             W     Silver           2
# 27178      Women  épée team             W     Silver           2
#
# [27179 rows x 11 columns]

# %%
oo = pd.read_csv('olympics_1896_2004.csv', skiprows=5)
oo
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal  Position
# 0          100km            M    Gold         1
# 1          100km            M  Silver         2
# 2           100m            M  Bronze         3
# 3           100m            M  Bronze         3
# 4           100m            M    Gold         1
# ...          ...          ...     ...       ...
# 27169  épée team            W    Gold         1
# 27170  épée team            W    Gold         1
# 27171  épée team            W  Silver         2
# 27172  épée team            W  Silver         2
# 27173  épée team            W  Silver         2
#
# [27174 rows x 11 columns]

# %%
filename = "olympics_1896_2004.csv"

# %%
#from google.colab import files
#files.upload()

# %% [markdown]
# ## Get an overview of the data and displaying it

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = pd.read_csv(filename, skiprows=5)
oo
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal  Position
# 0          100km            M    Gold         1
# 1          100km            M  Silver         2
# 2           100m            M  Bronze         3
# 3           100m            M  Bronze         3
# 4           100m            M    Gold         1
# ...          ...          ...     ...       ...
# 27169  épée team            W    Gold         1
# 27170  épée team            W    Gold         1
# 27171  épée team            W  Silver         2
# 27172  épée team            W  Silver         2
# 27173  épée team            W  Silver         2
#
# [27174 rows x 11 columns]

# %%
oo.shape
# Out:
# (27174, 11)

# %%
oo.shape?

# %%
oo.head()
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
#
#    Event Event Gender   Medal  Position
# 0  100km            M    Gold         1
# 1  100km            M  Silver         2
# 2   100m            M  Bronze         3
# 3   100m            M  Bronze         3
# 4   100m            M    Gold         1

# %%
oo.head?

# %%
oo.head(3)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
#
#    Event Event Gender   Medal  Position
# 0  100km            M    Gold         1
# 1  100km            M  Silver         2
# 2   100m            M  Bronze         3

# %%
oo.tail()
# Out:
#        Year    City    Sport Discipline        Athlete Name  NOC Gender  \
# 27169  2004  Athens  Fencing    Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens  Fencing    Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens  Fencing    Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens  Fencing    Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens  Fencing    Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal  Position
# 27169  épée team            W    Gold         1
# 27170  épée team            W    Gold         1
# 27171  épée team            W  Silver         2
# 27172  épée team            W  Silver         2
# 27173  épée team            W  Silver         2

# %%
oo.sample(5)
# Out:
#        Year                   City       Sport  Discipline  \
# 2402   1912              Stockholm   Athletics   Athletics
# 15062  1976               Montreal     Sailing     Sailing
# 20273  1992              Barcelona    Baseball    Baseball
# 9295   1956  Melbourne / Stockholm  Basketball  Basketball
# 18660  1988                  Seoul  Basketball  Basketball
#
#                 Athlete Name  NOC Gender                Event Event Gender  \
# 2402      ADAMS, Benjamin W.  USA    Men  high jump, standing            M
# 15062  CONNER, Dennis Walter  USA    Men              tempest            X
# 20273   KAWABATA, Shinichiro  JPN    Men             baseball            M
# 9295     TOMSIC, Ronald Paul  USA    Men           basketball            M
# 18660    PANKRASHKIN, Viktor  URS    Men           basketball            M
#
#         Medal  Position
# 2402   Silver         2
# 15062  Bronze         3
# 20273  Bronze         3
# 9295     Gold         1
# 18660    Gold         1

# %%
oo.sample?

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27174 entries, 0 to 27173
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          27174 non-null  int64
#  1   City          27174 non-null  object
#  2   Sport         27174 non-null  object
#  3   Discipline    27174 non-null  object
#  4   Athlete Name  27174 non-null  object
#  5   NOC           27174 non-null  object
#  6   Gender        27174 non-null  object
#  7   Event         27174 non-null  object
#  8   Event Gender  27174 non-null  object
#  9   Medal         27174 non-null  object
#  10  Position      27174 non-null  int64
# dtypes: int64(2), object(9)
# memory usage: 2.3+ MB

# %%
oo.describe()
# Out:
#                Year      Position
# count  27174.000000  27174.000000
# mean    1964.685803      1.992566
# std       31.590396      0.817469
# min     1896.000000      1.000000
# 25%     1936.000000      1.000000
# 50%     1972.000000      2.000000
# 75%     1992.000000      3.000000
# max     2004.000000      3.000000

# %%
pd.get_option("display.max_rows")
# Out:
# 60

# %%
pd.set_option("display.max_rows", 60)
oo
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal  Position
# 0          100km            M    Gold         1
# 1          100km            M  Silver         2
# 2           100m            M  Bronze         3
# 3           100m            M  Bronze         3
# 4           100m            M    Gold         1
# ...          ...          ...     ...       ...
# 27169  épée team            W    Gold         1
# 27170  épée team            W    Gold         1
# 27171  épée team            W  Silver         2
# 27172  épée team            W  Silver         2
# 27173  épée team            W  Silver         2
#
# [27174 rows x 11 columns]

# %%
pd.get_option("display.max_columns")
# Out:
# 20

# %%
pd.get_option("display.width")
# Out:
# 80

# %%
pd.set_option("display.width", 100)

# %% [markdown]
# ## Select a Series (column)

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.sample(3)
# Out:
#        Year         City       Sport   Discipline         Athlete Name  NOC Gender  \
# 26429  2004       Athens    Handball     Handball  KRETZSCHMAR, Stefan  GER    Men
# 17690  1984  Los Angeles  Gymnastics  Artistic G.        PAUCA, Simona  ROU  Women
# 19752  1992    Barcelona    Aquatics     Swimming     BURGESS, Gregory  USA    Men
#
#                         Event Event Gender   Medal  Position
# 26429                handball            M  Silver         2
# 17690    individual all-round            W  Bronze         3
# 19752  200m individual medley            M  Silver         2

# %%
type(oo)
# Out:
# pandas.core.frame.DataFrame

# %%
oo["Discipline"]
# Out:
# 0        Cycling Track
# 1        Cycling Track
# 2            Athletics
# 3            Athletics
# 4            Athletics
#              ...
# 27169          Fencing
# 27170          Fencing
# 27171          Fencing
# 27172          Fencing
# 27173          Fencing
# Name: Discipline, Length: 27174, dtype: object

# %%
oo['Discipline']
# Out:
# 0        Cycling Track
# 1        Cycling Track
# 2            Athletics
# 3            Athletics
# 4            Athletics
#              ...
# 27169          Fencing
# 27170          Fencing
# 27171          Fencing
# 27172          Fencing
# 27173          Fencing
# Name: Discipline, Length: 27174, dtype: object

# %%
#oo["discipline"]

# %%
type(oo["Discipline"])
# Out:
# pandas.core.series.Series

# %%
oo.Discipline
# Out:
# 0        Cycling Track
# 1        Cycling Track
# 2            Athletics
# 3            Athletics
# 4            Athletics
#              ...
# 27169          Fencing
# 27170          Fencing
# 27171          Fencing
# 27172          Fencing
# 27173          Fencing
# Name: Discipline, Length: 27174, dtype: object

# %%
oo.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender', 'Event',
#        'Event Gender', 'Medal', 'Position'],
#       dtype='object')

# %%
oo["Athlete Name"]
# Out:
# 0             FLAMENG, Léon
# 1        KOLETTIS, Georgios
# 2             LANE, Francis
# 3          SZOKOLYI, Alajos
# 4             BURKE, Thomas
#                 ...
# 27169    LOGOUNOVA, Tatiana
# 27170         SIVKOVA, Anna
# 27171        BOKEL, Claudia
# 27172       DUPLITZER, Imke
# 27173     HEIDEMANN, Britta
# Name: Athlete Name, Length: 27174, dtype: object

# %%
#oo.Athlete Name

# %%
oo.sample(3)
# Out:
#        Year     City       Sport   Discipline         Athlete Name  NOC Gender             Event  \
# 3894   1920  Antwerp  Gymnastics  Artistic G.     VAN GUYSSE, Jean  BEL    Men  team competition
# 23128  1996  Atlanta    Aquatics   Water polo  KOBESCAK, Vjekoslav  CRO    Men        water polo
# 4431   1924    Paris     Sailing      Sailing         GANTHIER, P.  FRA    Men                8m
#
#       Event Gender   Medal  Position
# 3894             M  Silver         2
# 23128            M  Silver         2
# 4431             X  Bronze         3

# %%
oo.Year.unique()
# Out:
# array([1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948,
#        1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992,
#        1996, 2000, 2004])

# %%
oo.Year.unique?

# %%
oo.Sport.unique()
# Out:
# array(['Cycling', 'Athletics', 'Aquatics', 'Shooting', 'Tennis',
#        'Fencing', 'Weightlifting', 'Gymnastics', 'Wrestling', 'Sailing',
#        'Archery', 'Basque Pelota', 'Cricket', 'Croquet', 'Rowing',
#        'Football', 'Equestrian', 'Golf', 'Polo', 'Rugby', 'Tug of War',
#        'Boxing', 'Roque', 'Lacrosse', 'Water Motorsports', 'Rackets',
#        'Hockey', 'Jeu de paume', 'Skating', 'Modern Pentathlon',
#        'Ice Hockey', 'Canoe / Kayak', 'Basketball', 'Handball', 'Judo',
#        'Volleyball', 'Table Tennis', 'Baseball', 'Badminton', 'Softball',
#        'Taekwondo', 'Triathlon'], dtype=object)

# %%
oo.sample(3)
# Out:
#        Year         City          Sport       Discipline          Athlete Name  NOC Gender  \
# 3570   1920      Antwerp         Hockey           Hockey   HANSEN, Hans Jörgen  DEN    Men
# 23778  2000       Sydney  Canoe / Kayak  Canoe / Kayak F     PEREIRA, Leobaldo  CUB    Men
# 16887  1984  Los Angeles      Athletics        Athletics  BROWN, Philip Andrew  GBR    Men
#
#                           Event Event Gender   Medal  Position
# 3570                     hockey            M  Silver         2
# 23778  C-2 1000m (canoe double)            M  Silver         2
# 16887              4x400m relay            M  Silver         2

# %%
oo.Year.value_counts()
# Out:
# Year
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1956     885
# 1912     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: count, dtype: int64

# %%
oo.Year.value_counts?

# %%
oo.Year.value_counts(normalize=True)
# Out:
# Year
# 2000    0.074152
# 2004    0.073526
# 1996    0.068411
# 1992    0.062744
# 1988    0.056893
# 1984    0.053691
# 1980    0.051041
# 1976    0.048024
# 1920    0.047766
# 1972    0.043608
# 1968    0.037941
# 1964    0.037168
# 1952    0.032715
# 1956    0.032568
# 1912    0.032568
# 1924    0.032531
# 1960    0.032457
# 1936    0.032200
# 1948    0.029955
# 1908    0.029587
# 1928    0.026128
# 1932    0.022632
# 1900    0.018842
# 1904    0.017296
# 1896    0.005557
# Name: proportion, dtype: float64

# %% [markdown]
# ## Challenge

# %% [markdown]
# Answer the following questions. Indicate the Pandas command where relevant.
#
# 1.   What is the time range covered in this dataset?
# 2.   The Olympics take place every 4 years. Why are there missing years?
# 3.   What are the types of medals awarded?
# 4.   Across all of the Olympic Games, how many Gold, Silver and Bronze medals have there been?
# 5.   Why are there not an equal number of Gold, Silver and Bronze medals?
# 6.   There are more Gold medals than Silver, and more Silver than Bronze. Why might that be?
# 7.   What are the different NOCs (National Olympic Committees)
# 8.   What does the NOC 'ZZX' represent?

# %% [markdown]
# ##Solution

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %% [markdown]
# 1. What is the time range covered in this dataset?

# %%
oo.Year.unique()
# Out:
# array([1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948,
#        1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992,
#        1996, 2000, 2004])

# %% [markdown]
# 2. The Olympics take place every 4 years. Why are there missing years?
# - World War 1: 1914-1918
# - World War 2: 1939-1945

# %% [markdown]
# 3. What are the types of medals awarded?

# %%
oo.Medal.unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %% [markdown]
# 4. Across all of the Olympics, how many Gold, Silver and Bronze medals have there been?

# %%
oo.Medal.value_counts()
# Out:
# Medal
# Gold      9181
# Silver    9014
# Bronze    8979
# Name: count, dtype: int64

# %% [markdown]
# 5. Why are there not an equal number of Gold, Silver and Bronze medals?
# - Tied results
# - Team events
# - Disqualifications

# %%
oo.head(10)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# 5  1896  Athens  Athletics      Athletics      HOFMANN, Fritz  GER    Men
# 6  1896  Athens   Aquatics       Swimming       HAJOS, Alfred  HUN    Men
# 7  1896  Athens   Aquatics       Swimming    HERSCHMANN, Otto  AUT    Men
# 8  1896  Athens   Aquatics       Swimming   DRIVAS, Dimitrios  GRE    Men
# 9  1896  Athens   Aquatics       Swimming  MALOKINIS, Ioannis  GRE    Men
#
#                         Event Event Gender   Medal  Position
# 0                       100km            M    Gold         1
# 1                       100km            M  Silver         2
# 2                        100m            M  Bronze         3
# 3                        100m            M  Bronze         3
# 4                        100m            M    Gold         1
# 5                        100m            M  Silver         2
# 6              100m freestyle            M    Gold         1
# 7              100m freestyle            M  Silver         2
# 8  100m freestyle for sailors            M  Bronze         3
# 9  100m freestyle for sailors            M    Gold         1

# %% [markdown]
# 6. There are more Gold medals than Silver, and more Silver than Bronze. Why might that be?
#
# Men's 100km cycling
# - https://en.wikipedia.org/wiki/Cycling_at_the_1896_Summer_Olympics_%E2%80%93_Men%27s_100_kilometres
# - https://en.wikipedia.org/wiki/Aristidis_Konstantinidis
#
# Men's 100m freestyle (1896)
# - https://en.wikipedia.org/wiki/Swimming_at_the_1896_Summer_Olympics_%E2%80%93_Men%27s_100_metre_freestyle

# %% [markdown]
# 7. What are the different NOCs (National Olympic Committees)

# %%
oo.NOC.unique()
# Out:
# array(['FRA', 'GRE', 'USA', 'HUN', 'GER', 'AUT', 'GBR', 'AUS', 'DEN',
#        'ZZX', 'SUI', 'IND', 'NED', 'CAN', 'NOR', 'BEL', 'ESP', 'BOH',
#        'ITA', 'SWE', 'CUB', 'RU1', 'FIN', 'RSA', 'ANZ', 'LUX', 'EST',
#        'BRA', 'JPN', 'TCH', 'NZL', 'ARG', 'HAI', 'POL', 'URU', 'YUG',
#        'ROU', 'POR', 'EGY', 'PHI', 'IRL', 'CHI', 'MEX', 'LAT', 'TUR',
#        'KOR', 'PAN', 'JAM', 'SRI', 'PER', 'PUR', 'IRI', 'TRI', 'URS',
#        'LIB', 'BUL', 'VEN', 'EUA', 'PAK', 'ISL', 'BAH', 'BWI', 'GHA',
#        'IRQ', 'SIN', 'TPE', 'ETH', 'MAR', 'TUN', 'NGR', 'KEN', 'FRG',
#        'MGL', 'GDR', 'UGA', 'CMR', 'PRK', 'COL', 'NIG', 'BER', 'THA',
#        'TAN', 'GUY', 'ZIM', 'ZAM', 'CHN', 'CIV', 'DOM', 'ALG', 'SYR',
#        'SUR', 'CRC', 'SEN', 'AHO', 'DJI', 'ISV', 'INA', 'EUN', 'NAM',
#        'IOP', 'QAT', 'ISR', 'LTU', 'CRO', 'SLO', 'MAS', 'RUS', 'UKR',
#        'TGA', 'ARM', 'BLR', 'MDA', 'ECU', 'KAZ', 'AZE', 'BDI', 'SVK',
#        'CZE', 'UZB', 'GEO', 'MOZ', 'HKG', 'KGZ', 'BAR', 'KSA', 'VIE',
#        'MKD', 'KUW', 'ERI', 'SCG', 'UAE', 'PAR'], dtype=object)

# %% [markdown]
# 8. What does the NOC 'ZZX' represent?
# - https://en.wikipedia.org/wiki/Mixed_teams_at_the_Olympics

# %% [markdown]
# ## Python Lists and Dictionaries

# %%
medals = ["Gold", "Silver", "Bronze"]
medals
# Out:
# ['Gold', 'Silver', 'Bronze']

# %%
type(medals)
# Out:
# list

# %%
position = {"First": "Gold",
            "Second": "Silver",
            "Third": "Bronze"
}
position
# Out:
# {'First': 'Gold', 'Second': 'Silver', 'Third': 'Bronze'}

# %%
type(position)
# Out:
# dict

# %%
position["First"]
# Out:
# 'Gold'

# %% [markdown]
# ## Rename a series (or column)

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.sample(3)
# Out:
#        Year                   City       Sport Discipline                Athlete Name  NOC Gender  \
# 3058   1920                Antwerp   Athletics  Athletics  RUDD, Bevil Gordon D'Urban  RSA    Men
# 11435  1964                  Tokyo     Fencing    Fencing                PEZSA, Tibor  HUN    Men
# 9525   1956  Melbourne / Stockholm  Equestrian   Dressage        LINSENHOFF, Liselott  EUA  Women
#
#                   Event Event Gender   Medal  Position
# 3058               400m            M    Gold         1
# 11435  sabre individual            M    Gold         1
# 9525         individual            X  Bronze         3

# %%
mapper = {"Athlete Name": "Athlete_Name",
          "Event Gender": "Event_Gender"}

# %%
oo.rename?

# %%
oo.rename(columns=mapper)
# Out:
#        Year    City      Sport     Discipline        Athlete_Name  NOC Gender      Event  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men      100km
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men      100km
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men       100m
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men       100m
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men       100m
# ...     ...     ...        ...            ...                 ...  ...    ...        ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women  épée team
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women  épée team
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women  épée team
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women  épée team
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women  épée team
#
#       Event_Gender   Medal  Position
# 0                M    Gold         1
# 1                M  Silver         2
# 2                M  Bronze         3
# 3                M  Bronze         3
# 4                M    Gold         1
# ...            ...     ...       ...
# 27169            W    Gold         1
# 27170            W    Gold         1
# 27171            W  Silver         2
# 27172            W  Silver         2
# 27173            W  Silver         2
#
# [27174 rows x 11 columns]

# %%
oo.sample(3)
# Out:
#        Year      City      Sport Discipline        Athlete Name  NOC Gender  \
# 25572  2004    Athens  Athletics  Athletics         DAVY, Nadia  JAM  Women
# 10226  1960      Rome  Athletics  Athletics      OERTER, Alfred  USA    Men
# 8469   1952  Helsinki     Rowing     Rowing  PAIN, Edward Oscar  AUS    Men
#
#                           Event Event Gender   Medal  Position
# 25572              4x400m relay            W  Bronze         3
# 10226              discus throw            M    Gold         1
# 8469   eight with coxswain (8+)            M  Bronze         3

# %%
oo = oo.rename(columns=mapper)
oo.sample(3)
# Out:
#        Year    City          Sport       Discipline    Athlete_Name  NOC Gender  \
# 24198  2000  Sydney         Rowing           Rowing  OLTEANU, Ioana  ROU  Women
# 24900  2000  Sydney     Equestrian         Eventing     LAW, Leslie  GBR    Men
# 12092  1968  Mexico  Canoe / Kayak  Canoe / Kayak F   PFEFFER, Anna  HUN  Women
#
#                           Event Event_Gender   Medal  Position
# 24198  eight with coxswain (8+)            W    Gold         1
# 24900                      team            X  Silver         2
# 12092   K-2 500m (kayak double)            W  Silver         2

# %%
oo = pd.read_csv(filename, skiprows=5).rename(columns=mapper)
oo.sample(3)
# Out:
#        Year    City      Sport    Discipline              Athlete_Name  NOC Gender  \
# 12421  1968  Mexico    Cycling  Cycling Road    PETTERSSON, Gösta A.B.  SWE    Men
# 26931  2004  Athens    Archery       Archery               CHEN, Li Ju  TPE  Women
# 25308  2004  Athens  Athletics     Athletics  CAMPBELL-BROWN, Veronica  JAM  Women
#
#                                  Event Event_Gender   Medal  Position
# 12421             individual road race            M  Bronze         3
# 26931  team (FITA Olympic round - 70m)            W  Bronze         3
# 25308                             200m            W    Gold         1

# %%
oo = pd.read_csv(filename, skiprows=5)
oo = oo.rename(columns={"Athlete Name": "Athlete_Name", "Event Gender": "Event_Gender"})
oo.sample(3)
# Out:
#       Year     City       Sport  Discipline                   Athlete_Name  NOC Gender  \
# 4053  1920  Antwerp  Tug of War  Tug of War  HUMPHREYS, Frederick Harkness  GBR    Men
# 7553  1948   London  Basketball  Basketball          LUMPP, Raymond George  USA    Men
# 1620  1908   London    Lacrosse    Lacrosse                   DUTTON, E.O.  GBR    Men
#
#            Event Event_Gender   Medal  Position
# 4053  tug of war            M    Gold         1
# 7553  basketball            M    Gold         1
# 1620    lacrosse            M  Silver         2

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender', 'Event',
#        'Event Gender', 'Medal', 'Position'],
#       dtype='object')

# %%
column_names = ['Year', 'City', 'Sport', 'Discipline', 'Athlete_Name', 'NOC', 'Gender',
       'Event', 'Event_Gender', 'Medal', 'Position']
oo.columns = column_names
oo.sample(3)
# Out:
#        Year      City          Sport     Discipline        Athlete_Name  NOC Gender  \
# 14297  1976  Montreal  Weightlifting  Weightlifting  RUTKOWSKI, Tadeusz  POL    Men
# 8281   1952  Helsinki        Sailing        Sailing    ENDT, Everard C.  USA    Men
# 13264  1972    Munich         Rowing         Rowing     MAGER, Wolfgang  GDR    Men
#
#                                  Event Event_Gender   Medal  Position
# 14297  91 - 110kg, total (heavyweight)            M  Bronze         3
# 8281                                6m            X    Gold         1
# 13264                coxless pair (2-)            M    Gold         1

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.sample(3)
# Out:
#        Year    City     Sport Discipline     Athlete Name  NOC Gender  \
# 26267  2004  Athens  Football   Football  FERRARI, Matteo  ITA    Men
# 23526  2000  Sydney  Aquatics   Swimming       BLACK, Kim  USA  Women
# 26758  2004  Athens   Sailing    Sailing  ZBOGAR, Vasilij  SLO    Men
#
#                                    Event Event Gender   Medal  Position
# 26267                           football            M  Bronze         3
# 23526             4x200m freestyle relay            W    Gold         1
# 26758  single-handed dinghy open (Laser)            X  Bronze         3

# %%
oo = pd.read_csv(filename, skiprows=5, names=column_names)
oo.head()
# Out:
#    Year    City      Sport     Discipline        Athlete_Name  NOC  Gender  Event  Event_Gender  \
# 0  Year    City      Sport     Discipline        Athlete Name  NOC  Gender  Event  Event Gender
# 1  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA     Men  100km             M
# 2  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE     Men  100km             M
# 3  1896  Athens  Athletics      Athletics       LANE, Francis  USA     Men   100m             M
# 4  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN     Men   100m             M
#
#     Medal  Position
# 0   Medal  Position
# 1    Gold         1
# 2  Silver         2
# 3  Bronze         3
# 4  Bronze         3

# %%
oo = pd.read_csv(filename, skiprows=5, names=column_names, header=0)
oo.head()
# Out:
#    Year    City      Sport     Discipline        Athlete_Name  NOC Gender  Event Event_Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men  100km            M
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men  100km            M
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men   100m            M
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men   100m            M
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men   100m            M
#
#     Medal  Position
# 0    Gold         1
# 1  Silver         2
# 2  Bronze         3
# 3  Bronze         3
# 4    Gold         1

# %% [markdown]
# ## Remove a Series (column) or row

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.sample(3)
# Out:
#        Year    City         Sport    Discipline                         Athlete Name  NOC Gender  \
# 1580   1908  London  Jeu de paume  Jeu de Paume                           GOULD, Jay  USA    Men
# 12874  1972  Munich      Aquatics      Swimming                       WEGNER, Gudrun  GDR  Women
# 7974   1948  London      Aquatics    Water polo  SALOMONS, Pieter Johannes Alexander  NED    Men
#
#                 Event Event Gender   Medal  Position
# 1580       individual            M    Gold         1
# 12874  400m freestyle            W  Bronze         3
# 7974       water polo            M  Bronze         3

# %%
oo.drop('Position', axis=1)
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender      Event  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men      100km
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men      100km
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men       100m
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men       100m
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men       100m
# ...     ...     ...        ...            ...                 ...  ...    ...        ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women  épée team
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women  épée team
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women  épée team
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women  épée team
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women  épée team
#
#       Event Gender   Medal
# 0                M    Gold
# 1                M  Silver
# 2                M  Bronze
# 3                M  Bronze
# 4                M    Gold
# ...            ...     ...
# 27169            W    Gold
# 27170            W    Gold
# 27171            W  Silver
# 27172            W  Silver
# 27173            W  Silver
#
# [27174 rows x 10 columns]

# %%
#oo.drop('Position', axis=0)

# %%
oo.sample(3)
# Out:
#        Year         City     Sport Discipline                  Athlete Name  NOC Gender  \
# 10270  1960         Rome    Rowing     Rowing  MCKERLICH, William Arthur M.  CAN    Men
# 1305   1908       London  Shooting   Shooting              COLAS, Paul René  FRA    Men
# 17375  1984  Los Angeles   Fencing    Fencing        MOLDOVAN-ZSAK, Marcela  ROU  Women
#
#                                 Event Event Gender   Medal  Position
# 10270        eight with coxswain (8+)            M  Silver         2
# 1305   50+100y small bore rifle, team            M  Bronze         3
# 17375                       foil team            W  Silver         2

# %%
oo = oo.drop('Position', axis=1)
oo.sample(3)
# Out:
#       Year                   City      Sport       Discipline         Athlete Name  NOC Gender  \
# 66    1896                 Athens    Fencing          Fencing     PYRGOS, Leonidas  GRE    Men
# 6715  1936                 Berlin     Rowing           Rowing    DAY, Charles Ward  USA    Men
# 9190  1956  Melbourne / Stockholm  Wrestling  Wrestling Free.  TAKHTI, Gholam Reza  IRI    Men
#
#                               Event Event Gender Medal
# 66                    foil, masters            M  Gold
# 6715       eight with coxswain (8+)            M  Gold
# 9190  79 - 87kg (light-heavyweight)            M  Gold

# %%
oo = pd.read_csv(filename, skiprows=5).drop('Position', axis=1)
oo.sample(3)
# Out:
#        Year       City       Sport   Discipline      Athlete Name  NOC Gender  \
# 26682  2004     Athens  Gymnastics  Artistic G.      LI, Xiaopeng  CHN    Men
# 20429  1992  Barcelona   Athletics    Athletics    ZMELIK, Robert  TCH    Men
# 20519  1992  Barcelona      Rowing       Rowing  ROBERTSON, Bruce  CAN    Men
#
#                           Event Event Gender   Medal
# 26682             parallel bars            M  Bronze
# 20429                 decathlon            M    Gold
# 20519  eight with coxswain (8+)            M    Gold

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year       City       Sport   Discipline        Athlete Name  NOC Gender  \
# 15276  1980     Moscow    Aquatics     Swimming     KRAUSE, Barbara  GDR  Women
# 20966  1992  Barcelona      Rowing       Rowing  KARSTEN, Ekaterina  EUN  Women
# 1838   1908     London  Gymnastics  Artistic G.        WIMAN, David  SWE    Men
#
#                                         Event Event Gender   Medal
# 15276                          100m freestyle            W    Gold
# 20966  quadruple sculls without coxswain (4x)            W  Bronze
# 1838                         team competition            M    Gold

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year       City       Sport Discipline       Athlete Name  NOC Gender  \
# 20101  1992  Barcelona      Boxing     Boxing       MAY, Torsten  GER    Men
# 10542  1960       Rome  Equestrian    Jumping  D'INZEO, Raimondo  ITA    Men
# 26141  2004     Athens   Badminton  Badminton     KIM, Dong Moon  KOR    Men
#
#                                Event Event Gender   Medal
# 20101  75 - 81kg (light-heavyweight)            M    Gold
# 10542                           team            X  Bronze
# 26141                        doubles            M    Gold

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.drop('Position', axis=1, inplace=True)
oo.sample(3)
# Out:
#       Year                   City          Sport       Discipline         Athlete Name  NOC  \
# 3727  1920                Antwerp           Polo             Polo      WODEHOUSE, John  GBR
# 9241  1956  Melbourne / Stockholm  Canoe / Kayak  Canoe / Kayak F  WIEDERMANN, Herbert  AUT
# 3934  1920                Antwerp     Gymnastics      Artistic G.         SON, Léopold  BEL
#
#      Gender                     Event Event Gender   Medal
# 3727    Men                      polo            M    Gold
# 9241    Men  K-2 1000m (kayak double)            M  Bronze
# 3934    Men      team, Swedish system            M  Bronze

# %%
#oo = (pd.read_csv(filename, skiprows=5)
#      .drop('Position', axis=1, inplace=True)
#)
#oo.sample(3)

# %%
oo.drop?

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year       City      Sport Discipline             Athlete Name  NOC Gender  \
# 8608   1952   Helsinki     Hockey     Hockey  DALUZ, Meldric St.Clair  IND    Men
# 5110   1928  Amsterdam   Aquatics   Swimming            RENNIE, Rhoda  RSA  Women
# 13520  1972     Munich  Athletics  Athletics             TARMAK, Yuri  URS    Men
#
#                         Event Event Gender   Medal
# 8608                   hockey            M    Gold
# 5110   4x100m freestyle relay            W  Bronze
# 13520               high jump            M    Gold

# %%
oo.head(3)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  Event Event Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men  100km            M
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men  100km            M
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men   100m            M
#
#     Medal
# 0    Gold
# 1  Silver
# 2  Bronze

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop(2, axis=0)
)
oo.head(3)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  Event Event Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men  100km            M
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men  100km            M
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men   100m            M
#
#     Medal  Position
# 0    Gold         1
# 1  Silver         2
# 3  Bronze         3

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop([0, 1, 3], axis=0)
)
oo.head(3)
# Out:
#    Year    City      Sport Discipline    Athlete Name  NOC Gender Event Event Gender   Medal  \
# 2  1896  Athens  Athletics  Athletics   LANE, Francis  USA    Men  100m            M  Bronze
# 4  1896  Athens  Athletics  Athletics   BURKE, Thomas  USA    Men  100m            M    Gold
# 5  1896  Athens  Athletics  Athletics  HOFMANN, Fritz  GER    Men  100m            M  Silver
#
#    Position
# 2         3
# 4         1
# 5         2

# %%
oo = oo.drop(['City', 'Sport'], axis=1)
oo.head(3)
# Out:
#    Year Discipline    Athlete Name  NOC Gender Event Event Gender   Medal  Position
# 2  1896  Athletics   LANE, Francis  USA    Men  100m            M  Bronze         3
# 4  1896  Athletics   BURKE, Thomas  USA    Men  100m            M    Gold         1
# 5  1896  Athletics  HOFMANN, Fritz  GER    Men  100m            M  Silver         2

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year      City          Sport       Discipline            Athlete Name  NOC Gender  \
# 24805  2000    Sydney       Softball         Softball          BUSTOS, Crystl  USA  Women
# 8626   1952  Helsinki         Hockey           Hockey     KRUIZE, Jan Hendrik  NED    Men
# 11029  1964     Tokyo  Canoe / Kayak  Canoe / Kayak F  NIELSEN, Peer Norrbohm  DEN    Men
#
#                           Event Event Gender   Medal
# 24805                  softball            W    Gold
# 8626                     hockey            M  Silver
# 11029  C-2 1000m (canoe double)            M  Bronze

# %%
pd.merge?

# %%
pd.concat?

# %%
oo.groupby?

# %% [markdown]
# ## Filtering rows for a single condition

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year    City     Sport Discipline       Athlete Name  NOC Gender  \
# 24856  2000  Sydney  Aquatics     Diving  PAKHALINA, Ioulia  RUS  Women
# 25151  2000  Sydney   Fencing    Fencing    KOLOBKOV, Pavel  RUS    Men
# 275    1900   Paris  Shooting   Shooting         ÖSTMO, Ole  NOR    Men
#
#                                     Event Event Gender   Medal
# 24856  synchronized diving 3m springboard            W    Gold
# 25151                     épée individual            M    Gold
# 275               army rifle, 300m, prone            M  Bronze

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
oo.Year.dtype
# Out:
# dtype('int64')

# %%
first_olympics = (oo.Year == 1896)
first_olympics
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 27169    False
# 27170    False
# 27171    False
# 27172    False
# 27173    False
# Name: Year, Length: 27174, dtype: bool

# %%
oo[first_olympics]
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC Gender        Event  \
# 0    1896  Athens     Cycling  Cycling Track         FLAMENG, Léon  FRA    Men        100km
# 1    1896  Athens     Cycling  Cycling Track    KOLETTIS, Georgios  GRE    Men        100km
# 2    1896  Athens   Athletics      Athletics         LANE, Francis  USA    Men         100m
# 3    1896  Athens   Athletics      Athletics      SZOKOLYI, Alajos  HUN    Men         100m
# 4    1896  Athens   Athletics      Athletics         BURKE, Thomas  USA    Men         100m
# ..    ...     ...         ...            ...                   ...  ...    ...          ...
# 146  1896  Athens   Athletics      Athletics       CONNOLLY, James  USA    Men  triple jump
# 147  1896  Athens   Athletics      Athletics    TUFFERI, Alexandre  FRA    Men  triple jump
# 148  1896  Athens  Gymnastics    Artistic G.  WEINGÄRTNER, Hermann  GER    Men        vault
# 149  1896  Athens  Gymnastics    Artistic G.        SCHUMANN, Carl  GER    Men        vault
# 150  1896  Athens  Gymnastics    Artistic G.         ZUTTER, Louis  SUI    Men        vault
#
#     Event Gender   Medal
# 0              M    Gold
# 1              M  Silver
# 2              M  Bronze
# 3              M  Bronze
# 4              M    Gold
# ..           ...     ...
# 146            M    Gold
# 147            M  Silver
# 148            M  Bronze
# 149            M    Gold
# 150            M  Silver
#
# [151 rows x 10 columns]

# %%
oo[oo.Year == 1896]
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC Gender        Event  \
# 0    1896  Athens     Cycling  Cycling Track         FLAMENG, Léon  FRA    Men        100km
# 1    1896  Athens     Cycling  Cycling Track    KOLETTIS, Georgios  GRE    Men        100km
# 2    1896  Athens   Athletics      Athletics         LANE, Francis  USA    Men         100m
# 3    1896  Athens   Athletics      Athletics      SZOKOLYI, Alajos  HUN    Men         100m
# 4    1896  Athens   Athletics      Athletics         BURKE, Thomas  USA    Men         100m
# ..    ...     ...         ...            ...                   ...  ...    ...          ...
# 146  1896  Athens   Athletics      Athletics       CONNOLLY, James  USA    Men  triple jump
# 147  1896  Athens   Athletics      Athletics    TUFFERI, Alexandre  FRA    Men  triple jump
# 148  1896  Athens  Gymnastics    Artistic G.  WEINGÄRTNER, Hermann  GER    Men        vault
# 149  1896  Athens  Gymnastics    Artistic G.        SCHUMANN, Carl  GER    Men        vault
# 150  1896  Athens  Gymnastics    Artistic G.         ZUTTER, Louis  SUI    Men        vault
#
#     Event Gender   Medal
# 0              M    Gold
# 1              M  Silver
# 2              M  Bronze
# 3              M  Bronze
# 4              M    Gold
# ..           ...     ...
# 146            M    Gold
# 147            M  Silver
# 148            M  Bronze
# 149            M    Gold
# 150            M  Silver
#
# [151 rows x 10 columns]

# %%
oo[oo.Year < 1896]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo[(oo.Year <= 1896)]
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC Gender        Event  \
# 0    1896  Athens     Cycling  Cycling Track         FLAMENG, Léon  FRA    Men        100km
# 1    1896  Athens     Cycling  Cycling Track    KOLETTIS, Georgios  GRE    Men        100km
# 2    1896  Athens   Athletics      Athletics         LANE, Francis  USA    Men         100m
# 3    1896  Athens   Athletics      Athletics      SZOKOLYI, Alajos  HUN    Men         100m
# 4    1896  Athens   Athletics      Athletics         BURKE, Thomas  USA    Men         100m
# ..    ...     ...         ...            ...                   ...  ...    ...          ...
# 146  1896  Athens   Athletics      Athletics       CONNOLLY, James  USA    Men  triple jump
# 147  1896  Athens   Athletics      Athletics    TUFFERI, Alexandre  FRA    Men  triple jump
# 148  1896  Athens  Gymnastics    Artistic G.  WEINGÄRTNER, Hermann  GER    Men        vault
# 149  1896  Athens  Gymnastics    Artistic G.        SCHUMANN, Carl  GER    Men        vault
# 150  1896  Athens  Gymnastics    Artistic G.         ZUTTER, Louis  SUI    Men        vault
#
#     Event Gender   Medal
# 0              M    Gold
# 1              M  Silver
# 2              M  Bronze
# 3              M  Bronze
# 4              M    Gold
# ..           ...     ...
# 146            M    Gold
# 147            M  Silver
# 148            M  Bronze
# 149            M    Gold
# 150            M  Silver
#
# [151 rows x 10 columns]

# %% [markdown]
# ## Filter rows for multiple conditions

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.tail(3)
# Out:
#        Year    City    Sport Discipline       Athlete Name  NOC Gender      Event Event Gender  \
# 27171  2004  Athens  Fencing    Fencing     BOKEL, Claudia  GER  Women  épée team            W
# 27172  2004  Athens  Fencing    Fencing    DUPLITZER, Imke  GER  Women  épée team            W
# 27173  2004  Athens  Fencing    Fencing  HEIDEMANN, Britta  GER  Women  épée team            W
#
#         Medal
# 27171  Silver
# 27172  Silver
# 27173  Silver

# %%
oo.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# dtype: object

# %%
oo[oo.City == 'Athens']
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender      Event  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men      100km
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men      100km
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men       100m
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men       100m
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men       100m
# ...     ...     ...        ...            ...                 ...  ...    ...        ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women  épée team
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women  épée team
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women  épée team
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women  épée team
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women  épée team
#
#       Event Gender   Medal
# 0                M    Gold
# 1                M  Silver
# 2                M  Bronze
# 3                M  Bronze
# 4                M    Gold
# ...            ...     ...
# 27169            W    Gold
# 27170            W    Gold
# 27171            W  Silver
# 27172            W  Silver
# 27173            W  Silver
#
# [2149 rows x 10 columns]

# %%
#oo[oo.City == Athens]

# %%
oo[(oo.Year == 1896) | (oo.Year == 2004)]
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender      Event  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men      100km
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men      100km
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men       100m
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men       100m
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men       100m
# ...     ...     ...        ...            ...                 ...  ...    ...        ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women  épée team
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women  épée team
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women  épée team
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women  épée team
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women  épée team
#
#       Event Gender   Medal
# 0                M    Gold
# 1                M  Silver
# 2                M  Bronze
# 3                M  Bronze
# 4                M    Gold
# ...            ...     ...
# 27169            W    Gold
# 27170            W    Gold
# 27171            W  Silver
# 27172            W  Silver
# 27173            W  Silver
#
# [2149 rows x 10 columns]

# %%
oo[(oo.City == 'Athens') & (oo.Year == 2004)]
# Out:
#        Year    City          Sport     Discipline           Athlete Name  NOC Gender  \
# 25176  2004  Athens           Judo           Judo      PERTELSON, Indrek  EST    Men
# 25177  2004  Athens           Judo           Judo  VAN DER GEEST, Dennis  NED    Men
# 25178  2004  Athens           Judo           Judo          SUZUKI, Keiji  JPN    Men
# 25179  2004  Athens           Judo           Judo       TMENOV, Tamerlan  RUS    Men
# 25180  2004  Athens  Weightlifting  Weightlifting     CHOLAKOV, Velichko  BUL    Men
# ...     ...     ...            ...            ...                    ...  ...    ...
# 27169  2004  Athens        Fencing        Fencing     LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens        Fencing        Fencing          SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens        Fencing        Fencing         BOKEL, Claudia  GER  Women
# 27172  2004  Athens        Fencing        Fencing        DUPLITZER, Imke  GER  Women
# 27173  2004  Athens        Fencing        Fencing      HEIDEMANN, Britta  GER  Women
#
#                        Event Event Gender   Medal
# 25176  + 100kg (heavyweight)            M  Bronze
# 25177  + 100kg (heavyweight)            M  Bronze
# 25178  + 100kg (heavyweight)            M    Gold
# 25179  + 100kg (heavyweight)            M  Silver
# 25180                + 105kg            M  Bronze
# ...                      ...          ...     ...
# 27169              épée team            W    Gold
# 27170              épée team            W    Gold
# 27171              épée team            W  Silver
# 27172              épée team            W  Silver
# 27173              épée team            W  Silver
#
# [1998 rows x 10 columns]

# %%
oo[(oo.City == 'Athens') & ~(oo.Year == 1896)]
# Out:
#        Year    City          Sport     Discipline           Athlete Name  NOC Gender  \
# 25176  2004  Athens           Judo           Judo      PERTELSON, Indrek  EST    Men
# 25177  2004  Athens           Judo           Judo  VAN DER GEEST, Dennis  NED    Men
# 25178  2004  Athens           Judo           Judo          SUZUKI, Keiji  JPN    Men
# 25179  2004  Athens           Judo           Judo       TMENOV, Tamerlan  RUS    Men
# 25180  2004  Athens  Weightlifting  Weightlifting     CHOLAKOV, Velichko  BUL    Men
# ...     ...     ...            ...            ...                    ...  ...    ...
# 27169  2004  Athens        Fencing        Fencing     LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens        Fencing        Fencing          SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens        Fencing        Fencing         BOKEL, Claudia  GER  Women
# 27172  2004  Athens        Fencing        Fencing        DUPLITZER, Imke  GER  Women
# 27173  2004  Athens        Fencing        Fencing      HEIDEMANN, Britta  GER  Women
#
#                        Event Event Gender   Medal
# 25176  + 100kg (heavyweight)            M  Bronze
# 25177  + 100kg (heavyweight)            M  Bronze
# 25178  + 100kg (heavyweight)            M    Gold
# 25179  + 100kg (heavyweight)            M  Silver
# 25180                + 105kg            M  Bronze
# ...                      ...          ...     ...
# 27169              épée team            W    Gold
# 27170              épée team            W    Gold
# 27171              épée team            W  Silver
# 27172              épée team            W  Silver
# 27173              épée team            W  Silver
#
# [1998 rows x 10 columns]

# %%
first_men_100m = oo[(oo.Year == 1896) & (oo.Gender == 'Men') & (oo.Event == '100m')]
first_men_100m
# Out:
#    Year    City      Sport Discipline      Athlete Name  NOC Gender Event Event Gender   Medal
# 2  1896  Athens  Athletics  Athletics     LANE, Francis  USA    Men  100m            M  Bronze
# 3  1896  Athens  Athletics  Athletics  SZOKOLYI, Alajos  HUN    Men  100m            M  Bronze
# 4  1896  Athens  Athletics  Athletics     BURKE, Thomas  USA    Men  100m            M    Gold
# 5  1896  Athens  Athletics  Athletics    HOFMANN, Fritz  GER    Men  100m            M  Silver

# %%
oo[(oo.Year == 1896) & (oo.Gender == 'Men') & (oo.Event == '100m')][["Year", "Athlete Name", "NOC", "Event", "Medal"]]
# Out:
#    Year      Athlete Name  NOC Event   Medal
# 2  1896     LANE, Francis  USA  100m  Bronze
# 3  1896  SZOKOLYI, Alajos  HUN  100m  Bronze
# 4  1896     BURKE, Thomas  USA  100m    Gold
# 5  1896    HOFMANN, Fritz  GER  100m  Silver

# %%
first_men_100m[["Year", "Athlete Name", "NOC", "Event", "Medal"]]
# Out:
#    Year      Athlete Name  NOC Event   Medal
# 2  1896     LANE, Francis  USA  100m  Bronze
# 3  1896  SZOKOLYI, Alajos  HUN  100m  Bronze
# 4  1896     BURKE, Thomas  USA  100m    Gold
# 5  1896    HOFMANN, Fritz  GER  100m  Silver

# %% [markdown]
# ## Using String methods

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.head(3)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  Event Event Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men  100km            M
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men  100km            M
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men   100m            M
#
#     Medal
# 0    Gold
# 1  Silver
# 2  Bronze

# %%
oo["Athlete Name"].str.lower()
# Out:
# 0             flameng, léon
# 1        kolettis, georgios
# 2             lane, francis
# 3          szokolyi, alajos
# 4             burke, thomas
#                 ...
# 27169    logounova, tatiana
# 27170         sivkova, anna
# 27171        bokel, claudia
# 27172       duplitzer, imke
# 27173     heidemann, britta
# Name: Athlete Name, Length: 27174, dtype: object

# %%
oo.Event.unique()
# Out:
# array(['100km', '100m', '100m freestyle', '100m freestyle for sailors',
#        '10km', '110m hurdles', '12-hour race', '1200m freestyle', '1500m',
#        '1km time trial', '25m army pistol',
#        '25m rapid fire pistol (60 shots)', '400m', '400m freestyle',
#        '50m pistol (60 shots)', '800m', 'Sprint indivual',
#        'army rifle, 200m', 'army rifle, 300m', 'discus throw', 'doubles',
#        'foil individual', 'foil, masters', 'heavyweight - one hand lift',
#        'heavyweight - two hand lift', 'high jump', 'horizontal bar',
#        'individual road race', 'long jump', 'marathon', 'open event',
#        'parallel bars', 'pole vault', 'pommel horse', 'rings',
#        'rope climbing', 'sabre individual', 'shot put', 'singles',
#        'team, horizontal bar', 'team, parallel bars', 'triple jump',
#        'vault', '0.5-1t', '10-20t', '1500m freestyle', '200m',
#        '200m backstroke', '200m freestyle', '200m hurdles',
#        '200m obstacle event', '200m team swimming', '25 kilometres',
#        '3-10t', '3000m steeplechase', '4000m freestyle',
#        '4000m steeplechase', '400m hurdles', '5000m team',
#        '50m army pistol, team', '60m', 'army rifle, 300m, 3 positions',
#        'army rifle, 300m, kneeling', 'army rifle, 300m, prone',
#        'army rifle, 300m, standing', 'au chapelet, 33m',
#        'au chapelet, 50m', 'au cordon doré, 33m', 'au cordon doré, 50m',
#        'cesta punta', 'cricket', 'double', 'eight with coxswain (8+)',
#        'football', 'four-oared shell with coxswain (4-)',
#        'free rifle, team', 'hammer throw', 'high jump, standing',
#        'individual', 'individual 1 ball', 'individual 2 balls',
#        'individual all-round', 'long jump individual',
#        'long jump, standing', 'mixed doubles', 'open class',
#        'pair-oared shell with coxswain (2+)', 'polo', 'rugby',
#        'sabre, masters', 'single sculls (1x)', 'sur la perche à la herse',
#        'sur la perche à la pyramide', 'trap (125 targets)',
#        'triple jump, standing', 'tug of war', 'underwater swimming',
#        'water polo', 'épée individual', 'épée, amateurs and masters',
#        'épée, masters', '+ 71.67kg (heavyweight)',
#        '- 47.63kg (flyweight)', '- 47.6kg (light-flyweight)',
#        '1 mile (1609.3m)', '1/2 mile (804.7m)', '1/3 mile (536.5m)',
#        '1/4 mile (402.3m)', '100m backstroke', '10m platform',
#        '2 miles (3.218km)', '25 miles (40.232km)', '400m breaststroke',
#        '47.6 - 52.16kg (flyweight)', '47.63 - 52.16kg (bantamweight)',
#        '4miles team', '4x50y freestyle relay', '5 miles (8.046km)',
#        '50y freestyle (45.72m)', '52.16 - 56.7kg (bantamweight)',
#        '52.16 - 56.7kg (featherweight)', '56.7 - 61.23kg (featherweight)',
#        '56.7 - 61.24kg (lightweight)', '56lb weight throw (25.4kg)',
#        '61.23 - 65.77kg (lightweight)', '61.24 - 65.77kg (welterweight)',
#        '65.77 - 71.67kg (middleweight)', '65.77 - 71.67kg (welterweight)',
#        '880y freestyle (804.66m)', 'all-around Dumbbell contest',
#        'club swinging', 'combined 3 events', 'combined 4 events',
#        'coxless pair (2-)', 'decathlon',
#        'double american round (60y - 50y - 40y)',
#        'double columbia round (50y - 40y - 30y)',
#        'double national round (60y - 50y)', 'double sculls (2x)',
#        'double york round (100y - 80y - 60y)', 'foil team',
#        'four without coxswain (4-)', 'lacrosse', 'plunge for distance',
#        'stick, single', 'team', 'team competition', 'team round 60y',
#        'teams FITA round', 'triathlon (long jump / shot put / 100 yards)',
#        '+ 73kg (heavyweight)', '+ 93kg (super heavyweight)',
#        '- 52.62kg (bantamweight)', '- 54kg (bantamweight)',
#        '- 66.6kg (lightweight)', '1000y free rifle, prone',
#        '100m running deer, double shots',
#        '100m running deer, single shots',
#        '100m running deer, single shots, team', '10miles walk (16093m)',
#        '12m', '1980 yards Pursuit, Team', '2000m tandem',
#        '200m breaststroke', '20km',
#        '25y small bore rifle, disappearing target',
#        '25y small bore rifle, moving target',
#        '300m free rifle 3 positions (3x40 shots)', '3200m steeplechase',
#        '3500m walk', '3m springboard', '3miles team (4828m)',
#        '4x200m freestyle relay', '4x400m relay', '5 miles (8047m)',
#        '50+100y small bore rifle, team', '5000m',
#        '50m rifle prone (60 shots)', '50y army pistol, team',
#        '52.62 - 57.15kg (featherweight)', '54 - 60.3kg (featherweight)',
#        '57.15 - 63.5kg (lightweight)', '60.3 - 66.6kg (lightweight)',
#        '63.5 - 71.67kg (middleweight)', '66.6 - 73kg (middleweight)',
#        '6m', '73 - 93kg (light-heavyweight)', '7m', '8m', '8m class C',
#        'One lap (660y) sprint', 'class B up to 60 feet',
#        'clay pigeons, team', 'continental style 50m',
#        'discus throw ancient style', 'doubles indoor', 'hockey',
#        'javelin throw', 'javelin throw freestyle',
#        'national round (60y - 50y)', 'open class A', 'pairs',
#        'rifle, team', 'sabre team', 'singles indoor', 'special figures',
#        'york round (100y - 80y - 60y)', 'épée team',
#        '+ 82.5kg (super heavyweight)', '- 60kg (featherweight)', '10000m',
#        '10000m walk', '10m', '25m small bore rifle, team',
#        '25m small rifle', '3000m team', '30m army pistol, team',
#        '4x100m freestyle relay', '4x100m relay',
#        '50m small bore rifle, team', '60 - 67.5kg (lightweight)',
#        '600m free rifle', '67.5 - 75kg (middleweight)',
#        '75 - 82.5kg (light-heavyweight)', 'Individual competition',
#        'coxed fours Jugriggers', 'cross country individual',
#        'cross country team', 'discus throw, both hands',
#        'individual time trial', 'javelin throw, both hands',
#        'mixed doubles indoor', 'pentathlon', 'plain high diving',
#        'shot put, both hands', 'team time trial', 'team, Swedish system',
#        'team, free system', '+ 79.38kg (heavyweight)',
#        '+ 80kg (heavyweight)',
#        '+ 82.5kg, one-two hand 3 events (heavyweight)',
#        '+ 82kg (super heavyweight)', '- 50.8kg (flyweight)',
#        '- 60kg, one-two hand 3 events (featherweight)',
#        '100m running deer, double shots, team', '10m (rating 1907)',
#        '10m (rating 1919)', '12 foot dinghy', '12m (rating 1907)',
#        '12m (rating 1919)', '18 foot dinghy',
#        '300+600m free rifle, team, prone', '3000m walk',
#        '300m free rifle, prone, team', '300m free rifle, standing, team',
#        '30m sq', '40m sq', '50.8 - 53.52kg (bantamweight)', '50km',
#        '50m small bore rifle, standing, individual',
#        '53.52 - 57.15kg (featherweight)', '57.15 - 61.24kg (lightweight)',
#        '6.5m (rating 1919)',
#        '60 - 67.5kg, one-two hand 3 events (lightweight)',
#        '600m free rifle, prone', '600m free rifle, team',
#        '61.24 - 66.68kg (welterweight)', '66.68 - 72.57kg (middleweight)',
#        '67.5 - 75kg, one-two hand 3 events (middleweight)',
#        '6m (rating 1907)', '6m (rating 1919)',
#        '72.57 - 79.38kg (light-heavyweight)',
#        '75 - 80kg (light-heavyweight)',
#        '75 - 82.5kg, one-two hand 3 e. (light-heavyweight)',
#        '75 - 82kg (light-heavyweight)', '8m (rating 1907)',
#        '8m (rating 1919)', 'Team Pursuit (4000m)',
#        'figure riding individual', 'figure riding team',
#        'fixed bird target large birds',
#        'fixed bird target large birds teams',
#        'fixed bird target small bird, teams',
#        'fixed bird target small birds', 'ice hockey',
#        'moving bird target 28m teams', 'moving bird target 33m teams',
#        'moving bird target 50m teams', 'moving bird target, 28m',
#        'moving bird target, 33m', 'moving bird target, 50m',
#        '+ 82.5kg, one-two hand 5 events (heavyweight)',
#        '+ 87kg (heavyweight)', '- 56kg (bantamweight)',
#        '- 58kg (bantamweight)',
#        '- 60kg, one-two hand 5 events (featherweight)',
#        '400, 600, 800m free rifle, team', '56 - 61kg (featherweight)',
#        '58 - 62kg (featherweight)',
#        '60 - 67.5kg, one-two hand 5 events (lightweight)',
#        '600m free rifle, individual', '61 - 66kg (lightweight)',
#        '62 - 67.5kg (lightweight)', '66 - 72kg (welterweight)',
#        '67.5 - 75kg, one-two hand 5 events (middleweight)',
#        '72 - 79kg (middleweight)',
#        '75 - 82.5kg, one-two hand 5 e. (light-heavyweight)',
#        '79 - 87kg (light-heavyweight)', 'Sidehorse vault',
#        'olympic class monotype', '+ 82.5kg, total (heavyweight)',
#        '- 60kg, total (featherweight)', '12 foot dinghy individual',
#        '1km Pursuit', '58 - 60kg (featherweight)',
#        '60 - 67.5kg, total (lightweight)',
#        '67.5 - 75kg, total (middleweight)',
#        '75 - 82.5kg, total (light-heavyweight)',
#        '+ 87kg (super heavyweight)', '50.8 - 54kg (bantamweight)',
#        '50km walk', '54 - 57.15kg (featherweight)', '80m hurdles',
#        'floor exercises', 'indian clubs', 'tumbling',
#        'two-person keelboat open (Star)', 'C-1 1000m (canoe single)',
#        'C-2 10000m', 'C-2 1000m (canoe double)', 'K-1 10000m',
#        'K-1 1000m (kayak single)', 'K-2 10000m',
#        'K-2 1000m (kayak double)', 'basketball', 'folding K-1 10000m',
#        'folding K-2 10000m', 'handball', '- 51kg (flyweight)',
#        '- 52kg (flyweight)', '- 56kg, total (bantamweight)',
#        '51 - 54kg (bantamweight)', '52 - 57kg (bantamweight)',
#        '54 - 58kg (featherweight)', '56 - 60kg, total (featherweight)',
#        '57 - 61kg (featherweight)', '57 - 63kg (featherweight)',
#        '58 - 62kg (lightweight)', '61 - 67kg (lightweight)',
#        '62 - 67kg (welterweight)', '63 - 67kg (lightweight)',
#        '67 - 73kg (middleweight)', '67 - 73kg (welterweight)',
#        '73 - 79kg (middleweight)', '73 - 80kg (light-heavyweight)',
#        'C-1 10000m', 'K-1 500m (kayak single)', 'dragon', 'firefly class',
#        'swallow (golondrina)', '+ 81kg (heavyweight)',
#        '+ 90kg, total (heavyweight)',
#        '100m running deer, single/double shots', '5.5m',
#        '50m rifle 3 positions (3x40 shots)', '54 - 57kg (featherweight)',
#        '57 - 60kg (lightweight)', '60 - 63.5kg (light-welterweight)',
#        '63.5 - 67kg (welterweight)', '67 - 71kg (light-middleweight)',
#        '71-75kg', '75 - 81kg (light-heavyweight)',
#        '82.5 - 90kg, total (middle-heavyweight)', 'Team competition',
#        'balance beam', 'single-handed dinghy (Finn)',
#        'team, portable apparatus', 'uneven bars', '100m butterfly',
#        '200m butterfly', '20km walk', 'sharpie 12m2',
#        '4x100m medley relay', 'K-1 4x500m', 'K-2 500m (kayak double)',
#        'flying dutchman', '+ 97kg (heavyweight)',
#        '+ 97kg (super heavyweight)', '- 68kg (lightweight)',
#        '400m individual medley', '63 - 70kg (lightweight)',
#        '68 - 80kg (middleweight)', '70 - 78kg (welterweight)',
#        '78 - 87kg (middleweight)', '87 - 97kg (light-heavyweight)',
#        'Individual Pursuit', 'K-4 1000m (kayak four)', 'open category',
#        'volleyball', '- 48kg (light-flyweight)', '100m breaststroke',
#        '200m individual medley', '48 - 51kg (flyweight)',
#        '800m freestyle', 'skeet (125 targets)',
#        '+ 100kg (super heavyweight)',
#        '+ 110kg, total (super heavyweight)', '+ 93kg (heavyweight)',
#        '- 52kg, total (flyweight)', '- 63kg (lightweight)',
#        '100m hurdles', '48 - 52kg (flyweight)',
#        '50m running target (30+30 shots)',
#        '52 - 56kg, total (bantamweight)', '57 - 62kg (featherweight)',
#        '62 - 68kg (lightweight)', '63 - 70kg (half-middleweight)',
#        '68 - 74kg (welterweight)', '70 - 80kg (middleweight)',
#        '74 - 82kg (middleweight)', '80 - 93kg (half-heavyweight)',
#        '82 - 90kg (light-heavyweight)', '90 - 100kg (heavyweight)',
#        '91 - 110kg, total (heavyweight)', 'C-1 (canoe single)',
#        'C-2 (canoe double)', 'K-1 (kayak single)',
#        'fleet/match race keelboat open (Soling)', 'individual FITA round',
#        'tempest', '470 - Two Person Dinghy', 'C-1 500m (canoe single)',
#        'C-2 500m (canoe double)', 'Tornado - Multihull',
#        'pair without coxswain (2-)',
#        'quadruple sculls with coxswain (4x)',
#        'quadruple sculls without coxswain (4x)', '+ 95kg (heavyweight)',
#        '- 60 kg', '100 - 110kg, total (heavyweight)',
#        '60 - 65kg (half-lightweight)', '65 - 71kg (lightweight)',
#        '71 - 78kg (half-middleweight)', '78 - 86kg (middleweight)',
#        '86 - 95kg (half-heavyweight)',
#        '90 - 100kg, total (first-heavyweight)',
#        '+ 91kg (super heavyweight)', '10m air rifle (40 shots)',
#        '10m air rifle (60 shots)', '25m pistol (30+30 shots)', '3000m',
#        '50m rifle 3 positions (3x20 shots)', '81 - 91kg (heavyweight)',
#        'K-4 500m (kayak four)', 'Points Race', 'board (windglider)',
#        'duet', 'heptathlon', 'solo', '100 - 130kg (super heavyweight)',
#        '10m air pistol (40 shots)', '10m air pistol (60 shots)',
#        '50m freestyle', 'board (division II)', 'sprint',
#        '+ 72kg (heavyweight)', '- 48kg (extra-lightweight)',
#        '48 - 52kg (half-lightweight)', '52 - 56kg (lightweight)',
#        '56 - 61kg (half-middleweight)', '61 - 66kg (middleweight)',
#        '66 - 72kg (half-heavyweight)', 'baseball', 'board (lechner)',
#        'coxless four (4-)', 'individual (FITA Olympic round - 70m)',
#        'individual pursuit', 'single-handed dinghy (Europe)',
#        'team (FITA Olympic round - 70m)', '+ 100kg (heavyweight)',
#        '+ 108kg, total (super heavyweight)', '- 54kg, total (flyweight)',
#        '54 - 59kg, total (bantamweight)',
#        '59 - 64kg, total (featherweight)', '60 - 66kg (half-lightweight)',
#        '64 - 70kg, total (lightweight)', '66 - 73kg (lightweight)',
#        '70 - 76kg, total (middleweight)', '73 - 81kg (half-middleweight)',
#        '76 - 83kg, total (light-heavyweight)', '81 - 90kg (middleweight)',
#        '83 - 91kg, total (middle-heavyweight)',
#        '90 - 100kg (half-heavyweight)',
#        '91 - 99kg, total (first-heavyweight)',
#        '99 - 108kg, total (heavyweight)', 'beach volleyball',
#        'board (Mistral)', 'cross-country', 'double trap (120 targets)',
#        'double trap (150 targets)', 'group competition',
#        'lightweight coxless four (4-)', 'lightweight double sculls (2x)',
#        'points race', 'single-handed dinghy open (Laser)', 'softball',
#        '+ 105kg', '+ 67 kg', '+ 75kg', '+ 78kg (heavyweight)', '+ 80 kg',
#        '- 49 kg', '- 58 kg', '105kg', '10m running target (30+30 shots)',
#        '20km race walk', '48 - 54kg', '48kg', '49 - 57 kg',
#        '49er - Skiff', '500m time trial', '52 - 57kg (lightweight)',
#        '53kg', '54 - 58kg', '56kg', '57 - 63kg (half-middleweight)',
#        '57 - 67 kg', '58 - 63kg', '58 - 68 kg', '58kg', '62kg',
#        '63 - 69kg', '63 - 70kg (middleweight)', '63kg', '68 - 80 kg',
#        '69 - 76kg', '69kg', '70 - 78kg (half-heavyweight)', '75kg',
#        '76 - 85kg', '77kg', '85 - 97kg', '85kg', '94kg', '97 - 130kg',
#        'Individual', 'Keirin', 'Madison', 'Olympic Sprint',
#        'skeet (75 targets)', 'synchronized diving 10m platform',
#        'synchronized diving 3m springboard', 'trap (75 targets)',
#        '- 48 kg', '- 48kg', '- 55kg', '48 - 55kg',
#        '48kg (light flywieght)', '55 - 60kg', '55 - 63kg', '60 - 64 kg',
#        '60 - 66kg', '63 - 72kg', '64 - 69 kg', '66 - 74kg', '69 - 75 kg',
#        '74 - 84kg', '84 - 96kg', '96 - 120kg', 'Star - Keelboat',
#        'Team Sprint', 'Yngling - Keelboat'], dtype=object)

# %%
oo.Event.str.capitalize()
# Out:
# 0            100km
# 1            100km
# 2             100m
# 3             100m
# 4             100m
#            ...
# 27169    Épée team
# 27170    Épée team
# 27171    Épée team
# 27172    Épée team
# 27173    Épée team
# Name: Event, Length: 27174, dtype: object

# %%
oo.Event = oo.Event.str.capitalize()
oo.Event.unique()
# Out:
# array(['100km', '100m', '100m freestyle', '100m freestyle for sailors',
#        '10km', '110m hurdles', '12-hour race', '1200m freestyle', '1500m',
#        '1km time trial', '25m army pistol',
#        '25m rapid fire pistol (60 shots)', '400m', '400m freestyle',
#        '50m pistol (60 shots)', '800m', 'Sprint indivual',
#        'Army rifle, 200m', 'Army rifle, 300m', 'Discus throw', 'Doubles',
#        'Foil individual', 'Foil, masters', 'Heavyweight - one hand lift',
#        'Heavyweight - two hand lift', 'High jump', 'Horizontal bar',
#        'Individual road race', 'Long jump', 'Marathon', 'Open event',
#        'Parallel bars', 'Pole vault', 'Pommel horse', 'Rings',
#        'Rope climbing', 'Sabre individual', 'Shot put', 'Singles',
#        'Team, horizontal bar', 'Team, parallel bars', 'Triple jump',
#        'Vault', '0.5-1t', '10-20t', '1500m freestyle', '200m',
#        '200m backstroke', '200m freestyle', '200m hurdles',
#        '200m obstacle event', '200m team swimming', '25 kilometres',
#        '3-10t', '3000m steeplechase', '4000m freestyle',
#        '4000m steeplechase', '400m hurdles', '5000m team',
#        '50m army pistol, team', '60m', 'Army rifle, 300m, 3 positions',
#        'Army rifle, 300m, kneeling', 'Army rifle, 300m, prone',
#        'Army rifle, 300m, standing', 'Au chapelet, 33m',
#        'Au chapelet, 50m', 'Au cordon doré, 33m', 'Au cordon doré, 50m',
#        'Cesta punta', 'Cricket', 'Double', 'Eight with coxswain (8+)',
#        'Football', 'Four-oared shell with coxswain (4-)',
#        'Free rifle, team', 'Hammer throw', 'High jump, standing',
#        'Individual', 'Individual 1 ball', 'Individual 2 balls',
#        'Individual all-round', 'Long jump individual',
#        'Long jump, standing', 'Mixed doubles', 'Open class',
#        'Pair-oared shell with coxswain (2+)', 'Polo', 'Rugby',
#        'Sabre, masters', 'Single sculls (1x)', 'Sur la perche à la herse',
#        'Sur la perche à la pyramide', 'Trap (125 targets)',
#        'Triple jump, standing', 'Tug of war', 'Underwater swimming',
#        'Water polo', 'Épée individual', 'Épée, amateurs and masters',
#        'Épée, masters', '+ 71.67kg (heavyweight)',
#        '- 47.63kg (flyweight)', '- 47.6kg (light-flyweight)',
#        '1 mile (1609.3m)', '1/2 mile (804.7m)', '1/3 mile (536.5m)',
#        '1/4 mile (402.3m)', '100m backstroke', '10m platform',
#        '2 miles (3.218km)', '25 miles (40.232km)', '400m breaststroke',
#        '47.6 - 52.16kg (flyweight)', '47.63 - 52.16kg (bantamweight)',
#        '4miles team', '4x50y freestyle relay', '5 miles (8.046km)',
#        '50y freestyle (45.72m)', '52.16 - 56.7kg (bantamweight)',
#        '52.16 - 56.7kg (featherweight)', '56.7 - 61.23kg (featherweight)',
#        '56.7 - 61.24kg (lightweight)', '56lb weight throw (25.4kg)',
#        '61.23 - 65.77kg (lightweight)', '61.24 - 65.77kg (welterweight)',
#        '65.77 - 71.67kg (middleweight)', '65.77 - 71.67kg (welterweight)',
#        '880y freestyle (804.66m)', 'All-around dumbbell contest',
#        'Club swinging', 'Combined 3 events', 'Combined 4 events',
#        'Coxless pair (2-)', 'Decathlon',
#        'Double american round (60y - 50y - 40y)',
#        'Double columbia round (50y - 40y - 30y)',
#        'Double national round (60y - 50y)', 'Double sculls (2x)',
#        'Double york round (100y - 80y - 60y)', 'Foil team',
#        'Four without coxswain (4-)', 'Lacrosse', 'Plunge for distance',
#        'Stick, single', 'Team', 'Team competition', 'Team round 60y',
#        'Teams fita round', 'Triathlon (long jump / shot put / 100 yards)',
#        '+ 73kg (heavyweight)', '+ 93kg (super heavyweight)',
#        '- 52.62kg (bantamweight)', '- 54kg (bantamweight)',
#        '- 66.6kg (lightweight)', '1000y free rifle, prone',
#        '100m running deer, double shots',
#        '100m running deer, single shots',
#        '100m running deer, single shots, team', '10miles walk (16093m)',
#        '12m', '1980 yards pursuit, team', '2000m tandem',
#        '200m breaststroke', '20km',
#        '25y small bore rifle, disappearing target',
#        '25y small bore rifle, moving target',
#        '300m free rifle 3 positions (3x40 shots)', '3200m steeplechase',
#        '3500m walk', '3m springboard', '3miles team (4828m)',
#        '4x200m freestyle relay', '4x400m relay', '5 miles (8047m)',
#        '50+100y small bore rifle, team', '5000m',
#        '50m rifle prone (60 shots)', '50y army pistol, team',
#        '52.62 - 57.15kg (featherweight)', '54 - 60.3kg (featherweight)',
#        '57.15 - 63.5kg (lightweight)', '60.3 - 66.6kg (lightweight)',
#        '63.5 - 71.67kg (middleweight)', '66.6 - 73kg (middleweight)',
#        '6m', '73 - 93kg (light-heavyweight)', '7m', '8m', '8m class c',
#        'One lap (660y) sprint', 'Class b up to 60 feet',
#        'Clay pigeons, team', 'Continental style 50m',
#        'Discus throw ancient style', 'Doubles indoor', 'Hockey',
#        'Javelin throw', 'Javelin throw freestyle',
#        'National round (60y - 50y)', 'Open class a', 'Pairs',
#        'Rifle, team', 'Sabre team', 'Singles indoor', 'Special figures',
#        'York round (100y - 80y - 60y)', 'Épée team',
#        '+ 82.5kg (super heavyweight)', '- 60kg (featherweight)', '10000m',
#        '10000m walk', '10m', '25m small bore rifle, team',
#        '25m small rifle', '3000m team', '30m army pistol, team',
#        '4x100m freestyle relay', '4x100m relay',
#        '50m small bore rifle, team', '60 - 67.5kg (lightweight)',
#        '600m free rifle', '67.5 - 75kg (middleweight)',
#        '75 - 82.5kg (light-heavyweight)', 'Individual competition',
#        'Coxed fours jugriggers', 'Cross country individual',
#        'Cross country team', 'Discus throw, both hands',
#        'Individual time trial', 'Javelin throw, both hands',
#        'Mixed doubles indoor', 'Pentathlon', 'Plain high diving',
#        'Shot put, both hands', 'Team time trial', 'Team, swedish system',
#        'Team, free system', '+ 79.38kg (heavyweight)',
#        '+ 80kg (heavyweight)',
#        '+ 82.5kg, one-two hand 3 events (heavyweight)',
#        '+ 82kg (super heavyweight)', '- 50.8kg (flyweight)',
#        '- 60kg, one-two hand 3 events (featherweight)',
#        '100m running deer, double shots, team', '10m (rating 1907)',
#        '10m (rating 1919)', '12 foot dinghy', '12m (rating 1907)',
#        '12m (rating 1919)', '18 foot dinghy',
#        '300+600m free rifle, team, prone', '3000m walk',
#        '300m free rifle, prone, team', '300m free rifle, standing, team',
#        '30m sq', '40m sq', '50.8 - 53.52kg (bantamweight)', '50km',
#        '50m small bore rifle, standing, individual',
#        '53.52 - 57.15kg (featherweight)', '57.15 - 61.24kg (lightweight)',
#        '6.5m (rating 1919)',
#        '60 - 67.5kg, one-two hand 3 events (lightweight)',
#        '600m free rifle, prone', '600m free rifle, team',
#        '61.24 - 66.68kg (welterweight)', '66.68 - 72.57kg (middleweight)',
#        '67.5 - 75kg, one-two hand 3 events (middleweight)',
#        '6m (rating 1907)', '6m (rating 1919)',
#        '72.57 - 79.38kg (light-heavyweight)',
#        '75 - 80kg (light-heavyweight)',
#        '75 - 82.5kg, one-two hand 3 e. (light-heavyweight)',
#        '75 - 82kg (light-heavyweight)', '8m (rating 1907)',
#        '8m (rating 1919)', 'Team pursuit (4000m)',
#        'Figure riding individual', 'Figure riding team',
#        'Fixed bird target large birds',
#        'Fixed bird target large birds teams',
#        'Fixed bird target small bird, teams',
#        'Fixed bird target small birds', 'Ice hockey',
#        'Moving bird target 28m teams', 'Moving bird target 33m teams',
#        'Moving bird target 50m teams', 'Moving bird target, 28m',
#        'Moving bird target, 33m', 'Moving bird target, 50m',
#        '+ 82.5kg, one-two hand 5 events (heavyweight)',
#        '+ 87kg (heavyweight)', '- 56kg (bantamweight)',
#        '- 58kg (bantamweight)',
#        '- 60kg, one-two hand 5 events (featherweight)',
#        '400, 600, 800m free rifle, team', '56 - 61kg (featherweight)',
#        '58 - 62kg (featherweight)',
#        '60 - 67.5kg, one-two hand 5 events (lightweight)',
#        '600m free rifle, individual', '61 - 66kg (lightweight)',
#        '62 - 67.5kg (lightweight)', '66 - 72kg (welterweight)',
#        '67.5 - 75kg, one-two hand 5 events (middleweight)',
#        '72 - 79kg (middleweight)',
#        '75 - 82.5kg, one-two hand 5 e. (light-heavyweight)',
#        '79 - 87kg (light-heavyweight)', 'Sidehorse vault',
#        'Olympic class monotype', '+ 82.5kg, total (heavyweight)',
#        '- 60kg, total (featherweight)', '12 foot dinghy individual',
#        '1km pursuit', '58 - 60kg (featherweight)',
#        '60 - 67.5kg, total (lightweight)',
#        '67.5 - 75kg, total (middleweight)',
#        '75 - 82.5kg, total (light-heavyweight)',
#        '+ 87kg (super heavyweight)', '50.8 - 54kg (bantamweight)',
#        '50km walk', '54 - 57.15kg (featherweight)', '80m hurdles',
#        'Floor exercises', 'Indian clubs', 'Tumbling',
#        'Two-person keelboat open (star)', 'C-1 1000m (canoe single)',
#        'C-2 10000m', 'C-2 1000m (canoe double)', 'K-1 10000m',
#        'K-1 1000m (kayak single)', 'K-2 10000m',
#        'K-2 1000m (kayak double)', 'Basketball', 'Folding k-1 10000m',
#        'Folding k-2 10000m', 'Handball', '- 51kg (flyweight)',
#        '- 52kg (flyweight)', '- 56kg, total (bantamweight)',
#        '51 - 54kg (bantamweight)', '52 - 57kg (bantamweight)',
#        '54 - 58kg (featherweight)', '56 - 60kg, total (featherweight)',
#        '57 - 61kg (featherweight)', '57 - 63kg (featherweight)',
#        '58 - 62kg (lightweight)', '61 - 67kg (lightweight)',
#        '62 - 67kg (welterweight)', '63 - 67kg (lightweight)',
#        '67 - 73kg (middleweight)', '67 - 73kg (welterweight)',
#        '73 - 79kg (middleweight)', '73 - 80kg (light-heavyweight)',
#        'C-1 10000m', 'K-1 500m (kayak single)', 'Dragon', 'Firefly class',
#        'Swallow (golondrina)', '+ 81kg (heavyweight)',
#        '+ 90kg, total (heavyweight)',
#        '100m running deer, single/double shots', '5.5m',
#        '50m rifle 3 positions (3x40 shots)', '54 - 57kg (featherweight)',
#        '57 - 60kg (lightweight)', '60 - 63.5kg (light-welterweight)',
#        '63.5 - 67kg (welterweight)', '67 - 71kg (light-middleweight)',
#        '71-75kg', '75 - 81kg (light-heavyweight)',
#        '82.5 - 90kg, total (middle-heavyweight)', 'Balance beam',
#        'Single-handed dinghy (finn)', 'Team, portable apparatus',
#        'Uneven bars', '100m butterfly', '200m butterfly', '20km walk',
#        'Sharpie 12m2', '4x100m medley relay', 'K-1 4x500m',
#        'K-2 500m (kayak double)', 'Flying dutchman',
#        '+ 97kg (heavyweight)', '+ 97kg (super heavyweight)',
#        '- 68kg (lightweight)', '400m individual medley',
#        '63 - 70kg (lightweight)', '68 - 80kg (middleweight)',
#        '70 - 78kg (welterweight)', '78 - 87kg (middleweight)',
#        '87 - 97kg (light-heavyweight)', 'Individual pursuit',
#        'K-4 1000m (kayak four)', 'Open category', 'Volleyball',
#        '- 48kg (light-flyweight)', '100m breaststroke',
#        '200m individual medley', '48 - 51kg (flyweight)',
#        '800m freestyle', 'Skeet (125 targets)',
#        '+ 100kg (super heavyweight)',
#        '+ 110kg, total (super heavyweight)', '+ 93kg (heavyweight)',
#        '- 52kg, total (flyweight)', '- 63kg (lightweight)',
#        '100m hurdles', '48 - 52kg (flyweight)',
#        '50m running target (30+30 shots)',
#        '52 - 56kg, total (bantamweight)', '57 - 62kg (featherweight)',
#        '62 - 68kg (lightweight)', '63 - 70kg (half-middleweight)',
#        '68 - 74kg (welterweight)', '70 - 80kg (middleweight)',
#        '74 - 82kg (middleweight)', '80 - 93kg (half-heavyweight)',
#        '82 - 90kg (light-heavyweight)', '90 - 100kg (heavyweight)',
#        '91 - 110kg, total (heavyweight)', 'C-1 (canoe single)',
#        'C-2 (canoe double)', 'K-1 (kayak single)',
#        'Fleet/match race keelboat open (soling)', 'Individual fita round',
#        'Tempest', '470 - two person dinghy', 'C-1 500m (canoe single)',
#        'C-2 500m (canoe double)', 'Tornado - multihull',
#        'Pair without coxswain (2-)',
#        'Quadruple sculls with coxswain (4x)',
#        'Quadruple sculls without coxswain (4x)', '+ 95kg (heavyweight)',
#        '- 60 kg', '100 - 110kg, total (heavyweight)',
#        '60 - 65kg (half-lightweight)', '65 - 71kg (lightweight)',
#        '71 - 78kg (half-middleweight)', '78 - 86kg (middleweight)',
#        '86 - 95kg (half-heavyweight)',
#        '90 - 100kg, total (first-heavyweight)',
#        '+ 91kg (super heavyweight)', '10m air rifle (40 shots)',
#        '10m air rifle (60 shots)', '25m pistol (30+30 shots)', '3000m',
#        '50m rifle 3 positions (3x20 shots)', '81 - 91kg (heavyweight)',
#        'K-4 500m (kayak four)', 'Points race', 'Board (windglider)',
#        'Duet', 'Heptathlon', 'Solo', '100 - 130kg (super heavyweight)',
#        '10m air pistol (40 shots)', '10m air pistol (60 shots)',
#        '50m freestyle', 'Board (division ii)', 'Sprint',
#        '+ 72kg (heavyweight)', '- 48kg (extra-lightweight)',
#        '48 - 52kg (half-lightweight)', '52 - 56kg (lightweight)',
#        '56 - 61kg (half-middleweight)', '61 - 66kg (middleweight)',
#        '66 - 72kg (half-heavyweight)', 'Baseball', 'Board (lechner)',
#        'Coxless four (4-)', 'Individual (fita olympic round - 70m)',
#        'Single-handed dinghy (europe)', 'Team (fita olympic round - 70m)',
#        '+ 100kg (heavyweight)', '+ 108kg, total (super heavyweight)',
#        '- 54kg, total (flyweight)', '54 - 59kg, total (bantamweight)',
#        '59 - 64kg, total (featherweight)', '60 - 66kg (half-lightweight)',
#        '64 - 70kg, total (lightweight)', '66 - 73kg (lightweight)',
#        '70 - 76kg, total (middleweight)', '73 - 81kg (half-middleweight)',
#        '76 - 83kg, total (light-heavyweight)', '81 - 90kg (middleweight)',
#        '83 - 91kg, total (middle-heavyweight)',
#        '90 - 100kg (half-heavyweight)',
#        '91 - 99kg, total (first-heavyweight)',
#        '99 - 108kg, total (heavyweight)', 'Beach volleyball',
#        'Board (mistral)', 'Cross-country', 'Double trap (120 targets)',
#        'Double trap (150 targets)', 'Group competition',
#        'Lightweight coxless four (4-)', 'Lightweight double sculls (2x)',
#        'Single-handed dinghy open (laser)', 'Softball', '+ 105kg',
#        '+ 67 kg', '+ 75kg', '+ 78kg (heavyweight)', '+ 80 kg', '- 49 kg',
#        '- 58 kg', '105kg', '10m running target (30+30 shots)',
#        '20km race walk', '48 - 54kg', '48kg', '49 - 57 kg',
#        '49er - skiff', '500m time trial', '52 - 57kg (lightweight)',
#        '53kg', '54 - 58kg', '56kg', '57 - 63kg (half-middleweight)',
#        '57 - 67 kg', '58 - 63kg', '58 - 68 kg', '58kg', '62kg',
#        '63 - 69kg', '63 - 70kg (middleweight)', '63kg', '68 - 80 kg',
#        '69 - 76kg', '69kg', '70 - 78kg (half-heavyweight)', '75kg',
#        '76 - 85kg', '77kg', '85 - 97kg', '85kg', '94kg', '97 - 130kg',
#        'Keirin', 'Madison', 'Olympic sprint', 'Skeet (75 targets)',
#        'Synchronized diving 10m platform',
#        'Synchronized diving 3m springboard', 'Trap (75 targets)',
#        '- 48 kg', '- 48kg', '- 55kg', '48 - 55kg',
#        '48kg (light flywieght)', '55 - 60kg', '55 - 63kg', '60 - 64 kg',
#        '60 - 66kg', '63 - 72kg', '64 - 69 kg', '66 - 74kg', '69 - 75 kg',
#        '74 - 84kg', '84 - 96kg', '96 - 120kg', 'Star - keelboat',
#        'Team sprint', 'Yngling - keelboat'], dtype=object)

# %%
dir(oo.Event.str)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__frozen',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_data',
#  '_doc_args',
#  '_freeze',
#  '_get_series_list',
#  '_index',
#  '_inferred_dtype',
#  '_is_categorical',
#  '_is_string',
#  '_name',
#  '_orig',
#  '_parent',
#  '_validate',
#  '_wrap_result',
#  'capitalize',
#  'casefold',
#  'cat',
#  'center',
#  'contains',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'extract',
#  'extractall',
#  'find',
#  'findall',
#  'fullmatch',
#  'get',
#  'get_dummies',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'islower',
#  'isnumeric',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'len',
#  'ljust',
#  'lower',
#  'lstrip',
#  'match',
#  'normalize',
#  'pad',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'repeat',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'slice',
#  'slice_replace',
#  'split',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'wrap',
#  'zfill']

# %%
oo["Athlete Name"].str.contains("Latynina")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27169    False
# 27170    False
# 27171    False
# 27172    False
# 27173    False
# Name: Athlete Name, Length: 27174, dtype: bool

# %%
# Larisa Latynina - most decorated Female athlete
oo[oo["Athlete Name"].str.contains("Latynina")]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo[oo["Athlete Name"].str.contains("LATYNINA")]
# Out:
#        Year                   City       Sport   Discipline      Athlete Name  NOC Gender  \
# 9372   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 9539   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 9679   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 9702   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 9735   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 9741   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 10179  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 10277  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 10458  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 10576  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 10612  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 10616  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 11095  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 11195  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 11387  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 11517  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 11551  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
# 11558  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa  URS  Women
#
#                           Event Event Gender   Medal
# 9372            Floor exercises            W    Gold
# 9539       Individual all-round            W    Gold
# 9679           Team competition            W    Gold
# 9702   Team, portable apparatus            W  Bronze
# 9735                Uneven bars            W  Silver
# 9741                      Vault            W    Gold
# 10179              Balance beam            W  Silver
# 10277           Floor exercises            W    Gold
# 10458      Individual all-round            W    Gold
# 10576          Team competition            W    Gold
# 10612               Uneven bars            W  Silver
# 10616                     Vault            W  Bronze
# 11095              Balance beam            W  Bronze
# 11195           Floor exercises            W    Gold
# 11387      Individual all-round            W  Silver
# 11517          Team competition            W    Gold
# 11551               Uneven bars            W  Bronze
# 11558                     Vault            W  Silver

# %%
dir(oo.Event.str)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__frozen',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_data',
#  '_doc_args',
#  '_freeze',
#  '_get_series_list',
#  '_index',
#  '_inferred_dtype',
#  '_is_categorical',
#  '_is_string',
#  '_name',
#  '_orig',
#  '_parent',
#  '_validate',
#  '_wrap_result',
#  'capitalize',
#  'casefold',
#  'cat',
#  'center',
#  'contains',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'extract',
#  'extractall',
#  'find',
#  'findall',
#  'fullmatch',
#  'get',
#  'get_dummies',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'islower',
#  'isnumeric',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'len',
#  'ljust',
#  'lower',
#  'lstrip',
#  'match',
#  'normalize',
#  'pad',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'repeat',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'slice',
#  'slice_replace',
#  'split',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'wrap',
#  'zfill']

# %%
oo.City = oo.City.str.upper()
oo.sample(3)
# Out:
#        Year       City       Sport   Discipline          Athlete Name  NOC Gender  \
# 2619   1912  STOCKHOLM  Gymnastics  Artistic G.   ENGEBRETSEN, Eugene  NOR    Men
# 24733  2000     SYDNEY     Fencing      Fencing      KOTHNY, Wiradech  GER    Men
# 14001  1976   MONTREAL    Aquatics     Swimming  NABER, John Phillips  USA    Men
#
#                       Event Event Gender   Medal
# 2619   Team, swedish system            M  Bronze
# 24733            Sabre team            M  Bronze
# 14001       200m backstroke            M    Gold

# %%
oo.City.unique()
# Out:
# array(['ATHENS', 'PARIS', 'ST LOUIS', 'LONDON', 'STOCKHOLM', 'ANTWERP',
#        'AMSTERDAM', 'LOS ANGELES', 'BERLIN', 'HELSINKI',
#        'MELBOURNE / STOCKHOLM', 'ROME', 'TOKYO', 'MEXICO', 'MUNICH',
#        'MONTREAL', 'MOSCOW', 'SEOUL', 'BARCELONA', 'ATLANTA', 'SYDNEY'],
#       dtype=object)

# %% [markdown]
# ## Sorting a DataFrame or Series

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year                   City     Sport Discipline          Athlete Name  NOC Gender  \
# 9097   1956  Melbourne / Stockholm   Sailing    Sailing  DILLON, John Desmond  GBR    Men
# 25358  2004                 Athens  Aquatics     Diving   DESPATIE, Alexandre  CAN    Men
# 17644  1984            Los Angeles    Hockey     Hockey     VAN MANEN, Aletta  NED  Women
#
#                 Event Event Gender   Medal
# 9097             5.5m            X  Silver
# 25358  3m springboard            M  Silver
# 17644          hockey            W    Gold

# %%
oo["Athlete Name"].sort_values()
# Out:
# 611                 AABYE, Edgar
# 3060       AALTONEN, Arvo Ossian
# 2963       AALTONEN, Arvo Ossian
# 7792    AALTONEN, Paavo Johannes
# 7906    AALTONEN, Paavo Johannes
#                   ...
# 275                   ÖSTMO, Ole
# 443                   ÖSTMO, Ole
# 280                   ÖSTMO, Ole
# 268                   ÖSTMO, Ole
# 8125           ÖSTRAND, Per-Olof
# Name: Athlete Name, Length: 27174, dtype: object

# %%
type(oo["Athlete Name"].sort_values())
# Out:
# pandas.core.series.Series

# %%
oo.sort_values("Athlete Name")
# Out:
#       Year      City       Sport   Discipline              Athlete Name  NOC Gender  \
# 611   1900     Paris  Tug of War   Tug of War              AABYE, Edgar  ZZX    Men
# 3060  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian  FIN    Men
# 2963  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian  FIN    Men
# 7792  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes  FIN    Men
# 7906  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes  FIN    Men
# ...    ...       ...         ...          ...                       ...  ...    ...
# 275   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR    Men
# 443   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR    Men
# 280   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR    Men
# 268   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR    Men
# 8125  1952  Helsinki    Aquatics     Swimming         ÖSTRAND, Per-Olof  SWE    Men
#
#                               Event Event Gender   Medal
# 611                      tug of war            M    Gold
# 3060              400m breaststroke            M  Bronze
# 2963              200m breaststroke            M  Bronze
# 7792           individual all-round            M  Bronze
# 7906               team competition            M    Gold
# ...                             ...          ...     ...
# 275         army rifle, 300m, prone            M  Bronze
# 443                free rifle, team            M  Silver
# 280      army rifle, 300m, standing            M  Silver
# 268   army rifle, 300m, 3 positions            M  Bronze
# 8125                 400m freestyle            M  Bronze
#
# [27174 rows x 10 columns]

# %%
type(oo.sort_values("Athlete Name"))
# Out:
# pandas.core.frame.DataFrame

# %%
oo.head(3)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  Event Event Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men  100km            M
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men  100km            M
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men   100m            M
#
#     Medal
# 0    Gold
# 1  Silver
# 2  Bronze

# %%
oo.sort_values("Athlete Name", ascending=False)
# Out:
#       Year      City       Sport   Discipline              Athlete Name  NOC Gender  \
# 8125  1952  Helsinki    Aquatics     Swimming         ÖSTRAND, Per-Olof  SWE    Men
# 268   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR    Men
# 443   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR    Men
# 275   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR    Men
# 280   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR    Men
# ...    ...       ...         ...          ...                       ...  ...    ...
# 7967  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes  FIN    Men
# 7792  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes  FIN    Men
# 2963  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian  FIN    Men
# 3060  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian  FIN    Men
# 611   1900     Paris  Tug of War   Tug of War              AABYE, Edgar  ZZX    Men
#
#                               Event Event Gender   Medal
# 8125                 400m freestyle            M  Bronze
# 268   army rifle, 300m, 3 positions            M  Bronze
# 443                free rifle, team            M  Silver
# 275         army rifle, 300m, prone            M  Bronze
# 280      army rifle, 300m, standing            M  Silver
# ...                             ...          ...     ...
# 7967                          vault            M    Gold
# 7792           individual all-round            M  Bronze
# 2963              200m breaststroke            M  Bronze
# 3060              400m breaststroke            M  Bronze
# 611                      tug of war            M    Gold
#
# [27174 rows x 10 columns]

# %%
oo.sort_values("Athlete Name", ascending=False).head(25)
# Out:
#        Year       City      Sport     Discipline               Athlete Name  NOC Gender  \
# 8125   1952   Helsinki   Aquatics       Swimming          ÖSTRAND, Per-Olof  SWE    Men
# 268    1900      Paris   Shooting       Shooting                 ÖSTMO, Ole  NOR    Men
# 443    1900      Paris   Shooting       Shooting                 ÖSTMO, Ole  NOR    Men
# 275    1900      Paris   Shooting       Shooting                 ÖSTMO, Ole  NOR    Men
# 280    1900      Paris   Shooting       Shooting                 ÖSTMO, Ole  NOR    Men
# 2936   1920    Antwerp    Sailing        Sailing       ÖSTERVOLD, Ole Olsen  NOR    Men
# 2935   1920    Antwerp    Sailing        Sailing  ÖSTERVOLD, Kristian Olsen  NOR    Men
# 2934   1920    Antwerp    Sailing        Sailing       ÖSTERVOLD, Jan Olsen  NOR    Men
# 2933   1920    Antwerp    Sailing        Sailing          ÖSTERVOLD, Henrik  NOR    Men
# 2390   1912  Stockholm   Shooting       Shooting            ÖSTENSEN, Östen  NOR    Men
# 2999   1920    Antwerp   Shooting       Shooting            ÖSTENSEN, Östen  NOR    Men
# 3161   1920    Antwerp   Shooting       Shooting            ÖSTENSEN, Östen  NOR    Men
# 2982   1920    Antwerp   Shooting       Shooting            ÖSTENSEN, Östen  NOR    Men
# 3526   1920    Antwerp   Shooting       Shooting            ÖSTENSEN, Östen  NOR    Men
# 2943   1920    Antwerp    Sailing        Sailing                ÖRVIG, Thor  NOR    Men
# 2942   1920    Antwerp    Sailing        Sailing                ÖRVIG, Olav  NOR    Men
# 2941   1920    Antwerp    Sailing        Sailing                ÖRVIG, Erik  NOR    Men
# 2185   1912  Stockholm   Shooting       Shooting            ÖRTEGREN, Ruben  SWE    Men
# 15637  1980     Moscow    Cycling  Cycling Track        ÖRSTED, Hans-Henrik  DEN    Men
# 2003   1912  Stockholm   Aquatics         Diving             ZÜRNER, Albert  GER    Men
# 1259   1908     London   Aquatics         Diving             ZÜRNER, Albert  GER    Men
# 18424  1988      Seoul     Boxing         Boxing             ZÜLOW, Andreas  GDR    Men
# 19265  1988      Seoul     Rowing         Rowing            ZÜHLKE, Steffen  GDR    Men
# 10013  1960       Rome   Shooting       Shooting           ZÄHRINGER, Klaus  EUA    Men
# 25587  2004     Athens  Athletics      Athletics             ZYKINA, Olesya  RUS  Women
#
#                                           Event Event Gender   Medal
# 8125                             400m freestyle            M  Bronze
# 268               army rifle, 300m, 3 positions            M  Bronze
# 443                            free rifle, team            M  Silver
# 275                     army rifle, 300m, prone            M  Bronze
# 280                  army rifle, 300m, standing            M  Silver
# 2936                          12m (rating 1907)            X    Gold
# 2935                          12m (rating 1907)            X    Gold
# 2934                          12m (rating 1907)            X    Gold
# 2933                          12m (rating 1907)            X    Gold
# 2390                           free rifle, team            M  Silver
# 2999   300m free rifle 3 positions (3x40 shots)            M  Bronze
# 3161                 50m small bore rifle, team            M  Bronze
# 2982           300+600m free rifle, team, prone            M  Silver
# 3526                           free rifle, team            M  Silver
# 2943                          12m (rating 1919)            X    Gold
# 2942                          12m (rating 1919)            X    Gold
# 2941                          12m (rating 1919)            X    Gold
# 2185                 50m small bore rifle, team            M  Silver
# 15637                        Individual Pursuit            M  Bronze
# 2003                               10m platform            M  Silver
# 1259                             3m springboard            M    Gold
# 18424                   57 - 60kg (lightweight)            M    Gold
# 19265    quadruple sculls without coxswain (4x)            M  Bronze
# 10013        50m rifle 3 positions (3x40 shots)            M  Bronze
# 25587                              4x400m relay            W  Silver

# %%
oo.sort_values(by=['Year','Athlete Name'])
# Out:
#        Year    City       Sport    Discipline              Athlete Name  NOC Gender  \
# 20     1896  Athens    Aquatics      Swimming          ANDREOU, Joannis  GRE    Men
# 103    1896  Athens  Gymnastics   Artistic G.  ANDRIAKOPOULOS, Nicolaos  GRE    Men
# 141    1896  Athens  Gymnastics   Artistic G.  ANDRIAKOPOULOS, Nicolaos  GRE    Men
# 142    1896  Athens  Gymnastics   Artistic G.    ATHANASOPOULOS, Spyros  GRE    Men
# 79     1896  Athens     Cycling  Cycling Road            BATTEL, Edward  GBR    Men
# ...     ...     ...         ...           ...                       ...  ...    ...
# 25753  2004  Athens      Boxing        Boxing             ZUYEV, Viktar  BLR    Men
# 25748  2004  Athens        Judo          Judo          ZVIADAURI, Zurab  GEO    Men
# 26570  2004  Athens      Hockey        Hockey              ZWEHL, Julia  GER  Women
# 25440  2004  Athens    Aquatics      Swimming       ZWERING, Klaas-Erik  NED    Men
# 25587  2004  Athens   Athletics     Athletics            ZYKINA, Olesya  RUS  Women
#
#                           Event Event Gender   Medal
# 20              1200m freestyle            M  Silver
# 103               rope climbing            M    Gold
# 141         team, parallel bars            M  Silver
# 142         team, parallel bars            M  Silver
# 79         individual road race            M  Bronze
# ...                         ...          ...     ...
# 25753   81 - 91kg (heavyweight)            M  Silver
# 25748  81 - 90kg (middleweight)            M    Gold
# 26570                    hockey            W    Gold
# 25440    4x100m freestyle relay            M  Silver
# 25587              4x400m relay            W  Silver
#
# [27174 rows x 10 columns]

# %%
oo.sort_values(by=["Year", "Athlete Name"], ascending=[False, True])
# Out:
#        Year    City       Sport       Discipline        Athlete Name  NOC Gender  \
# 25212  2004  Athens   Wrestling  Wrestling Free.       ABAS, Stephen  USA    Men
# 26832  2004  Athens     Cycling    Cycling Track   ABASSOVA, Tamilla  RUS  Women
# 25418  2004  Athens   Taekwondo        Taekwondo       ABDALLAH, Nia  USA  Women
# 25726  2004  Athens   Wrestling  Wrestling Gre-R     ABRAHAMIAN, Ara  SWE    Men
# 26997  2004  Athens  Volleyball       Volleyball      ABRAMOV, Pavel  RUS    Men
# ...     ...     ...         ...              ...                 ...  ...    ...
# 104    1896  Athens  Gymnastics      Artistic G.  XENAKIS, Thomasios  GRE    Men
# 144    1896  Athens  Gymnastics      Artistic G.  XENAKIS, Thomasios  GRE    Men
# 92     1896  Athens  Gymnastics      Artistic G.       ZUTTER, Louis  SUI    Men
# 97     1896  Athens  Gymnastics      Artistic G.       ZUTTER, Louis  SUI    Men
# 150    1896  Athens  Gymnastics      Artistic G.       ZUTTER, Louis  SUI    Men
#
#                      Event Event Gender   Medal
# 25212               - 55kg            M  Silver
# 26832               sprint            W  Silver
# 25418           49 - 57 kg            W  Silver
# 25726            74 - 84kg            M  Silver
# 26997           volleyball            M  Bronze
# ...                    ...          ...     ...
# 104          rope climbing            M  Silver
# 144    team, parallel bars            M  Silver
# 92           parallel bars            M  Silver
# 97            pommel horse            M    Gold
# 150                  vault            M  Silver
#
# [27174 rows x 10 columns]

# %%
oo.head(7)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender           Event  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men           100km
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men           100km
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men            100m
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men            100m
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men            100m
# 5  1896  Athens  Athletics      Athletics      HOFMANN, Fritz  GER    Men            100m
# 6  1896  Athens   Aquatics       Swimming       HAJOS, Alfred  HUN    Men  100m freestyle
#
#   Event Gender   Medal
# 0            M    Gold
# 1            M  Silver
# 2            M  Bronze
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            M    Gold

# %%
oo.sort_values(by=["Year", "Event", "Medal"], ascending=[True, True, False]).head(7)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender           Event  \
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men           100km
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men           100km
# 5  1896  Athens  Athletics      Athletics      HOFMANN, Fritz  GER    Men            100m
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men            100m
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men            100m
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men            100m
# 7  1896  Athens   Aquatics       Swimming    HERSCHMANN, Otto  AUT    Men  100m freestyle
#
#   Event Gender   Medal
# 1            M  Silver
# 0            M    Gold
# 5            M  Silver
# 4            M    Gold
# 2            M  Bronze
# 3            M  Bronze
# 7            M  Silver

# %%
oo.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# dtype: object

# %% [markdown]
# ## Working with data types (dtype)

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year    City       Sport  Discipline         Athlete Name  NOC Gender       Event  \
# 4682   1924   Paris   Athletics   Athletics  BROWN, Leroy Taylor  USA    Men   high jump
# 11270  1964   Tokyo    Football    Football        VARGA, Zoltan  HUN    Men    football
# 24044  2000  Sydney  Basketball  Basketball      JACKSON, Lauren  AUS  Women  basketball
#
#       Event Gender   Medal
# 4682             M  Silver
# 11270            M    Gold
# 24044            W  Silver

# %%
oo.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# dtype: object

# %%
oo.Medal.unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
oo.Medal = oo.Medal.astype("category")
oo.dtypes
# Out:
# Year               int64
# City              object
# Sport             object
# Discipline        object
# Athlete Name      object
# NOC               object
# Gender            object
# Event             object
# Event Gender      object
# Medal           category
# dtype: object

# %%
oo.Gender.unique()
# Out:
# array(['Men', 'Women'], dtype=object)

# %%
oo['Event Gender'].unique()
# Out:
# array(['M', 'X', 'W'], dtype=object)

# %%
oo.Gender = oo.Gender.astype("category")
oo['Event Gender'] = oo['Event Gender'].astype("category")
oo.dtypes
# Out:
# Year               int64
# City              object
# Sport             object
# Discipline        object
# Athlete Name      object
# NOC               object
# Gender          category
# Event             object
# Event Gender    category
# Medal           category
# dtype: object

# %%
oo.Medal.astype("category")
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3        Bronze
# 4          Gold
#           ...
# 27169      Gold
# 27170      Gold
# 27171    Silver
# 27172    Silver
# 27173    Silver
# Name: Medal, Length: 27174, dtype: category
# Categories (3, object): ['Bronze', 'Gold', 'Silver']

# %%
pd.Categorical?

# %%
medal_order = ["Bronze", "Silver", "Gold"]
pd.Categorical(oo.Medal, categories=medal_order, ordered=True)
# Out:
# ['Gold', 'Silver', 'Bronze', 'Bronze', 'Gold', ..., 'Gold', 'Gold', 'Silver', 'Silver', 'Silver']
# Length: 27174
# Categories (3, object): ['Bronze' < 'Silver' < 'Gold']

# %%
oo.Medal = pd.Categorical(oo.Medal, categories=medal_order, ordered=True)
oo.dtypes
# Out:
# Year               int64
# City              object
# Sport             object
# Discipline        object
# Athlete Name      object
# NOC               object
# Gender          category
# Event             object
# Event Gender    category
# Medal           category
# dtype: object

# %%
oo.Medal
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3        Bronze
# 4          Gold
#           ...
# 27169      Gold
# 27170      Gold
# 27171    Silver
# 27172    Silver
# 27173    Silver
# Name: Medal, Length: 27174, dtype: category
# Categories (3, object): ['Bronze' < 'Silver' < 'Gold']

# %%
oo.sort_values(by=["Year", "Event", "Medal"], ascending=[True, True, False]).head(7)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender           Event  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men           100km
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men           100km
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men            100m
# 5  1896  Athens  Athletics      Athletics      HOFMANN, Fritz  GER    Men            100m
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men            100m
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men            100m
# 6  1896  Athens   Aquatics       Swimming       HAJOS, Alfred  HUN    Men  100m freestyle
#
#   Event Gender   Medal
# 0            M    Gold
# 1            M  Silver
# 4            M    Gold
# 5            M  Silver
# 2            M  Bronze
# 3            M  Bronze
# 6            M    Gold

# %% [markdown]
# ## Memory usage of different dtypes

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
df = pd.read_csv(filename, skiprows=5)
df.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# Position         int64
# dtype: object

# %%
oo.dtypes
# Out:
# Year               int64
# City              object
# Sport             object
# Discipline        object
# Athlete Name      object
# NOC               object
# Gender          category
# Event             object
# Event Gender    category
# Medal           category
# dtype: object

# %%
oo.Medal.memory_usage?

# %%
print(f"Medal series memory usage using dtype category: {oo.Medal.memory_usage(deep=True)}")
print(f"Medal series memory usage using dtype object: {df.Medal.memory_usage(deep=True)}")
# Out:
# Medal series memory usage using dtype category: 27601
# Medal series memory usage using dtype object: 1693732

# %%
oo.Medal.memory_usage(deep=True) / df.Medal.memory_usage(deep=True)
# Out:
# 0.01629596654016102

# %%
print(f"Gender series memory usage using dtype category: {oo.Gender.memory_usage(deep=True)}")
print(f"Gender series memory usage using dtype object: {df.Gender.memory_usage(deep=True)}")
print(f"Gender series memory usage using dtype category: {oo['Event Gender'].memory_usage(deep=True)}")
print(f"Gender series memory usage using dtype object: {df['Event Gender'].memory_usage(deep=True)}")
# Out:
# Gender series memory usage using dtype category: 27536
# Gender series memory usage using dtype object: 1643698
# Gender series memory usage using dtype category: 27588
# Gender series memory usage using dtype object: 1576224

# %%
oo.City.astype("string")
# Out:
# 0        Athens
# 1        Athens
# 2        Athens
# 3        Athens
# 4        Athens
#           ...
# 27169    Athens
# 27170    Athens
# 27171    Athens
# 27172    Athens
# 27173    Athens
# Name: City, Length: 27174, dtype: string

# %%
oo.sample(2)
# Out:
#        Year      City   Sport Discipline      Athlete Name  NOC Gender    Event Event Gender  \
# 14798  1976  Montreal  Hockey     Hockey  KHAN, Sami Ullah  PAK    Men   hockey            M
# 10992  1964     Tokyo  Boxing     Boxing  WALASEK, Tadeusz  POL    Men  71-75kg            M
#
#         Medal
# 14798  Bronze
# 10992  Bronze

# %%
oo.dtypes
# Out:
# Year               int64
# City              object
# Sport             object
# Discipline        object
# Athlete Name      object
# NOC               object
# Gender          category
# Event             object
# Event Gender    category
# Medal           category
# dtype: object

# %%
oo.City = oo.City.astype("string")
oo.Sport = oo.Sport.astype("string")
oo.Discipline = oo.Discipline.astype("string")
oo["Athlete Name"] = oo["Athlete Name"].astype("string")
oo.NOC = oo.NOC.astype("string")
oo.Event = oo.Event.astype("string")
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
oo.City.dtype
# Out:
# string[python]

# %%
df.City.dtype
# Out:
# dtype('O')

# %%
print(f"City series memory usage using dtype string: {oo.City.memory_usage(deep=True)}")
print(f"City series memory usage using dtype object: {df.City.memory_usage(deep=True)}")
# Out:
# City series memory usage using dtype string: 1748408
# City series memory usage using dtype object: 1748408

# %% [markdown]
# ## Defining dtypes when you read in a file

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year     City       Sport Discipline     Athlete Name  NOC Gender                   Event  \
# 6448   1936   Berlin   Athletics  Athletics  METCALFE, Ralph  USA    Men            4x100m relay
# 21542  1996  Atlanta    Aquatics   Swimming   OSYGUS, Simone  GER  Women  4x100m freestyle relay
# 12522  1968   Mexico  Equestrian    Jumping   LEFEVRE, Janou  FRA  Women                    team
#
#       Event Gender   Medal
# 6448             M    Gold
# 21542            W  Bronze
# 12522            X  Silver

# %%
oo.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# dtype: object

# %%
dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": "category"}

dtype_mapper
# Out:
# {'Year': 'int64',
#  'City': 'string',
#  'Sport': 'string',
#  'Discipline': 'string',
#  'Athlete Name': 'string',
#  'NOC': 'string',
#  'Gender': 'category',
#  'Event': 'string',
#  'Event_gender': 'category',
#  'Medal': 'category'}

# %%
pd.api.types.CategoricalDtype?

# %%
ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
ordered_medals
# Out:
# CategoricalDtype(categories=['Bronze', 'Silver', 'Gold'], ordered=True)

# %%
dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}

dtype_mapper
# Out:
# {'Year': 'int64',
#  'City': 'string',
#  'Sport': 'string',
#  'Discipline': 'string',
#  'Athlete Name': 'string',
#  'NOC': 'string',
#  'Gender': 'category',
#  'Event': 'string',
#  'Event_gender': 'category',
#  'Medal': CategoricalDtype(categories=['Bronze', 'Silver', 'Gold'], ordered=True)}

# %%
oo = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
oo.sample(3)
# Out:
#        Year         City      Sport Discipline              Athlete Name  NOC Gender  \
# 11931  1968       Mexico  Athletics  Athletics       JELLINGHAUS, Martin  FRG    Men
# 6182   1932  Los Angeles     Rowing     Rowing  JENNINGS, Edward Francis  USA    Men
# 12727  1972       Munich     Boxing     Boxing                ALEXE, Ion  ROU    Men
#
#                                      Event Event Gender   Medal  Position
# 11931                         4x400m relay            M  Bronze         3
# 6182   pair-oared shell with coxswain (2+)            M    Gold         1
# 12727                 + 81kg (heavyweight)            M  Silver         2

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender            object
# Medal                 category
# Position                 int64
# dtype: object

# %%
oo["Event Gender"].unique()
# Out:
# array(['M', 'X', 'W'], dtype=object)

# %%
oo = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
oo['Event Gender'] = oo['Event Gender'].astype("category")
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# Position                 int64
# dtype: object

# %% [markdown]
# ## Python Functions

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def show_df(filename="olympics_1896_2004.csv"):
  """Read in csv file and display DataFrame"""
  df = pd.read_csv(filename, skiprows=5)
  return df

show_df()
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender      Event  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men      100km
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men      100km
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men       100m
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men       100m
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men       100m
# ...     ...     ...        ...            ...                 ...  ...    ...        ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women  épée team
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women  épée team
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women  épée team
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women  épée team
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women  épée team
#
#       Event Gender   Medal  Position
# 0                M    Gold         1
# 1                M  Silver         2
# 2                M  Bronze         3
# 3                M  Bronze         3
# 4                M    Gold         1
# ...            ...     ...       ...
# 27169            W    Gold         1
# 27170            W    Gold         1
# 27171            W  Silver         2
# 27172            W  Silver         2
# 27173            W  Silver         2
#
# [27174 rows x 11 columns]

# %%
type(show_df())
# Out:
# pandas.core.frame.DataFrame

# %%
ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}

dtype_mapper
# Out:
# {'Year': 'int64',
#  'City': 'string',
#  'Sport': 'string',
#  'Discipline': 'string',
#  'Athlete Name': 'string',
#  'NOC': 'string',
#  'Gender': 'category',
#  'Event': 'string',
#  'Event_gender': 'category',
#  'Medal': CategoricalDtype(categories=['Bronze', 'Silver', 'Gold'], ordered=True)}

# %%
oo = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year       City          Sport       Discipline       Athlete Name  NOC Gender  \
# 5258   1928  Amsterdam        Sailing          Sailing   HERIOT, Virginie  FRA  Women
# 19141  1988      Seoul         Hockey           Hockey      BUTER, Yvonne  NED  Women
# 11060  1964      Tokyo  Canoe / Kayak  Canoe / Kayak F  SCIOTNIC, Atanase  ROU    Men
#
#                         Event Event Gender   Medal
# 5258                       8m            X    Gold
# 19141                  hockey            W  Bronze
# 11060  K-4 1000m (kayak four)            M  Bronze

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )

  return df

preprocess()
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender      Event  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men      100km
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men      100km
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men       100m
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men       100m
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men       100m
# ...     ...     ...        ...            ...                 ...  ...    ...        ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women  épée team
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women  épée team
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women  épée team
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women  épée team
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women  épée team
#
#       Event Gender   Medal
# 0                M    Gold
# 1                M  Silver
# 2                M  Bronze
# 3                M  Bronze
# 4                M    Gold
# ...            ...     ...
# 27169            W    Gold
# 27170            W    Gold
# 27171            W  Silver
# 27172            W  Silver
# 27173            W  Silver
#
# [27174 rows x 10 columns]

# %%
preprocess()
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender      Event  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men      100km
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men      100km
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men       100m
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men       100m
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men       100m
# ...     ...     ...        ...            ...                 ...  ...    ...        ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women  épée team
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women  épée team
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women  épée team
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women  épée team
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women  épée team
#
#       Event Gender   Medal
# 0                M    Gold
# 1                M  Silver
# 2                M  Bronze
# 3                M  Bronze
# 4                M    Gold
# ...            ...     ...
# 27169            W    Gold
# 27170            W    Gold
# 27171            W  Silver
# 27172            W  Silver
# 27173            W  Silver
#
# [27174 rows x 10 columns]

# %%
oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year     City      Sport    Discipline        Athlete Name  NOC Gender  \
# 3908   1920  Antwerp    Cycling  Cycling Road    GOBILLOT, Marcel  FRA    Men
# 15404  1980   Moscow   Aquatics      Swimming   KOPLYAKOV, Sergei  URS    Men
# 3118   1920  Antwerp  Athletics     Athletics  DEVAUX, Jean André  FRA    Men
#
#                      Event Event Gender   Medal
# 3908       team time trial            M    Gold
# 15404  4x100m medley relay            M  Silver
# 3118          4x400m relay            M  Bronze

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender            object
# Medal                 category
# dtype: object

# %%
oo["Event Gender"].unique()
# Out:
# array(['M', 'X', 'W'], dtype=object)

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year      City     Sport  Discipline     Athlete Name  NOC Gender       Event Event Gender  \
# 19543  1988     Seoul  Aquatics  Water polo  GRISHIN, Evgeni  URS    Men  water polo            M
# 22312  1996   Atlanta  Football    Football  GUIARO, RONALDO  BRA    Men    football            M
# 8697   1952  Helsinki   Fencing     Fencing    PIOT, Maurice  FRA    Men  sabre team            M
#
#         Medal
# 19543  Bronze
# 22312  Bronze
# 8697   Bronze

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %% [markdown]
# ## Working with Indexes

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

oo = preprocess()
oo.head(5)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  Event Event Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men  100km            M
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men  100km            M
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men   100m            M
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men   100m            M
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men   100m            M
#
#     Medal
# 0    Gold
# 1  Silver
# 2  Bronze
# 3  Bronze
# 4    Gold

# %%
oo.index
# Out:
# RangeIndex(start=0, stop=27174, step=1)

# %%
oo.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender', 'Event',
#        'Event Gender', 'Medal'],
#       dtype='object')

# %%
oo.shape
# Out:
# (27174, 10)

# %%
pd.read_csv(filename, skiprows=5, header=None).head()
# Out:
#      0       1          2              3                   4    5       6      7             8   \
# 0  Year    City      Sport     Discipline        Athlete Name  NOC  Gender  Event  Event Gender
# 1  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA     Men  100km             M
# 2  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE     Men  100km             M
# 3  1896  Athens  Athletics      Athletics       LANE, Francis  USA     Men   100m             M
# 4  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN     Men   100m             M
#
#        9         10
# 0   Medal  Position
# 1    Gold         1
# 2  Silver         2
# 3  Bronze         3
# 4  Bronze         3

# %%
oo = preprocess()
oo.head(5)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  Event Event Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men  100km            M
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men  100km            M
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men   100m            M
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men   100m            M
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men   100m            M
#
#     Medal
# 0    Gold
# 1  Silver
# 2  Bronze
# 3  Bronze
# 4    Gold

# %%
oo[oo['Athlete Name'].str.contains("LEWIS, Carl")]
# Out:
#        Year         City      Sport Discipline Athlete Name  NOC Gender         Event  \
# 16636  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men          100m
# 16697  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men          200m
# 16847  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men  4x100m relay
# 17709  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men     long jump
# 18098  1988        Seoul  Athletics  Athletics  LEWIS, Carl  USA    Men          100m
# 18165  1988        Seoul  Athletics  Athletics  LEWIS, Carl  USA    Men          200m
# 19227  1988        Seoul  Athletics  Athletics  LEWIS, Carl  USA    Men     long jump
# 19908  1992    Barcelona  Athletics  Athletics  LEWIS, Carl  USA    Men  4x100m relay
# 20917  1992    Barcelona  Athletics  Athletics  LEWIS, Carl  USA    Men     long jump
# 22719  1996      Atlanta  Athletics  Athletics  LEWIS, Carl  USA    Men     long jump
#
#       Event Gender   Medal
# 16636            M    Gold
# 16697            M    Gold
# 16847            M    Gold
# 17709            M    Gold
# 18098            M    Gold
# 18165            M  Silver
# 19227            M    Gold
# 19908            M    Gold
# 20917            M    Gold
# 22719            M    Gold

# %%
oo.loc[22719, "Event"]
# Out:
# 'long jump'

# %%
oo = oo.set_index("Athlete Name")
oo.head(5)
# Out:
#                     Year    City      Sport     Discipline  NOC Gender  Event Event Gender   Medal
# Athlete Name
# FLAMENG, Léon       1896  Athens    Cycling  Cycling Track  FRA    Men  100km            M    Gold
# KOLETTIS, Georgios  1896  Athens    Cycling  Cycling Track  GRE    Men  100km            M  Silver
# LANE, Francis       1896  Athens  Athletics      Athletics  USA    Men   100m            M  Bronze
# SZOKOLYI, Alajos    1896  Athens  Athletics      Athletics  HUN    Men   100m            M  Bronze
# BURKE, Thomas       1896  Athens  Athletics      Athletics  USA    Men   100m            M    Gold

# %%
oo.index
# Out:
# Index(['FLAMENG, Léon', 'KOLETTIS, Georgios', 'LANE, Francis', 'SZOKOLYI, Alajos', 'BURKE, Thomas',
#        'HOFMANN, Fritz', 'HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#        'MALOKINIS, Ioannis',
#        ...
#        'FLESSEL-COLOVIC, Laura', 'KIRALY PICOT, Hajnalka', 'NISIMA, Maureen',
#        'AZNAVOURIAN, Karina', 'ERMAKOVA, Oxana', 'LOGOUNOVA, Tatiana', 'SIVKOVA, Anna',
#        'BOKEL, Claudia', 'DUPLITZER, Imke', 'HEIDEMANN, Britta'],
#       dtype='string', name='Athlete Name', length=27174)

# %%
oo.loc["LEWIS, Carl", "Event"]
# Out:
# Athlete Name
# LEWIS, Carl            100m
# LEWIS, Carl            200m
# LEWIS, Carl    4x100m relay
# LEWIS, Carl       long jump
# LEWIS, Carl            100m
# LEWIS, Carl            200m
# LEWIS, Carl       long jump
# LEWIS, Carl    4x100m relay
# LEWIS, Carl       long jump
# LEWIS, Carl       long jump
# Name: Event, dtype: string

# %%
oo.head(3)
# Out:
#                     Year    City      Sport     Discipline  NOC Gender  Event Event Gender   Medal
# Athlete Name
# FLAMENG, Léon       1896  Athens    Cycling  Cycling Track  FRA    Men  100km            M    Gold
# KOLETTIS, Georgios  1896  Athens    Cycling  Cycling Track  GRE    Men  100km            M  Silver
# LANE, Francis       1896  Athens  Athletics      Athletics  USA    Men   100m            M  Bronze

# %%
oo.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'NOC', 'Gender', 'Event', 'Event Gender', 'Medal'], dtype='object')

# %%
oo.shape
# Out:
# (27174, 9)

# %%
oo.head(3)
# Out:
#                     Year    City      Sport     Discipline  NOC Gender  Event Event Gender   Medal
# Athlete Name
# FLAMENG, Léon       1896  Athens    Cycling  Cycling Track  FRA    Men  100km            M    Gold
# KOLETTIS, Georgios  1896  Athens    Cycling  Cycling Track  GRE    Men  100km            M  Silver
# LANE, Francis       1896  Athens  Athletics      Athletics  USA    Men   100m            M  Bronze

# %%
oo.loc["LEWIS, Carl", ["Year", "Event", "Medal"]]
# Out:
#               Year         Event   Medal
# Athlete Name
# LEWIS, Carl   1984          100m    Gold
# LEWIS, Carl   1984          200m    Gold
# LEWIS, Carl   1984  4x100m relay    Gold
# LEWIS, Carl   1984     long jump    Gold
# LEWIS, Carl   1988          100m    Gold
# LEWIS, Carl   1988          200m  Silver
# LEWIS, Carl   1988     long jump    Gold
# LEWIS, Carl   1992  4x100m relay    Gold
# LEWIS, Carl   1992     long jump    Gold
# LEWIS, Carl   1996     long jump    Gold

# %%
oo.loc["LEWIS, Carl", :]
# Out:
#               Year         City      Sport Discipline  NOC Gender         Event Event Gender  \
# Athlete Name
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men          100m            M
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men          200m            M
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men  4x100m relay            M
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men     long jump            M
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men          100m            M
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men          200m            M
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men     long jump            M
# LEWIS, Carl   1992    Barcelona  Athletics  Athletics  USA    Men  4x100m relay            M
# LEWIS, Carl   1992    Barcelona  Athletics  Athletics  USA    Men     long jump            M
# LEWIS, Carl   1996      Atlanta  Athletics  Athletics  USA    Men     long jump            M
#
#                Medal
# Athlete Name
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl   Silver
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold

# %%
oo.loc["LEWIS, Carl"]
# Out:
#               Year         City      Sport Discipline  NOC Gender         Event Event Gender  \
# Athlete Name
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men          100m            M
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men          200m            M
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men  4x100m relay            M
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men     long jump            M
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men          100m            M
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men          200m            M
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men     long jump            M
# LEWIS, Carl   1992    Barcelona  Athletics  Athletics  USA    Men  4x100m relay            M
# LEWIS, Carl   1992    Barcelona  Athletics  Athletics  USA    Men     long jump            M
# LEWIS, Carl   1996      Atlanta  Athletics  Athletics  USA    Men     long jump            M
#
#                Medal
# Athlete Name
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl   Silver
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold
# LEWIS, Carl     Gold

# %%
oo = oo.sort_index()
oo.head(3)
# Out:
#                        Year     City       Sport  Discipline  NOC Gender              Event  \
# Athlete Name
# AABYE, Edgar           1900    Paris  Tug of War  Tug of War  ZZX    Men         tug of war
# AALTONEN, Arvo Ossian  1920  Antwerp    Aquatics    Swimming  FIN    Men  400m breaststroke
# AALTONEN, Arvo Ossian  1920  Antwerp    Aquatics    Swimming  FIN    Men  200m breaststroke
#
#                       Event Gender   Medal
# Athlete Name
# AABYE, Edgar                     M    Gold
# AALTONEN, Arvo Ossian            M  Bronze
# AALTONEN, Arvo Ossian            M  Bronze

# %%
oo = oo.reset_index()
oo.head(3)
# Out:
#             Athlete Name  Year     City       Sport  Discipline  NOC Gender              Event  \
# 0           AABYE, Edgar  1900    Paris  Tug of War  Tug of War  ZZX    Men         tug of war
# 1  AALTONEN, Arvo Ossian  1920  Antwerp    Aquatics    Swimming  FIN    Men  400m breaststroke
# 2  AALTONEN, Arvo Ossian  1920  Antwerp    Aquatics    Swimming  FIN    Men  200m breaststroke
#
#   Event Gender   Medal
# 0            M    Gold
# 1            M  Bronze
# 2            M  Bronze

# %%
oo.iloc[0, 0]
# Out:
# 'AABYE, Edgar'

# %%
oo.iloc[0, 5]
# Out:
# 'ZZX'

# %%
oo.iloc[0, :]
# Out:
# Athlete Name    AABYE, Edgar
# Year                    1900
# City                   Paris
# Sport             Tug of War
# Discipline        Tug of War
# NOC                      ZZX
# Gender                   Men
# Event             tug of war
# Event Gender               M
# Medal                   Gold
# Name: 0, dtype: object

# %%
oo.iloc[0]
# Out:
# Athlete Name    AABYE, Edgar
# Year                    1900
# City                   Paris
# Sport             Tug of War
# Discipline        Tug of War
# NOC                      ZZX
# Gender                   Men
# Event             tug of war
# Event Gender               M
# Medal                   Gold
# Name: 0, dtype: object

# %% [markdown]
# ## Being Productive in pandas - My Best Practices

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year                   City      Sport       Discipline              Athlete Name  NOC  \
# 17312  1984            Los Angeles     Rowing           Rowing  BALAN-SNEP, Doina Lilian  ROU
# 9341   1956  Melbourne / Stockholm     Rowing           Rowing    BOYKETT, David Herbert  AUS
# 11705  1968                 Mexico  Wrestling  Wrestling Gre-R              KIROV, Petar  BUL
#
#       Gender                     Event Event Gender   Medal
# 17312  Women  eight with coxswain (8+)            W  Silver
# 9341     Men  eight with coxswain (8+)            M  Bronze
# 11705    Men        - 52kg (flyweight)            M    Gold

# %% [markdown]
# **Get immediate feedback**

# %%
oo = preprocess()
# Out:
# Preprocessing olympics_1896_2004.csv ...

# %%
oo.sample(3)
# Out:
#        Year      City      Sport       Discipline              Athlete Name  NOC Gender  \
# 8475   1952  Helsinki     Rowing           Rowing        FRYE, Wayne Thomas  USA    Men
# 8192   1952  Helsinki  Athletics        Athletics  MOORE, Charles Hewes Jr.  USA    Men
# 18466  1988     Seoul  Wrestling  Wrestling Free.             VARAEV, Adlan  URS    Men
#
#                           Event Event Gender   Medal
# 8475   eight with coxswain (8+)            M    Gold
# 8192               4x400m relay            M  Silver
# 18466  68 - 74kg (welterweight)            M  Silver

# %%
oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year         City     Sport Discipline                   Athlete Name  NOC Gender  \
# 23215  2000       Sydney  Aquatics   Swimming                  THELOKE, Stev  GER    Men
# 7447   1948       London   Sailing    Sailing  RODRIGUEZ DE LA TORRE, Rufino  ARG    Men
# 6078   1932  Los Angeles    Rowing     Rowing                BERESFORD, Jack  GBR    Men
#
#                             Event Event Gender   Medal
# 23215             100m backstroke            M  Bronze
# 7447                           6m            X  Silver
# 6078   four without coxswain (4-)            M    Gold

# %% [markdown]
# **Understand the basics of Python**

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
#  '_testing',
#  '_typing',
#  '_version',
#  'annotations',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'from_dummies',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'read_xml',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %%
[func.upper() for func in dir(pd)]
# Out:
# ['ARROWDTYPE',
#  'BOOLEANDTYPE',
#  'CATEGORICAL',
#  'CATEGORICALDTYPE',
#  'CATEGORICALINDEX',
#  'DATAFRAME',
#  'DATEOFFSET',
#  'DATETIMEINDEX',
#  'DATETIMETZDTYPE',
#  'EXCELFILE',
#  'EXCELWRITER',
#  'FLAGS',
#  'FLOAT32DTYPE',
#  'FLOAT64DTYPE',
#  'GROUPER',
#  'HDFSTORE',
#  'INDEX',
#  'INDEXSLICE',
#  'INT16DTYPE',
#  'INT32DTYPE',
#  'INT64DTYPE',
#  'INT8DTYPE',
#  'INTERVAL',
#  'INTERVALDTYPE',
#  'INTERVALINDEX',
#  'MULTIINDEX',
#  'NA',
#  'NAT',
#  'NAMEDAGG',
#  'PERIOD',
#  'PERIODDTYPE',
#  'PERIODINDEX',
#  'RANGEINDEX',
#  'SERIES',
#  'SPARSEDTYPE',
#  'STRINGDTYPE',
#  'TIMEDELTA',
#  'TIMEDELTAINDEX',
#  'TIMESTAMP',
#  'UINT16DTYPE',
#  'UINT32DTYPE',
#  'UINT64DTYPE',
#  'UINT8DTYPE',
#  '__ALL__',
#  '__BUILTINS__',
#  '__CACHED__',
#  '__DOC__',
#  '__DOCFORMAT__',
#  '__FILE__',
#  '__GIT_VERSION__',
#  '__LOADER__',
#  '__NAME__',
#  '__PACKAGE__',
#  '__PATH__',
#  '__SPEC__',
#  '__VERSION__',
#  '_CONFIG',
#  '_IS_NUMPY_DEV',
#  '_LIBS',
#  '_TESTING',
#  '_TYPING',
#  '_VERSION',
#  'ANNOTATIONS',
#  'API',
#  'ARRAY',
#  'ARRAYS',
#  'BDATE_RANGE',
#  'COMPAT',
#  'CONCAT',
#  'CORE',
#  'CROSSTAB',
#  'CUT',
#  'DATE_RANGE',
#  'DESCRIBE_OPTION',
#  'ERRORS',
#  'EVAL',
#  'FACTORIZE',
#  'FROM_DUMMIES',
#  'GET_DUMMIES',
#  'GET_OPTION',
#  'INFER_FREQ',
#  'INTERVAL_RANGE',
#  'IO',
#  'ISNA',
#  'ISNULL',
#  'JSON_NORMALIZE',
#  'LRESHAPE',
#  'MELT',
#  'MERGE',
#  'MERGE_ASOF',
#  'MERGE_ORDERED',
#  'NOTNA',
#  'NOTNULL',
#  'OFFSETS',
#  'OPTION_CONTEXT',
#  'OPTIONS',
#  'PANDAS',
#  'PERIOD_RANGE',
#  'PIVOT',
#  'PIVOT_TABLE',
#  'PLOTTING',
#  'QCUT',
#  'READ_CLIPBOARD',
#  'READ_CSV',
#  'READ_EXCEL',
#  'READ_FEATHER',
#  'READ_FWF',
#  'READ_GBQ',
#  'READ_HDF',
#  'READ_HTML',
#  'READ_JSON',
#  'READ_ORC',
#  'READ_PARQUET',
#  'READ_PICKLE',
#  'READ_SAS',
#  'READ_SPSS',
#  'READ_SQL',
#  'READ_SQL_QUERY',
#  'READ_SQL_TABLE',
#  'READ_STATA',
#  'READ_TABLE',
#  'READ_XML',
#  'RESET_OPTION',
#  'SET_ENG_FLOAT_FORMAT',
#  'SET_OPTION',
#  'SHOW_VERSIONS',
#  'TEST',
#  'TESTING',
#  'TIMEDELTA_RANGE',
#  'TO_DATETIME',
#  'TO_NUMERIC',
#  'TO_PICKLE',
#  'TO_TIMEDELTA',
#  'TSERIES',
#  'UNIQUE',
#  'UTIL',
#  'VALUE_COUNTS',
#  'WIDE_TO_LONG']

# %% [markdown]
# **Searching for method names**

# %%
import re
import pandas as pd

search_string = "excel"

[func for func in dir(pd) if re.search(rf"{search_string}", func, re.IGNORECASE)]
# Out:
# ['ExcelFile', 'ExcelWriter', 'read_excel']

# %%
pd.read_excel?

# %%
[func
 for func in dir(pd)
 if re.search(rf"{search_string}", func, re.IGNORECASE)]
# Out:
# ['ExcelFile', 'ExcelWriter', 'read_excel']

# %% [markdown]
# **Documentation while staying in the IDE**

# %%
pd.read_excel?

# %% [markdown]
# **head() vs. sample()**

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year     City      Sport       Discipline       Athlete Name  NOC Gender  \
# 10395  1960     Rome  Athletics        Athletics   ZSIVOTZKY, Gyula  HUN    Men
# 23655  2000   Sydney  Wrestling  Wrestling Gre-R  GLOUCHKOV, Alexei  RUS    Men
# 3676   1920  Antwerp    Archery          Archery   DE MAYER, Jérome  BEL    Men
#
#                               Event Event Gender   Medal
# 10395                  hammer throw            M  Silver
# 23655                     63 - 69kg            M  Bronze
# 3676   moving bird target 50m teams            M    Gold

# %% [markdown]
# **Functions to preprocess data. Modify the data, not the original files**

# %%
def preprocess(filename):
  """Transform the data. Change the dataframe and not the original csv files"""
  ...

preprocess(filename)

# %% [markdown]
# **Using python assert**

# %%
oo[(oo.Year < 1896) & (oo.Year > 2004)].shape
# Out:
# (0, 10)

# %%
oo[(oo.Year < 1896) & (oo.Year > 2004)].shape[0] == 0
# Out:
# True

# %%
assert(oo[(oo.Year < 1896) & (oo.Year > 2004)].shape[0] == 0)

# %%
assert(oo[(oo.Year < 1896) & (oo.Year > 2004)].shape[0] == 0)
print("All tests passed")
# Out:
# All tests passed

# %%
#assert(oo[(oo.Year < 1896) & (oo.Year > 2004)].shape[0] == (0, 10))
#print("All tests passed")

# %% [markdown]
# **Chaining and splitting over several rows. No inplace=True**

# %%
oo = pd.read_csv(filename, skiprows=5)
oo = oo.drop('Position', axis=1)
oo.head(3)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  Event Event Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men  100km            M
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men  100km            M
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men   100m            M
#
#     Medal
# 0    Gold
# 1  Silver
# 2  Bronze

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.head(3)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  Event Event Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men  100km            M
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men  100km            M
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men   100m            M
#
#     Medal
# 0    Gold
# 1  Silver
# 2  Bronze

# %%
last3 = pd.read_csv(filename, skiprows=5).sort_values(['Year', 'Athlete Name']).tail(3)
last3
# Out:
#        Year    City      Sport Discipline         Athlete Name  NOC Gender  \
# 26570  2004  Athens     Hockey     Hockey         ZWEHL, Julia  GER  Women
# 25440  2004  Athens   Aquatics   Swimming  ZWERING, Klaas-Erik  NED    Men
# 25587  2004  Athens  Athletics  Athletics       ZYKINA, Olesya  RUS  Women
#
#                         Event Event Gender   Medal  Position
# 26570                  hockey            W    Gold         1
# 25440  4x100m freestyle relay            M  Silver         2
# 25587            4x400m relay            W  Silver         2

# %%
last3 = (pd.read_csv(filename, skiprows=5)
        .sort_values(['Year', 'Athlete Name'])
        .tail(3)
)
last3
# Out:
#        Year    City      Sport Discipline         Athlete Name  NOC Gender  \
# 26570  2004  Athens     Hockey     Hockey         ZWEHL, Julia  GER  Women
# 25440  2004  Athens   Aquatics   Swimming  ZWERING, Klaas-Erik  NED    Men
# 25587  2004  Athens  Athletics  Athletics       ZYKINA, Olesya  RUS  Women
#
#                         Event Event Gender   Medal  Position
# 26570                  hockey            W    Gold         1
# 25440  4x100m freestyle relay            M  Silver         2
# 25587            4x400m relay            W  Silver         2

# %%
last3 = (pd.read_csv(filename, skiprows=5)
#        .sort_values(['Year', 'Athlete Name'])
        .tail(3)
)
last3
# Out:
#        Year    City    Sport Discipline       Athlete Name  NOC Gender      Event Event Gender  \
# 27171  2004  Athens  Fencing    Fencing     BOKEL, Claudia  GER  Women  épée team            W
# 27172  2004  Athens  Fencing    Fencing    DUPLITZER, Imke  GER  Women  épée team            W
# 27173  2004  Athens  Fencing    Fencing  HEIDEMANN, Britta  GER  Women  épée team            W
#
#         Medal  Position
# 27171  Silver         2
# 27172  Silver         2
# 27173  Silver         2

# %% [markdown]
# **isin()**

# %%
oo.Year.isin?

# %%
years_of_interest = [1972, 1980, 1984, 1992, 2000, 2004]

# %%
oo[oo.Year.isin(years_of_interest)]
# Out:
#        Year    City      Sport       Discipline            Athlete Name  NOC Gender  \
# 12715  1972  Munich  Wrestling  Wrestling Free.  TAYLOR, Christopher J.  USA    Men
# 12716  1972  Munich  Wrestling  Wrestling Free.       MEDVED, Aleksandr  URS    Men
# 12717  1972  Munich  Wrestling  Wrestling Free.         DURALIEV, Osman  BUL    Men
# 12718  1972  Munich  Wrestling  Wrestling Gre-R       DOLIPSCHI, Victor  ROU    Men
# 12719  1972  Munich  Wrestling  Wrestling Gre-R       ROSHCHIN, Anatoli  URS    Men
# ...     ...     ...        ...              ...                     ...  ...    ...
# 27169  2004  Athens    Fencing          Fencing      LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing          Fencing           SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing          Fencing          BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing          Fencing         DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing          Fencing       HEIDEMANN, Britta  GER  Women
#
#                              Event Event Gender   Medal
# 12715  + 100kg (super heavyweight)            M  Bronze
# 12716  + 100kg (super heavyweight)            M    Gold
# 12717  + 100kg (super heavyweight)            M  Silver
# 12718  + 100kg (super heavyweight)            M  Bronze
# 12719  + 100kg (super heavyweight)            M    Gold
# ...                            ...          ...     ...
# 27169                    épée team            W    Gold
# 27170                    épée team            W    Gold
# 27171                    épée team            W  Silver
# 27172                    épée team            W  Silver
# 27173                    épée team            W  Silver
#
# [9749 rows x 10 columns]

# %%
oo[~oo.Year.isin(years_of_interest)]
# Out:
#        Year     City      Sport     Discipline            Athlete Name  NOC Gender      Event  \
# 0      1896   Athens    Cycling  Cycling Track           FLAMENG, Léon  FRA    Men      100km
# 1      1896   Athens    Cycling  Cycling Track      KOLETTIS, Georgios  GRE    Men      100km
# 2      1896   Athens  Athletics      Athletics           LANE, Francis  USA    Men       100m
# 3      1896   Athens  Athletics      Athletics        SZOKOLYI, Alajos  HUN    Men       100m
# 4      1896   Athens  Athletics      Athletics           BURKE, Thomas  USA    Men       100m
# ...     ...      ...        ...            ...                     ...  ...    ...        ...
# 23156  1996  Atlanta    Fencing        Fencing  FLESSEL-COLOVIC, Laura  FRA  Women  épée team
# 23157  1996  Atlanta    Fencing        Fencing  MORESEE-PICHOT, Sophie  FRA  Women  épée team
# 23158  1996  Atlanta    Fencing        Fencing           CHIESA, Laura  ITA  Women  épée team
# 23159  1996  Atlanta    Fencing        Fencing              UGA, Elisa  ITA  Women  épée team
# 23160  1996  Atlanta    Fencing        Fencing     ZALAFFI, Margherita  ITA  Women  épée team
#
#       Event Gender   Medal
# 0                M    Gold
# 1                M  Silver
# 2                M  Bronze
# 3                M  Bronze
# 4                M    Gold
# ...            ...     ...
# 23156            W    Gold
# 23157            W    Gold
# 23158            W  Silver
# 23159            W  Silver
# 23160            W  Silver
#
# [17425 rows x 10 columns]

# %% [markdown]
# **Finding and dealing with missing values**

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27174 entries, 0 to 27173
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          27174 non-null  int64
#  1   City          27174 non-null  object
#  2   Sport         27174 non-null  object
#  3   Discipline    27174 non-null  object
#  4   Athlete Name  27174 non-null  object
#  5   NOC           27174 non-null  object
#  6   Gender        27174 non-null  object
#  7   Event         27174 non-null  object
#  8   Event Gender  27174 non-null  object
#  9   Medal         27174 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.1+ MB

# %% [markdown]
# ## Creating Series and DataFrames

# %%
import pandas as pd

# %%
city = ["London", "Rio", "Tokyo"]
start_date = ["27th Jul, 2012", "5th Aug, 2016", "23rd July, 2021"]

# %%
pd.Series(city)
# Out:
# 0    London
# 1       Rio
# 2     Tokyo
# dtype: object

# %%
pd.DataFrame({"City": pd.Series(city),
              "Start Date": pd.Series(start_date)})
# Out:
#      City       Start Date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
pd.DataFrame({"City": city,
              "Start Date": start_date})
# Out:
#      City       Start Date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
pd.DataFrame(zip(city, start_date))
# Out:
#         0                1
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
pd.DataFrame(zip(city, start_date), columns=["City", "Start Date"])
# Out:
#      City       Start Date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %% [markdown]
# ## Working with dates

# %%
import pandas as pd

# %%
city = ["London", "Rio", "Tokyo"]
start_date = ["07-27-2012", "5th Aug, 2016", "23rd Jul, 2021"]
end_date = ["12th Aug, 2012", "21-08-2016", "8th Aug, 2021"]

# %%
games = pd.DataFrame(zip(city, start_date, end_date), columns=["City", "Start Date", "End Date"])
games
# Out:
#      City      Start Date        End Date
# 0  London      07-27-2012  12th Aug, 2012
# 1     Rio   5th Aug, 2016      21-08-2016
# 2   Tokyo  23rd Jul, 2021   8th Aug, 2021

# %%
games.dtypes
# Out:
# City          object
# Start Date    object
# End Date      object
# dtype: object

# %%
import re
import pandas as pd

search_string = "date"

[func for func in dir(pd) if re.search(rf"{search_string}", func, re.IGNORECASE)]
# Out:
# ['DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'bdate_range',
#  'date_range',
#  'to_datetime']

# %%
pd.to_datetime?

# %%
#pd.to_datetime(games["Start Date"])

# %%
pd.to_datetime(games["Start Date"], format='mixed')
# Out:
# 0   2012-07-27
# 1   2016-08-05
# 2   2021-07-23
# Name: Start Date, dtype: datetime64[ns]

# %%
games["Start Date"] = pd.to_datetime(games["Start Date"], format='mixed')
games["End Date"] = pd.to_datetime(games["End Date"], format='mixed')
games["City"] = games.City.astype("string")
games
# Out:
#      City Start Date   End Date
# 0  London 2012-07-27 2012-08-12
# 1     Rio 2016-08-05 2016-08-21
# 2   Tokyo 2021-07-23 2021-08-08

# %%
games.dtypes
# Out:
# City          string[python]
# Start Date    datetime64[ns]
# End Date      datetime64[ns]
# dtype: object

# %%
games["End Date"]
# Out:
# 0   2012-08-12
# 1   2016-08-21
# 2   2021-08-08
# Name: End Date, dtype: datetime64[ns]

# %%
games["Start Date"]
# Out:
# 0   2012-07-27
# 1   2016-08-05
# 2   2021-07-23
# Name: Start Date, dtype: datetime64[ns]

# %%
games["End Date"] - games["Start Date"]
# Out:
# 0   16 days
# 1   16 days
# 2   16 days
# dtype: timedelta64[ns]

# %%
games = games.assign(duration=games["End Date"] - games["Start Date"])
games
# Out:
#      City Start Date   End Date duration
# 0  London 2012-07-27 2012-08-12  16 days
# 1     Rio 2016-08-05 2016-08-21  16 days
# 2   Tokyo 2021-07-23 2021-08-08  16 days

# %%
games.dtypes
# Out:
# City           string[python]
# Start Date     datetime64[ns]
# End Date       datetime64[ns]
# duration      timedelta64[ns]
# dtype: object

# %% [markdown]
# ## Combining DataFrames

# %%
import pandas as pd

# %%
start = pd.DataFrame({"city": ["London", "Rio", "Tokyo"],
                      "start_date": ["27th Jul, 2012", "5th Aug, 2016", "23rd July, 2021"]})
start
# Out:
#      city       start_date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
end = pd.DataFrame({"City": ["London", "Tokyo", "Paris"],
                    "end_date": ["12th Aug, 2012", "8th Aug, 2021", "11th Aug, 2024"]})
end
# Out:
#      City        end_date
# 0  London  12th Aug, 2012
# 1   Tokyo   8th Aug, 2021
# 2   Paris  11th Aug, 2024

# %%
pd.concat?

# %%
pd.concat([start, end], axis=0)
# Out:
#      city       start_date    City        end_date
# 0  London   27th Jul, 2012     NaN             NaN
# 1     Rio    5th Aug, 2016     NaN             NaN
# 2   Tokyo  23rd July, 2021     NaN             NaN
# 0     NaN              NaN  London  12th Aug, 2012
# 1     NaN              NaN   Tokyo   8th Aug, 2021
# 2     NaN              NaN   Paris  11th Aug, 2024

# %%
end = pd.DataFrame({"city": ["London", "Tokyo", "Paris"],
                    "end_date": ["12th Aug, 2012", "8th Aug, 2021", "11th Aug, 2024"]})
end
# Out:
#      city        end_date
# 0  London  12th Aug, 2012
# 1   Tokyo   8th Aug, 2021
# 2   Paris  11th Aug, 2024

# %%
pd.concat([start, end], axis=0)
# Out:
#      city       start_date        end_date
# 0  London   27th Jul, 2012             NaN
# 1     Rio    5th Aug, 2016             NaN
# 2   Tokyo  23rd July, 2021             NaN
# 0  London              NaN  12th Aug, 2012
# 1   Tokyo              NaN   8th Aug, 2021
# 2   Paris              NaN  11th Aug, 2024

# %%
pd.concat([start, end], axis=1)
# Out:
#      city       start_date    city        end_date
# 0  London   27th Jul, 2012  London  12th Aug, 2012
# 1     Rio    5th Aug, 2016   Tokyo   8th Aug, 2021
# 2   Tokyo  23rd July, 2021   Paris  11th Aug, 2024

# %% [markdown]
# **Inner join**

# %%
start
# Out:
#      city       start_date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
end
# Out:
#      city        end_date
# 0  London  12th Aug, 2012
# 1   Tokyo   8th Aug, 2021
# 2   Paris  11th Aug, 2024

# %%
pd.merge?

# %%
pd.merge(left=start, right=end, on="city", how="inner")
# Out:
#      city       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1   Tokyo  23rd July, 2021   8th Aug, 2021

# %% [markdown]
# **Outer join**

# %%
start
# Out:
#      city       start_date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
end
# Out:
#      city        end_date
# 0  London  12th Aug, 2012
# 1   Tokyo   8th Aug, 2021
# 2   Paris  11th Aug, 2024

# %%
pd.merge(left=start, right=end, on="city", how="outer")
# Out:
#      city       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1     Rio    5th Aug, 2016             NaN
# 2   Tokyo  23rd July, 2021   8th Aug, 2021
# 3   Paris              NaN  11th Aug, 2024

# %% [markdown]
# **Left join**

# %%
start
# Out:
#      city       start_date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
pd.merge(left=start, right=end, on="city", how="left")
# Out:
#      city       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1     Rio    5th Aug, 2016             NaN
# 2   Tokyo  23rd July, 2021   8th Aug, 2021

# %% [markdown]
# **Right join**

# %%
end
# Out:
#      city        end_date
# 0  London  12th Aug, 2012
# 1   Tokyo   8th Aug, 2021
# 2   Paris  11th Aug, 2024

# %%
pd.merge(left=start, right=end, on="city", how="right")
# Out:
#      city       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1   Tokyo  23rd July, 2021   8th Aug, 2021
# 2   Paris              NaN  11th Aug, 2024

# %% [markdown]
# ## Combining Datasets

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

preprocess()
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender      Event  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men      100km
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men      100km
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men       100m
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men       100m
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men       100m
# ...     ...     ...        ...            ...                 ...  ...    ...        ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women  épée team
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women  épée team
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women  épée team
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women  épée team
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women  épée team
#
#       Event Gender   Medal
# 0                M    Gold
# 1                M  Silver
# 2                M  Bronze
# 3                M  Bronze
# 4                M    Gold
# ...            ...     ...
# 27169            W    Gold
# 27170            W    Gold
# 27171            W  Silver
# 27172            W  Silver
# 27173            W  Silver
#
# [27174 rows x 10 columns]

# %%
oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year    City       Sport       Discipline        Athlete Name  NOC Gender  \
# 569    1900   Paris       Rugby            Rugby  STOCKHAUSEN, Adolf  GER    Men
# 12518  1968  Mexico  Equestrian          Jumping  ELDER, Henry James  CAN    Men
# 15228  1980  Moscow   Wrestling  Wrestling Free.       JANG, Se Hong  PRK    Men
#
#                           Event Event Gender   Medal
# 569                       rugby            M  Silver
# 12518                      team            X    Gold
# 15228  - 48kg (light-flyweight)            M  Silver

# %%
# !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv
# Out:
# --2025-06-15 02:14:27--  https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/jonfernandes/pandas_essential/main/olympics_2008.csv [following]
# --2025-06-15 02:14:27--  https://raw.githubusercontent.com/jonfernandes/pandas_essential/main/olympics_2008.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 174220 (170K) [text/plain]
# Saving to: ‘olympics_2008.csv’
#
# olympics_2008.csv   100%[===================>] 170.14K  --.-KB/s    in 0.03s
#
# 2025-06-15 02:14:28 (5.26 MB/s) - ‘olympics_2008.csv’ saved [174220/174220]

# %%
new_filename =  "olympics_2008.csv"
nw = pd.read_csv(new_filename)
nw.head(5)
# Out:
#       city  edition     sport discipline           athlete country_code gender         event  \
# 0  Beijing   2008.0  aquatics     Diving    GALPERIN, Gleb          RUS    Men  10m platform
# 1  Beijing   2008.0  aquatics     Diving  MITCHAM, Matthew          AUS    Men  10m platform
# 2  Beijing   2008.0  aquatics     Diving       ZHOU, Luxin          CHN    Men  10m platform
# 3  Beijing   2008.0  aquatics     Diving         WANG, Xin          CHN  Women  10m platform
# 4  Beijing   2008.0  aquatics     Diving      CHEN, Ruolin          CHN  Women  10m platform
#
#   event_gender   medal  result
# 0            M  bronze     3.0
# 1            M    gold     1.0
# 2            M  silver     2.0
# 3            W  bronze     3.0
# 4            W    gold     1.0

# %%
oo.sample(3)
# Out:
#        Year    City       Sport   Discipline           Athlete Name  NOC Gender  \
# 16459  1980  Moscow  Gymnastics  Artistic G.        FILATOVA, Maria  URS  Women
# 25559  2004  Athens   Athletics    Athletics     UDO OBONG, Enefiok  NGR    Men
# 13301  1972  Munich      Rowing       Rowing  DICKIE, Simon Charles  NZL    Men
#
#                           Event Event Gender   Medal
# 16459               uneven bars            W  Bronze
# 25559              4x400m relay            M  Bronze
# 13301  eight with coxswain (8+)            M    Gold

# %%
pd.concat([oo, nw], axis=0)
# Out:
#         Year    City      Sport     Discipline        Athlete Name   NOC Gender  Event  \
# 0     1896.0  Athens    Cycling  Cycling Track       FLAMENG, Léon   FRA    Men  100km
# 1     1896.0  Athens    Cycling  Cycling Track  KOLETTIS, Georgios   GRE    Men  100km
# 2     1896.0  Athens  Athletics      Athletics       LANE, Francis   USA    Men   100m
# 3     1896.0  Athens  Athletics      Athletics    SZOKOLYI, Alajos   HUN    Men   100m
# 4     1896.0  Athens  Athletics      Athletics       BURKE, Thomas   USA    Men   100m
# ...      ...     ...        ...            ...                 ...   ...    ...    ...
# 2054     NaN    <NA>       <NA>           <NA>                <NA>  <NA>    NaN   <NA>
# 2055     NaN    <NA>       <NA>           <NA>                <NA>  <NA>    NaN   <NA>
# 2056     NaN    <NA>       <NA>           <NA>                <NA>  <NA>    NaN   <NA>
# 2057     NaN    <NA>       <NA>           <NA>                <NA>  <NA>    NaN   <NA>
# 2058     NaN    <NA>       <NA>           <NA>                <NA>  <NA>    NaN   <NA>
#
#      Event Gender   Medal  ... edition      sport       discipline         athlete country_code  \
# 0               M    Gold  ...     NaN        NaN              NaN             NaN          NaN
# 1               M  Silver  ...     NaN        NaN              NaN             NaN          NaN
# 2               M  Bronze  ...     NaN        NaN              NaN             NaN          NaN
# 3               M  Bronze  ...     NaN        NaN              NaN             NaN          NaN
# 4               M    Gold  ...     NaN        NaN              NaN             NaN          NaN
# ...           ...     ...  ...     ...        ...              ...             ...          ...
# 2054          NaN     NaN  ...  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan          RUS
# 2055          NaN     NaN  ...  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan          RUS
# 2056          NaN     NaN  ...  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan          RUS
# 2057          NaN     NaN  ...  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan          RUS
# 2058          NaN     NaN  ...  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan          RUS
#
#      gender       event event_gender   medal result
# 0       NaN         NaN          NaN     NaN    NaN
# 1       NaN         NaN          NaN     NaN    NaN
# 2       NaN         NaN          NaN     NaN    NaN
# 3       NaN         NaN          NaN     NaN    NaN
# 4       NaN         NaN          NaN     NaN    NaN
# ...     ...         ...          ...     ...    ...
# 2054    Men  96 - 120kg            M  silver    2.0
# 2055    Men  96 - 120kg            M  silver    2.0
# 2056    Men  96 - 120kg            M  silver    2.0
# 2057    Men  96 - 120kg            M  silver    2.0
# 2058    Men  96 - 120kg            M  silver    2.0
#
# [29233 rows x 21 columns]

# %%
nw.columns
# Out:
# Index(['city', 'edition', 'sport', 'discipline', 'athlete', 'country_code', 'gender', 'event',
#        'event_gender', 'medal', 'result'],
#       dtype='object')

# %%
oo.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender', 'Event',
#        'Event Gender', 'Medal'],
#       dtype='object')

# %%
nw.columns = ['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code',
       'Gender', 'Event', 'Event_gender', 'Medal', 'Result']
nw.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code', 'Gender', 'Event',
#        'Event_gender', 'Medal', 'Result'],
#       dtype='object')

# %%
new_columns = ['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code',
       'Gender', 'Event', 'Event_gender', 'Medal', 'Result']

# %%
nw = pd.read_csv(new_filename, names=new_columns)
nw.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code', 'Gender', 'Event',
#        'Event_gender', 'Medal', 'Result'],
#       dtype='object')

# %%
nw.columns = [column.capitalize() for column in nw.columns]
nw.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code', 'Gender', 'Event',
#        'Event_gender', 'Medal', 'Result'],
#       dtype='object')

# %%
pd.concat([oo, nw], axis=0)
# Out:
#         Year     City      Sport       Discipline        Athlete Name   NOC Gender       Event  \
# 0     1896.0   Athens    Cycling    Cycling Track       FLAMENG, Léon   FRA    Men       100km
# 1     1896.0   Athens    Cycling    Cycling Track  KOLETTIS, Georgios   GRE    Men       100km
# 2     1896.0   Athens  Athletics        Athletics       LANE, Francis   USA    Men        100m
# 3     1896.0   Athens  Athletics        Athletics    SZOKOLYI, Alajos   HUN    Men        100m
# 4     1896.0   Athens  Athletics        Athletics       BURKE, Thomas   USA    Men        100m
# ...      ...      ...        ...              ...                 ...   ...    ...         ...
# 2055     NaN  Beijing  wrestling  Wrestling Gre-R                <NA>  <NA>    Men  96 - 120kg
# 2056     NaN  Beijing  wrestling  Wrestling Gre-R                <NA>  <NA>    Men  96 - 120kg
# 2057     NaN  Beijing  wrestling  Wrestling Gre-R                <NA>  <NA>    Men  96 - 120kg
# 2058     NaN  Beijing  wrestling  Wrestling Gre-R                <NA>  <NA>    Men  96 - 120kg
# 2059     NaN  Beijing  wrestling  Wrestling Gre-R                <NA>  <NA>    Men  96 - 120kg
#
#      Event Gender   Medal Edition         Athlete Country_code Event_gender Result
# 0               M    Gold     NaN             NaN          NaN          NaN    NaN
# 1               M  Silver     NaN             NaN          NaN          NaN    NaN
# 2               M  Bronze     NaN             NaN          NaN          NaN    NaN
# 3               M  Bronze     NaN             NaN          NaN          NaN    NaN
# 4               M    Gold     NaN             NaN          NaN          NaN    NaN
# ...           ...     ...     ...             ...          ...          ...    ...
# 2055          NaN  silver    2008  BAROEV, Khasan          RUS            M      2
# 2056          NaN  silver    2008  BAROEV, Khasan          RUS            M      2
# 2057          NaN  silver    2008  BAROEV, Khasan          RUS            M      2
# 2058          NaN  silver    2008  BAROEV, Khasan          RUS            M      2
# 2059          NaN  silver    2008  BAROEV, Khasan          RUS            M      2
#
# [29234 rows x 15 columns]

# %%
oo.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender', 'Event',
#        'Event Gender', 'Medal'],
#       dtype='object')

# %%
nw.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code', 'Gender', 'Event',
#        'Event_gender', 'Medal', 'Result'],
#       dtype='object')

# %%
nw.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']

# %%
pd.concat([oo, nw], axis=0)
# Out:
#       Year     City      Sport       Discipline        Athlete Name  NOC Gender       Event  \
# 0     1896   Athens    Cycling    Cycling Track       FLAMENG, Léon  FRA    Men       100km
# 1     1896   Athens    Cycling    Cycling Track  KOLETTIS, Georgios  GRE    Men       100km
# 2     1896   Athens  Athletics        Athletics       LANE, Francis  USA    Men        100m
# 3     1896   Athens  Athletics        Athletics    SZOKOLYI, Alajos  HUN    Men        100m
# 4     1896   Athens  Athletics        Athletics       BURKE, Thomas  USA    Men        100m
# ...    ...      ...        ...              ...                 ...  ...    ...         ...
# 2055  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS    Men  96 - 120kg
# 2056  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS    Men  96 - 120kg
# 2057  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS    Men  96 - 120kg
# 2058  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS    Men  96 - 120kg
# 2059  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS    Men  96 - 120kg
#
#      Event Gender   Medal Result
# 0               M    Gold    NaN
# 1               M  Silver    NaN
# 2               M  Bronze    NaN
# 3               M  Bronze    NaN
# 4               M    Gold    NaN
# ...           ...     ...    ...
# 2055            M  silver      2
# 2056            M  silver      2
# 2057            M  silver      2
# 2058            M  silver      2
# 2059            M  silver      2
#
# [29234 rows x 11 columns]

# %%
nw.Result.unique()
# Out:
# array(['result', '3', '1', '2', nan], dtype=object)

# %%
nw = nw.drop("Result", axis=1)
nw.sample(3)
# Out:
#          City  Year      Sport Discipline        Athlete Name  NOC Gender       Event  \
# 544   Beijing  2008  athletics  Athletics  LUKYANENKO, Evgeny  RUS    Men  pole vault
# 1033  Beijing  2008    fencing    Fencing            TAN, Xue  CHN  Women  sabre team
# 549   Beijing  2008  athletics  Athletics    MAJEWSKI, Tomasz  POL    Men    shot put
#
#      Event Gender   Medal
# 544             M  silver
# 1033            W  silver
# 549             M    gold

# %%
pd.concat([oo, nw], axis=0)
# Out:
#       Year     City      Sport       Discipline        Athlete Name  NOC Gender       Event  \
# 0     1896   Athens    Cycling    Cycling Track       FLAMENG, Léon  FRA    Men       100km
# 1     1896   Athens    Cycling    Cycling Track  KOLETTIS, Georgios  GRE    Men       100km
# 2     1896   Athens  Athletics        Athletics       LANE, Francis  USA    Men        100m
# 3     1896   Athens  Athletics        Athletics    SZOKOLYI, Alajos  HUN    Men        100m
# 4     1896   Athens  Athletics        Athletics       BURKE, Thomas  USA    Men        100m
# ...    ...      ...        ...              ...                 ...  ...    ...         ...
# 2055  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS    Men  96 - 120kg
# 2056  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS    Men  96 - 120kg
# 2057  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS    Men  96 - 120kg
# 2058  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS    Men  96 - 120kg
# 2059  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS    Men  96 - 120kg
#
#      Event Gender   Medal
# 0               M    Gold
# 1               M  Silver
# 2               M  Bronze
# 3               M  Bronze
# 4               M    Gold
# ...           ...     ...
# 2055            M  silver
# 2056            M  silver
# 2057            M  silver
# 2058            M  silver
# 2059            M  silver
#
# [29234 rows x 10 columns]

# %%
pd.concat([oo, nw], axis=0).dtypes
# Out:
# Year            object
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# dtype: object

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year       Sport       Discipline     Athlete Name  NOC Gender        Event  \
# 2004  Beijing  2008.0   wrestling  Wrestling Free.   SAHIN, Ramazan  TUR    Men    60 - 66kg
# 887   Beijing  2008.0     cycling    Cycling Track    NEWTON, Chris  GBR    Men  Points Race
# 1239  Beijing  2008.0  gymnastics       Trampoline  COCKBURN, Karen  CAN  Women   individual
#
#      Event Gender   Medal
# 2004            M    gold
# 887             M  bronze
# 1239            W  silver

# %% [markdown]
# ## Working with Missing Data

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year     Sport Discipline          Athlete Name  NOC Gender  \
# 1630  Beijing  2008.0   sailing    Sailing  CHARBONNIER, Nicolas  FRA    Men
# 50    Beijing  2008.0  aquatics   Swimming       PHELPS, Michael  USA    Men
# 112   Beijing  2008.0  aquatics   Swimming          CSEH, Laszlo  HUN    Men
#
#                         Event Event Gender   Medal
# 1630  470 - Two Person Dinghy            M  bronze
# 50             100m butterfly            M    gold
# 112    400m individual medley            M  silver

# %%
nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2033 non-null   object
#  1   Year          2025 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 161.0+ KB

# %%
import re

search_string = "na"

[func for func in dir(nw.City) if re.search(rf"{search_string}$", func, re.IGNORECASE)]
# Out:
# ['_can_hold_na', 'dropna', 'fillna', 'isna', 'notna']

# %%
nw.City.isna?

# %%
nw.City.isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2054    False
# 2055    False
# 2056    False
# 2057    False
# 2058    False
# Name: City, Length: 2059, dtype: bool

# %%
nw.City.isna().sum()
# Out:
# 26

# %%
nw[nw.City.isna()]
# Out:
#      City    Year          Sport       Discipline                    Athlete Name  NOC Gender  \
# 17    NaN  2008.0       aquatics           Diving                   KLEIN, Sascha  GER    Men
# 25    NaN  2008.0       aquatics           Diving               PRYGOROV, Oleksiy  UKR    Men
# 83    NaN  2008.0       aquatics         Swimming                NORDENSTAM, Sara  NOR  Women
# 133   NaN  2008.0       aquatics         Swimming                 MALLET, Gregory  FRA    Men
# 199   NaN  2008.0       aquatics         Swimming                   KELLER, Klete  USA    Men
# 364   NaN  2008.0        archery          Archery                      JIANG, Lin  CHN    Men
# 372   NaN  2008.0        archery          Archery                  NESPOLI, Mauro  ITA    Men
# 531   NaN  2008.0      athletics        Athletics                 MOKOENA, Khotso  RSA    Men
# 640   NaN  2008.0       baseball         Baseball                MARTINEZ, Jonder  CUB    Men
# 660   NaN  2008.0     basketball       Basketball  KAMMERICHS, Guillermo Federico  ARG    Men
# 701   NaN  2008.0     basketball       Basketball                STEPANOVA, Maria  RUS  Women
# 785   NaN  2008.0  canoe / kayak  Canoe / Kayak F                 MENG, Guanliang  CHN    Men
# 895   NaN  2008.0        cycling    Cycling Track                    MEARES, Anna  AUS  Women
# 938   NaN  2008.0     equestrian         Eventing                ROMEIKE, Hinrich  GER    Men
# 1036  NaN  2008.0       football         Football                           BRENO  BRA    Men
# 1183  NaN  2008.0     gymnastics      Artistic G.                  SAKAMOTO, Koki  JPN    Men
# 1411  NaN  2008.0         hockey           Hockey                      GAO, Lihua  CHN  Women
# 1505  NaN  2008.0         rowing           Rowing                 COPPOLA, Steven  USA    Men
# 1515  NaN  2008.0         rowing           Rowing                     KREEK, Adam  CAN    Men
# 1690  NaN  2008.0       shooting         Shooting                EMMONS, Katerina  CZE  Women
# 1700  NaN  2008.0       shooting         Shooting                  SCHUMANN, Ralf  GER    Men
# 1819  NaN  2008.0      taekwondo        Taekwondo                HWANG, Kyung Sun  KOR  Women
# 1845  NaN  2008.0         tennis           Tennis               DEMENTIEVA, Elena  RUS  Women
# 1853  NaN  2008.0     volleyball    Beach volley.                   REGO, Emanuel  BRA    Men
# 1913  NaN     NaN     volleyball       Volleyball           ALBUQUERQUE, Carolina  BRA  Women
# 1995  NaN  2008.0      wrestling  Wrestling Free.                 YUMOTO, Kenichi  JPN    Men
#
#                                    Event Event Gender   Medal
# 17      synchronized diving 10m platform            M  silver
# 25    synchronized diving 3m springboard            M  bronze
# 83                     200m breaststroke            W  bronze
# 133               4x100m freestyle relay            M  silver
# 199               4x200m freestyle relay            M    gold
# 364      team (FITA Olympic round - 70m)            M  bronze
# 372      team (FITA Olympic round - 70m)            M  silver
# 531                            long jump            M  silver
# 640                             baseball            M  silver
# 660                           basketball            M  bronze
# 701                           basketball            W  bronze
# 785              C-2 500m (canoe double)            M    gold
# 895                               sprint            W  silver
# 938                           individual            X    gold
# 1036                            football            M  bronze
# 1183                    team competition            M  silver
# 1411                              hockey            W  silver
# 1505            eight with coxswain (8+)            M  bronze
# 1515            eight with coxswain (8+)            M    gold
# 1690            10m air rifle (40 shots)            W    gold
# 1700    25m rapid fire pistol (60 shots)            M  silver
# 1819                          57 - 67 kg            W    gold
# 1845                             singles            W    gold
# 1853                    beach volleyball            M  bronze
# 1913                          volleyball            W    gold
# 1995                           55 - 60kg            M  bronze

# %%
nw.City.unique()
# Out:
# array(['Beijing', nan], dtype=object)

# %%
nw.shape
# Out:
# (2059, 10)

# %%
import re

search_string = "na"

[func for func in dir(nw.City) if re.search(rf"{search_string}$", func, re.IGNORECASE)]
# Out:
# ['_can_hold_na', 'dropna', 'fillna', 'isna', 'notna']

# %%
nw.City.fillna?

# %%
nw.City = nw.City.fillna(value="Beijing")
nw.City.unique()
# Out:
# array(['Beijing'], dtype=object)

# %%
nw.Year
# Out:
# 0       2008.0
# 1       2008.0
# 2       2008.0
# 3       2008.0
# 4       2008.0
#          ...
# 2054    2008.0
# 2055    2008.0
# 2056    2008.0
# 2057    2008.0
# 2058    2008.0
# Name: Year, Length: 2059, dtype: float64

# %%
nw.Year.unique()
# Out:
# array([2008.,   nan])

# %%
nw.Year = nw.Year.fillna(value=2008)
nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2059 non-null   object
#  1   Year          2059 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 161.0+ KB

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year          Sport     Discipline     Athlete Name  NOC Gender  \
# 1949  Beijing  2008.0  weightlifting  Weightlifting   CHEN, Wei-Ling  TPE  Women
# 1114  Beijing  2008.0       football       Football     LLOYD, Carli  USA  Women
# 80    Beijing  2008.0       aquatics       Swimming  DUBOSCQ, Hugues  FRA    Men
#
#                   Event Event Gender   Medal
# 1949               48kg            W  bronze
# 1114           football            W    gold
# 80    200m breaststroke            M  bronze

# %%
nw.dtypes
# Out:
# City             object
# Year            float64
# Sport            object
# Discipline       object
# Athlete Name     object
# NOC              object
# Gender           object
# Event            object
# Event Gender     object
# Medal            object
# dtype: object

# %% [markdown]
# ## Removing Missing Data

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year     Sport Discipline        Athlete Name  NOC Gender                Event  \
# 1281  Beijing  2008.0  handball   Handball  SIGURDSSON, Sigfus  ISL    Men             handball
# 173   Beijing  2008.0  aquatics   Swimming             SUN, Ye  CHN  Women  4x100m medley relay
# 1304  Beijing  2008.0  handball   Handball       LARSEN, Tonje  NOR  Women             handball
#
#      Event Gender   Medal
# 1281            M  silver
# 173             W  bronze
# 1304            W    gold

# %%
nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2059 non-null   object
#  1   Year          2059 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 161.0+ KB

# %%
nw[nw.Sport.isna()]
# Out:
#         City    Year Sport Discipline Athlete Name  NOC Gender Event Event Gender Medal
# 62   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 63   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 64   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 65   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 66   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 67   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 68   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 69   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 70   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 220  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 221  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN

# %%
nw.dropna(how="all", axis=0)
# Out:
#          City    Year      Sport       Discipline      Athlete Name  NOC Gender         Event  \
# 0     Beijing  2008.0   aquatics           Diving    GALPERIN, Gleb  RUS    Men  10m platform
# 1     Beijing  2008.0   aquatics           Diving  MITCHAM, Matthew  AUS    Men  10m platform
# 2     Beijing  2008.0   aquatics           Diving       ZHOU, Luxin  CHN    Men  10m platform
# 3     Beijing  2008.0   aquatics           Diving         WANG, Xin  CHN  Women  10m platform
# 4     Beijing  2008.0   aquatics           Diving      CHEN, Ruolin  CHN  Women  10m platform
# ...       ...     ...        ...              ...               ...  ...    ...           ...
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
#
#      Event Gender   Medal
# 0               M  bronze
# 1               M    gold
# 2               M  silver
# 3               W  bronze
# 4               W    gold
# ...           ...     ...
# 2054            M  silver
# 2055            M  silver
# 2056            M  silver
# 2057            M  silver
# 2058            M  silver
#
# [2059 rows x 10 columns]

# %%
nw.dropna(how="any", axis=0)
# Out:
#          City    Year      Sport       Discipline      Athlete Name  NOC Gender         Event  \
# 0     Beijing  2008.0   aquatics           Diving    GALPERIN, Gleb  RUS    Men  10m platform
# 1     Beijing  2008.0   aquatics           Diving  MITCHAM, Matthew  AUS    Men  10m platform
# 2     Beijing  2008.0   aquatics           Diving       ZHOU, Luxin  CHN    Men  10m platform
# 3     Beijing  2008.0   aquatics           Diving         WANG, Xin  CHN  Women  10m platform
# 4     Beijing  2008.0   aquatics           Diving      CHEN, Ruolin  CHN  Women  10m platform
# ...       ...     ...        ...              ...               ...  ...    ...           ...
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
#
#      Event Gender   Medal
# 0               M  bronze
# 1               M    gold
# 2               M  silver
# 3               W  bronze
# 4               W    gold
# ...           ...     ...
# 2054            M  silver
# 2055            M  silver
# 2056            M  silver
# 2057            M  silver
# 2058            M  silver
#
# [2048 rows x 10 columns]

# %%
nw[nw.Sport.isna()]
# Out:
#         City    Year Sport Discipline Athlete Name  NOC Gender Event Event Gender Medal
# 62   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 63   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 64   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 65   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 66   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 67   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 68   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 69   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 70   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 220  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN
# 221  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN          NaN   NaN

# %%
nw.dropna?

# %%
nw.columns
# Out:
# Index(['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender', 'Event',
#        'Event Gender', 'Medal'],
#       dtype='object')

# %%
nw.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
# Out:
#          City    Year      Sport       Discipline      Athlete Name  NOC Gender         Event  \
# 0     Beijing  2008.0   aquatics           Diving    GALPERIN, Gleb  RUS    Men  10m platform
# 1     Beijing  2008.0   aquatics           Diving  MITCHAM, Matthew  AUS    Men  10m platform
# 2     Beijing  2008.0   aquatics           Diving       ZHOU, Luxin  CHN    Men  10m platform
# 3     Beijing  2008.0   aquatics           Diving         WANG, Xin  CHN  Women  10m platform
# 4     Beijing  2008.0   aquatics           Diving      CHEN, Ruolin  CHN  Women  10m platform
# ...       ...     ...        ...              ...               ...  ...    ...           ...
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS    Men    96 - 120kg
#
#      Event Gender   Medal
# 0               M  bronze
# 1               M    gold
# 2               M  silver
# 3               W  bronze
# 4               W    gold
# ...           ...     ...
# 2054            M  silver
# 2055            M  silver
# 2056            M  silver
# 2057            M  silver
# 2058            M  silver
#
# [2048 rows x 10 columns]

# %%
nw = nw.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2048 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2048 non-null   object
#  1   Year          2048 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 176.0+ KB

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year      Sport       Discipline      Athlete Name  NOC Gender  \
# 2011  Beijing  2008.0  wrestling  Wrestling Free.    TERZIEV, Kiril  BUL    Men
# 169   Beijing  2008.0   aquatics         Swimming  STOECKEL, Hayden  AUS    Men
# 117   Beijing  2008.0   aquatics         Swimming    CALLUS, Ashley  AUS    Men
#
#                        Event Event Gender   Medal
# 2011               66 - 74kg            M  bronze
# 169      4x100m medley relay            M  silver
# 117   4x100m freestyle relay            M  bronze

# %% [markdown]
# ##Working with Duplicates

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year       Sport   Discipline          Athlete Name  NOC Gender  \
# 1299  Beijing  2008.0    handball     Handball  FRAFJORD, Marit Malm  NOR  Women
# 90    Beijing  2008.0    aquatics     Swimming             LIU, Zige  CHN  Women
# 1226  Beijing  2008.0  gymnastics  Rhythmic G.             CHOU, Tao  CHN  Women
#
#                   Event Event Gender   Medal
# 1299           handball            W    gold
# 90       200m butterfly            W    gold
# 1226  group competition            W  silver

# %%
nw.shape
# Out:
# (2048, 10)

# %%
nw.duplicated?

# %%
nw.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2054     True
# 2055     True
# 2056     True
# 2057     True
# 2058     True
# Length: 2048, dtype: bool

# %%
nw.duplicated().sum()
# Out:
# 6

# %%
nw.loc[nw.duplicated(), :]
# Out:
#          City    Year      Sport       Discipline    Athlete Name  NOC Gender       Event  \
# 2053  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men  96 - 120kg
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men  96 - 120kg
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men  96 - 120kg
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men  96 - 120kg
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men  96 - 120kg
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men  96 - 120kg
#
#      Event Gender   Medal
# 2053            M  silver
# 2054            M  silver
# 2055            M  silver
# 2056            M  silver
# 2057            M  silver
# 2058            M  silver

# %%
nw.shape
# Out:
# (2048, 10)

# %%
nw = nw.drop_duplicates()
nw.shape
# Out:
# (2042, 10)

# %%
nw.columns
# Out:
# Index(['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender', 'Event',
#        'Event Gender', 'Medal'],
#       dtype='object')

# %%
athlete_multiple_events = nw.duplicated(subset=['Athlete Name', 'NOC', 'Gender'])
athlete_multiple_events
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2048    False
# 2049    False
# 2050    False
# 2051    False
# 2052    False
# Length: 2042, dtype: bool

# %%
nw.duplicated?

# %%
nw.loc[athlete_multiple_events, :]
# Out:
#          City    Year         Sport    Discipline    Athlete Name  NOC Gender  \
# 13    Beijing  2008.0      aquatics        Diving  GALPERIN, Gleb  RUS    Men
# 20    Beijing  2008.0      aquatics        Diving    CHEN, Ruolin  CHN  Women
# 21    Beijing  2008.0      aquatics        Diving       WANG, Xin  CHN  Women
# 26    Beijing  2008.0      aquatics        Diving        QIN, Kai  CHN    Men
# 32    Beijing  2008.0      aquatics        Diving   GUO, Jingjing  CHN  Women
# ...       ...     ...           ...           ...             ...  ...    ...
# 1783  Beijing  2008.0  table tennis  Table Tennis       WANG, Hao  CHN    Men
# 1784  Beijing  2008.0  table tennis  Table Tennis     WANG, Liqin  CHN    Men
# 1791  Beijing  2008.0  table tennis  Table Tennis        GUO, Yue  CHN  Women
# 1792  Beijing  2008.0  table tennis  Table Tennis       WANG, Nan  CHN  Women
# 1793  Beijing  2008.0  table tennis  Table Tennis   ZHANG, Yining  CHN  Women
#
#                                    Event Event Gender   Medal
# 13      synchronized diving 10m platform            M  bronze
# 20      synchronized diving 10m platform            W    gold
# 21      synchronized diving 10m platform            W    gold
# 26    synchronized diving 3m springboard            M    gold
# 32    synchronized diving 3m springboard            W    gold
# ...                                  ...          ...     ...
# 1783                                team            M    gold
# 1784                                team            M    gold
# 1791                                team            W    gold
# 1792                                team            W    gold
# 1793                                team            W    gold
#
# [175 rows x 10 columns]

# %%
nw.loc[athlete_multiple_events, :].sort_values("Athlete Name")
# Out:
#          City    Year         Sport    Discipline          Athlete Name  NOC Gender  \
# 489   Beijing  2008.0     athletics     Athletics    ABEYLEGESSE, Elvan  TUR  Women
# 239   Beijing  2008.0      aquatics      Swimming    ADLINGTON, Rebecca  GBR  Women
# 1595  Beijing  2008.0        rowing        Rowing  ANDRUNACHE, Georgeta  ROU  Women
# 485   Beijing  2008.0     athletics     Athletics      BEKELE, Kenenisa  ETH    Men
# 129   Beijing  2008.0      aquatics      Swimming        BERNARD, Alain  FRA    Men
# ...       ...     ...           ...           ...                   ...  ...    ...
# 1024  Beijing  2008.0       fencing       Fencing       ZAGUNIS, Mariel  USA  Women
# 381   Beijing  2008.0       archery       Archery      ZHANG, Juan Juan  CHN  Women
# 1793  Beijing  2008.0  table tennis  Table Tennis         ZHANG, Yining  CHN  Women
# 1179  Beijing  2008.0    gymnastics   Artistic G.              ZOU, Kai  CHN    Men
# 1151  Beijing  2008.0    gymnastics   Artistic G.              ZOU, Kai  CHN    Men
#
#                                 Event Event Gender   Medal
# 489                             5000m            W  silver
# 239                    800m freestyle            W    gold
# 1595       pair without coxswain (2-)            W    gold
# 485                             5000m            M    gold
# 129            4x100m freestyle relay            M  silver
# ...                               ...          ...     ...
# 1024                       sabre team            W  bronze
# 381   team (FITA Olympic round - 70m)            W  silver
# 1793                             team            W    gold
# 1179                 team competition            M    gold
# 1151                   horizontal bar            M    gold
#
# [175 rows x 10 columns]

# %%
nw.loc[nw["Athlete Name"] == "ZOU, Kai"]
# Out:
#          City    Year       Sport   Discipline Athlete Name  NOC Gender             Event  \
# 1145  Beijing  2008.0  gymnastics  Artistic G.     ZOU, Kai  CHN    Men   floor exercises
# 1151  Beijing  2008.0  gymnastics  Artistic G.     ZOU, Kai  CHN    Men    horizontal bar
# 1179  Beijing  2008.0  gymnastics  Artistic G.     ZOU, Kai  CHN    Men  team competition
#
#      Event Gender Medal
# 1145            M  gold
# 1151            M  gold
# 1179            M  gold

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year         Sport    Discipline       Athlete Name  NOC Gender         Event  \
# 462   Beijing  2008.0     athletics     Athletics  FROLOV, Vladislav  RUS    Men  4x400m relay
# 721   Beijing  2008.0    basketball    Basketball     PHILLIPS, Erin  AUS  Women    basketball
# 1778  Beijing  2008.0  table tennis  Table Tennis          WANG, Nan  CHN  Women       singles
#
#      Event Gender   Medal
# 462             M  bronze
# 721             W  silver
# 1778            W  silver

# %% [markdown]
# ## Validating data

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

oo = preprocess()

def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#          City    Year      Sport Discipline         Athlete Name  NOC Gender  \
# 1085  Beijing  2008.0   football   Football     OLUFEMI, Oladapo  NGR    Men
# 444   Beijing  2008.0  athletics  Athletics      BLEDMAN, Keston  TRI    Men
# 727   Beijing  2008.0     boxing     Boxing  GLAZKOV, Vyacheslav  UKR    Men
#
#                            Event Event Gender   Medal
# 1085                    football            M  silver
# 444                 4x100m relay            M  silver
# 727   + 91kg (super heavyweight)            M  bronze

# %%
nw["Event Gender"].unique()
# Out:
# array(['M', 'W', 'X'], dtype=object)

# %%
nw.Gender.unique()
# Out:
# array(['Men', 'Women'], dtype=object)

# %%
nw.loc[(nw["Event Gender"] == "M") & (nw.Gender != "Men")]
# Out:
# Empty DataFrame
# Columns: [City, Year, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
nw.loc[(nw["Event Gender"] == "F") & (nw.Gender != "Women")]
# Out:
# Empty DataFrame
# Columns: [City, Year, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
nw.loc[(nw.Gender == "Women") & ((nw["Event Gender"] != "W") & (nw["Event Gender"] != "X"))]
# Out:
# Empty DataFrame
# Columns: [City, Year, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
nw.loc[(nw.Gender == "Men") & ((nw["Event Gender"] != "M") & (nw["Event Gender"] != "X"))]
# Out:
# Empty DataFrame
# Columns: [City, Year, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo["Event Gender"].unique()
# Out:
# ['M', 'X', 'W']
# Categories (3, object): ['M', 'W', 'X']

# %%
oo.Gender.unique()
# Out:
# ['Men', 'Women']
# Categories (2, object): ['Men', 'Women']

# %%
oo.loc[(oo["Event Gender"] == "M") & (oo.Gender != "Men")]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo.loc[(oo["Event Gender"] == "F") & (oo.Gender != "Women")]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo.loc[(oo.Gender == "Women") & ((oo["Event Gender"] != "W") & (oo["Event Gender"] != "X"))]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo.loc[(oo.Gender == "Men") & ((oo["Event Gender"] != "M") & (oo["Event Gender"] != "X"))]
# Out:
#        Year    City      Sport Discipline       Athlete Name  NOC Gender     Event Event Gender  \
# 24676  2000  Sydney  Athletics  Athletics  CHEPCHUMBA, Joyce  KEN    Men  marathon            W
#
#         Medal
# 24676  Bronze

# %%
oo.loc[(oo.Year == 2000) & (oo.Event == "marathon")]
# Out:
#        Year    City      Sport Discipline        Athlete Name  NOC Gender     Event Event Gender  \
# 24675  2000  Sydney  Athletics  Athletics       TOLA, Tesfaye  ETH    Men  marathon            M
# 24676  2000  Sydney  Athletics  Athletics   CHEPCHUMBA, Joyce  KEN    Men  marathon            W
# 24677  2000  Sydney  Athletics  Athletics    ABERA, Gezahegne  ETH    Men  marathon            M
# 24678  2000  Sydney  Athletics  Athletics     WAINAINA, Erick  KEN    Men  marathon            M
# 24679  2000  Sydney  Athletics  Athletics    TAKAHASHI, Naoko  JPN  Women  marathon            W
# 24680  2000  Sydney  Athletics  Athletics  SIMON, Lidia Elena  ROU  Women  marathon            W
#
#         Medal
# 24675  Bronze
# 24676  Bronze
# 24677    Gold
# 24678  Silver
# 24679    Gold
# 24680  Silver

# %%
oo.loc[24676, "Gender"] = "Women"
oo.loc[(oo.Year == 2000) & (oo.Event == "marathon")]
# Out:
#        Year    City      Sport Discipline        Athlete Name  NOC Gender     Event Event Gender  \
# 24675  2000  Sydney  Athletics  Athletics       TOLA, Tesfaye  ETH    Men  marathon            M
# 24676  2000  Sydney  Athletics  Athletics   CHEPCHUMBA, Joyce  KEN  Women  marathon            W
# 24677  2000  Sydney  Athletics  Athletics    ABERA, Gezahegne  ETH    Men  marathon            M
# 24678  2000  Sydney  Athletics  Athletics     WAINAINA, Erick  KEN    Men  marathon            M
# 24679  2000  Sydney  Athletics  Athletics    TAKAHASHI, Naoko  JPN  Women  marathon            W
# 24680  2000  Sydney  Athletics  Athletics  SIMON, Lidia Elena  ROU  Women  marathon            W
#
#         Medal
# 24675  Bronze
# 24676  Bronze
# 24677    Gold
# 24678  Silver
# 24679    Gold
# 24680  Silver

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  return df

oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year       City       Sport   Discipline         Athlete Name  NOC Gender  \
# 21165  1992  Barcelona  Gymnastics  Artistic G.      MILLER, Shannon  USA  Women
# 2619   1912  Stockholm  Gymnastics  Artistic G.  ENGEBRETSEN, Eugene  NOR    Men
# 11164  1964      Tokyo      Rowing       Rowing         CERMAK, Petr  TCH    Men
#
#                           Event Event Gender   Medal
# 21165               uneven bars            W  Bronze
# 2619       team, Swedish system            M  Bronze
# 11164  eight with coxswain (8+)            M  Bronze

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
nw.Year.unique()
# Out:
# array([2008.])

# %%
nw.City.unique()
# Out:
# array(['Beijing'], dtype=object)

# %%
nw["Event Gender"].unique()
# Out:
# array(['M', 'W', 'X'], dtype=object)

# %%
nw["Event Gender"].unique().tolist()
# Out:
# ['M', 'W', 'X']

# %%
oo["Event Gender"].unique().tolist()
# Out:
# ['M', 'X', 'W']

# %%
nw["Event Gender"].unique().tolist() == oo["Event Gender"].unique().tolist()
# Out:
# False

# %%
sorted(nw["Event Gender"].unique().tolist())
# Out:
# ['M', 'W', 'X']

# %%
sorted(oo["Event Gender"].unique().tolist())
# Out:
# ['M', 'W', 'X']

# %%
assert(sorted(nw["Event Gender"].unique().tolist()) == sorted(oo["Event Gender"].unique().tolist()))
print("Passes all tests ...")
# Out:
# Passes all tests ...

# %%
#assert(sorted(nw["Event Gender"].unique().tolist()) == sorted(oo["Event Gender"].unique().tolist()))
#assert(sorted(nw.Gender.unique().tolist()) == sorted(oo.Gender.unique().tolist()))
#assert(sorted(nw.Medal.unique().tolist()) == sorted(oo.Medal.unique().tolist()))
#print("Passes all tests ...")

# %%
sorted(oo.Medal.unique().tolist())
# Out:
# ['Bronze', 'Gold', 'Silver']

# %%
sorted(nw.Medal.unique().tolist())
# Out:
# ['bronze', 'gold', 'silver']

# %%
nw.Medal.str.capitalize()
# Out:
# 0       Bronze
# 1         Gold
# 2       Silver
# 3       Bronze
# 4         Gold
#          ...
# 2048    Silver
# 2049    Bronze
# 2050    Bronze
# 2051      Gold
# 2052    Silver
# Name: Medal, Length: 2042, dtype: object

# %%
nw.Medal = nw.Medal.str.capitalize()
nw.sample(3)
# Out:
#          City    Year       Sport       Discipline    Athlete Name  NOC Gender       Event  \
# 1875  Beijing  2008.0  volleyball       Volleyball  VERBOV, Alexey  RUS    Men  volleyball
# 347   Beijing  2008.0    aquatics       Water polo     CRAIG, Kami  USA  Women  water polo
# 254   Beijing  2008.0    aquatics  Synchronized S.  HUANG, Xuechen  CHN  Women        team
#
#      Event Gender   Medal
# 1875            M  Bronze
# 347             W  Silver
# 254             W  Bronze

# %%
assert(sorted(nw["Event Gender"].unique().tolist()) == sorted(oo["Event Gender"].unique().tolist()))
assert(sorted(nw.Gender.unique().tolist()) == sorted(oo.Gender.unique().tolist()))
assert(sorted(nw.Medal.unique().tolist()) == sorted(oo.Medal.unique().tolist()))
print("Passes all tests ...")
# Out:
# Passes all tests ...

# %%
sorted(nw.Sport.unique().tolist())
# Out:
# ['aquatics',
#  'archery',
#  'athletics',
#  'badminton',
#  'baseball',
#  'basketball',
#  'boxing',
#  'canoe / kayak',
#  'cycling',
#  'equestrian',
#  'fencing',
#  'football',
#  'gymnastics',
#  'handball',
#  'hockey',
#  'judo',
#  'modern pentathlon',
#  'rowing',
#  'sailing',
#  'shooting',
#  'softball',
#  'table tennis',
#  'taekwondo',
#  'tennis',
#  'triathlon',
#  'volleyball',
#  'weightlifting',
#  'wrestling']

# %%
sorted(oo.Sport.unique().tolist())
# Out:
# ['Aquatics',
#  'Archery',
#  'Athletics',
#  'Badminton',
#  'Baseball',
#  'Basketball',
#  'Basque Pelota',
#  'Boxing',
#  'Canoe / Kayak',
#  'Cricket',
#  'Croquet',
#  'Cycling',
#  'Equestrian',
#  'Fencing',
#  'Football',
#  'Golf',
#  'Gymnastics',
#  'Handball',
#  'Hockey',
#  'Ice Hockey',
#  'Jeu de paume',
#  'Judo',
#  'Lacrosse',
#  'Modern Pentathlon',
#  'Polo',
#  'Rackets',
#  'Roque',
#  'Rowing',
#  'Rugby',
#  'Sailing',
#  'Shooting',
#  'Skating',
#  'Softball',
#  'Table Tennis',
#  'Taekwondo',
#  'Tennis',
#  'Triathlon',
#  'Tug of War',
#  'Volleyball',
#  'Water Motorsports',
#  'Weightlifting',
#  'Wrestling']

# %%
nw.NOC.unique()
# Out:
# array(['RUS', 'AUS', 'CHN', 'CAN', 'GER', 'MEX', 'UKR', 'USA', 'ZIM',
#        'FRA', 'JPN', 'NOR', 'AUT', 'SRB', 'BRA', 'TUN', 'HUN', 'KOR',
#        'ITA', 'SLO', 'GBR', 'NED', 'DEN', 'ESP', 'KEN', 'ETH', 'TUR',
#        'JAM', 'TRI', 'CUB', 'NZL', 'ECU', 'NGR', 'BEL', 'BAH', 'SUD',
#        'MAR', 'BLR', 'LTU', 'EST', 'POL', 'CRO', 'FIN', 'LAT', 'CZE',
#        'PAN', 'RSA', 'ROU', 'POR', 'GRE', 'CMR', 'INA', 'MAS', 'ARG',
#        'THA', 'IRL', 'MGL', 'MDA', 'MRI', 'AZE', 'ARM', 'DOM', 'KAZ',
#        'IND', 'SVK', 'TOG', 'SUI', 'SWE', 'UZB', 'PRK', 'ISL', 'ALG',
#        'TJK', 'EGY', 'GEO', 'BUL', 'ISR', 'SIN', 'VEN', 'TPE', 'AFG',
#        'IRI', 'CHI', 'VIE', 'COL', 'KGZ'], dtype=object)

# %%
nw.Sport = nw.Sport.str.lower()
nw.Discipline = nw.Discipline.str.lower()
nw.Event = nw.Event.str.lower()
nw.NOC = nw.NOC.str.upper()
nw.sample(3)
# Out:
#          City    Year       Sport   Discipline       Athlete Name  NOC Gender             Event  \
# 1238  Beijing  2008.0  gymnastics   trampoline          HE, Wenna  CHN  Women        individual
# 1177  Beijing  2008.0  gymnastics  artistic g.          XIAO, Qin  CHN    Men  team competition
# 1059  Beijing  2008.0    football     football  LAVEZZI, Ezequiel  ARG    Men          football
#
#      Event Gender Medal
# 1238            W  Gold
# 1177            M  Gold
# 1059            M  Gold

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year       Sport  Discipline          Athlete Name  NOC Gender       Event  \
# 1080  Beijing  2008.0    football    football        OBINNA, Victor  NGR    Men    football
# 1917  Beijing  2008.0  volleyball  volleyball  DE OLIVEIRA, Fabiana  BRA  Women  volleyball
# 995   Beijing  2008.0     fencing     fencing     SALVATORI, Ilaria  ITA  Women   foil team
#
#      Event Gender   Medal
# 1080            M  Silver
# 1917            W    Gold
# 995             W  Bronze

# %% [markdown]
# ## Further Data Validation

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

oo = preprocess()

def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#          City    Year      Sport Discipline     Athlete Name  NOC Gender         Event  \
# 652   Beijing  2008.0   baseball   Baseball   SANCHEZ, Eriel  CUB    Men      baseball
# 513   Beijing  2008.0  athletics  Athletics    MORENO, Yipsi  CUB  Women  hammer throw
# 1728  Beijing  2008.0   softball   Softball  BOWERING, Jodie  AUS  Women      softball
#
#      Event Gender   Medal
# 652             M  silver
# 513             W  silver
# 1728            W  bronze

# %%
medals = ['Gold', 'Silver', 'Bronze', 'Bronze', 'Gold']
medals
# Out:
# ['Gold', 'Silver', 'Bronze', 'Bronze', 'Gold']

# %%
medals[0]
# Out:
# 'Gold'

# %%
medals[1]
# Out:
# 'Silver'

# %%
len(medals)
# Out:
# 5

# %%
nw["Athlete Name"]
# Out:
# 0             GALPERIN, Gleb
# 1           MITCHAM, Matthew
# 2                ZHOU, Luxin
# 3                  WANG, Xin
# 4               CHEN, Ruolin
#                 ...
# 2048          ENGLICH, Mirko
# 2049    MIZGAITIS, Mindaugas
# 2050         PATRIKEEV, Yuri
# 2051           LOPEZ, Mijain
# 2052          BAROEV, Khasan
# Name: Athlete Name, Length: 2042, dtype: object

# %%
import re

search_string = "split"

[func for func in dir(nw["Athlete Name"].str) if re.search(rf"{search_string}", func, re.IGNORECASE)]
# Out:
# ['rsplit', 'split']

# %%
nw["Athlete Name"].str.split?

# %%
nw["Athlete Name"].str.split(", ")
# Out:
# 0             [GALPERIN, Gleb]
# 1           [MITCHAM, Matthew]
# 2                [ZHOU, Luxin]
# 3                  [WANG, Xin]
# 4               [CHEN, Ruolin]
#                  ...
# 2048          [ENGLICH, Mirko]
# 2049    [MIZGAITIS, Mindaugas]
# 2050         [PATRIKEEV, Yuri]
# 2051           [LOPEZ, Mijain]
# 2052          [BAROEV, Khasan]
# Name: Athlete Name, Length: 2042, dtype: object

# %%
nw["Athlete Name"].str.split(", ").tolist()
# Out:
# [['GALPERIN', 'Gleb'],
#  ['MITCHAM', 'Matthew'],
#  ['ZHOU', 'Luxin'],
#  ['WANG', 'Xin'],
#  ['CHEN', 'Ruolin'],
#  ['HEYMANS', 'Emilie'],
#  ['QIN', 'Kai'],
#  ['HE', 'Chong'],
#  ['DESPATIE', 'Alexandre'],
#  ['WU', 'Minxia'],
#  ['GUO', 'Jingjing'],
#  ['PAKHALINA', 'Julia'],
#  ['DOBROSKOK', 'Dmitriy'],
#  ['GALPERIN', 'Gleb'],
#  ['HUO', 'Liang'],
#  ['LIN', 'Yue'],
#  ['HAUSDING', 'Patrick'],
#  ['KLEIN', 'Sascha'],
#  ['ESPINOSA', 'Paola'],
#  ['ORTIZ', 'Tatiana'],
#  ['CHEN', 'Ruolin'],
#  ['WANG', 'Xin'],
#  ['COLE', 'Briony'],
#  ['WU', 'Melissa'],
#  ['KVASHA', 'Illya'],
#  ['PRYGOROV', 'Oleksiy'],
#  ['QIN', 'Kai'],
#  ['WANG', 'Feng'],
#  ['KUNAKOV', 'Yuriy'],
#  ['SAUTIN', 'Dmitry'],
#  ['FISCHER', 'Heike'],
#  ['KOTZIAN', 'Ditte'],
#  ['GUO', 'Jingjing'],
#  ['WU', 'Minxia'],
#  ['PAKHALINA', 'Julia'],
#  ['POZDNYAKOVA', 'Anastasia'],
#  ['STOECKEL', 'Hayden'],
#  ['VYATCHANIN', 'Arkady'],
#  ['PEIRSOL', 'Aaron'],
#  ['GREVERS', 'Matt'],
#  ['HOELZER', 'Margaret'],
#  ['COUGHLIN', 'Natalie'],
#  ['COVENTRY', 'Kirsty'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['OEN', 'Alexander Dale'],
#  ['JUKIC', 'Mirna'],
#  ['JONES', 'Leisel'],
#  ['SONI', 'Rebecca'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PHELPS', 'Michael'],
#  ['CAVIC', 'Milorad'],
#  ['SCHIPPER', 'Jessicah'],
#  ['TRICKETT', 'Lisbeth'],
#  ['MAGNUSON', 'Christine'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEZAK', 'Jason'],
#  ['BERNARD', 'Alain'],
#  ['SULLIVAN', 'Eamon'],
#  ['COUGHLIN', 'Natalie'],
#  ['STEFFEN', 'Britta'],
#  ['TRICKETT', 'Lisbeth'],
#  ['COCHRANE', 'Ryan'],
#  ['MELLOULI', 'Oussama'],
#  ['HACKETT', 'Grant'],
#  ['VYATCHANIN', 'Arkady'],
#  ['LOCHTE', 'Ryan'],
#  ['PEIRSOL', 'Aaron'],
#  ['NAKAMURA', 'Reiko'],
#  ['COVENTRY', 'Kirsty'],
#  ['HOELZER', 'Margaret'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['RICKARD', 'Brenton'],
#  ['NORDENSTAM', 'Sara'],
#  ['SONI', 'Rebecca'],
#  ['JONES', 'Leisel'],
#  ['MATSUDA', 'Takeshi'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['SCHIPPER', 'Jessicah'],
#  ['LIU', 'Zige'],
#  ['JIAO', 'Liuyang'],
#  ['VANDERKAAY', 'Peter'],
#  ['PHELPS', 'Michael'],
#  ['PARK', 'Taehwan'],
#  ['PANG', 'Jiaying'],
#  ['PELLEGRINI', 'Federica'],
#  ['ISAKOVIC', 'Sara'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['COUGHLIN', 'Natalie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['JENSEN', 'Larsen'],
#  ['PARK', 'Taehwan'],
#  ['ZHANG', 'Lin'],
#  ['JACKSON', 'Joanne'],
#  ['ADLINGTON', 'Rebecca'],
#  ['HOFF', 'Katie'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['HOFF', 'Katie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['BRODIE', 'Leith'],
#  ['CALLUS', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['MURPHY', 'Patrick'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['ADRIAN', 'Nathan'],
#  ['GREVERS', 'Matt'],
#  ['JONES', 'Cullen'],
#  ['LEZAK', 'Jason'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['WILDMAN-TOBRINER', 'Ben'],
#  ['BERNARD', 'Alain'],
#  ['BOUSQUET', 'Frederick'],
#  ['GILOT', 'Fabien'],
#  ['LEVEAUX', 'Amaury'],
#  ['MALLET', 'Gregory'],
#  ['STEIMETZ', 'Boris'],
#  ['CAMPBELL', 'Cate'],
#  ['MILLS', 'Alice'],
#  ['REESE', 'Shayne'],
#  ['SCHLANGER', 'Melanie'],
#  ['TRICKETT', 'Lisbeth'],
#  ['DEKKER', 'Inge'],
#  ['HEEMSKERK', 'Femke'],
#  ['KROMOWIDJOJO', 'Ranomi'],
#  ['SCHREUDER', 'Hinkelien'],
#  ['VAN ROOIJEN', 'Manon'],
#  ['VELDHUIS', 'Marleen'],
#  ['COUGHLIN', 'Natalie'],
#  ['JOYCE', 'Kara Lynn'],
#  ['NYMEYER', 'Lacey'],
#  ['SILVER', 'Emily'],
#  ['SMIT', 'Julia'],
#  ['TORRES', 'Dara'],
#  ['FUJII', 'Takuro'],
#  ['KITAJIMA', 'Kosuke'],
#  ['MIYASHITA', 'Junichi'],
#  ['SATO', 'Hisayoshi'],
#  ['CROCKER', 'Ian'],
#  ['GANGLOFF', 'Mark'],
#  ['GREVERS', 'Matt'],
#  ['HANSEN', 'Brendan'],
#  ['LEZAK', 'Jason'],
#  ['PEIRSOL', 'Aaron'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['DELANEY', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PINE', 'Adam'],
#  ['RICKARD', 'Brenton'],
#  ['SPRENGER', 'Christian'],
#  ['STOECKEL', 'Hayden'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['PANG', 'Jiaying'],
#  ['SUN', 'Ye'],
#  ['XU', 'Tianlongzi'],
#  ['ZHAO', 'Jing'],
#  ['ZHOU', 'Yafei'],
#  ['GALVEZ', 'Felicity'],
#  ['JONES', 'Leisel'],
#  ['REESE', 'Shayne'],
#  ['SCHIPPER', 'Jessicah'],
#  ['SEEBOHM', 'Emily'],
#  ['TRICKETT', 'Lisbeth'],
#  ['WHITE', 'Tarnee'],
#  ['BREEDEN', 'Elaine'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOELZER', 'Margaret'],
#  ['JENDRICK', 'Megan'],
#  ['JOYCE', 'Kara Lynn'],
#  ['MAGNUSON', 'Christine'],
#  ['SONI', 'Rebecca'],
#  ['TORRES', 'Dara'],
#  ['BRITS', 'Grant'],
#  ['BRODIE', 'Leith'],
#  ['FFROST', 'Nick'],
#  ['HACKETT', 'Grant'],
#  ['MURPHY', 'Patrick'],
#  ['PALMER', 'Kirk'],
#  ['BERENS', 'Ricky'],
#  ['KELLER', 'Klete'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['VANDERKAAY', 'Peter'],
#  ['VENDT', 'Erik'],
#  ['WALTERS', 'David'],
#  ['IZOTOV', 'Danila'],
#  ['LAGUNOV', 'Evgeniy'],
#  ['LOBINTSEV', 'Nikita'],
#  ['POLISHCHUK', 'Mikhail'],
#  ['SUKHORUKOV', 'Alexander'],
#  ['BURCKLE', 'Caroline'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOFF', 'Katie'],
#  ['MARSHALL', 'Christine'],
#  ['SCHMITT', 'Allison'],
#  ['SMIT', 'Julia'],
#  ['VANDENBERG', 'Kim'],
#  ['BAINBRIDGE', 'Angie'],
#  ['BARRATT', 'Bronte'],
#  ['DAVENPORT', 'Lara'],
#  ['GALVEZ', 'Felicity'],
#  ['MACKENZIE', 'Linda'],
#  ['PALMER', 'Kylie'],
#  ['RICE', 'Stephanie'],
#  ['SCHLANGER', 'Melanie'],
#  ['PANG', 'Jiaying'],
#  ['TAN', 'Miao'],
#  ['TANG', 'Jingzhi'],
#  ['YANG', 'Yu'],
#  ['ZHU', 'Qianwei'],
#  ['BERNARD', 'Alain'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEVEAUX', 'Amaury'],
#  ['CAMPBELL', 'Cate'],
#  ['STEFFEN', 'Britta'],
#  ['TORRES', 'Dara'],
#  ['FRIIS', 'Lotte'],
#  ['ADLINGTON', 'Rebecca'],
#  ['FILIPPI', 'Alessia'],
#  ['LURZ', 'Thomas'],
#  ['VAN DER WEIJDEN', 'Maarten'],
#  ['DAVIES', 'David'],
#  ['PATTEN', 'Cassandra'],
#  ['ILCHENKO', 'Larisa'],
#  ['PAYNE', 'Keri-Anne'],
#  ['HARADA', 'Saho'],
#  ['SUZUKI', 'Emiko'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['FUENTES', 'Andrea'],
#  ['MENGUAL', 'Gemma'],
#  ['GU', 'Beibei'],
#  ['HUANG', 'Xuechen'],
#  ['JIANG', 'Tingting'],
#  ['JIANG', 'Wenwen'],
#  ['LIU', 'Ou'],
#  ['LUO', 'Xi'],
#  ['SUN', 'Qiuting'],
#  ['WANG', 'Na'],
#  ['ZHANG', 'Xiaohuan'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['GROMOVA', 'Maria'],
#  ['ISHCHENKO', 'Natalia'],
#  ['KHASYANOVA', 'Elvira'],
#  ['KUZHELA', 'Olga'],
#  ['OVCHINNIKOVA', 'Elena'],
#  ['ROMASHINA', 'Svetlana'],
#  ['SHORINA', 'Anna'],
#  ['CABELLO', 'Alba Maria'],
#  ['CORRAL', 'Raquel'],
#  ['FUENTES', 'Andrea'],
#  ['HENRIQUEZ', 'Thais'],
#  ['LOPEZ', 'Laura'],
#  ['MENGUAL', 'Gemma'],
#  ['MORON', 'Gisela'],
#  ['RODRIGUEZ', 'Irina'],
#  ['TIRADOS', 'Paola'],
#  ['CIRIC', 'Aleksandar'],
#  ['FILIPOVIC', 'Filip'],
#  ['GOCIC', 'Zivko'],
#  ['PEKOVIC', 'Branko'],
#  ['PIJETLOVIC', 'Dusko'],
#  ['PRLAINOVIC', 'Andrija'],
#  ['RADJEN', 'Nikola'],
#  ['SAPIC', 'Aleksandar'],
#  ['SAVIC', 'Dejan'],
#  ['SEFIK', 'Denis'],
#  ['SORO', 'Slobodan'],
#  ['UDOVICIC', 'Vanja'],
#  ['VUJASINOVIC', 'Vladimir'],
#  ['BENEDEK', 'Tibor'],
#  ['BIROS', 'Peter'],
#  ['GERGELY', 'Istvan'],
#  ['HOSNYANSZKY', 'Norbert'],
#  ['KASAS', 'Tamas'],
#  ['KIS', 'Gabor'],
#  ['KISS', 'Gergely'],
#  ['MADARAS', 'Norbert'],
#  ['MOLNAR', 'Tamas'],
#  ['SZECSI', 'Zoltan'],
#  ['VARGA', 'Daniel Rudolf'],
#  ['VARGA', 'Denes Andor'],
#  ['VARGA', 'Tamas'],
#  ['AZEVEDO', 'Tony'],
#  ['BAILEY', 'Ryan'],
#  ['BEAUBIEN', 'Layne'],
#  ['BROOKS', 'Brandon'],
#  ['HUDNUT', 'Peter'],
#  ['HUTTEN', 'Tim'],
#  ['KRUMPHOLZ', 'James'],
#  ['MERLO', 'Rick'],
#  ['MOSES', 'Merrill'],
#  ['POWERS', 'Jeffrey'],
#  ['SMITH', 'Jesse'],
#  ['VARELLAS', 'Peter'],
#  ['WRIGHT', 'Adam'],
#  ['BEADSWORTH', 'Gemma'],
#  ['CUFFE', 'Nikita'],
#  ['FRASER', 'Suzie'],
#  ['GOFERS', 'Taniele'],
#  ['GYNTHER', 'Kate'],
#  ['HETZEL', 'Amy'],
#  ['KNOX', 'Bronwen'],
#  ['KNOX', 'Emma'],
#  ['MCCORMACK', 'Alicia'],
#  ['RIPPON', 'Melissa'],
#  ['RIPPON', 'Rebecca'],
#  ['SANTOROMITO', 'Jenna'],
#  ['SANTOROMITO', 'Mia'],
#  ['CABOUT', 'Mieke'],
#  ['DE BRUIJN', 'Danielle'],
#  ['DE NOOY', 'Meike'],
#  ['GUICHELAAR', 'Rianne'],
#  ['HAKHVERDIAN', 'Biurakn'],
#  ['KLEIN', 'Noeki'],
#  ['KOOT', 'Simone'],
#  ['SIJBRING', 'Alette'],
#  ['SMIT', 'Yasemin'],
#  ['VAN BELKUM', 'Iefke'],
#  ['VAN DEN BERG', 'Gillian'],
#  ['VAN DEN HAM', 'Marieke'],
#  ['VAN DER MEIJDEN', 'Ilse'],
#  ['ARMSTRONG', 'Elizabeth'],
#  ['CARDENAS', 'Patty'],
#  ['CRAIG', 'Kami'],
#  ['GOLDA', 'Natalie'],
#  ['GREGORKA', 'Alison'],
#  ['HAYES', 'Brittany'],
#  ['HIPP', 'Jaime'],
#  ['PETRI', 'Heather'],
#  ['STEFFENS', 'Jessica'],
#  ['VAN NORMAN', 'Moriah'],
#  ['VILLA', 'Brenda'],
#  ['WENGER', 'Lauren'],
#  ['WINDES', 'Elsie'],
#  ['BADENOV', 'Bair'],
#  ['RUBAN', 'Viktor'],
#  ['PARK', 'Kyung-Mo'],
#  ['YUN', 'Ok-Hee'],
#  ['ZHANG', 'Juan Juan'],
#  ['PARK', 'Sung-Hyun'],
#  ['JIANG', 'Lin'],
#  ['LI', 'Wenquan'],
#  ['XUE', 'Hai Feng'],
#  ['IM', 'Dong-Hyun'],
#  ['LEE', 'Chang-Hwan'],
#  ['PARK', 'Kyung-Mo'],
#  ["DI BUO'", 'Ilario'],
#  ['GALIAZZO', 'Marco'],
#  ['NESPOLI', 'Mauro'],
#  ['ARNOLD', 'Virginie'],
#  ['DODEMONT', 'Sophie'],
#  ['SCHUH', 'Berengere'],
#  ['JOO', 'Hyun-Jung'],
#  ['PARK', 'Sung-Hyun'],
#  ['YUN', 'Ok-Hee'],
#  ['CHEN', 'Ling'],
#  ['GUO', 'Dan'],
#  ['ZHANG', 'Juan Juan'],
#  ['KOGO', 'Micah'],
#  ['BEKELE', 'Kenenisa'],
#  ['SIHINE', 'Sileshi'],
#  ['FLANAGAN', 'Shalane'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['THOMPSON', 'Richard'],
#  ['FRASER', 'Shelly-ann'],
#  ['SIMPSON', 'Sherone'],
#  ['STEWART', 'Kerron'],
#  ['LOPES-SCHLIEP', 'Priscilla'],
#  ['HARPER', 'Dawn'],
#  ['MCLELLAN', 'Sally'],
#  ['OLIVER', 'David'],
#  ['ROBLES', 'Dayron'],
#  ['PAYNE', 'David'],
#  ['BAALA', 'Mehdi'],
#  ['KIPROP', 'Asbel Kipruto'],
#  ['WILLIS', 'Nicholas'],
#  ['TOBIAS', 'Nataliya'],
#  ['LANGAT', 'Nancy jebet'],
#  ['LISHCHYNSKA', 'Iryna'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['CRAWFORD', 'Shawn'],
#  ['STEWART', 'Kerron'],
#  ['CAMPBELL-BROWN', 'Veronica'],
#  ['FELIX', 'Allyson'],
#  ['RIGAUDO', 'Elisa'],
#  ['KANISKINA', 'Olga'],
#  ['PLATZER', 'Kjersti Tysse'],
#  ['TALLENT', 'Jared'],
#  ['BORCHIN', 'Valeriy'],
#  ['PEREZ', 'Jefferson'],
#  ['MATEELONG', 'Richard Kipkemboi'],
#  ['KIPRUTO', 'Brimin Kiprop'],
#  ['MEKHISSI-B.', 'Mahiedine'],
#  ['VOLKOVA', 'Ekaterina'],
#  ['GALKINA-SAMITOVA', 'Gulnara'],
#  ['JEPKORIR', 'Eunice'],
#  ['NEVILLE', 'David'],
#  ['MERRITT', 'LaShawn'],
#  ['WARINER', 'Jeremy'],
#  ['RICHARDS', 'Sanya'],
#  ['OHURUOGU', 'Christine'],
#  ['WILLIAMS', 'Shericka'],
#  ['JACKSON', 'Bershawn'],
#  ['TAYLOR', 'Angelo'],
#  ['CLEMENT', 'Kerron'],
#  ['DANVERS', 'Tasha'],
#  ['WALKER', 'Melaine'],
#  ['TOSTA', 'Sheena'],
#  ['ASAHARA', 'Nobuharu'],
#  ['SUETSUGU', 'Shingo'],
#  ['TAKAHIRA', 'Shinji'],
#  ['TSUKAHARA', 'Naoki'],
#  ['BOLT', 'Usain'],
#  ['CARTER', 'Nesta'],
#  ['FRATER', 'Michael'],
#  ['POWELL', 'Asafa'],
#  ['BLEDMAN', 'Keston'],
#  ['BURNS', 'Marc'],
#  ['CALLENDER', 'Emmanuel'],
#  ['THOMPSON', 'Richard'],
#  ['IDOKO', 'Franca'],
#  ['ISMAILA', 'Halimat'],
#  ['KEMASUODE', 'Gloria'],
#  ['OSAYOMI', 'Oludamola'],
#  ['CHERMOSHANSKAYA', 'Yuliya'],
#  ['FEDORIVA', 'Aleksandra'],
#  ['GUSHCHINA', 'Yulia'],
#  ['POLYAKOVA', 'Evgeniya'],
#  ['BORLEE', 'Olivia'],
#  ['GEVAERT', 'Kim'],
#  ['MARIEN', 'Hanna'],
#  ['OUEDRAOGO', 'Elodie'],
#  ['ALEXEEV', 'Denis'],
#  ['DYLDIN', 'Maksim'],
#  ['FROLOV', 'Vladislav'],
#  ['KOKORIN', 'Anton'],
#  ['MERRITT', 'LaShawn'],
#  ['NEVILLE', 'David'],
#  ['TAYLOR', 'Angelo'],
#  ['WARINER', 'Jeremy'],
#  ['BAIN', 'Andretti'],
#  ['BROWN', 'Christopher'],
#  ['MATHIEU', 'Michael'],
#  ['WILLIAMS', 'Andrae'],
#  ['LLOYD', 'Shereefa'],
#  ['WHYTE', 'Rosemarie'],
#  ['WILLIAMS', 'Novelene'],
#  ['WILLIAMS', 'Shericka'],
#  ['FELIX', 'Allyson'],
#  ['HENDERSON', 'Monique'],
#  ['RICHARDS', 'Sanya'],
#  ['WINEBERG', 'Mary'],
#  ['FIROVA', 'Tatiana'],
#  ['GUSHCHINA', 'Yulia'],
#  ['KAPACHINSKAYA', 'Anastasia'],
#  ['LITVINOVA', 'Liudmila'],
#  ['SOI', 'Edwin Cheruiyot'],
#  ['BEKELE', 'Kenenisa'],
#  ['KIPCHOGE', 'Eliud'],
#  ['DEFAR', 'Meseret'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['NIZHEGORODOV', 'Denis'],
#  ['SCHWAZER', 'Alex'],
#  ['TALLENT', 'Jared'],
#  ['YEGO', 'Alfred Kirwa'],
#  ['BUNGEI', 'Wilfred'],
#  ['ISMAIL', 'Ismail Ahmed'],
#  ['BENHASSI', 'Hasna'],
#  ['JELIMO', 'Pamela'],
#  ['BUSIENEI', 'Janeth Jepkosgei'],
#  ['SUAREZ', 'Leonel'],
#  ['CLAY', 'Bryan'],
#  ['KRAUCHANKA', 'Andrei'],
#  ['ALEKNA', 'Virgilijus'],
#  ['KANTER', 'Gerd'],
#  ['MALACHOWSKI', 'Piotr'],
#  ['ANTONOVA', 'Olena'],
#  ['BROWN TRAFTON', 'Stephanie'],
#  ['BARRIOS', 'Yarelys'],
#  ['TSIKHAN', 'Ivan'],
#  ['KOZMUS', 'Primoz'],
#  ['DEVYATOVSKIY', 'Vadim'],
#  ['ZHANG', 'Wenxiu'],
#  ['MIANKOVA', 'Aksana'],
#  ['MORENO', 'Yipsi'],
#  ['CHERNOVA', 'Tatiana'],
#  ['DOBRYNSKA', 'Nataliia'],
#  ['FOUNTAIN', 'Hyleas'],
#  ['RYBAKOV', 'Yaroslav'],
#  ['SILNOV', 'Andrey'],
#  ['MASON', 'Germaine'],
#  ['CHICHEROVA', 'Anna'],
#  ['HELLEBAUT', 'Tia'],
#  ['VLASIC', 'Blanka'],
#  ['PITKAMAKI', 'Tero'],
#  ['THORKILDSEN', 'Andreas'],
#  ['KOVALS', 'Ainars'],
#  ['OBERGFOLL', 'Christina'],
#  ['SPOTAKOVA', 'Barbora'],
#  ['ABAKUMOVA', 'Maria'],
#  ['CAMEJO', 'Ibrahim'],
#  ['SALADINO ARANDA', 'Irving Jahir'],
#  ['MOKOENA', 'Khotso'],
#  ['OKAGBARE', 'Blessing'],
#  ['MAGGI', 'Maurren Higa'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['KEBEDE', 'Tsegay'],
#  ['WANSIRU', 'Samuel Kamau'],
#  ['GHARIB', 'Jaouad'],
#  ['ZHOU', 'Chunxiu'],
#  ['TOMESCU', 'Constantina'],
#  ['NDEREBA', 'Catherine'],
#  ['YURCHENKO', 'Denys'],
#  ['HOOKER', 'Steve'],
#  ['LUKYANENKO', 'Evgeny'],
#  ['FEOFANOVA', 'Svetlana'],
#  ['ISINBAEVA', 'Elena'],
#  ['STUCZYNSKI', 'Jennifer'],
#  ['MIKHNEVICH', 'Andrei'],
#  ['MAJEWSKI', 'Tomasz'],
#  ['CANTWELL', 'Christian'],
#  ['OSTAPCHUK', 'Nadzeya'],
#  ['VILI', 'Valerie'],
#  ['MIKHNEVICH', 'Natallia'],
#  ['SANDS', 'Leevan'],
#  ['EVORA', 'Nelson'],
#  ['IDOWU', 'Phillips'],
#  ['DEVETZI', 'Hrysopiyi'],
#  ['MBANGO ETONE', 'Francoise'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['HWANG', 'Jiman'],
#  ['LEE', 'Jaejin'],
#  ['HE', 'Hanbin'],
#  ['KIDO', 'Markis'],
#  ['SETIAWAN', 'Hendra'],
#  ['LEE', 'Yongdae'],
#  ['CAI', 'Yun'],
#  ['FU', 'Haifeng'],
#  ['WIDIANTO', 'Nova'],
#  ['WEI', 'Yili'],
#  ['ZHANG', 'Yawen'],
#  ['YU', 'Yang'],
#  ['DU', 'Jing'],
#  ['YU', 'Yang'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Kyungwon'],
#  ['LILIYANA'],
#  ['CHEN', 'Jin'],
#  ['LIN', 'Dan'],
#  ['LEE', 'Chong Wei'],
#  ['YULIANTI', 'Maria Kristin'],
#  ['ZHANG', 'Ning'],
#  ['XIE', 'Xingfang'],
#  ['ANDERSON', 'Brett'],
#  ['ARRIETA', 'Jake'],
#  ['BARDEN', 'Brian'],
#  ['BROWN', 'Matt'],
#  ['CAHILL', 'Trevor'],
#  ['CUMMINGS', 'Jeremy'],
#  ['DONALD', 'Jason'],
#  ['DUENSING', 'Brian'],
#  ['FOWLER', 'Dexter'],
#  ['GALL', 'John'],
#  ['HESSMAN', 'Mike'],
#  ['JEPSEN', 'Kevin'],
#  ['KNIGHT', 'Brandon'],
#  ['KOPLOVE', 'Michael'],
#  ['LAPORTA', 'Matt'],
#  ['MARSON', 'Lou'],
#  ['NEAL', 'Blaine'],
#  ['NIX', 'Jayson'],
#  ['SCHIERHOLTZ', 'Nate'],
#  ['STEVENS', 'Jeff'],
#  ['STRASBURG', 'Stephen'],
#  ['TEAGARDEN', 'Taylor'],
#  ['TIFFEE', 'Terry'],
#  ['WEATHERS', 'Casey'],
#  ['BONG', 'Jungkeun'],
#  ['CHONG', 'Taehyon'],
#  ['HAN', 'Kijoo'],
#  ['JANG', 'Wonsam'],
#  ['JEONG', 'Keunwoo'],
#  ['JIN', 'Kabyong'],
#  ['KANG', 'Minho'],
#  ['KIM', 'Dongjoo'],
#  ['KIM', 'Hyunsoo'],
#  ['KIM', 'Kwanghyun'],
#  ['KIM', 'Minjae'],
#  ['KO', 'Youngmin'],
#  ['KWON', 'Hyuk'],
#  ['LEE', 'Daeho'],
#  ['LEE', 'Jinyoung'],
#  ['LEE', 'Jongwook'],
#  ['LEE', 'Seungyuop'],
#  ['LEE', 'Taekkeun'],
#  ['LEE', 'Yongkyu'],
#  ['OH', 'Seunghwan'],
#  ['PARK', 'Jinman'],
#  ['RYU', 'Hyunjin'],
#  ['SONG', 'Seungjun'],
#  ['YOON', 'Suk Min'],
#  ['BELL', 'Alexei'],
#  ['CEPEDA', 'Frederich'],
#  ['DESPAIGNE', 'Alfredo'],
#  ['DUVERGEL', 'Giorbis'],
#  ['ENRIQUEZ', 'Michel'],
#  ['GONZALEZ', 'Norberto'],
#  ['GOURRIEL', 'Yuliesky'],
#  ['LA HERA', 'Miguel'],
#  ['LAZO', 'Pedro Luis'],
#  ['MARTINEZ', 'Jonder'],
#  ['MAYETA', 'Alexander'],
#  ['MERINO', 'Rolando'],
#  ['NAVAS', 'Luis'],
#  ['ODELIN SANAME', 'Vicyohandri'],
#  ['OLIVERA', 'Hector'],
#  ['PALMA', 'Adiel'],
#  ['PARET', 'Eduardo'],
#  ['PEDROSO', 'Yadier'],
#  ['PESTANO', 'Ariel'],
#  ['RODRIGUEZ', 'Luis'],
#  ['SANCHEZ', 'Elier'],
#  ['SANCHEZ', 'Eriel'],
#  ['URGELLES', 'Yoandry'],
#  ['VERA', 'Norge Luis'],
#  ['DELFINO', 'Carlos Francisco'],
#  ['GINOBILI', 'Emanuel David'],
#  ['GONZALEZ', 'Roman Javier'],
#  ['GUTIERREZ LLANAS', 'Juan Pedro'],
#  ['GUTIERREZ', 'Leonardo Martin'],
#  ['KAMMERICHS', 'Guillermo Federico'],
#  ['NOCIONI', 'Andres Marcelo'],
#  ['OBERTO', 'Fabricio Raul Jesus'],
#  ['PORTA PERNIGOTTI', 'Antonio Alejandro'],
#  ['PRIGIONI', 'Pablo'],
#  ['QUINTEROS', 'Alfredo Paolo'],
#  ['SCOLA', 'Luis Alberto'],
#  ['ANTHONY', 'Carmelo'],
#  ['BOOZER', 'Carlos'],
#  ['BOSH', 'Chris'],
#  ['BRYANT', 'Kobe'],
#  ['HOWARD', 'Dwight'],
#  ['JAMES', 'Lebron'],
#  ['KIDD', 'Jason'],
#  ['PAUL', 'Chris'],
#  ['PRINCE', 'Tayshaun'],
#  ['REDD', 'Michael'],
#  ['WADE', 'Dwyane'],
#  ['WILLIAMS', 'Deron'],
#  ['CALDERON', 'Jose Manuel'],
#  ['FERNANDEZ', 'Rudy'],
#  ['GARBAJOSA', 'Jorge'],
#  ['GASOL', 'Marc'],
#  ['GASOL', 'Pau'],
#  ['JIMENEZ', 'Carlos'],
#  ['LOPEZ', 'Raul'],
#  ['MUMBRU', 'Alex'],
#  ['NAVARRO', 'Juan Carlos'],
#  ['REYES', 'Felipe'],
#  ['RODRIGUEZ', 'Berni'],
#  ['RUBIO', 'Ricky'],
#  ['ABROSIMOVA', 'Svetlana'],
#  ['HAMMON', 'Rebekka Linn'],
#  ['KARPUNINA', 'Marina'],
#  ['KORSTIN', 'Ilona'],
#  ['KUZINA', 'Marina'],
#  ['LISINA', 'Ekaterina'],
#  ['OSIPOVA', 'Irina'],
#  ['RAKHMATULINA', 'Oxana'],
#  ['SHCHEGOLEVA', 'Tatiana'],
#  ['SOKOLOVSKAYA', 'Irina'],
#  ['STEPANOVA', 'Maria'],
#  ['VODOPYANOVA', 'Natalia'],
#  ['AUGUSTUS', 'Seimone'],
#  ['BIRD', 'Sue'],
#  ['CATCHINGS', 'Tamika'],
#  ['FOWLES', 'Sylvia'],
#  ['LAWSON', 'Kara'],
#  ['LESLIE', 'Lisa'],
#  ['MILTON-JONES', 'Delisha'],
#  ['PARKER', 'Candace'],
#  ['PONDEXTER', 'Cappie'],
#  ['SMITH', 'Katie'],
#  ['TAURASI', 'Diana'],
#  ['THOMPSON', 'Tina'],
#  ['BATKOVIC', 'Suzy'],
#  ['BEVILAQUA', 'Tully'],
#  ['COX', 'Rohanee'],
#  ['GRIMA', 'Hollie'],
#  ['HARROWER', 'Kristi'],
#  ['JACKSON', 'Lauren'],
#  ['PHILLIPS', 'Erin'],
#  ['RANDALL', 'Emma'],
#  ['SCREEN', 'Jenni'],
#  ['SNELL', 'Belinda'],
#  ['SUMMERTON', 'Laura'],
#  ['TAYLOR', 'Penny'],
#  ['GLAZKOV', 'Vyacheslav'],
#  ['PRICE', 'David'],
#  ['CAMMARELLE', 'Roberto'],
#  ['ZHANG', 'Zhilei'],
#  ['BALAKSHIN', 'Georgy'],
#  ['PICARDI', 'Vincenzo'],
#  ['JONGJOHOR', 'Somjit'],
#  ['LAFFITA HERNANDEZ', 'Andris'],
#  ['BARNES', 'Paddy'],
#  ['HERNANDEZ G', 'Yampier'],
#  ['ZOU', 'Shiming'],
#  ['PUREVDORJ', 'Serdamba'],
#  ['GOJAN', 'Veaceslav'],
#  ['JULIE', 'Bruno'],
#  ['ENKHBAT', 'Badar-Uugan'],
#  ['LEON ALARCON', 'Yankiel'],
#  ['IMRANOV', 'Shahin'],
#  ['KILIC', 'Yakup'],
#  ['LOMACHENKO', 'Vasyl'],
#  ['DJELKHIR', 'Khedafi'],
#  ['JAVAKHYAN', 'Hrachik'],
#  ['UGAS', 'Yordenis'],
#  ['TISHCHENKO', 'Alexey'],
#  ['SOW', 'Daouda'],
#  ['IGLESIAS SOTOLONGO', 'Roniel'],
#  ['VASTINE', 'Alexis'],
#  ['DIAZ', 'Felix'],
#  ['BOONJUMNONG', 'Manus'],
#  ['HANATI', 'Silamu'],
#  ['KIM', 'Jungjoo'],
#  ['SARSEKBAYEV', 'Bakhyt'],
#  ['BANTEAUX SUAREZ', 'Carlos'],
#  ['KUMAR', 'Vijender'],
#  ['SUTHERLAND', 'Darren John'],
#  ['DEGALE', 'James'],
#  ['CORREA BAYEAUX', 'Emilio'],
#  ['JEFFRIES', 'Tony'],
#  ['SHYNALIYEV', 'Yerkebulan'],
#  ['ZHANG', 'Xiaoping'],
#  ['EGAN', 'Kenny'],
#  ['ACOSTA DUARTE', 'Osmai'],
#  ['WILDER', 'Deontay'],
#  ['CHAKHKIEV', 'Rakhim'],
#  ['RUSSO', 'Clemente'],
#  ['HALL', 'Thomas'],
#  ['VAJDA', 'Attila Sandor'],
#  ['CAL', 'David'],
#  ['CHEBAN', 'Iurii'],
#  ['OPALEV', 'Maxim'],
#  ['CAL', 'David'],
#  ['KISS', 'Tamas'],
#  ['KOZMANN', 'Gyorgy'],
#  ['BAHDANOVICH', 'Aliaksandr'],
#  ['BAHDANOVICH', 'Andrei'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['MENG', 'Guanliang'],
#  ['YANG', 'Wenjun'],
#  ['KOSTOGLOD', 'Alexander'],
#  ['ULEGIN', 'Sergey'],
#  ['WALLACE', 'Ken'],
#  ['BRABANTS', 'Tim'],
#  ['LARSEN', 'Eirik Veraas'],
#  ['BRABANTS', 'Tim'],
#  ['WALLACE', 'Ken'],
#  ['VAN KOEVERDEN', 'Adam'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['OSYPENKO-RADOMSKA', 'Inna'],
#  ['IDEM', 'Josefa'],
#  ['FACCHIN', 'Andrea'],
#  ['SCADUTO', 'Antonio Massimiliano'],
#  ['HOLLSTEIN', 'Martin'],
#  ['IHLE', 'Andreas'],
#  ['KNUDSEN', 'Kim Wraae'],
#  ['POULSEN', 'Rene Holten'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['CRAVIOTTO', 'Saul'],
#  ['PEREZ', 'Carlos'],
#  ['RAUHE', 'Ronald'],
#  ['WIESKOTTER', 'Tim'],
#  ['DELATTRE', 'Marie'],
#  ['VIARD', 'Anne-Laure'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KONIECZNA', 'Aneta'],
#  ['MIKOLAJCZYK', 'Beata'],
#  ['ALTEPOST', 'Lutz'],
#  ['BROCKL', 'Norman'],
#  ['ECKBRETT', 'Torsten'],
#  ['GOLDSCHMIDT', 'Bjorn'],
#  ['ABALMASAU', 'Aliaksei'],
#  ['LITVINCHUK', 'Artur'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['RISZDORFER', 'Michal'],
#  ['RISZDORFER', 'Richard'],
#  ['TARR', 'Juraj'],
#  ['VLCEK', 'Erik'],
#  ['DAVIS', 'Hannah'],
#  ['FOGARTY', 'Lyndsie'],
#  ['MEEK', 'Chantal'],
#  ['OLDENHOF', 'Lisa'],
#  ['FISCHER', 'Fanny'],
#  ['REINHARDT', 'Nicole'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['WASSMUTH', 'Conny'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KOZAK', 'Danuta'],
#  ['SZABO', 'Gabriella Timea'],
#  ['BELL', 'Robin'],
#  ['MARTIKAN', 'Michal'],
#  ['FLORENCE', 'David'],
#  ['KUZNETSOV', 'Mikhail'],
#  ['LARIONOV', 'Dmitry'],
#  ['HOCHSCHORNER', 'Pavol'],
#  ['HOCHSCHORNER', 'Peter'],
#  ['STEPANEK', 'Ondrej'],
#  ['VOLF', 'Jaroslav'],
#  ['BOUKPETI', 'Benjamin'],
#  ['GRIMM', 'Alexander'],
#  ['LEFEVRE', 'Fabien'],
#  ['OBLINGER PETERS', 'Violetta'],
#  ['KALISKA', 'Elena'],
#  ['LAWRENCE', 'Jacqueline'],
#  ['ROBINSON', 'Donny'],
#  ['STROMBERGS', 'Maris'],
#  ['DAY', 'Mike'],
#  ['KINTNER', 'Jill'],
#  ['CHAUSSON', 'Anne-Caroline'],
#  ['LE CORGUILLE', 'Laetitia'],
#  ['CANCELLARA', 'Fabian'],
#  ['SANCHEZ', 'Samuel'],
#  ['GUDERZO', 'Tatiana'],
#  ['COOKE', 'Nicole'],
#  ['JOHANSSON', 'Emma'],
#  ['LEIPHEIMER', 'Levi'],
#  ['CANCELLARA', 'Fabian'],
#  ['LARSSON', 'Gustav'],
#  ['THURIG', 'Karin'],
#  ['ARMSTRONG', 'Kristin'],
#  ['POOLEY', 'Emma'],
#  ['BURKE', 'Steven'],
#  ['WIGGINS', 'Bradley'],
#  ['ROULSTON', 'Hayden'],
#  ['KALITOVSKA', 'Lesya'],
#  ['ROMERO', 'Rebecca'],
#  ['HOUVENAGHEL', 'Wendy'],
#  ['NAGAI', 'Kiyofumi'],
#  ['HOY', 'Chris'],
#  ['EDGAR', 'Ross'],
#  ['IGNATYEV', 'Mikhail'],
#  ['MARKOV', 'Alexei'],
#  ['CURUCHET', 'Juan Esteban'],
#  ['PEREZ', 'Walter Fernando'],
#  ['LLANERAS', 'Joan'],
#  ['TAULER', 'Antonio'],
#  ['NEWTON', 'Chris'],
#  ['LLANERAS', 'Joan'],
#  ['KLUGE', 'Roger'],
#  ['OLABERRIA', 'Leire'],
#  ['VOS', 'Marianne'],
#  ['GONZALEZ', 'Yoanka'],
#  ['GUO', 'Shuang'],
#  ['PENDLETON', 'Victoria'],
#  ['MEARES', 'Anna'],
#  ['BOURGAIN', 'Mickael'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['BEWLEY', 'Sam'],
#  ['ROULSTON', 'Hayden'],
#  ['RYAN', 'Marc'],
#  ['SERGENT', 'Jesse'],
#  ['CLANCY', 'Ed'],
#  ['MANNING', 'Paul'],
#  ['THOMAS', 'Geraint'],
#  ['WIGGINS', 'Bradley'],
#  ['JOERGENSEN', 'Casper'],
#  ['MADSEN', 'Jens-Erik'],
#  ['MOERKOEV', 'Michael'],
#  ['RASMUSSEN', 'Alex Nicki'],
#  ['ENDERS', 'Rene'],
#  ['LEVY', 'Maximilian'],
#  ['NIMKE', 'Stefan'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['STAFF', 'Jamie'],
#  ['BAUGE', 'Gregory'],
#  ['SIREAU', 'Kevin'],
#  ['TOURNANT', 'Arnaud'],
#  ['SCHURTER', 'Nino'],
#  ['ABSALON', 'Julien'],
#  ['PERAUD', 'Jean-Christophe'],
#  ['KALENTYEVA', 'Irina'],
#  ['SPITZ', 'Sabine'],
#  ['WLOSZCZOWSKA', 'Maja'],
#  ['KEMMER', 'Heike'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['WERTH', 'Isabell'],
#  ['HELGSTRAND', 'Andreas'],
#  ['MINDERHOUD', 'Hans Peter'],
#  ['VAN OLST', 'Anne'],
#  ['ZU-SAYN WITTGENSTEIN', 'Nathalie'],
#  ['CAPELLMANN', 'Nadine'],
#  ['KEMMER', 'Heike'],
#  ['WERTH', 'Isabell'],
#  ['SCHELLEKENS-BARTELS', 'Imke'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['ROMEIKE', 'Hinrich'],
#  ['COOK', 'Kristina'],
#  ['MILES', 'Gina'],
#  ['FOX-PITT', 'William'],
#  ['DIBOWSKI', 'Andreas'],
#  ['OSTHOLT', 'Frank'],
#  ['ROMEIKE', 'Hinrich'],
#  ['THOMSEN', 'Peter'],
#  ['FREDERICKS', 'Clayton'],
#  ['ROSE', 'Shane'],
#  ['COOK', 'Kristina'],
#  ['DICK', 'Daisy'],
#  ['HUNT', 'Sharon'],
#  ['KING', 'Mary'],
#  ['KLIMKE', 'Ingrid'],
#  ['FREDERICKS', 'Lucinda'],
#  ['JOHNSON', 'Sonja'],
#  ['JONES', 'Megan'],
#  ['LAMAZE', 'Eric'],
#  ['BENGTSSON', 'Rolf-Goran'],
#  ['MADDEN', 'Beezie'],
#  ['GUERDAT', 'Steve'],
#  ['SCHURTENBERGER', 'Niklaus'],
#  ['SCHWIZER', 'Pius'],
#  ['SIMPSON', 'Will'],
#  ['WARD', 'Mclain'],
#  ['CONE', 'Mac'],
#  ['LAMAZE', 'Eric'],
#  ['MILLAR', 'Ian'],
#  ['LIEBHERR', 'Christina'],
#  ['KRAUT', 'Laura'],
#  ['MADDEN', 'Beezie'],
#  ['HENSELWOOD', 'Jill'],
#  ['ABAJO', 'Jose Luis'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['MINCZA-NEBALD', 'Ildiko'],
#  ['HEIDEMANN', 'Britta'],
#  ['BRANZA', 'Ana Maria'],
#  ['CAROZZO', 'Stefano'],
#  ['CONFALONIERI', 'Diego'],
#  ['ROTA', 'Alfredo'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['JEANNET', 'Jerome'],
#  ['ROBEIRI', 'Ulrich'],
#  ['ANDRZEJUK', 'Robert'],
#  ['MOTYKA', 'Tomasz'],
#  ['WIERCIOCH', 'Adam'],
#  ['ZAWROTNIAK', 'Radoslaw'],
#  ['SANZO', 'Salvatore'],
#  ['KLEIBRINK', 'Benjamin'],
#  ['OTA', 'Yuki'],
#  ['GRANBASSI', 'Margherita'],
#  ['VEZZALI', 'Valentina'],
#  ['NAM', 'Hyunhee'],
#  ['GRANBASSI', 'Margherita'],
#  ['SALVATORI', 'Ilaria'],
#  ['TRILLINI', 'Giovanna'],
#  ['VEZZALI', 'Valentina'],
#  ['BOYKO', 'Svetlana'],
#  ['CHANAEVA', 'Aida'],
#  ['LAMONOVA', 'Evgenia'],
#  ['NIKICHINA', 'Victoria'],
#  ['CROSS', 'Emily'],
#  ['SMART', 'Erinn'],
#  ['THOMPSON', 'Hanna'],
#  ['COVALIU', 'Mihai'],
#  ['ZHONG', 'Man'],
#  ['LOPEZ', 'Nicolas'],
#  ['WARD', 'Becca'],
#  ['ZAGUNIS', 'Mariel'],
#  ['JACOBSON', 'Sada'],
#  ...]

# %%
athlete_names = nw["Athlete Name"].str.split(", ").tolist()
athlete_names
# Out:
# [['GALPERIN', 'Gleb'],
#  ['MITCHAM', 'Matthew'],
#  ['ZHOU', 'Luxin'],
#  ['WANG', 'Xin'],
#  ['CHEN', 'Ruolin'],
#  ['HEYMANS', 'Emilie'],
#  ['QIN', 'Kai'],
#  ['HE', 'Chong'],
#  ['DESPATIE', 'Alexandre'],
#  ['WU', 'Minxia'],
#  ['GUO', 'Jingjing'],
#  ['PAKHALINA', 'Julia'],
#  ['DOBROSKOK', 'Dmitriy'],
#  ['GALPERIN', 'Gleb'],
#  ['HUO', 'Liang'],
#  ['LIN', 'Yue'],
#  ['HAUSDING', 'Patrick'],
#  ['KLEIN', 'Sascha'],
#  ['ESPINOSA', 'Paola'],
#  ['ORTIZ', 'Tatiana'],
#  ['CHEN', 'Ruolin'],
#  ['WANG', 'Xin'],
#  ['COLE', 'Briony'],
#  ['WU', 'Melissa'],
#  ['KVASHA', 'Illya'],
#  ['PRYGOROV', 'Oleksiy'],
#  ['QIN', 'Kai'],
#  ['WANG', 'Feng'],
#  ['KUNAKOV', 'Yuriy'],
#  ['SAUTIN', 'Dmitry'],
#  ['FISCHER', 'Heike'],
#  ['KOTZIAN', 'Ditte'],
#  ['GUO', 'Jingjing'],
#  ['WU', 'Minxia'],
#  ['PAKHALINA', 'Julia'],
#  ['POZDNYAKOVA', 'Anastasia'],
#  ['STOECKEL', 'Hayden'],
#  ['VYATCHANIN', 'Arkady'],
#  ['PEIRSOL', 'Aaron'],
#  ['GREVERS', 'Matt'],
#  ['HOELZER', 'Margaret'],
#  ['COUGHLIN', 'Natalie'],
#  ['COVENTRY', 'Kirsty'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['OEN', 'Alexander Dale'],
#  ['JUKIC', 'Mirna'],
#  ['JONES', 'Leisel'],
#  ['SONI', 'Rebecca'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PHELPS', 'Michael'],
#  ['CAVIC', 'Milorad'],
#  ['SCHIPPER', 'Jessicah'],
#  ['TRICKETT', 'Lisbeth'],
#  ['MAGNUSON', 'Christine'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEZAK', 'Jason'],
#  ['BERNARD', 'Alain'],
#  ['SULLIVAN', 'Eamon'],
#  ['COUGHLIN', 'Natalie'],
#  ['STEFFEN', 'Britta'],
#  ['TRICKETT', 'Lisbeth'],
#  ['COCHRANE', 'Ryan'],
#  ['MELLOULI', 'Oussama'],
#  ['HACKETT', 'Grant'],
#  ['VYATCHANIN', 'Arkady'],
#  ['LOCHTE', 'Ryan'],
#  ['PEIRSOL', 'Aaron'],
#  ['NAKAMURA', 'Reiko'],
#  ['COVENTRY', 'Kirsty'],
#  ['HOELZER', 'Margaret'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['RICKARD', 'Brenton'],
#  ['NORDENSTAM', 'Sara'],
#  ['SONI', 'Rebecca'],
#  ['JONES', 'Leisel'],
#  ['MATSUDA', 'Takeshi'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['SCHIPPER', 'Jessicah'],
#  ['LIU', 'Zige'],
#  ['JIAO', 'Liuyang'],
#  ['VANDERKAAY', 'Peter'],
#  ['PHELPS', 'Michael'],
#  ['PARK', 'Taehwan'],
#  ['PANG', 'Jiaying'],
#  ['PELLEGRINI', 'Federica'],
#  ['ISAKOVIC', 'Sara'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['COUGHLIN', 'Natalie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['JENSEN', 'Larsen'],
#  ['PARK', 'Taehwan'],
#  ['ZHANG', 'Lin'],
#  ['JACKSON', 'Joanne'],
#  ['ADLINGTON', 'Rebecca'],
#  ['HOFF', 'Katie'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['HOFF', 'Katie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['BRODIE', 'Leith'],
#  ['CALLUS', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['MURPHY', 'Patrick'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['ADRIAN', 'Nathan'],
#  ['GREVERS', 'Matt'],
#  ['JONES', 'Cullen'],
#  ['LEZAK', 'Jason'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['WILDMAN-TOBRINER', 'Ben'],
#  ['BERNARD', 'Alain'],
#  ['BOUSQUET', 'Frederick'],
#  ['GILOT', 'Fabien'],
#  ['LEVEAUX', 'Amaury'],
#  ['MALLET', 'Gregory'],
#  ['STEIMETZ', 'Boris'],
#  ['CAMPBELL', 'Cate'],
#  ['MILLS', 'Alice'],
#  ['REESE', 'Shayne'],
#  ['SCHLANGER', 'Melanie'],
#  ['TRICKETT', 'Lisbeth'],
#  ['DEKKER', 'Inge'],
#  ['HEEMSKERK', 'Femke'],
#  ['KROMOWIDJOJO', 'Ranomi'],
#  ['SCHREUDER', 'Hinkelien'],
#  ['VAN ROOIJEN', 'Manon'],
#  ['VELDHUIS', 'Marleen'],
#  ['COUGHLIN', 'Natalie'],
#  ['JOYCE', 'Kara Lynn'],
#  ['NYMEYER', 'Lacey'],
#  ['SILVER', 'Emily'],
#  ['SMIT', 'Julia'],
#  ['TORRES', 'Dara'],
#  ['FUJII', 'Takuro'],
#  ['KITAJIMA', 'Kosuke'],
#  ['MIYASHITA', 'Junichi'],
#  ['SATO', 'Hisayoshi'],
#  ['CROCKER', 'Ian'],
#  ['GANGLOFF', 'Mark'],
#  ['GREVERS', 'Matt'],
#  ['HANSEN', 'Brendan'],
#  ['LEZAK', 'Jason'],
#  ['PEIRSOL', 'Aaron'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['DELANEY', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PINE', 'Adam'],
#  ['RICKARD', 'Brenton'],
#  ['SPRENGER', 'Christian'],
#  ['STOECKEL', 'Hayden'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['PANG', 'Jiaying'],
#  ['SUN', 'Ye'],
#  ['XU', 'Tianlongzi'],
#  ['ZHAO', 'Jing'],
#  ['ZHOU', 'Yafei'],
#  ['GALVEZ', 'Felicity'],
#  ['JONES', 'Leisel'],
#  ['REESE', 'Shayne'],
#  ['SCHIPPER', 'Jessicah'],
#  ['SEEBOHM', 'Emily'],
#  ['TRICKETT', 'Lisbeth'],
#  ['WHITE', 'Tarnee'],
#  ['BREEDEN', 'Elaine'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOELZER', 'Margaret'],
#  ['JENDRICK', 'Megan'],
#  ['JOYCE', 'Kara Lynn'],
#  ['MAGNUSON', 'Christine'],
#  ['SONI', 'Rebecca'],
#  ['TORRES', 'Dara'],
#  ['BRITS', 'Grant'],
#  ['BRODIE', 'Leith'],
#  ['FFROST', 'Nick'],
#  ['HACKETT', 'Grant'],
#  ['MURPHY', 'Patrick'],
#  ['PALMER', 'Kirk'],
#  ['BERENS', 'Ricky'],
#  ['KELLER', 'Klete'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['VANDERKAAY', 'Peter'],
#  ['VENDT', 'Erik'],
#  ['WALTERS', 'David'],
#  ['IZOTOV', 'Danila'],
#  ['LAGUNOV', 'Evgeniy'],
#  ['LOBINTSEV', 'Nikita'],
#  ['POLISHCHUK', 'Mikhail'],
#  ['SUKHORUKOV', 'Alexander'],
#  ['BURCKLE', 'Caroline'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOFF', 'Katie'],
#  ['MARSHALL', 'Christine'],
#  ['SCHMITT', 'Allison'],
#  ['SMIT', 'Julia'],
#  ['VANDENBERG', 'Kim'],
#  ['BAINBRIDGE', 'Angie'],
#  ['BARRATT', 'Bronte'],
#  ['DAVENPORT', 'Lara'],
#  ['GALVEZ', 'Felicity'],
#  ['MACKENZIE', 'Linda'],
#  ['PALMER', 'Kylie'],
#  ['RICE', 'Stephanie'],
#  ['SCHLANGER', 'Melanie'],
#  ['PANG', 'Jiaying'],
#  ['TAN', 'Miao'],
#  ['TANG', 'Jingzhi'],
#  ['YANG', 'Yu'],
#  ['ZHU', 'Qianwei'],
#  ['BERNARD', 'Alain'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEVEAUX', 'Amaury'],
#  ['CAMPBELL', 'Cate'],
#  ['STEFFEN', 'Britta'],
#  ['TORRES', 'Dara'],
#  ['FRIIS', 'Lotte'],
#  ['ADLINGTON', 'Rebecca'],
#  ['FILIPPI', 'Alessia'],
#  ['LURZ', 'Thomas'],
#  ['VAN DER WEIJDEN', 'Maarten'],
#  ['DAVIES', 'David'],
#  ['PATTEN', 'Cassandra'],
#  ['ILCHENKO', 'Larisa'],
#  ['PAYNE', 'Keri-Anne'],
#  ['HARADA', 'Saho'],
#  ['SUZUKI', 'Emiko'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['FUENTES', 'Andrea'],
#  ['MENGUAL', 'Gemma'],
#  ['GU', 'Beibei'],
#  ['HUANG', 'Xuechen'],
#  ['JIANG', 'Tingting'],
#  ['JIANG', 'Wenwen'],
#  ['LIU', 'Ou'],
#  ['LUO', 'Xi'],
#  ['SUN', 'Qiuting'],
#  ['WANG', 'Na'],
#  ['ZHANG', 'Xiaohuan'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['GROMOVA', 'Maria'],
#  ['ISHCHENKO', 'Natalia'],
#  ['KHASYANOVA', 'Elvira'],
#  ['KUZHELA', 'Olga'],
#  ['OVCHINNIKOVA', 'Elena'],
#  ['ROMASHINA', 'Svetlana'],
#  ['SHORINA', 'Anna'],
#  ['CABELLO', 'Alba Maria'],
#  ['CORRAL', 'Raquel'],
#  ['FUENTES', 'Andrea'],
#  ['HENRIQUEZ', 'Thais'],
#  ['LOPEZ', 'Laura'],
#  ['MENGUAL', 'Gemma'],
#  ['MORON', 'Gisela'],
#  ['RODRIGUEZ', 'Irina'],
#  ['TIRADOS', 'Paola'],
#  ['CIRIC', 'Aleksandar'],
#  ['FILIPOVIC', 'Filip'],
#  ['GOCIC', 'Zivko'],
#  ['PEKOVIC', 'Branko'],
#  ['PIJETLOVIC', 'Dusko'],
#  ['PRLAINOVIC', 'Andrija'],
#  ['RADJEN', 'Nikola'],
#  ['SAPIC', 'Aleksandar'],
#  ['SAVIC', 'Dejan'],
#  ['SEFIK', 'Denis'],
#  ['SORO', 'Slobodan'],
#  ['UDOVICIC', 'Vanja'],
#  ['VUJASINOVIC', 'Vladimir'],
#  ['BENEDEK', 'Tibor'],
#  ['BIROS', 'Peter'],
#  ['GERGELY', 'Istvan'],
#  ['HOSNYANSZKY', 'Norbert'],
#  ['KASAS', 'Tamas'],
#  ['KIS', 'Gabor'],
#  ['KISS', 'Gergely'],
#  ['MADARAS', 'Norbert'],
#  ['MOLNAR', 'Tamas'],
#  ['SZECSI', 'Zoltan'],
#  ['VARGA', 'Daniel Rudolf'],
#  ['VARGA', 'Denes Andor'],
#  ['VARGA', 'Tamas'],
#  ['AZEVEDO', 'Tony'],
#  ['BAILEY', 'Ryan'],
#  ['BEAUBIEN', 'Layne'],
#  ['BROOKS', 'Brandon'],
#  ['HUDNUT', 'Peter'],
#  ['HUTTEN', 'Tim'],
#  ['KRUMPHOLZ', 'James'],
#  ['MERLO', 'Rick'],
#  ['MOSES', 'Merrill'],
#  ['POWERS', 'Jeffrey'],
#  ['SMITH', 'Jesse'],
#  ['VARELLAS', 'Peter'],
#  ['WRIGHT', 'Adam'],
#  ['BEADSWORTH', 'Gemma'],
#  ['CUFFE', 'Nikita'],
#  ['FRASER', 'Suzie'],
#  ['GOFERS', 'Taniele'],
#  ['GYNTHER', 'Kate'],
#  ['HETZEL', 'Amy'],
#  ['KNOX', 'Bronwen'],
#  ['KNOX', 'Emma'],
#  ['MCCORMACK', 'Alicia'],
#  ['RIPPON', 'Melissa'],
#  ['RIPPON', 'Rebecca'],
#  ['SANTOROMITO', 'Jenna'],
#  ['SANTOROMITO', 'Mia'],
#  ['CABOUT', 'Mieke'],
#  ['DE BRUIJN', 'Danielle'],
#  ['DE NOOY', 'Meike'],
#  ['GUICHELAAR', 'Rianne'],
#  ['HAKHVERDIAN', 'Biurakn'],
#  ['KLEIN', 'Noeki'],
#  ['KOOT', 'Simone'],
#  ['SIJBRING', 'Alette'],
#  ['SMIT', 'Yasemin'],
#  ['VAN BELKUM', 'Iefke'],
#  ['VAN DEN BERG', 'Gillian'],
#  ['VAN DEN HAM', 'Marieke'],
#  ['VAN DER MEIJDEN', 'Ilse'],
#  ['ARMSTRONG', 'Elizabeth'],
#  ['CARDENAS', 'Patty'],
#  ['CRAIG', 'Kami'],
#  ['GOLDA', 'Natalie'],
#  ['GREGORKA', 'Alison'],
#  ['HAYES', 'Brittany'],
#  ['HIPP', 'Jaime'],
#  ['PETRI', 'Heather'],
#  ['STEFFENS', 'Jessica'],
#  ['VAN NORMAN', 'Moriah'],
#  ['VILLA', 'Brenda'],
#  ['WENGER', 'Lauren'],
#  ['WINDES', 'Elsie'],
#  ['BADENOV', 'Bair'],
#  ['RUBAN', 'Viktor'],
#  ['PARK', 'Kyung-Mo'],
#  ['YUN', 'Ok-Hee'],
#  ['ZHANG', 'Juan Juan'],
#  ['PARK', 'Sung-Hyun'],
#  ['JIANG', 'Lin'],
#  ['LI', 'Wenquan'],
#  ['XUE', 'Hai Feng'],
#  ['IM', 'Dong-Hyun'],
#  ['LEE', 'Chang-Hwan'],
#  ['PARK', 'Kyung-Mo'],
#  ["DI BUO'", 'Ilario'],
#  ['GALIAZZO', 'Marco'],
#  ['NESPOLI', 'Mauro'],
#  ['ARNOLD', 'Virginie'],
#  ['DODEMONT', 'Sophie'],
#  ['SCHUH', 'Berengere'],
#  ['JOO', 'Hyun-Jung'],
#  ['PARK', 'Sung-Hyun'],
#  ['YUN', 'Ok-Hee'],
#  ['CHEN', 'Ling'],
#  ['GUO', 'Dan'],
#  ['ZHANG', 'Juan Juan'],
#  ['KOGO', 'Micah'],
#  ['BEKELE', 'Kenenisa'],
#  ['SIHINE', 'Sileshi'],
#  ['FLANAGAN', 'Shalane'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['THOMPSON', 'Richard'],
#  ['FRASER', 'Shelly-ann'],
#  ['SIMPSON', 'Sherone'],
#  ['STEWART', 'Kerron'],
#  ['LOPES-SCHLIEP', 'Priscilla'],
#  ['HARPER', 'Dawn'],
#  ['MCLELLAN', 'Sally'],
#  ['OLIVER', 'David'],
#  ['ROBLES', 'Dayron'],
#  ['PAYNE', 'David'],
#  ['BAALA', 'Mehdi'],
#  ['KIPROP', 'Asbel Kipruto'],
#  ['WILLIS', 'Nicholas'],
#  ['TOBIAS', 'Nataliya'],
#  ['LANGAT', 'Nancy jebet'],
#  ['LISHCHYNSKA', 'Iryna'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['CRAWFORD', 'Shawn'],
#  ['STEWART', 'Kerron'],
#  ['CAMPBELL-BROWN', 'Veronica'],
#  ['FELIX', 'Allyson'],
#  ['RIGAUDO', 'Elisa'],
#  ['KANISKINA', 'Olga'],
#  ['PLATZER', 'Kjersti Tysse'],
#  ['TALLENT', 'Jared'],
#  ['BORCHIN', 'Valeriy'],
#  ['PEREZ', 'Jefferson'],
#  ['MATEELONG', 'Richard Kipkemboi'],
#  ['KIPRUTO', 'Brimin Kiprop'],
#  ['MEKHISSI-B.', 'Mahiedine'],
#  ['VOLKOVA', 'Ekaterina'],
#  ['GALKINA-SAMITOVA', 'Gulnara'],
#  ['JEPKORIR', 'Eunice'],
#  ['NEVILLE', 'David'],
#  ['MERRITT', 'LaShawn'],
#  ['WARINER', 'Jeremy'],
#  ['RICHARDS', 'Sanya'],
#  ['OHURUOGU', 'Christine'],
#  ['WILLIAMS', 'Shericka'],
#  ['JACKSON', 'Bershawn'],
#  ['TAYLOR', 'Angelo'],
#  ['CLEMENT', 'Kerron'],
#  ['DANVERS', 'Tasha'],
#  ['WALKER', 'Melaine'],
#  ['TOSTA', 'Sheena'],
#  ['ASAHARA', 'Nobuharu'],
#  ['SUETSUGU', 'Shingo'],
#  ['TAKAHIRA', 'Shinji'],
#  ['TSUKAHARA', 'Naoki'],
#  ['BOLT', 'Usain'],
#  ['CARTER', 'Nesta'],
#  ['FRATER', 'Michael'],
#  ['POWELL', 'Asafa'],
#  ['BLEDMAN', 'Keston'],
#  ['BURNS', 'Marc'],
#  ['CALLENDER', 'Emmanuel'],
#  ['THOMPSON', 'Richard'],
#  ['IDOKO', 'Franca'],
#  ['ISMAILA', 'Halimat'],
#  ['KEMASUODE', 'Gloria'],
#  ['OSAYOMI', 'Oludamola'],
#  ['CHERMOSHANSKAYA', 'Yuliya'],
#  ['FEDORIVA', 'Aleksandra'],
#  ['GUSHCHINA', 'Yulia'],
#  ['POLYAKOVA', 'Evgeniya'],
#  ['BORLEE', 'Olivia'],
#  ['GEVAERT', 'Kim'],
#  ['MARIEN', 'Hanna'],
#  ['OUEDRAOGO', 'Elodie'],
#  ['ALEXEEV', 'Denis'],
#  ['DYLDIN', 'Maksim'],
#  ['FROLOV', 'Vladislav'],
#  ['KOKORIN', 'Anton'],
#  ['MERRITT', 'LaShawn'],
#  ['NEVILLE', 'David'],
#  ['TAYLOR', 'Angelo'],
#  ['WARINER', 'Jeremy'],
#  ['BAIN', 'Andretti'],
#  ['BROWN', 'Christopher'],
#  ['MATHIEU', 'Michael'],
#  ['WILLIAMS', 'Andrae'],
#  ['LLOYD', 'Shereefa'],
#  ['WHYTE', 'Rosemarie'],
#  ['WILLIAMS', 'Novelene'],
#  ['WILLIAMS', 'Shericka'],
#  ['FELIX', 'Allyson'],
#  ['HENDERSON', 'Monique'],
#  ['RICHARDS', 'Sanya'],
#  ['WINEBERG', 'Mary'],
#  ['FIROVA', 'Tatiana'],
#  ['GUSHCHINA', 'Yulia'],
#  ['KAPACHINSKAYA', 'Anastasia'],
#  ['LITVINOVA', 'Liudmila'],
#  ['SOI', 'Edwin Cheruiyot'],
#  ['BEKELE', 'Kenenisa'],
#  ['KIPCHOGE', 'Eliud'],
#  ['DEFAR', 'Meseret'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['NIZHEGORODOV', 'Denis'],
#  ['SCHWAZER', 'Alex'],
#  ['TALLENT', 'Jared'],
#  ['YEGO', 'Alfred Kirwa'],
#  ['BUNGEI', 'Wilfred'],
#  ['ISMAIL', 'Ismail Ahmed'],
#  ['BENHASSI', 'Hasna'],
#  ['JELIMO', 'Pamela'],
#  ['BUSIENEI', 'Janeth Jepkosgei'],
#  ['SUAREZ', 'Leonel'],
#  ['CLAY', 'Bryan'],
#  ['KRAUCHANKA', 'Andrei'],
#  ['ALEKNA', 'Virgilijus'],
#  ['KANTER', 'Gerd'],
#  ['MALACHOWSKI', 'Piotr'],
#  ['ANTONOVA', 'Olena'],
#  ['BROWN TRAFTON', 'Stephanie'],
#  ['BARRIOS', 'Yarelys'],
#  ['TSIKHAN', 'Ivan'],
#  ['KOZMUS', 'Primoz'],
#  ['DEVYATOVSKIY', 'Vadim'],
#  ['ZHANG', 'Wenxiu'],
#  ['MIANKOVA', 'Aksana'],
#  ['MORENO', 'Yipsi'],
#  ['CHERNOVA', 'Tatiana'],
#  ['DOBRYNSKA', 'Nataliia'],
#  ['FOUNTAIN', 'Hyleas'],
#  ['RYBAKOV', 'Yaroslav'],
#  ['SILNOV', 'Andrey'],
#  ['MASON', 'Germaine'],
#  ['CHICHEROVA', 'Anna'],
#  ['HELLEBAUT', 'Tia'],
#  ['VLASIC', 'Blanka'],
#  ['PITKAMAKI', 'Tero'],
#  ['THORKILDSEN', 'Andreas'],
#  ['KOVALS', 'Ainars'],
#  ['OBERGFOLL', 'Christina'],
#  ['SPOTAKOVA', 'Barbora'],
#  ['ABAKUMOVA', 'Maria'],
#  ['CAMEJO', 'Ibrahim'],
#  ['SALADINO ARANDA', 'Irving Jahir'],
#  ['MOKOENA', 'Khotso'],
#  ['OKAGBARE', 'Blessing'],
#  ['MAGGI', 'Maurren Higa'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['KEBEDE', 'Tsegay'],
#  ['WANSIRU', 'Samuel Kamau'],
#  ['GHARIB', 'Jaouad'],
#  ['ZHOU', 'Chunxiu'],
#  ['TOMESCU', 'Constantina'],
#  ['NDEREBA', 'Catherine'],
#  ['YURCHENKO', 'Denys'],
#  ['HOOKER', 'Steve'],
#  ['LUKYANENKO', 'Evgeny'],
#  ['FEOFANOVA', 'Svetlana'],
#  ['ISINBAEVA', 'Elena'],
#  ['STUCZYNSKI', 'Jennifer'],
#  ['MIKHNEVICH', 'Andrei'],
#  ['MAJEWSKI', 'Tomasz'],
#  ['CANTWELL', 'Christian'],
#  ['OSTAPCHUK', 'Nadzeya'],
#  ['VILI', 'Valerie'],
#  ['MIKHNEVICH', 'Natallia'],
#  ['SANDS', 'Leevan'],
#  ['EVORA', 'Nelson'],
#  ['IDOWU', 'Phillips'],
#  ['DEVETZI', 'Hrysopiyi'],
#  ['MBANGO ETONE', 'Francoise'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['HWANG', 'Jiman'],
#  ['LEE', 'Jaejin'],
#  ['HE', 'Hanbin'],
#  ['KIDO', 'Markis'],
#  ['SETIAWAN', 'Hendra'],
#  ['LEE', 'Yongdae'],
#  ['CAI', 'Yun'],
#  ['FU', 'Haifeng'],
#  ['WIDIANTO', 'Nova'],
#  ['WEI', 'Yili'],
#  ['ZHANG', 'Yawen'],
#  ['YU', 'Yang'],
#  ['DU', 'Jing'],
#  ['YU', 'Yang'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Kyungwon'],
#  ['LILIYANA'],
#  ['CHEN', 'Jin'],
#  ['LIN', 'Dan'],
#  ['LEE', 'Chong Wei'],
#  ['YULIANTI', 'Maria Kristin'],
#  ['ZHANG', 'Ning'],
#  ['XIE', 'Xingfang'],
#  ['ANDERSON', 'Brett'],
#  ['ARRIETA', 'Jake'],
#  ['BARDEN', 'Brian'],
#  ['BROWN', 'Matt'],
#  ['CAHILL', 'Trevor'],
#  ['CUMMINGS', 'Jeremy'],
#  ['DONALD', 'Jason'],
#  ['DUENSING', 'Brian'],
#  ['FOWLER', 'Dexter'],
#  ['GALL', 'John'],
#  ['HESSMAN', 'Mike'],
#  ['JEPSEN', 'Kevin'],
#  ['KNIGHT', 'Brandon'],
#  ['KOPLOVE', 'Michael'],
#  ['LAPORTA', 'Matt'],
#  ['MARSON', 'Lou'],
#  ['NEAL', 'Blaine'],
#  ['NIX', 'Jayson'],
#  ['SCHIERHOLTZ', 'Nate'],
#  ['STEVENS', 'Jeff'],
#  ['STRASBURG', 'Stephen'],
#  ['TEAGARDEN', 'Taylor'],
#  ['TIFFEE', 'Terry'],
#  ['WEATHERS', 'Casey'],
#  ['BONG', 'Jungkeun'],
#  ['CHONG', 'Taehyon'],
#  ['HAN', 'Kijoo'],
#  ['JANG', 'Wonsam'],
#  ['JEONG', 'Keunwoo'],
#  ['JIN', 'Kabyong'],
#  ['KANG', 'Minho'],
#  ['KIM', 'Dongjoo'],
#  ['KIM', 'Hyunsoo'],
#  ['KIM', 'Kwanghyun'],
#  ['KIM', 'Minjae'],
#  ['KO', 'Youngmin'],
#  ['KWON', 'Hyuk'],
#  ['LEE', 'Daeho'],
#  ['LEE', 'Jinyoung'],
#  ['LEE', 'Jongwook'],
#  ['LEE', 'Seungyuop'],
#  ['LEE', 'Taekkeun'],
#  ['LEE', 'Yongkyu'],
#  ['OH', 'Seunghwan'],
#  ['PARK', 'Jinman'],
#  ['RYU', 'Hyunjin'],
#  ['SONG', 'Seungjun'],
#  ['YOON', 'Suk Min'],
#  ['BELL', 'Alexei'],
#  ['CEPEDA', 'Frederich'],
#  ['DESPAIGNE', 'Alfredo'],
#  ['DUVERGEL', 'Giorbis'],
#  ['ENRIQUEZ', 'Michel'],
#  ['GONZALEZ', 'Norberto'],
#  ['GOURRIEL', 'Yuliesky'],
#  ['LA HERA', 'Miguel'],
#  ['LAZO', 'Pedro Luis'],
#  ['MARTINEZ', 'Jonder'],
#  ['MAYETA', 'Alexander'],
#  ['MERINO', 'Rolando'],
#  ['NAVAS', 'Luis'],
#  ['ODELIN SANAME', 'Vicyohandri'],
#  ['OLIVERA', 'Hector'],
#  ['PALMA', 'Adiel'],
#  ['PARET', 'Eduardo'],
#  ['PEDROSO', 'Yadier'],
#  ['PESTANO', 'Ariel'],
#  ['RODRIGUEZ', 'Luis'],
#  ['SANCHEZ', 'Elier'],
#  ['SANCHEZ', 'Eriel'],
#  ['URGELLES', 'Yoandry'],
#  ['VERA', 'Norge Luis'],
#  ['DELFINO', 'Carlos Francisco'],
#  ['GINOBILI', 'Emanuel David'],
#  ['GONZALEZ', 'Roman Javier'],
#  ['GUTIERREZ LLANAS', 'Juan Pedro'],
#  ['GUTIERREZ', 'Leonardo Martin'],
#  ['KAMMERICHS', 'Guillermo Federico'],
#  ['NOCIONI', 'Andres Marcelo'],
#  ['OBERTO', 'Fabricio Raul Jesus'],
#  ['PORTA PERNIGOTTI', 'Antonio Alejandro'],
#  ['PRIGIONI', 'Pablo'],
#  ['QUINTEROS', 'Alfredo Paolo'],
#  ['SCOLA', 'Luis Alberto'],
#  ['ANTHONY', 'Carmelo'],
#  ['BOOZER', 'Carlos'],
#  ['BOSH', 'Chris'],
#  ['BRYANT', 'Kobe'],
#  ['HOWARD', 'Dwight'],
#  ['JAMES', 'Lebron'],
#  ['KIDD', 'Jason'],
#  ['PAUL', 'Chris'],
#  ['PRINCE', 'Tayshaun'],
#  ['REDD', 'Michael'],
#  ['WADE', 'Dwyane'],
#  ['WILLIAMS', 'Deron'],
#  ['CALDERON', 'Jose Manuel'],
#  ['FERNANDEZ', 'Rudy'],
#  ['GARBAJOSA', 'Jorge'],
#  ['GASOL', 'Marc'],
#  ['GASOL', 'Pau'],
#  ['JIMENEZ', 'Carlos'],
#  ['LOPEZ', 'Raul'],
#  ['MUMBRU', 'Alex'],
#  ['NAVARRO', 'Juan Carlos'],
#  ['REYES', 'Felipe'],
#  ['RODRIGUEZ', 'Berni'],
#  ['RUBIO', 'Ricky'],
#  ['ABROSIMOVA', 'Svetlana'],
#  ['HAMMON', 'Rebekka Linn'],
#  ['KARPUNINA', 'Marina'],
#  ['KORSTIN', 'Ilona'],
#  ['KUZINA', 'Marina'],
#  ['LISINA', 'Ekaterina'],
#  ['OSIPOVA', 'Irina'],
#  ['RAKHMATULINA', 'Oxana'],
#  ['SHCHEGOLEVA', 'Tatiana'],
#  ['SOKOLOVSKAYA', 'Irina'],
#  ['STEPANOVA', 'Maria'],
#  ['VODOPYANOVA', 'Natalia'],
#  ['AUGUSTUS', 'Seimone'],
#  ['BIRD', 'Sue'],
#  ['CATCHINGS', 'Tamika'],
#  ['FOWLES', 'Sylvia'],
#  ['LAWSON', 'Kara'],
#  ['LESLIE', 'Lisa'],
#  ['MILTON-JONES', 'Delisha'],
#  ['PARKER', 'Candace'],
#  ['PONDEXTER', 'Cappie'],
#  ['SMITH', 'Katie'],
#  ['TAURASI', 'Diana'],
#  ['THOMPSON', 'Tina'],
#  ['BATKOVIC', 'Suzy'],
#  ['BEVILAQUA', 'Tully'],
#  ['COX', 'Rohanee'],
#  ['GRIMA', 'Hollie'],
#  ['HARROWER', 'Kristi'],
#  ['JACKSON', 'Lauren'],
#  ['PHILLIPS', 'Erin'],
#  ['RANDALL', 'Emma'],
#  ['SCREEN', 'Jenni'],
#  ['SNELL', 'Belinda'],
#  ['SUMMERTON', 'Laura'],
#  ['TAYLOR', 'Penny'],
#  ['GLAZKOV', 'Vyacheslav'],
#  ['PRICE', 'David'],
#  ['CAMMARELLE', 'Roberto'],
#  ['ZHANG', 'Zhilei'],
#  ['BALAKSHIN', 'Georgy'],
#  ['PICARDI', 'Vincenzo'],
#  ['JONGJOHOR', 'Somjit'],
#  ['LAFFITA HERNANDEZ', 'Andris'],
#  ['BARNES', 'Paddy'],
#  ['HERNANDEZ G', 'Yampier'],
#  ['ZOU', 'Shiming'],
#  ['PUREVDORJ', 'Serdamba'],
#  ['GOJAN', 'Veaceslav'],
#  ['JULIE', 'Bruno'],
#  ['ENKHBAT', 'Badar-Uugan'],
#  ['LEON ALARCON', 'Yankiel'],
#  ['IMRANOV', 'Shahin'],
#  ['KILIC', 'Yakup'],
#  ['LOMACHENKO', 'Vasyl'],
#  ['DJELKHIR', 'Khedafi'],
#  ['JAVAKHYAN', 'Hrachik'],
#  ['UGAS', 'Yordenis'],
#  ['TISHCHENKO', 'Alexey'],
#  ['SOW', 'Daouda'],
#  ['IGLESIAS SOTOLONGO', 'Roniel'],
#  ['VASTINE', 'Alexis'],
#  ['DIAZ', 'Felix'],
#  ['BOONJUMNONG', 'Manus'],
#  ['HANATI', 'Silamu'],
#  ['KIM', 'Jungjoo'],
#  ['SARSEKBAYEV', 'Bakhyt'],
#  ['BANTEAUX SUAREZ', 'Carlos'],
#  ['KUMAR', 'Vijender'],
#  ['SUTHERLAND', 'Darren John'],
#  ['DEGALE', 'James'],
#  ['CORREA BAYEAUX', 'Emilio'],
#  ['JEFFRIES', 'Tony'],
#  ['SHYNALIYEV', 'Yerkebulan'],
#  ['ZHANG', 'Xiaoping'],
#  ['EGAN', 'Kenny'],
#  ['ACOSTA DUARTE', 'Osmai'],
#  ['WILDER', 'Deontay'],
#  ['CHAKHKIEV', 'Rakhim'],
#  ['RUSSO', 'Clemente'],
#  ['HALL', 'Thomas'],
#  ['VAJDA', 'Attila Sandor'],
#  ['CAL', 'David'],
#  ['CHEBAN', 'Iurii'],
#  ['OPALEV', 'Maxim'],
#  ['CAL', 'David'],
#  ['KISS', 'Tamas'],
#  ['KOZMANN', 'Gyorgy'],
#  ['BAHDANOVICH', 'Aliaksandr'],
#  ['BAHDANOVICH', 'Andrei'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['MENG', 'Guanliang'],
#  ['YANG', 'Wenjun'],
#  ['KOSTOGLOD', 'Alexander'],
#  ['ULEGIN', 'Sergey'],
#  ['WALLACE', 'Ken'],
#  ['BRABANTS', 'Tim'],
#  ['LARSEN', 'Eirik Veraas'],
#  ['BRABANTS', 'Tim'],
#  ['WALLACE', 'Ken'],
#  ['VAN KOEVERDEN', 'Adam'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['OSYPENKO-RADOMSKA', 'Inna'],
#  ['IDEM', 'Josefa'],
#  ['FACCHIN', 'Andrea'],
#  ['SCADUTO', 'Antonio Massimiliano'],
#  ['HOLLSTEIN', 'Martin'],
#  ['IHLE', 'Andreas'],
#  ['KNUDSEN', 'Kim Wraae'],
#  ['POULSEN', 'Rene Holten'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['CRAVIOTTO', 'Saul'],
#  ['PEREZ', 'Carlos'],
#  ['RAUHE', 'Ronald'],
#  ['WIESKOTTER', 'Tim'],
#  ['DELATTRE', 'Marie'],
#  ['VIARD', 'Anne-Laure'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KONIECZNA', 'Aneta'],
#  ['MIKOLAJCZYK', 'Beata'],
#  ['ALTEPOST', 'Lutz'],
#  ['BROCKL', 'Norman'],
#  ['ECKBRETT', 'Torsten'],
#  ['GOLDSCHMIDT', 'Bjorn'],
#  ['ABALMASAU', 'Aliaksei'],
#  ['LITVINCHUK', 'Artur'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['RISZDORFER', 'Michal'],
#  ['RISZDORFER', 'Richard'],
#  ['TARR', 'Juraj'],
#  ['VLCEK', 'Erik'],
#  ['DAVIS', 'Hannah'],
#  ['FOGARTY', 'Lyndsie'],
#  ['MEEK', 'Chantal'],
#  ['OLDENHOF', 'Lisa'],
#  ['FISCHER', 'Fanny'],
#  ['REINHARDT', 'Nicole'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['WASSMUTH', 'Conny'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KOZAK', 'Danuta'],
#  ['SZABO', 'Gabriella Timea'],
#  ['BELL', 'Robin'],
#  ['MARTIKAN', 'Michal'],
#  ['FLORENCE', 'David'],
#  ['KUZNETSOV', 'Mikhail'],
#  ['LARIONOV', 'Dmitry'],
#  ['HOCHSCHORNER', 'Pavol'],
#  ['HOCHSCHORNER', 'Peter'],
#  ['STEPANEK', 'Ondrej'],
#  ['VOLF', 'Jaroslav'],
#  ['BOUKPETI', 'Benjamin'],
#  ['GRIMM', 'Alexander'],
#  ['LEFEVRE', 'Fabien'],
#  ['OBLINGER PETERS', 'Violetta'],
#  ['KALISKA', 'Elena'],
#  ['LAWRENCE', 'Jacqueline'],
#  ['ROBINSON', 'Donny'],
#  ['STROMBERGS', 'Maris'],
#  ['DAY', 'Mike'],
#  ['KINTNER', 'Jill'],
#  ['CHAUSSON', 'Anne-Caroline'],
#  ['LE CORGUILLE', 'Laetitia'],
#  ['CANCELLARA', 'Fabian'],
#  ['SANCHEZ', 'Samuel'],
#  ['GUDERZO', 'Tatiana'],
#  ['COOKE', 'Nicole'],
#  ['JOHANSSON', 'Emma'],
#  ['LEIPHEIMER', 'Levi'],
#  ['CANCELLARA', 'Fabian'],
#  ['LARSSON', 'Gustav'],
#  ['THURIG', 'Karin'],
#  ['ARMSTRONG', 'Kristin'],
#  ['POOLEY', 'Emma'],
#  ['BURKE', 'Steven'],
#  ['WIGGINS', 'Bradley'],
#  ['ROULSTON', 'Hayden'],
#  ['KALITOVSKA', 'Lesya'],
#  ['ROMERO', 'Rebecca'],
#  ['HOUVENAGHEL', 'Wendy'],
#  ['NAGAI', 'Kiyofumi'],
#  ['HOY', 'Chris'],
#  ['EDGAR', 'Ross'],
#  ['IGNATYEV', 'Mikhail'],
#  ['MARKOV', 'Alexei'],
#  ['CURUCHET', 'Juan Esteban'],
#  ['PEREZ', 'Walter Fernando'],
#  ['LLANERAS', 'Joan'],
#  ['TAULER', 'Antonio'],
#  ['NEWTON', 'Chris'],
#  ['LLANERAS', 'Joan'],
#  ['KLUGE', 'Roger'],
#  ['OLABERRIA', 'Leire'],
#  ['VOS', 'Marianne'],
#  ['GONZALEZ', 'Yoanka'],
#  ['GUO', 'Shuang'],
#  ['PENDLETON', 'Victoria'],
#  ['MEARES', 'Anna'],
#  ['BOURGAIN', 'Mickael'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['BEWLEY', 'Sam'],
#  ['ROULSTON', 'Hayden'],
#  ['RYAN', 'Marc'],
#  ['SERGENT', 'Jesse'],
#  ['CLANCY', 'Ed'],
#  ['MANNING', 'Paul'],
#  ['THOMAS', 'Geraint'],
#  ['WIGGINS', 'Bradley'],
#  ['JOERGENSEN', 'Casper'],
#  ['MADSEN', 'Jens-Erik'],
#  ['MOERKOEV', 'Michael'],
#  ['RASMUSSEN', 'Alex Nicki'],
#  ['ENDERS', 'Rene'],
#  ['LEVY', 'Maximilian'],
#  ['NIMKE', 'Stefan'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['STAFF', 'Jamie'],
#  ['BAUGE', 'Gregory'],
#  ['SIREAU', 'Kevin'],
#  ['TOURNANT', 'Arnaud'],
#  ['SCHURTER', 'Nino'],
#  ['ABSALON', 'Julien'],
#  ['PERAUD', 'Jean-Christophe'],
#  ['KALENTYEVA', 'Irina'],
#  ['SPITZ', 'Sabine'],
#  ['WLOSZCZOWSKA', 'Maja'],
#  ['KEMMER', 'Heike'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['WERTH', 'Isabell'],
#  ['HELGSTRAND', 'Andreas'],
#  ['MINDERHOUD', 'Hans Peter'],
#  ['VAN OLST', 'Anne'],
#  ['ZU-SAYN WITTGENSTEIN', 'Nathalie'],
#  ['CAPELLMANN', 'Nadine'],
#  ['KEMMER', 'Heike'],
#  ['WERTH', 'Isabell'],
#  ['SCHELLEKENS-BARTELS', 'Imke'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['ROMEIKE', 'Hinrich'],
#  ['COOK', 'Kristina'],
#  ['MILES', 'Gina'],
#  ['FOX-PITT', 'William'],
#  ['DIBOWSKI', 'Andreas'],
#  ['OSTHOLT', 'Frank'],
#  ['ROMEIKE', 'Hinrich'],
#  ['THOMSEN', 'Peter'],
#  ['FREDERICKS', 'Clayton'],
#  ['ROSE', 'Shane'],
#  ['COOK', 'Kristina'],
#  ['DICK', 'Daisy'],
#  ['HUNT', 'Sharon'],
#  ['KING', 'Mary'],
#  ['KLIMKE', 'Ingrid'],
#  ['FREDERICKS', 'Lucinda'],
#  ['JOHNSON', 'Sonja'],
#  ['JONES', 'Megan'],
#  ['LAMAZE', 'Eric'],
#  ['BENGTSSON', 'Rolf-Goran'],
#  ['MADDEN', 'Beezie'],
#  ['GUERDAT', 'Steve'],
#  ['SCHURTENBERGER', 'Niklaus'],
#  ['SCHWIZER', 'Pius'],
#  ['SIMPSON', 'Will'],
#  ['WARD', 'Mclain'],
#  ['CONE', 'Mac'],
#  ['LAMAZE', 'Eric'],
#  ['MILLAR', 'Ian'],
#  ['LIEBHERR', 'Christina'],
#  ['KRAUT', 'Laura'],
#  ['MADDEN', 'Beezie'],
#  ['HENSELWOOD', 'Jill'],
#  ['ABAJO', 'Jose Luis'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['MINCZA-NEBALD', 'Ildiko'],
#  ['HEIDEMANN', 'Britta'],
#  ['BRANZA', 'Ana Maria'],
#  ['CAROZZO', 'Stefano'],
#  ['CONFALONIERI', 'Diego'],
#  ['ROTA', 'Alfredo'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['JEANNET', 'Jerome'],
#  ['ROBEIRI', 'Ulrich'],
#  ['ANDRZEJUK', 'Robert'],
#  ['MOTYKA', 'Tomasz'],
#  ['WIERCIOCH', 'Adam'],
#  ['ZAWROTNIAK', 'Radoslaw'],
#  ['SANZO', 'Salvatore'],
#  ['KLEIBRINK', 'Benjamin'],
#  ['OTA', 'Yuki'],
#  ['GRANBASSI', 'Margherita'],
#  ['VEZZALI', 'Valentina'],
#  ['NAM', 'Hyunhee'],
#  ['GRANBASSI', 'Margherita'],
#  ['SALVATORI', 'Ilaria'],
#  ['TRILLINI', 'Giovanna'],
#  ['VEZZALI', 'Valentina'],
#  ['BOYKO', 'Svetlana'],
#  ['CHANAEVA', 'Aida'],
#  ['LAMONOVA', 'Evgenia'],
#  ['NIKICHINA', 'Victoria'],
#  ['CROSS', 'Emily'],
#  ['SMART', 'Erinn'],
#  ['THOMPSON', 'Hanna'],
#  ['COVALIU', 'Mihai'],
#  ['ZHONG', 'Man'],
#  ['LOPEZ', 'Nicolas'],
#  ['WARD', 'Becca'],
#  ['ZAGUNIS', 'Mariel'],
#  ['JACOBSON', 'Sada'],
#  ...]

# %%
import re

search_string = "upper"

[func for func in dir(nw["Athlete Name"].str) if re.search(rf"{search_string}", func, re.IGNORECASE)]
# Out:
# ['isupper', 'upper']

# %%
[athlete_name for athlete_name in athlete_names]
# Out:
# [['GALPERIN', 'Gleb'],
#  ['MITCHAM', 'Matthew'],
#  ['ZHOU', 'Luxin'],
#  ['WANG', 'Xin'],
#  ['CHEN', 'Ruolin'],
#  ['HEYMANS', 'Emilie'],
#  ['QIN', 'Kai'],
#  ['HE', 'Chong'],
#  ['DESPATIE', 'Alexandre'],
#  ['WU', 'Minxia'],
#  ['GUO', 'Jingjing'],
#  ['PAKHALINA', 'Julia'],
#  ['DOBROSKOK', 'Dmitriy'],
#  ['GALPERIN', 'Gleb'],
#  ['HUO', 'Liang'],
#  ['LIN', 'Yue'],
#  ['HAUSDING', 'Patrick'],
#  ['KLEIN', 'Sascha'],
#  ['ESPINOSA', 'Paola'],
#  ['ORTIZ', 'Tatiana'],
#  ['CHEN', 'Ruolin'],
#  ['WANG', 'Xin'],
#  ['COLE', 'Briony'],
#  ['WU', 'Melissa'],
#  ['KVASHA', 'Illya'],
#  ['PRYGOROV', 'Oleksiy'],
#  ['QIN', 'Kai'],
#  ['WANG', 'Feng'],
#  ['KUNAKOV', 'Yuriy'],
#  ['SAUTIN', 'Dmitry'],
#  ['FISCHER', 'Heike'],
#  ['KOTZIAN', 'Ditte'],
#  ['GUO', 'Jingjing'],
#  ['WU', 'Minxia'],
#  ['PAKHALINA', 'Julia'],
#  ['POZDNYAKOVA', 'Anastasia'],
#  ['STOECKEL', 'Hayden'],
#  ['VYATCHANIN', 'Arkady'],
#  ['PEIRSOL', 'Aaron'],
#  ['GREVERS', 'Matt'],
#  ['HOELZER', 'Margaret'],
#  ['COUGHLIN', 'Natalie'],
#  ['COVENTRY', 'Kirsty'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['OEN', 'Alexander Dale'],
#  ['JUKIC', 'Mirna'],
#  ['JONES', 'Leisel'],
#  ['SONI', 'Rebecca'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PHELPS', 'Michael'],
#  ['CAVIC', 'Milorad'],
#  ['SCHIPPER', 'Jessicah'],
#  ['TRICKETT', 'Lisbeth'],
#  ['MAGNUSON', 'Christine'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEZAK', 'Jason'],
#  ['BERNARD', 'Alain'],
#  ['SULLIVAN', 'Eamon'],
#  ['COUGHLIN', 'Natalie'],
#  ['STEFFEN', 'Britta'],
#  ['TRICKETT', 'Lisbeth'],
#  ['COCHRANE', 'Ryan'],
#  ['MELLOULI', 'Oussama'],
#  ['HACKETT', 'Grant'],
#  ['VYATCHANIN', 'Arkady'],
#  ['LOCHTE', 'Ryan'],
#  ['PEIRSOL', 'Aaron'],
#  ['NAKAMURA', 'Reiko'],
#  ['COVENTRY', 'Kirsty'],
#  ['HOELZER', 'Margaret'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['RICKARD', 'Brenton'],
#  ['NORDENSTAM', 'Sara'],
#  ['SONI', 'Rebecca'],
#  ['JONES', 'Leisel'],
#  ['MATSUDA', 'Takeshi'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['SCHIPPER', 'Jessicah'],
#  ['LIU', 'Zige'],
#  ['JIAO', 'Liuyang'],
#  ['VANDERKAAY', 'Peter'],
#  ['PHELPS', 'Michael'],
#  ['PARK', 'Taehwan'],
#  ['PANG', 'Jiaying'],
#  ['PELLEGRINI', 'Federica'],
#  ['ISAKOVIC', 'Sara'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['COUGHLIN', 'Natalie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['JENSEN', 'Larsen'],
#  ['PARK', 'Taehwan'],
#  ['ZHANG', 'Lin'],
#  ['JACKSON', 'Joanne'],
#  ['ADLINGTON', 'Rebecca'],
#  ['HOFF', 'Katie'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['HOFF', 'Katie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['BRODIE', 'Leith'],
#  ['CALLUS', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['MURPHY', 'Patrick'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['ADRIAN', 'Nathan'],
#  ['GREVERS', 'Matt'],
#  ['JONES', 'Cullen'],
#  ['LEZAK', 'Jason'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['WILDMAN-TOBRINER', 'Ben'],
#  ['BERNARD', 'Alain'],
#  ['BOUSQUET', 'Frederick'],
#  ['GILOT', 'Fabien'],
#  ['LEVEAUX', 'Amaury'],
#  ['MALLET', 'Gregory'],
#  ['STEIMETZ', 'Boris'],
#  ['CAMPBELL', 'Cate'],
#  ['MILLS', 'Alice'],
#  ['REESE', 'Shayne'],
#  ['SCHLANGER', 'Melanie'],
#  ['TRICKETT', 'Lisbeth'],
#  ['DEKKER', 'Inge'],
#  ['HEEMSKERK', 'Femke'],
#  ['KROMOWIDJOJO', 'Ranomi'],
#  ['SCHREUDER', 'Hinkelien'],
#  ['VAN ROOIJEN', 'Manon'],
#  ['VELDHUIS', 'Marleen'],
#  ['COUGHLIN', 'Natalie'],
#  ['JOYCE', 'Kara Lynn'],
#  ['NYMEYER', 'Lacey'],
#  ['SILVER', 'Emily'],
#  ['SMIT', 'Julia'],
#  ['TORRES', 'Dara'],
#  ['FUJII', 'Takuro'],
#  ['KITAJIMA', 'Kosuke'],
#  ['MIYASHITA', 'Junichi'],
#  ['SATO', 'Hisayoshi'],
#  ['CROCKER', 'Ian'],
#  ['GANGLOFF', 'Mark'],
#  ['GREVERS', 'Matt'],
#  ['HANSEN', 'Brendan'],
#  ['LEZAK', 'Jason'],
#  ['PEIRSOL', 'Aaron'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['DELANEY', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PINE', 'Adam'],
#  ['RICKARD', 'Brenton'],
#  ['SPRENGER', 'Christian'],
#  ['STOECKEL', 'Hayden'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['PANG', 'Jiaying'],
#  ['SUN', 'Ye'],
#  ['XU', 'Tianlongzi'],
#  ['ZHAO', 'Jing'],
#  ['ZHOU', 'Yafei'],
#  ['GALVEZ', 'Felicity'],
#  ['JONES', 'Leisel'],
#  ['REESE', 'Shayne'],
#  ['SCHIPPER', 'Jessicah'],
#  ['SEEBOHM', 'Emily'],
#  ['TRICKETT', 'Lisbeth'],
#  ['WHITE', 'Tarnee'],
#  ['BREEDEN', 'Elaine'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOELZER', 'Margaret'],
#  ['JENDRICK', 'Megan'],
#  ['JOYCE', 'Kara Lynn'],
#  ['MAGNUSON', 'Christine'],
#  ['SONI', 'Rebecca'],
#  ['TORRES', 'Dara'],
#  ['BRITS', 'Grant'],
#  ['BRODIE', 'Leith'],
#  ['FFROST', 'Nick'],
#  ['HACKETT', 'Grant'],
#  ['MURPHY', 'Patrick'],
#  ['PALMER', 'Kirk'],
#  ['BERENS', 'Ricky'],
#  ['KELLER', 'Klete'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['VANDERKAAY', 'Peter'],
#  ['VENDT', 'Erik'],
#  ['WALTERS', 'David'],
#  ['IZOTOV', 'Danila'],
#  ['LAGUNOV', 'Evgeniy'],
#  ['LOBINTSEV', 'Nikita'],
#  ['POLISHCHUK', 'Mikhail'],
#  ['SUKHORUKOV', 'Alexander'],
#  ['BURCKLE', 'Caroline'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOFF', 'Katie'],
#  ['MARSHALL', 'Christine'],
#  ['SCHMITT', 'Allison'],
#  ['SMIT', 'Julia'],
#  ['VANDENBERG', 'Kim'],
#  ['BAINBRIDGE', 'Angie'],
#  ['BARRATT', 'Bronte'],
#  ['DAVENPORT', 'Lara'],
#  ['GALVEZ', 'Felicity'],
#  ['MACKENZIE', 'Linda'],
#  ['PALMER', 'Kylie'],
#  ['RICE', 'Stephanie'],
#  ['SCHLANGER', 'Melanie'],
#  ['PANG', 'Jiaying'],
#  ['TAN', 'Miao'],
#  ['TANG', 'Jingzhi'],
#  ['YANG', 'Yu'],
#  ['ZHU', 'Qianwei'],
#  ['BERNARD', 'Alain'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEVEAUX', 'Amaury'],
#  ['CAMPBELL', 'Cate'],
#  ['STEFFEN', 'Britta'],
#  ['TORRES', 'Dara'],
#  ['FRIIS', 'Lotte'],
#  ['ADLINGTON', 'Rebecca'],
#  ['FILIPPI', 'Alessia'],
#  ['LURZ', 'Thomas'],
#  ['VAN DER WEIJDEN', 'Maarten'],
#  ['DAVIES', 'David'],
#  ['PATTEN', 'Cassandra'],
#  ['ILCHENKO', 'Larisa'],
#  ['PAYNE', 'Keri-Anne'],
#  ['HARADA', 'Saho'],
#  ['SUZUKI', 'Emiko'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['FUENTES', 'Andrea'],
#  ['MENGUAL', 'Gemma'],
#  ['GU', 'Beibei'],
#  ['HUANG', 'Xuechen'],
#  ['JIANG', 'Tingting'],
#  ['JIANG', 'Wenwen'],
#  ['LIU', 'Ou'],
#  ['LUO', 'Xi'],
#  ['SUN', 'Qiuting'],
#  ['WANG', 'Na'],
#  ['ZHANG', 'Xiaohuan'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['GROMOVA', 'Maria'],
#  ['ISHCHENKO', 'Natalia'],
#  ['KHASYANOVA', 'Elvira'],
#  ['KUZHELA', 'Olga'],
#  ['OVCHINNIKOVA', 'Elena'],
#  ['ROMASHINA', 'Svetlana'],
#  ['SHORINA', 'Anna'],
#  ['CABELLO', 'Alba Maria'],
#  ['CORRAL', 'Raquel'],
#  ['FUENTES', 'Andrea'],
#  ['HENRIQUEZ', 'Thais'],
#  ['LOPEZ', 'Laura'],
#  ['MENGUAL', 'Gemma'],
#  ['MORON', 'Gisela'],
#  ['RODRIGUEZ', 'Irina'],
#  ['TIRADOS', 'Paola'],
#  ['CIRIC', 'Aleksandar'],
#  ['FILIPOVIC', 'Filip'],
#  ['GOCIC', 'Zivko'],
#  ['PEKOVIC', 'Branko'],
#  ['PIJETLOVIC', 'Dusko'],
#  ['PRLAINOVIC', 'Andrija'],
#  ['RADJEN', 'Nikola'],
#  ['SAPIC', 'Aleksandar'],
#  ['SAVIC', 'Dejan'],
#  ['SEFIK', 'Denis'],
#  ['SORO', 'Slobodan'],
#  ['UDOVICIC', 'Vanja'],
#  ['VUJASINOVIC', 'Vladimir'],
#  ['BENEDEK', 'Tibor'],
#  ['BIROS', 'Peter'],
#  ['GERGELY', 'Istvan'],
#  ['HOSNYANSZKY', 'Norbert'],
#  ['KASAS', 'Tamas'],
#  ['KIS', 'Gabor'],
#  ['KISS', 'Gergely'],
#  ['MADARAS', 'Norbert'],
#  ['MOLNAR', 'Tamas'],
#  ['SZECSI', 'Zoltan'],
#  ['VARGA', 'Daniel Rudolf'],
#  ['VARGA', 'Denes Andor'],
#  ['VARGA', 'Tamas'],
#  ['AZEVEDO', 'Tony'],
#  ['BAILEY', 'Ryan'],
#  ['BEAUBIEN', 'Layne'],
#  ['BROOKS', 'Brandon'],
#  ['HUDNUT', 'Peter'],
#  ['HUTTEN', 'Tim'],
#  ['KRUMPHOLZ', 'James'],
#  ['MERLO', 'Rick'],
#  ['MOSES', 'Merrill'],
#  ['POWERS', 'Jeffrey'],
#  ['SMITH', 'Jesse'],
#  ['VARELLAS', 'Peter'],
#  ['WRIGHT', 'Adam'],
#  ['BEADSWORTH', 'Gemma'],
#  ['CUFFE', 'Nikita'],
#  ['FRASER', 'Suzie'],
#  ['GOFERS', 'Taniele'],
#  ['GYNTHER', 'Kate'],
#  ['HETZEL', 'Amy'],
#  ['KNOX', 'Bronwen'],
#  ['KNOX', 'Emma'],
#  ['MCCORMACK', 'Alicia'],
#  ['RIPPON', 'Melissa'],
#  ['RIPPON', 'Rebecca'],
#  ['SANTOROMITO', 'Jenna'],
#  ['SANTOROMITO', 'Mia'],
#  ['CABOUT', 'Mieke'],
#  ['DE BRUIJN', 'Danielle'],
#  ['DE NOOY', 'Meike'],
#  ['GUICHELAAR', 'Rianne'],
#  ['HAKHVERDIAN', 'Biurakn'],
#  ['KLEIN', 'Noeki'],
#  ['KOOT', 'Simone'],
#  ['SIJBRING', 'Alette'],
#  ['SMIT', 'Yasemin'],
#  ['VAN BELKUM', 'Iefke'],
#  ['VAN DEN BERG', 'Gillian'],
#  ['VAN DEN HAM', 'Marieke'],
#  ['VAN DER MEIJDEN', 'Ilse'],
#  ['ARMSTRONG', 'Elizabeth'],
#  ['CARDENAS', 'Patty'],
#  ['CRAIG', 'Kami'],
#  ['GOLDA', 'Natalie'],
#  ['GREGORKA', 'Alison'],
#  ['HAYES', 'Brittany'],
#  ['HIPP', 'Jaime'],
#  ['PETRI', 'Heather'],
#  ['STEFFENS', 'Jessica'],
#  ['VAN NORMAN', 'Moriah'],
#  ['VILLA', 'Brenda'],
#  ['WENGER', 'Lauren'],
#  ['WINDES', 'Elsie'],
#  ['BADENOV', 'Bair'],
#  ['RUBAN', 'Viktor'],
#  ['PARK', 'Kyung-Mo'],
#  ['YUN', 'Ok-Hee'],
#  ['ZHANG', 'Juan Juan'],
#  ['PARK', 'Sung-Hyun'],
#  ['JIANG', 'Lin'],
#  ['LI', 'Wenquan'],
#  ['XUE', 'Hai Feng'],
#  ['IM', 'Dong-Hyun'],
#  ['LEE', 'Chang-Hwan'],
#  ['PARK', 'Kyung-Mo'],
#  ["DI BUO'", 'Ilario'],
#  ['GALIAZZO', 'Marco'],
#  ['NESPOLI', 'Mauro'],
#  ['ARNOLD', 'Virginie'],
#  ['DODEMONT', 'Sophie'],
#  ['SCHUH', 'Berengere'],
#  ['JOO', 'Hyun-Jung'],
#  ['PARK', 'Sung-Hyun'],
#  ['YUN', 'Ok-Hee'],
#  ['CHEN', 'Ling'],
#  ['GUO', 'Dan'],
#  ['ZHANG', 'Juan Juan'],
#  ['KOGO', 'Micah'],
#  ['BEKELE', 'Kenenisa'],
#  ['SIHINE', 'Sileshi'],
#  ['FLANAGAN', 'Shalane'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['THOMPSON', 'Richard'],
#  ['FRASER', 'Shelly-ann'],
#  ['SIMPSON', 'Sherone'],
#  ['STEWART', 'Kerron'],
#  ['LOPES-SCHLIEP', 'Priscilla'],
#  ['HARPER', 'Dawn'],
#  ['MCLELLAN', 'Sally'],
#  ['OLIVER', 'David'],
#  ['ROBLES', 'Dayron'],
#  ['PAYNE', 'David'],
#  ['BAALA', 'Mehdi'],
#  ['KIPROP', 'Asbel Kipruto'],
#  ['WILLIS', 'Nicholas'],
#  ['TOBIAS', 'Nataliya'],
#  ['LANGAT', 'Nancy jebet'],
#  ['LISHCHYNSKA', 'Iryna'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['CRAWFORD', 'Shawn'],
#  ['STEWART', 'Kerron'],
#  ['CAMPBELL-BROWN', 'Veronica'],
#  ['FELIX', 'Allyson'],
#  ['RIGAUDO', 'Elisa'],
#  ['KANISKINA', 'Olga'],
#  ['PLATZER', 'Kjersti Tysse'],
#  ['TALLENT', 'Jared'],
#  ['BORCHIN', 'Valeriy'],
#  ['PEREZ', 'Jefferson'],
#  ['MATEELONG', 'Richard Kipkemboi'],
#  ['KIPRUTO', 'Brimin Kiprop'],
#  ['MEKHISSI-B.', 'Mahiedine'],
#  ['VOLKOVA', 'Ekaterina'],
#  ['GALKINA-SAMITOVA', 'Gulnara'],
#  ['JEPKORIR', 'Eunice'],
#  ['NEVILLE', 'David'],
#  ['MERRITT', 'LaShawn'],
#  ['WARINER', 'Jeremy'],
#  ['RICHARDS', 'Sanya'],
#  ['OHURUOGU', 'Christine'],
#  ['WILLIAMS', 'Shericka'],
#  ['JACKSON', 'Bershawn'],
#  ['TAYLOR', 'Angelo'],
#  ['CLEMENT', 'Kerron'],
#  ['DANVERS', 'Tasha'],
#  ['WALKER', 'Melaine'],
#  ['TOSTA', 'Sheena'],
#  ['ASAHARA', 'Nobuharu'],
#  ['SUETSUGU', 'Shingo'],
#  ['TAKAHIRA', 'Shinji'],
#  ['TSUKAHARA', 'Naoki'],
#  ['BOLT', 'Usain'],
#  ['CARTER', 'Nesta'],
#  ['FRATER', 'Michael'],
#  ['POWELL', 'Asafa'],
#  ['BLEDMAN', 'Keston'],
#  ['BURNS', 'Marc'],
#  ['CALLENDER', 'Emmanuel'],
#  ['THOMPSON', 'Richard'],
#  ['IDOKO', 'Franca'],
#  ['ISMAILA', 'Halimat'],
#  ['KEMASUODE', 'Gloria'],
#  ['OSAYOMI', 'Oludamola'],
#  ['CHERMOSHANSKAYA', 'Yuliya'],
#  ['FEDORIVA', 'Aleksandra'],
#  ['GUSHCHINA', 'Yulia'],
#  ['POLYAKOVA', 'Evgeniya'],
#  ['BORLEE', 'Olivia'],
#  ['GEVAERT', 'Kim'],
#  ['MARIEN', 'Hanna'],
#  ['OUEDRAOGO', 'Elodie'],
#  ['ALEXEEV', 'Denis'],
#  ['DYLDIN', 'Maksim'],
#  ['FROLOV', 'Vladislav'],
#  ['KOKORIN', 'Anton'],
#  ['MERRITT', 'LaShawn'],
#  ['NEVILLE', 'David'],
#  ['TAYLOR', 'Angelo'],
#  ['WARINER', 'Jeremy'],
#  ['BAIN', 'Andretti'],
#  ['BROWN', 'Christopher'],
#  ['MATHIEU', 'Michael'],
#  ['WILLIAMS', 'Andrae'],
#  ['LLOYD', 'Shereefa'],
#  ['WHYTE', 'Rosemarie'],
#  ['WILLIAMS', 'Novelene'],
#  ['WILLIAMS', 'Shericka'],
#  ['FELIX', 'Allyson'],
#  ['HENDERSON', 'Monique'],
#  ['RICHARDS', 'Sanya'],
#  ['WINEBERG', 'Mary'],
#  ['FIROVA', 'Tatiana'],
#  ['GUSHCHINA', 'Yulia'],
#  ['KAPACHINSKAYA', 'Anastasia'],
#  ['LITVINOVA', 'Liudmila'],
#  ['SOI', 'Edwin Cheruiyot'],
#  ['BEKELE', 'Kenenisa'],
#  ['KIPCHOGE', 'Eliud'],
#  ['DEFAR', 'Meseret'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['NIZHEGORODOV', 'Denis'],
#  ['SCHWAZER', 'Alex'],
#  ['TALLENT', 'Jared'],
#  ['YEGO', 'Alfred Kirwa'],
#  ['BUNGEI', 'Wilfred'],
#  ['ISMAIL', 'Ismail Ahmed'],
#  ['BENHASSI', 'Hasna'],
#  ['JELIMO', 'Pamela'],
#  ['BUSIENEI', 'Janeth Jepkosgei'],
#  ['SUAREZ', 'Leonel'],
#  ['CLAY', 'Bryan'],
#  ['KRAUCHANKA', 'Andrei'],
#  ['ALEKNA', 'Virgilijus'],
#  ['KANTER', 'Gerd'],
#  ['MALACHOWSKI', 'Piotr'],
#  ['ANTONOVA', 'Olena'],
#  ['BROWN TRAFTON', 'Stephanie'],
#  ['BARRIOS', 'Yarelys'],
#  ['TSIKHAN', 'Ivan'],
#  ['KOZMUS', 'Primoz'],
#  ['DEVYATOVSKIY', 'Vadim'],
#  ['ZHANG', 'Wenxiu'],
#  ['MIANKOVA', 'Aksana'],
#  ['MORENO', 'Yipsi'],
#  ['CHERNOVA', 'Tatiana'],
#  ['DOBRYNSKA', 'Nataliia'],
#  ['FOUNTAIN', 'Hyleas'],
#  ['RYBAKOV', 'Yaroslav'],
#  ['SILNOV', 'Andrey'],
#  ['MASON', 'Germaine'],
#  ['CHICHEROVA', 'Anna'],
#  ['HELLEBAUT', 'Tia'],
#  ['VLASIC', 'Blanka'],
#  ['PITKAMAKI', 'Tero'],
#  ['THORKILDSEN', 'Andreas'],
#  ['KOVALS', 'Ainars'],
#  ['OBERGFOLL', 'Christina'],
#  ['SPOTAKOVA', 'Barbora'],
#  ['ABAKUMOVA', 'Maria'],
#  ['CAMEJO', 'Ibrahim'],
#  ['SALADINO ARANDA', 'Irving Jahir'],
#  ['MOKOENA', 'Khotso'],
#  ['OKAGBARE', 'Blessing'],
#  ['MAGGI', 'Maurren Higa'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['KEBEDE', 'Tsegay'],
#  ['WANSIRU', 'Samuel Kamau'],
#  ['GHARIB', 'Jaouad'],
#  ['ZHOU', 'Chunxiu'],
#  ['TOMESCU', 'Constantina'],
#  ['NDEREBA', 'Catherine'],
#  ['YURCHENKO', 'Denys'],
#  ['HOOKER', 'Steve'],
#  ['LUKYANENKO', 'Evgeny'],
#  ['FEOFANOVA', 'Svetlana'],
#  ['ISINBAEVA', 'Elena'],
#  ['STUCZYNSKI', 'Jennifer'],
#  ['MIKHNEVICH', 'Andrei'],
#  ['MAJEWSKI', 'Tomasz'],
#  ['CANTWELL', 'Christian'],
#  ['OSTAPCHUK', 'Nadzeya'],
#  ['VILI', 'Valerie'],
#  ['MIKHNEVICH', 'Natallia'],
#  ['SANDS', 'Leevan'],
#  ['EVORA', 'Nelson'],
#  ['IDOWU', 'Phillips'],
#  ['DEVETZI', 'Hrysopiyi'],
#  ['MBANGO ETONE', 'Francoise'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['HWANG', 'Jiman'],
#  ['LEE', 'Jaejin'],
#  ['HE', 'Hanbin'],
#  ['KIDO', 'Markis'],
#  ['SETIAWAN', 'Hendra'],
#  ['LEE', 'Yongdae'],
#  ['CAI', 'Yun'],
#  ['FU', 'Haifeng'],
#  ['WIDIANTO', 'Nova'],
#  ['WEI', 'Yili'],
#  ['ZHANG', 'Yawen'],
#  ['YU', 'Yang'],
#  ['DU', 'Jing'],
#  ['YU', 'Yang'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Kyungwon'],
#  ['LILIYANA'],
#  ['CHEN', 'Jin'],
#  ['LIN', 'Dan'],
#  ['LEE', 'Chong Wei'],
#  ['YULIANTI', 'Maria Kristin'],
#  ['ZHANG', 'Ning'],
#  ['XIE', 'Xingfang'],
#  ['ANDERSON', 'Brett'],
#  ['ARRIETA', 'Jake'],
#  ['BARDEN', 'Brian'],
#  ['BROWN', 'Matt'],
#  ['CAHILL', 'Trevor'],
#  ['CUMMINGS', 'Jeremy'],
#  ['DONALD', 'Jason'],
#  ['DUENSING', 'Brian'],
#  ['FOWLER', 'Dexter'],
#  ['GALL', 'John'],
#  ['HESSMAN', 'Mike'],
#  ['JEPSEN', 'Kevin'],
#  ['KNIGHT', 'Brandon'],
#  ['KOPLOVE', 'Michael'],
#  ['LAPORTA', 'Matt'],
#  ['MARSON', 'Lou'],
#  ['NEAL', 'Blaine'],
#  ['NIX', 'Jayson'],
#  ['SCHIERHOLTZ', 'Nate'],
#  ['STEVENS', 'Jeff'],
#  ['STRASBURG', 'Stephen'],
#  ['TEAGARDEN', 'Taylor'],
#  ['TIFFEE', 'Terry'],
#  ['WEATHERS', 'Casey'],
#  ['BONG', 'Jungkeun'],
#  ['CHONG', 'Taehyon'],
#  ['HAN', 'Kijoo'],
#  ['JANG', 'Wonsam'],
#  ['JEONG', 'Keunwoo'],
#  ['JIN', 'Kabyong'],
#  ['KANG', 'Minho'],
#  ['KIM', 'Dongjoo'],
#  ['KIM', 'Hyunsoo'],
#  ['KIM', 'Kwanghyun'],
#  ['KIM', 'Minjae'],
#  ['KO', 'Youngmin'],
#  ['KWON', 'Hyuk'],
#  ['LEE', 'Daeho'],
#  ['LEE', 'Jinyoung'],
#  ['LEE', 'Jongwook'],
#  ['LEE', 'Seungyuop'],
#  ['LEE', 'Taekkeun'],
#  ['LEE', 'Yongkyu'],
#  ['OH', 'Seunghwan'],
#  ['PARK', 'Jinman'],
#  ['RYU', 'Hyunjin'],
#  ['SONG', 'Seungjun'],
#  ['YOON', 'Suk Min'],
#  ['BELL', 'Alexei'],
#  ['CEPEDA', 'Frederich'],
#  ['DESPAIGNE', 'Alfredo'],
#  ['DUVERGEL', 'Giorbis'],
#  ['ENRIQUEZ', 'Michel'],
#  ['GONZALEZ', 'Norberto'],
#  ['GOURRIEL', 'Yuliesky'],
#  ['LA HERA', 'Miguel'],
#  ['LAZO', 'Pedro Luis'],
#  ['MARTINEZ', 'Jonder'],
#  ['MAYETA', 'Alexander'],
#  ['MERINO', 'Rolando'],
#  ['NAVAS', 'Luis'],
#  ['ODELIN SANAME', 'Vicyohandri'],
#  ['OLIVERA', 'Hector'],
#  ['PALMA', 'Adiel'],
#  ['PARET', 'Eduardo'],
#  ['PEDROSO', 'Yadier'],
#  ['PESTANO', 'Ariel'],
#  ['RODRIGUEZ', 'Luis'],
#  ['SANCHEZ', 'Elier'],
#  ['SANCHEZ', 'Eriel'],
#  ['URGELLES', 'Yoandry'],
#  ['VERA', 'Norge Luis'],
#  ['DELFINO', 'Carlos Francisco'],
#  ['GINOBILI', 'Emanuel David'],
#  ['GONZALEZ', 'Roman Javier'],
#  ['GUTIERREZ LLANAS', 'Juan Pedro'],
#  ['GUTIERREZ', 'Leonardo Martin'],
#  ['KAMMERICHS', 'Guillermo Federico'],
#  ['NOCIONI', 'Andres Marcelo'],
#  ['OBERTO', 'Fabricio Raul Jesus'],
#  ['PORTA PERNIGOTTI', 'Antonio Alejandro'],
#  ['PRIGIONI', 'Pablo'],
#  ['QUINTEROS', 'Alfredo Paolo'],
#  ['SCOLA', 'Luis Alberto'],
#  ['ANTHONY', 'Carmelo'],
#  ['BOOZER', 'Carlos'],
#  ['BOSH', 'Chris'],
#  ['BRYANT', 'Kobe'],
#  ['HOWARD', 'Dwight'],
#  ['JAMES', 'Lebron'],
#  ['KIDD', 'Jason'],
#  ['PAUL', 'Chris'],
#  ['PRINCE', 'Tayshaun'],
#  ['REDD', 'Michael'],
#  ['WADE', 'Dwyane'],
#  ['WILLIAMS', 'Deron'],
#  ['CALDERON', 'Jose Manuel'],
#  ['FERNANDEZ', 'Rudy'],
#  ['GARBAJOSA', 'Jorge'],
#  ['GASOL', 'Marc'],
#  ['GASOL', 'Pau'],
#  ['JIMENEZ', 'Carlos'],
#  ['LOPEZ', 'Raul'],
#  ['MUMBRU', 'Alex'],
#  ['NAVARRO', 'Juan Carlos'],
#  ['REYES', 'Felipe'],
#  ['RODRIGUEZ', 'Berni'],
#  ['RUBIO', 'Ricky'],
#  ['ABROSIMOVA', 'Svetlana'],
#  ['HAMMON', 'Rebekka Linn'],
#  ['KARPUNINA', 'Marina'],
#  ['KORSTIN', 'Ilona'],
#  ['KUZINA', 'Marina'],
#  ['LISINA', 'Ekaterina'],
#  ['OSIPOVA', 'Irina'],
#  ['RAKHMATULINA', 'Oxana'],
#  ['SHCHEGOLEVA', 'Tatiana'],
#  ['SOKOLOVSKAYA', 'Irina'],
#  ['STEPANOVA', 'Maria'],
#  ['VODOPYANOVA', 'Natalia'],
#  ['AUGUSTUS', 'Seimone'],
#  ['BIRD', 'Sue'],
#  ['CATCHINGS', 'Tamika'],
#  ['FOWLES', 'Sylvia'],
#  ['LAWSON', 'Kara'],
#  ['LESLIE', 'Lisa'],
#  ['MILTON-JONES', 'Delisha'],
#  ['PARKER', 'Candace'],
#  ['PONDEXTER', 'Cappie'],
#  ['SMITH', 'Katie'],
#  ['TAURASI', 'Diana'],
#  ['THOMPSON', 'Tina'],
#  ['BATKOVIC', 'Suzy'],
#  ['BEVILAQUA', 'Tully'],
#  ['COX', 'Rohanee'],
#  ['GRIMA', 'Hollie'],
#  ['HARROWER', 'Kristi'],
#  ['JACKSON', 'Lauren'],
#  ['PHILLIPS', 'Erin'],
#  ['RANDALL', 'Emma'],
#  ['SCREEN', 'Jenni'],
#  ['SNELL', 'Belinda'],
#  ['SUMMERTON', 'Laura'],
#  ['TAYLOR', 'Penny'],
#  ['GLAZKOV', 'Vyacheslav'],
#  ['PRICE', 'David'],
#  ['CAMMARELLE', 'Roberto'],
#  ['ZHANG', 'Zhilei'],
#  ['BALAKSHIN', 'Georgy'],
#  ['PICARDI', 'Vincenzo'],
#  ['JONGJOHOR', 'Somjit'],
#  ['LAFFITA HERNANDEZ', 'Andris'],
#  ['BARNES', 'Paddy'],
#  ['HERNANDEZ G', 'Yampier'],
#  ['ZOU', 'Shiming'],
#  ['PUREVDORJ', 'Serdamba'],
#  ['GOJAN', 'Veaceslav'],
#  ['JULIE', 'Bruno'],
#  ['ENKHBAT', 'Badar-Uugan'],
#  ['LEON ALARCON', 'Yankiel'],
#  ['IMRANOV', 'Shahin'],
#  ['KILIC', 'Yakup'],
#  ['LOMACHENKO', 'Vasyl'],
#  ['DJELKHIR', 'Khedafi'],
#  ['JAVAKHYAN', 'Hrachik'],
#  ['UGAS', 'Yordenis'],
#  ['TISHCHENKO', 'Alexey'],
#  ['SOW', 'Daouda'],
#  ['IGLESIAS SOTOLONGO', 'Roniel'],
#  ['VASTINE', 'Alexis'],
#  ['DIAZ', 'Felix'],
#  ['BOONJUMNONG', 'Manus'],
#  ['HANATI', 'Silamu'],
#  ['KIM', 'Jungjoo'],
#  ['SARSEKBAYEV', 'Bakhyt'],
#  ['BANTEAUX SUAREZ', 'Carlos'],
#  ['KUMAR', 'Vijender'],
#  ['SUTHERLAND', 'Darren John'],
#  ['DEGALE', 'James'],
#  ['CORREA BAYEAUX', 'Emilio'],
#  ['JEFFRIES', 'Tony'],
#  ['SHYNALIYEV', 'Yerkebulan'],
#  ['ZHANG', 'Xiaoping'],
#  ['EGAN', 'Kenny'],
#  ['ACOSTA DUARTE', 'Osmai'],
#  ['WILDER', 'Deontay'],
#  ['CHAKHKIEV', 'Rakhim'],
#  ['RUSSO', 'Clemente'],
#  ['HALL', 'Thomas'],
#  ['VAJDA', 'Attila Sandor'],
#  ['CAL', 'David'],
#  ['CHEBAN', 'Iurii'],
#  ['OPALEV', 'Maxim'],
#  ['CAL', 'David'],
#  ['KISS', 'Tamas'],
#  ['KOZMANN', 'Gyorgy'],
#  ['BAHDANOVICH', 'Aliaksandr'],
#  ['BAHDANOVICH', 'Andrei'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['MENG', 'Guanliang'],
#  ['YANG', 'Wenjun'],
#  ['KOSTOGLOD', 'Alexander'],
#  ['ULEGIN', 'Sergey'],
#  ['WALLACE', 'Ken'],
#  ['BRABANTS', 'Tim'],
#  ['LARSEN', 'Eirik Veraas'],
#  ['BRABANTS', 'Tim'],
#  ['WALLACE', 'Ken'],
#  ['VAN KOEVERDEN', 'Adam'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['OSYPENKO-RADOMSKA', 'Inna'],
#  ['IDEM', 'Josefa'],
#  ['FACCHIN', 'Andrea'],
#  ['SCADUTO', 'Antonio Massimiliano'],
#  ['HOLLSTEIN', 'Martin'],
#  ['IHLE', 'Andreas'],
#  ['KNUDSEN', 'Kim Wraae'],
#  ['POULSEN', 'Rene Holten'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['CRAVIOTTO', 'Saul'],
#  ['PEREZ', 'Carlos'],
#  ['RAUHE', 'Ronald'],
#  ['WIESKOTTER', 'Tim'],
#  ['DELATTRE', 'Marie'],
#  ['VIARD', 'Anne-Laure'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KONIECZNA', 'Aneta'],
#  ['MIKOLAJCZYK', 'Beata'],
#  ['ALTEPOST', 'Lutz'],
#  ['BROCKL', 'Norman'],
#  ['ECKBRETT', 'Torsten'],
#  ['GOLDSCHMIDT', 'Bjorn'],
#  ['ABALMASAU', 'Aliaksei'],
#  ['LITVINCHUK', 'Artur'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['RISZDORFER', 'Michal'],
#  ['RISZDORFER', 'Richard'],
#  ['TARR', 'Juraj'],
#  ['VLCEK', 'Erik'],
#  ['DAVIS', 'Hannah'],
#  ['FOGARTY', 'Lyndsie'],
#  ['MEEK', 'Chantal'],
#  ['OLDENHOF', 'Lisa'],
#  ['FISCHER', 'Fanny'],
#  ['REINHARDT', 'Nicole'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['WASSMUTH', 'Conny'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KOZAK', 'Danuta'],
#  ['SZABO', 'Gabriella Timea'],
#  ['BELL', 'Robin'],
#  ['MARTIKAN', 'Michal'],
#  ['FLORENCE', 'David'],
#  ['KUZNETSOV', 'Mikhail'],
#  ['LARIONOV', 'Dmitry'],
#  ['HOCHSCHORNER', 'Pavol'],
#  ['HOCHSCHORNER', 'Peter'],
#  ['STEPANEK', 'Ondrej'],
#  ['VOLF', 'Jaroslav'],
#  ['BOUKPETI', 'Benjamin'],
#  ['GRIMM', 'Alexander'],
#  ['LEFEVRE', 'Fabien'],
#  ['OBLINGER PETERS', 'Violetta'],
#  ['KALISKA', 'Elena'],
#  ['LAWRENCE', 'Jacqueline'],
#  ['ROBINSON', 'Donny'],
#  ['STROMBERGS', 'Maris'],
#  ['DAY', 'Mike'],
#  ['KINTNER', 'Jill'],
#  ['CHAUSSON', 'Anne-Caroline'],
#  ['LE CORGUILLE', 'Laetitia'],
#  ['CANCELLARA', 'Fabian'],
#  ['SANCHEZ', 'Samuel'],
#  ['GUDERZO', 'Tatiana'],
#  ['COOKE', 'Nicole'],
#  ['JOHANSSON', 'Emma'],
#  ['LEIPHEIMER', 'Levi'],
#  ['CANCELLARA', 'Fabian'],
#  ['LARSSON', 'Gustav'],
#  ['THURIG', 'Karin'],
#  ['ARMSTRONG', 'Kristin'],
#  ['POOLEY', 'Emma'],
#  ['BURKE', 'Steven'],
#  ['WIGGINS', 'Bradley'],
#  ['ROULSTON', 'Hayden'],
#  ['KALITOVSKA', 'Lesya'],
#  ['ROMERO', 'Rebecca'],
#  ['HOUVENAGHEL', 'Wendy'],
#  ['NAGAI', 'Kiyofumi'],
#  ['HOY', 'Chris'],
#  ['EDGAR', 'Ross'],
#  ['IGNATYEV', 'Mikhail'],
#  ['MARKOV', 'Alexei'],
#  ['CURUCHET', 'Juan Esteban'],
#  ['PEREZ', 'Walter Fernando'],
#  ['LLANERAS', 'Joan'],
#  ['TAULER', 'Antonio'],
#  ['NEWTON', 'Chris'],
#  ['LLANERAS', 'Joan'],
#  ['KLUGE', 'Roger'],
#  ['OLABERRIA', 'Leire'],
#  ['VOS', 'Marianne'],
#  ['GONZALEZ', 'Yoanka'],
#  ['GUO', 'Shuang'],
#  ['PENDLETON', 'Victoria'],
#  ['MEARES', 'Anna'],
#  ['BOURGAIN', 'Mickael'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['BEWLEY', 'Sam'],
#  ['ROULSTON', 'Hayden'],
#  ['RYAN', 'Marc'],
#  ['SERGENT', 'Jesse'],
#  ['CLANCY', 'Ed'],
#  ['MANNING', 'Paul'],
#  ['THOMAS', 'Geraint'],
#  ['WIGGINS', 'Bradley'],
#  ['JOERGENSEN', 'Casper'],
#  ['MADSEN', 'Jens-Erik'],
#  ['MOERKOEV', 'Michael'],
#  ['RASMUSSEN', 'Alex Nicki'],
#  ['ENDERS', 'Rene'],
#  ['LEVY', 'Maximilian'],
#  ['NIMKE', 'Stefan'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['STAFF', 'Jamie'],
#  ['BAUGE', 'Gregory'],
#  ['SIREAU', 'Kevin'],
#  ['TOURNANT', 'Arnaud'],
#  ['SCHURTER', 'Nino'],
#  ['ABSALON', 'Julien'],
#  ['PERAUD', 'Jean-Christophe'],
#  ['KALENTYEVA', 'Irina'],
#  ['SPITZ', 'Sabine'],
#  ['WLOSZCZOWSKA', 'Maja'],
#  ['KEMMER', 'Heike'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['WERTH', 'Isabell'],
#  ['HELGSTRAND', 'Andreas'],
#  ['MINDERHOUD', 'Hans Peter'],
#  ['VAN OLST', 'Anne'],
#  ['ZU-SAYN WITTGENSTEIN', 'Nathalie'],
#  ['CAPELLMANN', 'Nadine'],
#  ['KEMMER', 'Heike'],
#  ['WERTH', 'Isabell'],
#  ['SCHELLEKENS-BARTELS', 'Imke'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['ROMEIKE', 'Hinrich'],
#  ['COOK', 'Kristina'],
#  ['MILES', 'Gina'],
#  ['FOX-PITT', 'William'],
#  ['DIBOWSKI', 'Andreas'],
#  ['OSTHOLT', 'Frank'],
#  ['ROMEIKE', 'Hinrich'],
#  ['THOMSEN', 'Peter'],
#  ['FREDERICKS', 'Clayton'],
#  ['ROSE', 'Shane'],
#  ['COOK', 'Kristina'],
#  ['DICK', 'Daisy'],
#  ['HUNT', 'Sharon'],
#  ['KING', 'Mary'],
#  ['KLIMKE', 'Ingrid'],
#  ['FREDERICKS', 'Lucinda'],
#  ['JOHNSON', 'Sonja'],
#  ['JONES', 'Megan'],
#  ['LAMAZE', 'Eric'],
#  ['BENGTSSON', 'Rolf-Goran'],
#  ['MADDEN', 'Beezie'],
#  ['GUERDAT', 'Steve'],
#  ['SCHURTENBERGER', 'Niklaus'],
#  ['SCHWIZER', 'Pius'],
#  ['SIMPSON', 'Will'],
#  ['WARD', 'Mclain'],
#  ['CONE', 'Mac'],
#  ['LAMAZE', 'Eric'],
#  ['MILLAR', 'Ian'],
#  ['LIEBHERR', 'Christina'],
#  ['KRAUT', 'Laura'],
#  ['MADDEN', 'Beezie'],
#  ['HENSELWOOD', 'Jill'],
#  ['ABAJO', 'Jose Luis'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['MINCZA-NEBALD', 'Ildiko'],
#  ['HEIDEMANN', 'Britta'],
#  ['BRANZA', 'Ana Maria'],
#  ['CAROZZO', 'Stefano'],
#  ['CONFALONIERI', 'Diego'],
#  ['ROTA', 'Alfredo'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['JEANNET', 'Jerome'],
#  ['ROBEIRI', 'Ulrich'],
#  ['ANDRZEJUK', 'Robert'],
#  ['MOTYKA', 'Tomasz'],
#  ['WIERCIOCH', 'Adam'],
#  ['ZAWROTNIAK', 'Radoslaw'],
#  ['SANZO', 'Salvatore'],
#  ['KLEIBRINK', 'Benjamin'],
#  ['OTA', 'Yuki'],
#  ['GRANBASSI', 'Margherita'],
#  ['VEZZALI', 'Valentina'],
#  ['NAM', 'Hyunhee'],
#  ['GRANBASSI', 'Margherita'],
#  ['SALVATORI', 'Ilaria'],
#  ['TRILLINI', 'Giovanna'],
#  ['VEZZALI', 'Valentina'],
#  ['BOYKO', 'Svetlana'],
#  ['CHANAEVA', 'Aida'],
#  ['LAMONOVA', 'Evgenia'],
#  ['NIKICHINA', 'Victoria'],
#  ['CROSS', 'Emily'],
#  ['SMART', 'Erinn'],
#  ['THOMPSON', 'Hanna'],
#  ['COVALIU', 'Mihai'],
#  ['ZHONG', 'Man'],
#  ['LOPEZ', 'Nicolas'],
#  ['WARD', 'Becca'],
#  ['ZAGUNIS', 'Mariel'],
#  ['JACOBSON', 'Sada'],
#  ...]

# %%
[athlete_name[0] for athlete_name in athlete_names]
# Out:
# ['GALPERIN',
#  'MITCHAM',
#  'ZHOU',
#  'WANG',
#  'CHEN',
#  'HEYMANS',
#  'QIN',
#  'HE',
#  'DESPATIE',
#  'WU',
#  'GUO',
#  'PAKHALINA',
#  'DOBROSKOK',
#  'GALPERIN',
#  'HUO',
#  'LIN',
#  'HAUSDING',
#  'KLEIN',
#  'ESPINOSA',
#  'ORTIZ',
#  'CHEN',
#  'WANG',
#  'COLE',
#  'WU',
#  'KVASHA',
#  'PRYGOROV',
#  'QIN',
#  'WANG',
#  'KUNAKOV',
#  'SAUTIN',
#  'FISCHER',
#  'KOTZIAN',
#  'GUO',
#  'WU',
#  'PAKHALINA',
#  'POZDNYAKOVA',
#  'STOECKEL',
#  'VYATCHANIN',
#  'PEIRSOL',
#  'GREVERS',
#  'HOELZER',
#  'COUGHLIN',
#  'COVENTRY',
#  'DUBOSCQ',
#  'KITAJIMA',
#  'OEN',
#  'JUKIC',
#  'JONES',
#  'SONI',
#  'LAUTERSTEIN',
#  'PHELPS',
#  'CAVIC',
#  'SCHIPPER',
#  'TRICKETT',
#  'MAGNUSON',
#  'CIELO FILHO',
#  'LEZAK',
#  'BERNARD',
#  'SULLIVAN',
#  'COUGHLIN',
#  'STEFFEN',
#  'TRICKETT',
#  'COCHRANE',
#  'MELLOULI',
#  'HACKETT',
#  'VYATCHANIN',
#  'LOCHTE',
#  'PEIRSOL',
#  'NAKAMURA',
#  'COVENTRY',
#  'HOELZER',
#  'DUBOSCQ',
#  'KITAJIMA',
#  'RICKARD',
#  'NORDENSTAM',
#  'SONI',
#  'JONES',
#  'MATSUDA',
#  'PHELPS',
#  'CSEH',
#  'SCHIPPER',
#  'LIU',
#  'JIAO',
#  'VANDERKAAY',
#  'PHELPS',
#  'PARK',
#  'PANG',
#  'PELLEGRINI',
#  'ISAKOVIC',
#  'LOCHTE',
#  'PHELPS',
#  'CSEH',
#  'COUGHLIN',
#  'RICE',
#  'COVENTRY',
#  'JENSEN',
#  'PARK',
#  'ZHANG',
#  'JACKSON',
#  'ADLINGTON',
#  'HOFF',
#  'LOCHTE',
#  'PHELPS',
#  'CSEH',
#  'HOFF',
#  'RICE',
#  'COVENTRY',
#  'BRODIE',
#  'CALLUS',
#  'LAUTERSTEIN',
#  'MURPHY',
#  'SULLIVAN',
#  'TARGETT',
#  'ADRIAN',
#  'GREVERS',
#  'JONES',
#  'LEZAK',
#  'PHELPS',
#  'WEBER-GALE',
#  'WILDMAN-TOBRINER',
#  'BERNARD',
#  'BOUSQUET',
#  'GILOT',
#  'LEVEAUX',
#  'MALLET',
#  'STEIMETZ',
#  'CAMPBELL',
#  'MILLS',
#  'REESE',
#  'SCHLANGER',
#  'TRICKETT',
#  'DEKKER',
#  'HEEMSKERK',
#  'KROMOWIDJOJO',
#  'SCHREUDER',
#  'VAN ROOIJEN',
#  'VELDHUIS',
#  'COUGHLIN',
#  'JOYCE',
#  'NYMEYER',
#  'SILVER',
#  'SMIT',
#  'TORRES',
#  'FUJII',
#  'KITAJIMA',
#  'MIYASHITA',
#  'SATO',
#  'CROCKER',
#  'GANGLOFF',
#  'GREVERS',
#  'HANSEN',
#  'LEZAK',
#  'PEIRSOL',
#  'PHELPS',
#  'WEBER-GALE',
#  'DELANEY',
#  'LAUTERSTEIN',
#  'PINE',
#  'RICKARD',
#  'SPRENGER',
#  'STOECKEL',
#  'SULLIVAN',
#  'TARGETT',
#  'PANG',
#  'SUN',
#  'XU',
#  'ZHAO',
#  'ZHOU',
#  'GALVEZ',
#  'JONES',
#  'REESE',
#  'SCHIPPER',
#  'SEEBOHM',
#  'TRICKETT',
#  'WHITE',
#  'BREEDEN',
#  'COUGHLIN',
#  'HOELZER',
#  'JENDRICK',
#  'JOYCE',
#  'MAGNUSON',
#  'SONI',
#  'TORRES',
#  'BRITS',
#  'BRODIE',
#  'FFROST',
#  'HACKETT',
#  'MURPHY',
#  'PALMER',
#  'BERENS',
#  'KELLER',
#  'LOCHTE',
#  'PHELPS',
#  'VANDERKAAY',
#  'VENDT',
#  'WALTERS',
#  'IZOTOV',
#  'LAGUNOV',
#  'LOBINTSEV',
#  'POLISHCHUK',
#  'SUKHORUKOV',
#  'BURCKLE',
#  'COUGHLIN',
#  'HOFF',
#  'MARSHALL',
#  'SCHMITT',
#  'SMIT',
#  'VANDENBERG',
#  'BAINBRIDGE',
#  'BARRATT',
#  'DAVENPORT',
#  'GALVEZ',
#  'MACKENZIE',
#  'PALMER',
#  'RICE',
#  'SCHLANGER',
#  'PANG',
#  'TAN',
#  'TANG',
#  'YANG',
#  'ZHU',
#  'BERNARD',
#  'CIELO FILHO',
#  'LEVEAUX',
#  'CAMPBELL',
#  'STEFFEN',
#  'TORRES',
#  'FRIIS',
#  'ADLINGTON',
#  'FILIPPI',
#  'LURZ',
#  'VAN DER WEIJDEN',
#  'DAVIES',
#  'PATTEN',
#  'ILCHENKO',
#  'PAYNE',
#  'HARADA',
#  'SUZUKI',
#  'DAVYDOVA',
#  'ERMAKOVA',
#  'FUENTES',
#  'MENGUAL',
#  'GU',
#  'HUANG',
#  'JIANG',
#  'JIANG',
#  'LIU',
#  'LUO',
#  'SUN',
#  'WANG',
#  'ZHANG',
#  'DAVYDOVA',
#  'ERMAKOVA',
#  'GROMOVA',
#  'ISHCHENKO',
#  'KHASYANOVA',
#  'KUZHELA',
#  'OVCHINNIKOVA',
#  'ROMASHINA',
#  'SHORINA',
#  'CABELLO',
#  'CORRAL',
#  'FUENTES',
#  'HENRIQUEZ',
#  'LOPEZ',
#  'MENGUAL',
#  'MORON',
#  'RODRIGUEZ',
#  'TIRADOS',
#  'CIRIC',
#  'FILIPOVIC',
#  'GOCIC',
#  'PEKOVIC',
#  'PIJETLOVIC',
#  'PRLAINOVIC',
#  'RADJEN',
#  'SAPIC',
#  'SAVIC',
#  'SEFIK',
#  'SORO',
#  'UDOVICIC',
#  'VUJASINOVIC',
#  'BENEDEK',
#  'BIROS',
#  'GERGELY',
#  'HOSNYANSZKY',
#  'KASAS',
#  'KIS',
#  'KISS',
#  'MADARAS',
#  'MOLNAR',
#  'SZECSI',
#  'VARGA',
#  'VARGA',
#  'VARGA',
#  'AZEVEDO',
#  'BAILEY',
#  'BEAUBIEN',
#  'BROOKS',
#  'HUDNUT',
#  'HUTTEN',
#  'KRUMPHOLZ',
#  'MERLO',
#  'MOSES',
#  'POWERS',
#  'SMITH',
#  'VARELLAS',
#  'WRIGHT',
#  'BEADSWORTH',
#  'CUFFE',
#  'FRASER',
#  'GOFERS',
#  'GYNTHER',
#  'HETZEL',
#  'KNOX',
#  'KNOX',
#  'MCCORMACK',
#  'RIPPON',
#  'RIPPON',
#  'SANTOROMITO',
#  'SANTOROMITO',
#  'CABOUT',
#  'DE BRUIJN',
#  'DE NOOY',
#  'GUICHELAAR',
#  'HAKHVERDIAN',
#  'KLEIN',
#  'KOOT',
#  'SIJBRING',
#  'SMIT',
#  'VAN BELKUM',
#  'VAN DEN BERG',
#  'VAN DEN HAM',
#  'VAN DER MEIJDEN',
#  'ARMSTRONG',
#  'CARDENAS',
#  'CRAIG',
#  'GOLDA',
#  'GREGORKA',
#  'HAYES',
#  'HIPP',
#  'PETRI',
#  'STEFFENS',
#  'VAN NORMAN',
#  'VILLA',
#  'WENGER',
#  'WINDES',
#  'BADENOV',
#  'RUBAN',
#  'PARK',
#  'YUN',
#  'ZHANG',
#  'PARK',
#  'JIANG',
#  'LI',
#  'XUE',
#  'IM',
#  'LEE',
#  'PARK',
#  "DI BUO'",
#  'GALIAZZO',
#  'NESPOLI',
#  'ARNOLD',
#  'DODEMONT',
#  'SCHUH',
#  'JOO',
#  'PARK',
#  'YUN',
#  'CHEN',
#  'GUO',
#  'ZHANG',
#  'KOGO',
#  'BEKELE',
#  'SIHINE',
#  'FLANAGAN',
#  'DIBABA',
#  'ABEYLEGESSE',
#  'DIX',
#  'BOLT',
#  'THOMPSON',
#  'FRASER',
#  'SIMPSON',
#  'STEWART',
#  'LOPES-SCHLIEP',
#  'HARPER',
#  'MCLELLAN',
#  'OLIVER',
#  'ROBLES',
#  'PAYNE',
#  'BAALA',
#  'KIPROP',
#  'WILLIS',
#  'TOBIAS',
#  'LANGAT',
#  'LISHCHYNSKA',
#  'DIX',
#  'BOLT',
#  'CRAWFORD',
#  'STEWART',
#  'CAMPBELL-BROWN',
#  'FELIX',
#  'RIGAUDO',
#  'KANISKINA',
#  'PLATZER',
#  'TALLENT',
#  'BORCHIN',
#  'PEREZ',
#  'MATEELONG',
#  'KIPRUTO',
#  'MEKHISSI-B.',
#  'VOLKOVA',
#  'GALKINA-SAMITOVA',
#  'JEPKORIR',
#  'NEVILLE',
#  'MERRITT',
#  'WARINER',
#  'RICHARDS',
#  'OHURUOGU',
#  'WILLIAMS',
#  'JACKSON',
#  'TAYLOR',
#  'CLEMENT',
#  'DANVERS',
#  'WALKER',
#  'TOSTA',
#  'ASAHARA',
#  'SUETSUGU',
#  'TAKAHIRA',
#  'TSUKAHARA',
#  'BOLT',
#  'CARTER',
#  'FRATER',
#  'POWELL',
#  'BLEDMAN',
#  'BURNS',
#  'CALLENDER',
#  'THOMPSON',
#  'IDOKO',
#  'ISMAILA',
#  'KEMASUODE',
#  'OSAYOMI',
#  'CHERMOSHANSKAYA',
#  'FEDORIVA',
#  'GUSHCHINA',
#  'POLYAKOVA',
#  'BORLEE',
#  'GEVAERT',
#  'MARIEN',
#  'OUEDRAOGO',
#  'ALEXEEV',
#  'DYLDIN',
#  'FROLOV',
#  'KOKORIN',
#  'MERRITT',
#  'NEVILLE',
#  'TAYLOR',
#  'WARINER',
#  'BAIN',
#  'BROWN',
#  'MATHIEU',
#  'WILLIAMS',
#  'LLOYD',
#  'WHYTE',
#  'WILLIAMS',
#  'WILLIAMS',
#  'FELIX',
#  'HENDERSON',
#  'RICHARDS',
#  'WINEBERG',
#  'FIROVA',
#  'GUSHCHINA',
#  'KAPACHINSKAYA',
#  'LITVINOVA',
#  'SOI',
#  'BEKELE',
#  'KIPCHOGE',
#  'DEFAR',
#  'DIBABA',
#  'ABEYLEGESSE',
#  'NIZHEGORODOV',
#  'SCHWAZER',
#  'TALLENT',
#  'YEGO',
#  'BUNGEI',
#  'ISMAIL',
#  'BENHASSI',
#  'JELIMO',
#  'BUSIENEI',
#  'SUAREZ',
#  'CLAY',
#  'KRAUCHANKA',
#  'ALEKNA',
#  'KANTER',
#  'MALACHOWSKI',
#  'ANTONOVA',
#  'BROWN TRAFTON',
#  'BARRIOS',
#  'TSIKHAN',
#  'KOZMUS',
#  'DEVYATOVSKIY',
#  'ZHANG',
#  'MIANKOVA',
#  'MORENO',
#  'CHERNOVA',
#  'DOBRYNSKA',
#  'FOUNTAIN',
#  'RYBAKOV',
#  'SILNOV',
#  'MASON',
#  'CHICHEROVA',
#  'HELLEBAUT',
#  'VLASIC',
#  'PITKAMAKI',
#  'THORKILDSEN',
#  'KOVALS',
#  'OBERGFOLL',
#  'SPOTAKOVA',
#  'ABAKUMOVA',
#  'CAMEJO',
#  'SALADINO ARANDA',
#  'MOKOENA',
#  'OKAGBARE',
#  'MAGGI',
#  'LEBEDEVA',
#  'KEBEDE',
#  'WANSIRU',
#  'GHARIB',
#  'ZHOU',
#  'TOMESCU',
#  'NDEREBA',
#  'YURCHENKO',
#  'HOOKER',
#  'LUKYANENKO',
#  'FEOFANOVA',
#  'ISINBAEVA',
#  'STUCZYNSKI',
#  'MIKHNEVICH',
#  'MAJEWSKI',
#  'CANTWELL',
#  'OSTAPCHUK',
#  'VILI',
#  'MIKHNEVICH',
#  'SANDS',
#  'EVORA',
#  'IDOWU',
#  'DEVETZI',
#  'MBANGO ETONE',
#  'LEBEDEVA',
#  'HWANG',
#  'LEE',
#  'HE',
#  'KIDO',
#  'SETIAWAN',
#  'LEE',
#  'CAI',
#  'FU',
#  'WIDIANTO',
#  'WEI',
#  'ZHANG',
#  'YU',
#  'DU',
#  'YU',
#  'LEE',
#  'LEE',
#  'LEE',
#  'LILIYANA',
#  'CHEN',
#  'LIN',
#  'LEE',
#  'YULIANTI',
#  'ZHANG',
#  'XIE',
#  'ANDERSON',
#  'ARRIETA',
#  'BARDEN',
#  'BROWN',
#  'CAHILL',
#  'CUMMINGS',
#  'DONALD',
#  'DUENSING',
#  'FOWLER',
#  'GALL',
#  'HESSMAN',
#  'JEPSEN',
#  'KNIGHT',
#  'KOPLOVE',
#  'LAPORTA',
#  'MARSON',
#  'NEAL',
#  'NIX',
#  'SCHIERHOLTZ',
#  'STEVENS',
#  'STRASBURG',
#  'TEAGARDEN',
#  'TIFFEE',
#  'WEATHERS',
#  'BONG',
#  'CHONG',
#  'HAN',
#  'JANG',
#  'JEONG',
#  'JIN',
#  'KANG',
#  'KIM',
#  'KIM',
#  'KIM',
#  'KIM',
#  'KO',
#  'KWON',
#  'LEE',
#  'LEE',
#  'LEE',
#  'LEE',
#  'LEE',
#  'LEE',
#  'OH',
#  'PARK',
#  'RYU',
#  'SONG',
#  'YOON',
#  'BELL',
#  'CEPEDA',
#  'DESPAIGNE',
#  'DUVERGEL',
#  'ENRIQUEZ',
#  'GONZALEZ',
#  'GOURRIEL',
#  'LA HERA',
#  'LAZO',
#  'MARTINEZ',
#  'MAYETA',
#  'MERINO',
#  'NAVAS',
#  'ODELIN SANAME',
#  'OLIVERA',
#  'PALMA',
#  'PARET',
#  'PEDROSO',
#  'PESTANO',
#  'RODRIGUEZ',
#  'SANCHEZ',
#  'SANCHEZ',
#  'URGELLES',
#  'VERA',
#  'DELFINO',
#  'GINOBILI',
#  'GONZALEZ',
#  'GUTIERREZ LLANAS',
#  'GUTIERREZ',
#  'KAMMERICHS',
#  'NOCIONI',
#  'OBERTO',
#  'PORTA PERNIGOTTI',
#  'PRIGIONI',
#  'QUINTEROS',
#  'SCOLA',
#  'ANTHONY',
#  'BOOZER',
#  'BOSH',
#  'BRYANT',
#  'HOWARD',
#  'JAMES',
#  'KIDD',
#  'PAUL',
#  'PRINCE',
#  'REDD',
#  'WADE',
#  'WILLIAMS',
#  'CALDERON',
#  'FERNANDEZ',
#  'GARBAJOSA',
#  'GASOL',
#  'GASOL',
#  'JIMENEZ',
#  'LOPEZ',
#  'MUMBRU',
#  'NAVARRO',
#  'REYES',
#  'RODRIGUEZ',
#  'RUBIO',
#  'ABROSIMOVA',
#  'HAMMON',
#  'KARPUNINA',
#  'KORSTIN',
#  'KUZINA',
#  'LISINA',
#  'OSIPOVA',
#  'RAKHMATULINA',
#  'SHCHEGOLEVA',
#  'SOKOLOVSKAYA',
#  'STEPANOVA',
#  'VODOPYANOVA',
#  'AUGUSTUS',
#  'BIRD',
#  'CATCHINGS',
#  'FOWLES',
#  'LAWSON',
#  'LESLIE',
#  'MILTON-JONES',
#  'PARKER',
#  'PONDEXTER',
#  'SMITH',
#  'TAURASI',
#  'THOMPSON',
#  'BATKOVIC',
#  'BEVILAQUA',
#  'COX',
#  'GRIMA',
#  'HARROWER',
#  'JACKSON',
#  'PHILLIPS',
#  'RANDALL',
#  'SCREEN',
#  'SNELL',
#  'SUMMERTON',
#  'TAYLOR',
#  'GLAZKOV',
#  'PRICE',
#  'CAMMARELLE',
#  'ZHANG',
#  'BALAKSHIN',
#  'PICARDI',
#  'JONGJOHOR',
#  'LAFFITA HERNANDEZ',
#  'BARNES',
#  'HERNANDEZ G',
#  'ZOU',
#  'PUREVDORJ',
#  'GOJAN',
#  'JULIE',
#  'ENKHBAT',
#  'LEON ALARCON',
#  'IMRANOV',
#  'KILIC',
#  'LOMACHENKO',
#  'DJELKHIR',
#  'JAVAKHYAN',
#  'UGAS',
#  'TISHCHENKO',
#  'SOW',
#  'IGLESIAS SOTOLONGO',
#  'VASTINE',
#  'DIAZ',
#  'BOONJUMNONG',
#  'HANATI',
#  'KIM',
#  'SARSEKBAYEV',
#  'BANTEAUX SUAREZ',
#  'KUMAR',
#  'SUTHERLAND',
#  'DEGALE',
#  'CORREA BAYEAUX',
#  'JEFFRIES',
#  'SHYNALIYEV',
#  'ZHANG',
#  'EGAN',
#  'ACOSTA DUARTE',
#  'WILDER',
#  'CHAKHKIEV',
#  'RUSSO',
#  'HALL',
#  'VAJDA',
#  'CAL',
#  'CHEBAN',
#  'OPALEV',
#  'CAL',
#  'KISS',
#  'KOZMANN',
#  'BAHDANOVICH',
#  'BAHDANOVICH',
#  'GILLE',
#  'WYLENZEK',
#  'GILLE',
#  'WYLENZEK',
#  'MENG',
#  'YANG',
#  'KOSTOGLOD',
#  'ULEGIN',
#  'WALLACE',
#  'BRABANTS',
#  'LARSEN',
#  'BRABANTS',
#  'WALLACE',
#  'VAN KOEVERDEN',
#  'WAGNER-AUGUSTIN',
#  'OSYPENKO-RADOMSKA',
#  'IDEM',
#  'FACCHIN',
#  'SCADUTO',
#  'HOLLSTEIN',
#  'IHLE',
#  'KNUDSEN',
#  'POULSEN',
#  'MAKHNEU',
#  'PIATRUSHENKA',
#  'CRAVIOTTO',
#  'PEREZ',
#  'RAUHE',
#  'WIESKOTTER',
#  'DELATTRE',
#  'VIARD',
#  'JANIC',
#  'KOVACS',
#  'KONIECZNA',
#  'MIKOLAJCZYK',
#  'ALTEPOST',
#  'BROCKL',
#  'ECKBRETT',
#  'GOLDSCHMIDT',
#  'ABALMASAU',
#  'LITVINCHUK',
#  'MAKHNEU',
#  'PIATRUSHENKA',
#  'RISZDORFER',
#  'RISZDORFER',
#  'TARR',
#  'VLCEK',
#  'DAVIS',
#  'FOGARTY',
#  'MEEK',
#  'OLDENHOF',
#  'FISCHER',
#  'REINHARDT',
#  'WAGNER-AUGUSTIN',
#  'WASSMUTH',
#  'JANIC',
#  'KOVACS',
#  'KOZAK',
#  'SZABO',
#  'BELL',
#  'MARTIKAN',
#  'FLORENCE',
#  'KUZNETSOV',
#  'LARIONOV',
#  'HOCHSCHORNER',
#  'HOCHSCHORNER',
#  'STEPANEK',
#  'VOLF',
#  'BOUKPETI',
#  'GRIMM',
#  'LEFEVRE',
#  'OBLINGER PETERS',
#  'KALISKA',
#  'LAWRENCE',
#  'ROBINSON',
#  'STROMBERGS',
#  'DAY',
#  'KINTNER',
#  'CHAUSSON',
#  'LE CORGUILLE',
#  'CANCELLARA',
#  'SANCHEZ',
#  'GUDERZO',
#  'COOKE',
#  'JOHANSSON',
#  'LEIPHEIMER',
#  'CANCELLARA',
#  'LARSSON',
#  'THURIG',
#  'ARMSTRONG',
#  'POOLEY',
#  'BURKE',
#  'WIGGINS',
#  'ROULSTON',
#  'KALITOVSKA',
#  'ROMERO',
#  'HOUVENAGHEL',
#  'NAGAI',
#  'HOY',
#  'EDGAR',
#  'IGNATYEV',
#  'MARKOV',
#  'CURUCHET',
#  'PEREZ',
#  'LLANERAS',
#  'TAULER',
#  'NEWTON',
#  'LLANERAS',
#  'KLUGE',
#  'OLABERRIA',
#  'VOS',
#  'GONZALEZ',
#  'GUO',
#  'PENDLETON',
#  'MEARES',
#  'BOURGAIN',
#  'HOY',
#  'KENNY',
#  'BEWLEY',
#  'ROULSTON',
#  'RYAN',
#  'SERGENT',
#  'CLANCY',
#  'MANNING',
#  'THOMAS',
#  'WIGGINS',
#  'JOERGENSEN',
#  'MADSEN',
#  'MOERKOEV',
#  'RASMUSSEN',
#  'ENDERS',
#  'LEVY',
#  'NIMKE',
#  'HOY',
#  'KENNY',
#  'STAFF',
#  'BAUGE',
#  'SIREAU',
#  'TOURNANT',
#  'SCHURTER',
#  'ABSALON',
#  'PERAUD',
#  'KALENTYEVA',
#  'SPITZ',
#  'WLOSZCZOWSKA',
#  'KEMMER',
#  'VAN GRUNSVEN',
#  'WERTH',
#  'HELGSTRAND',
#  'MINDERHOUD',
#  'VAN OLST',
#  'ZU-SAYN WITTGENSTEIN',
#  'CAPELLMANN',
#  'KEMMER',
#  'WERTH',
#  'SCHELLEKENS-BARTELS',
#  'VAN GRUNSVEN',
#  'ROMEIKE',
#  'COOK',
#  'MILES',
#  'FOX-PITT',
#  'DIBOWSKI',
#  'OSTHOLT',
#  'ROMEIKE',
#  'THOMSEN',
#  'FREDERICKS',
#  'ROSE',
#  'COOK',
#  'DICK',
#  'HUNT',
#  'KING',
#  'KLIMKE',
#  'FREDERICKS',
#  'JOHNSON',
#  'JONES',
#  'LAMAZE',
#  'BENGTSSON',
#  'MADDEN',
#  'GUERDAT',
#  'SCHURTENBERGER',
#  'SCHWIZER',
#  'SIMPSON',
#  'WARD',
#  'CONE',
#  'LAMAZE',
#  'MILLAR',
#  'LIEBHERR',
#  'KRAUT',
#  'MADDEN',
#  'HENSELWOOD',
#  'ABAJO',
#  'TAGLIARIOL',
#  'JEANNET',
#  'MINCZA-NEBALD',
#  'HEIDEMANN',
#  'BRANZA',
#  'CAROZZO',
#  'CONFALONIERI',
#  'ROTA',
#  'TAGLIARIOL',
#  'JEANNET',
#  'JEANNET',
#  'ROBEIRI',
#  'ANDRZEJUK',
#  'MOTYKA',
#  'WIERCIOCH',
#  'ZAWROTNIAK',
#  'SANZO',
#  'KLEIBRINK',
#  'OTA',
#  'GRANBASSI',
#  'VEZZALI',
#  'NAM',
#  'GRANBASSI',
#  'SALVATORI',
#  'TRILLINI',
#  'VEZZALI',
#  'BOYKO',
#  'CHANAEVA',
#  'LAMONOVA',
#  'NIKICHINA',
#  'CROSS',
#  'SMART',
#  'THOMPSON',
#  'COVALIU',
#  'ZHONG',
#  'LOPEZ',
#  'WARD',
#  'ZAGUNIS',
#  'JACOBSON',
#  ...]

# %%
[athlete_name[0].isupper() for athlete_name in athlete_names]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %%
len([item[0].isupper() for item in athlete_names])
# Out:
# 2042

# %%
nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2042 entries, 0 to 2052
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2042 non-null   object
#  1   Year          2042 non-null   float64
#  2   Sport         2042 non-null   object
#  3   Discipline    2042 non-null   object
#  4   Athlete Name  2042 non-null   object
#  5   NOC           2042 non-null   object
#  6   Gender        2042 non-null   object
#  7   Event         2042 non-null   object
#  8   Event Gender  2042 non-null   object
#  9   Medal         2042 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 175.5+ KB

# %% [markdown]
# ##Updating the dtypes

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  return df

oo = preprocess()
nw = preprocess_2008()
nw.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#          City    Year     Sport       Discipline      Athlete Name  NOC Gender     Event  \
# 1140  Beijing  2008.0  football         football             TANIA  BRA  Women  football
# 593   Beijing  2008.0  baseball         baseball     HESSMAN, Mike  USA    Men  baseball
# 274   Beijing  2008.0  aquatics  synchronized s.  HENRIQUEZ, Thais  ESP  Women      team
#
#      Event Gender   Medal
# 1140            W  Silver
# 593             M  Bronze
# 274             W  Silver

# %%
nw.dtypes
# Out:
# City             object
# Year            float64
# Sport            object
# Discipline       object
# Athlete Name     object
# NOC              object
# Gender           object
# Event            object
# Event Gender     object
# Medal            object
# dtype: object

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
# Preprocessing olympics_2008.csv ...
#          City  Year          Sport       Discipline               Athlete Name  NOC Gender  \
# 2019  Beijing  2008      wrestling  wrestling free.        GOGSHELIDZE, George  GEO    Men
# 1226  Beijing  2008     gymnastics      rhythmic g.                  CHOU, Tao  CHN  Women
# 852   Beijing  2008  canoe / kayak  canoe / kayak s  OBLINGER PETERS, Violetta  AUT  Women
#
#                    Event Event Gender   Medal
# 2019           84 - 96kg            M  Bronze
# 1226   group competition            W  Silver
# 852   k-1 (kayak single)            W  Bronze

# %%
nw.dtypes
# Out:
# City            string[python]
# Year                     int64
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %% [markdown]
# ## Combine the datasets

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

# %%
oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year       City      Sport  Discipline        Athlete Name  NOC Gender  \
# 18332  1988      Seoul  athletics   athletics     ZHIROVA, Marina  URS  Women
# 3681   1920    Antwerp    archery     archery  VAN THIELT, Pierre  BEL    Men
# 2783   1912  Stockholm   aquatics  water polo    PLETINCX, Joseph  BEL    Men
#
#                               Event Event Gender   Medal
# 18332                  4x100m relay            W  Bronze
# 3681   moving bird target 50m teams            M    Gold
# 2783                     water polo            M  Bronze

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
nw = preprocess_2008()
nw.sample(3)
# Out:
# Preprocessing olympics_2008.csv ...
#         City  Year          Sport       Discipline     Athlete Name  NOC Gender  \
# 486  Beijing  2008      athletics        athletics  KIPCHOGE, Eliud  KEN    Men
# 828  Beijing  2008  canoe / kayak  canoe / kayak f    DAVIS, Hannah  AUS  Women
# 80   Beijing  2008       aquatics         swimming  DUBOSCQ, Hugues  FRA    Men
#
#                      Event Event Gender   Medal
# 486                  5000m            M  Silver
# 828  k-4 500m (kayak four)            W  Bronze
# 80       200m breaststroke            M  Bronze

# %%
nw.dtypes
# Out:
# City            string[python]
# Year                     int64
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
pd.concat([oo, nw])
# Out:
#       Year     City      Sport       Discipline          Athlete Name  NOC Gender       Event  \
# 0     1896   Athens    cycling    cycling track         FLAMENG, Léon  FRA    Men       100km
# 1     1896   Athens    cycling    cycling track    KOLETTIS, Georgios  GRE    Men       100km
# 2     1896   Athens  athletics        athletics         LANE, Francis  USA    Men        100m
# 3     1896   Athens  athletics        athletics      SZOKOLYI, Alajos  HUN    Men        100m
# 4     1896   Athens  athletics        athletics         BURKE, Thomas  USA    Men        100m
# ...    ...      ...        ...              ...                   ...  ...    ...         ...
# 2048  2008  Beijing  wrestling  wrestling gre-r        ENGLICH, Mirko  GER    Men   84 - 96kg
# 2049  2008  Beijing  wrestling  wrestling gre-r  MIZGAITIS, Mindaugas  LTU    Men  96 - 120kg
# 2050  2008  Beijing  wrestling  wrestling gre-r       PATRIKEEV, Yuri  ARM    Men  96 - 120kg
# 2051  2008  Beijing  wrestling  wrestling gre-r         LOPEZ, Mijain  CUB    Men  96 - 120kg
# 2052  2008  Beijing  wrestling  wrestling gre-r        BAROEV, Khasan  RUS    Men  96 - 120kg
#
#      Event Gender   Medal
# 0               M    Gold
# 1               M  Silver
# 2               M  Bronze
# 3               M  Bronze
# 4               M    Gold
# ...           ...     ...
# 2048            M  Silver
# 2049            M  Bronze
# 2050            M  Bronze
# 2051            M    Gold
# 2052            M  Silver
#
# [29216 rows x 10 columns]

# %%
pd.concat([oo, nw]).dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
up = pd.concat([oo, nw])
up.sample(3)
# Out:
#        Year     City     Sport Discipline      Athlete Name  NOC Gender  \
# 1618   2008  Beijing    rowing     rowing   ZHANG, Yangyang  CHN  Women
# 4289   1924    Paris  aquatics   swimming  NORELIUS, Martha  USA  Women
# 23258  2000   Sydney  aquatics     diving    SAUTIN, Dmitry  RUS    Men
#
#                                         Event Event Gender   Medal
# 1618   quadruple sculls without coxswain (4x)            W    Gold
# 4289                           400m freestyle            W    Gold
# 23258                            10m platform            M  Bronze

# %%
up.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %% [markdown]
# ##Plotting data

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt


if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df


def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#       Year       City      Sport       Discipline       Athlete Name  NOC Gender  \
# 7852  1948     London    fencing          fencing     NOSTINI, Renzo  ITA    Men
# 2221  1912  Stockholm    sailing          sailing      HEYMAN, Bengt  SWE    Men
# 6346  1936     Berlin  wrestling  wrestling free.  FLOOD, Aaron Ross  USA    Men
#
#                       Event Event Gender   Medal
# 7852             sabre team            M  Silver
# 2221                     8m            X  Silver
# 6346  - 56kg (bantamweight)            M  Silver

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **For the first Olympics, how many events were there for each of the different sports? Plot them using different graphs.**

# %%
first_games = up[up.Year == 1896]
first_games
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC Gender        Event  \
# 0    1896  Athens     cycling  cycling track         FLAMENG, Léon  FRA    Men        100km
# 1    1896  Athens     cycling  cycling track    KOLETTIS, Georgios  GRE    Men        100km
# 2    1896  Athens   athletics      athletics         LANE, Francis  USA    Men         100m
# 3    1896  Athens   athletics      athletics      SZOKOLYI, Alajos  HUN    Men         100m
# 4    1896  Athens   athletics      athletics         BURKE, Thomas  USA    Men         100m
# ..    ...     ...         ...            ...                   ...  ...    ...          ...
# 146  1896  Athens   athletics      athletics       CONNOLLY, James  USA    Men  triple jump
# 147  1896  Athens   athletics      athletics    TUFFERI, Alexandre  FRA    Men  triple jump
# 148  1896  Athens  gymnastics    artistic g.  WEINGÄRTNER, Hermann  GER    Men        vault
# 149  1896  Athens  gymnastics    artistic g.        SCHUMANN, Carl  GER    Men        vault
# 150  1896  Athens  gymnastics    artistic g.         ZUTTER, Louis  SUI    Men        vault
#
#     Event Gender   Medal
# 0              M    Gold
# 1              M  Silver
# 2              M  Bronze
# 3              M  Bronze
# 4              M    Gold
# ..           ...     ...
# 146            M    Gold
# 147            M  Silver
# 148            M  Bronze
# 149            M    Gold
# 150            M  Silver
#
# [151 rows x 10 columns]

# %%
first_games.Sport.value_counts()
# Out:
# Sport
# gymnastics       45
# athletics        37
# cycling          16
# shooting         15
# aquatics         11
# tennis           10
# fencing           8
# weightlifting     6
# wrestling         3
# Name: count, dtype: Int64

# %%
first_games.Sport.value_counts().plot?
# Out:
# Object `plot` not found.

# %%
type(first_games.Sport.value_counts())
# Out:
# pandas.core.series.Series

# %%
dir(pd.Series)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_add_numeric_operations',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_align_frame',
#  '_align_series',
#  '_append',
#  '_arith_method',
#  '_as_manager',
#  '_binop',
#  '_can_hold_na',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_convert_dtypes',
#  '_data',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_duplicated',
#  '_find_valid_index',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_index_resolvers',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_get_values',
#  '_get_values_tuple',
#  '_get_with',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_init_dict',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_cached',
#  '_is_copy',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_ixs',
#  '_logical_func',
#  '_logical_method',
#  '_map_values',
#  '_maybe_update_cacher',
#  '_memory_usage',
#  '_metadata',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_protect_consolidate',
#  '_reduce',
#  '_references',
#  '_reindex_axes',
#  '_reindex_indexer',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_rename',
#  '_replace_single',
#  '_repr_data_resource_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_labels',
#  '_set_name',
#  '_set_value',
#  '_set_values',
#  '_set_with',
#  '_set_with_engine',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take',
#  '_take_with_is_copy',
#  '_to_latex_via_styler',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'apply',
#  'argmax',
#  'argmin',
#  'argsort',
#  'array',
#  'asfreq',
#  'asof',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'autocorr',
#  'axes',
#  'backfill',
#  'between',
#  'between_time',
#  'bfill',
#  'bool',
#  'cat',
#  'clip',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'divmod',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dt',
#  'dtype',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'ewm',
#  'expanding',
#  'explode',
#  'factorize',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'hasnans',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'interpolate',
#  'is_monotonic_decreasing',
#  'is_monotonic_increasing',
#  'is_unique',
#  'isin',
#  'isna',
#  'isnull',
#  'item',
#  'items',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lt',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'memory_usage',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'name',
#  'nbytes',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'radd',
#  'rank',
#  'ravel',
#  'rdiv',
#  'rdivmod',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'repeat',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'searchsorted',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'sort_index',
#  'sort_values',
#  'sparse',
#  'squeeze',
#  'std',
#  'str',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_frame',
#  'to_hdf',
#  'to_json',
#  'to_latex',
#  'to_list',
#  'to_markdown',
#  'to_numpy',
#  'to_period',
#  'to_pickle',
#  'to_sql',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'tolist',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unique',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'view',
#  'where',
#  'xs']

# %%
pd.Series.plot?

# %%
first_games.Sport.value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Sport'>

# %%
first_games.Sport.value_counts().plot(figsize=(10,3))
# Out:
# <Axes: xlabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 .plot(figsize=(10,3))
)
# Out:
# <Axes: xlabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 #.plot(figsize=(10,3))
)
# Out:
# Sport
# gymnastics       45
# athletics        37
# cycling          16
# shooting         15
# aquatics         11
# tennis           10
# fencing           8
# weightlifting     6
# wrestling         3
# Name: count, dtype: Int64

# %%
(first_games
 .Sport
 .value_counts()
 .plot(kind='bar')
)
# Out:
# <Axes: xlabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 .plot
 .bar()
)
# Out:
# <Axes: xlabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 .plot(kind='barh')
)
# Out:
# <Axes: ylabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 .plot(kind='barh', color='red')
)
# Out:
# <Axes: ylabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 .plot(kind='barh', color=['blue', 'red'])
)
# Out:
# <Axes: ylabel='Sport'>

# %% [markdown]
# ##Working with colormaps and Seaborn

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year       City       Sport  Discipline             Athlete Name  NOC Gender         Event  \
# 21182  1992  Barcelona  volleyball  volleyball  SAMUELSON, Robert Lewis  USA    Men    volleyball
# 24812  2000     Sydney    softball    softball            O'BRIEN, Leah  USA  Women      softball
# 829    1904   St Louis   athletics   athletics         SHERIDAN, Martin  USA    Men  discus throw
#
#       Event Gender   Medal
# 21182            M  Bronze
# 24812            W    Gold
# 829              M    Gold

# %%
games_2008 = up[up.Year == 2008]
games_2008.sample(3)
# Out:
#       Year     City     Sport  Discipline           Athlete Name  NOC Gender  \
# 1020  2008  Beijing   fencing     fencing           SMART, Keeth  USA    Men
# 342   2008  Beijing  aquatics  water polo  VAN DEN BERG, Gillian  NED  Women
# 1651  2008  Beijing   sailing     sailing         GOODISON, Paul  GBR    Men
#
#                           Event Event Gender   Medal
# 1020                 sabre team            M  Silver
# 342                  water polo            W    Gold
# 1651  laser - one person dinghy            M    Gold

# %%
(games_2008
 .Medal
 .value_counts())
# Out:
# Medal
# Bronze    710
# Gold      669
# Silver    663
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              )
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"])
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender',
              palette='seismic')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender',
              palette='coolwarm')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender',
              palette='bwr')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender',
              palette='bwr_r')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %% [markdown]
# ##Working with groupby

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt


if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year      City              Sport       Discipline              Athlete Name  NOC Gender  \
# 27062  2004    Athens         volleyball       volleyball         PLOTNIKOVA, Elena  RUS  Women
# 8437   1952  Helsinki             rowing           rowing  BAETENS, Robert Frederik  BEL    Men
# 11039  1964     Tokyo  modern pentathlon  modern pentath.             TÖRÖK, Ferenc  HUN    Men
#
#                         Event Event Gender   Medal
# 27062              volleyball            W  Silver
# 8437        coxless pair (2-)            M  Silver
# 11039  individual competition            M    Gold

# %%
sprints = up[(up.Year == 2008) & ((up.Event == '100m') | (up.Event == '200m'))]
sprints
# Out:
#      Year     City      Sport Discipline              Athlete Name  NOC Gender Event Event Gender  \
# 388  2008  Beijing  athletics  athletics               DIX, Walter  USA    Men  100m            M
# 389  2008  Beijing  athletics  athletics               BOLT, Usain  JAM    Men  100m            M
# 390  2008  Beijing  athletics  athletics         THOMPSON, Richard  TRI    Men  100m            M
# 391  2008  Beijing  athletics  athletics        FRASER, Shelly-ann  JAM  Women  100m            W
# 392  2008  Beijing  athletics  athletics          SIMPSON, Sherone  JAM  Women  100m            W
# 393  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM  Women  100m            W
# 406  2008  Beijing  athletics  athletics               DIX, Walter  USA    Men  200m            M
# 407  2008  Beijing  athletics  athletics               BOLT, Usain  JAM    Men  200m            M
# 408  2008  Beijing  athletics  athletics           CRAWFORD, Shawn  USA    Men  200m            M
# 409  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM  Women  200m            W
# 410  2008  Beijing  athletics  athletics  CAMPBELL-BROWN, Veronica  JAM  Women  200m            W
# 411  2008  Beijing  athletics  athletics            FELIX, Allyson  USA  Women  200m            W
#
#       Medal
# 388  Bronze
# 389    Gold
# 390  Silver
# 391    Gold
# 392  Silver
# 393  Silver
# 406  Bronze
# 407    Gold
# 408  Silver
# 409  Bronze
# 410    Gold
# 411  Silver

# %%
sp = sprints.groupby(['NOC', 'Gender', 'Event'])
sp

# %%
up.groupby("Year")

# %%
type(up.groupby('Year'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
up.groupby("Year").count()
# Out:
#       City  Sport  Discipline  Athlete Name   NOC  Gender  Event  Event Gender  Medal
# Year
# 1896   151    151         151           151   151     151    151           151    151
# 1900   512    512         512           512   512     512    512           512    512
# 1904   470    470         470           470   470     470    470           470    470
# 1908   804    804         804           804   804     804    804           804    804
# 1912   885    885         885           885   885     885    885           885    885
# 1920  1298   1298        1298          1298  1298    1298   1298          1298   1298
# 1924   884    884         884           884   884     884    884           884    884
# 1928   710    710         710           710   710     710    710           710    710
# 1932   615    615         615           615   615     615    615           615    615
# 1936   875    875         875           875   875     875    875           875    875
# 1948   814    814         814           814   814     814    814           814    814
# 1952   889    889         889           889   889     889    889           889    889
# 1956   885    885         885           885   885     885    885           885    885
# 1960   882    882         882           882   882     882    882           882    882
# 1964  1010   1010        1010          1010  1010    1010   1010          1010   1010
# 1968  1031   1031        1031          1031  1031    1031   1031          1031   1031
# 1972  1185   1185        1185          1185  1185    1185   1185          1185   1185
# 1976  1305   1305        1305          1305  1305    1305   1305          1305   1305
# 1980  1387   1387        1387          1387  1387    1387   1387          1387   1387
# 1984  1459   1459        1459          1459  1459    1459   1459          1459   1459
# 1988  1546   1546        1546          1546  1546    1546   1546          1546   1546
# 1992  1705   1705        1705          1705  1705    1705   1705          1705   1705
# 1996  1859   1859        1859          1859  1859    1859   1859          1859   1859
# 2000  2015   2015        2015          2015  2015    2015   2015          2015   2015
# 2004  1998   1998        1998          1998  1998    1998   1998          1998   1998
# 2008  2042   2042        2042          2042  2042    2042   2042          2042   2042

# %%
for group_key, group_value in up.groupby('Year'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#      Year    City       Sport     Discipline          Athlete Name  NOC Gender        Event  \
# 0    1896  Athens     cycling  cycling track         FLAMENG, Léon  FRA    Men        100km
# 1    1896  Athens     cycling  cycling track    KOLETTIS, Georgios  GRE    Men        100km
# 2    1896  Athens   athletics      athletics         LANE, Francis  USA    Men         100m
# 3    1896  Athens   athletics      athletics      SZOKOLYI, Alajos  HUN    Men         100m
# 4    1896  Athens   athletics      athletics         BURKE, Thomas  USA    Men         100m
# ..    ...     ...         ...            ...                   ...  ...    ...          ...
# 146  1896  Athens   athletics      athletics       CONNOLLY, James  USA    Men  triple jump
# 147  1896  Athens   athletics      athletics    TUFFERI, Alexandre  FRA    Men  triple jump
# 148  1896  Athens  gymnastics    artistic g.  WEINGÄRTNER, Hermann  GER    Men        vault
# 149  1896  Athens  gymnastics    artistic g.        SCHUMANN, Carl  GER    Men        vault
# 150  1896  Athens  gymnastics    artistic g.         ZUTTER, Louis  SUI    Men        vault
#
#     Event Gender   Medal
# 0              M    Gold
# 1              M  Silver
# 2              M  Bronze
# 3              M  Bronze
# 4              M    Gold
# ..           ...     ...
# 146            M    Gold
# 147            M  Silver
# 148            M  Bronze
# 149            M    Gold
# 150            M  Silver
#
# [151 rows x 10 columns]
# 1900
#      Year   City    Sport Discipline                 Athlete Name  NOC Gender  \
# 151  1900  Paris  sailing    sailing                 MICHELET, E.  FRA    Men
# 152  1900  Paris  sailing    sailing                 MICHELET, F.  FRA    Men
# 153  1900  Paris  sailing    sailing             GRETTON, John H.  GBR    Men
# 154  1900  Paris  sailing    sailing                 HOPE, Linton  GBR    Men
# 155  1900  Paris  sailing    sailing  LORD CURRIE, Lorne Campbell  GBR    Men
# ..    ...    ...      ...        ...                          ...  ...    ...
# 658  1900  Paris  fencing    fencing                 AYAT, Albert  FRA    Men
# 659  1900  Paris  fencing    fencing                 FONST, Ramon  CUB    Men
# 660  1900  Paris  fencing    fencing               LAURENT, Henri  FRA    Men
# 661  1900  Paris  fencing    fencing                 AYAT, Albert  FRA    Men
# 662  1900  Paris  fencing    fencing               BOUGNOL, Emile  FRA    Men
#
#                           Event Event Gender   Medal
# 151                      0.5-1t            X  Bronze
# 152                      0.5-1t            X  Bronze
# 153                      0.5-1t            X    Gold
# 154                      0.5-1t            X    Gold
# 155                      0.5-1t            X    Gold
# ..                          ...          ...     ...
# 658  épée, amateurs and masters            M    Gold
# 659  épée, amateurs and masters            M  Silver
# 660               épée, masters            M  Bronze
# 661               épée, masters            M    Gold
# 662               épée, masters            M  Silver
#
# [512 rows x 10 columns]
# 1904
#       Year      City       Sport       Discipline                 Athlete Name  NOC Gender  \
# 663   1904  St Louis      boxing           boxing            MICHAELS, William  USA    Men
# 664   1904  St Louis      boxing           boxing               BERGER, Samuel  USA    Men
# 665   1904  St Louis      boxing           boxing               MAYER, Charles  USA    Men
# 666   1904  St Louis   wrestling  wrestling free.  WARMBOLD, Frederick Charles  USA    Men
# 667   1904  St Louis   wrestling  wrestling free.             HANSEN, Bernhuff  USA    Men
# ...    ...       ...         ...              ...                          ...  ...    ...
# 1128  1904  St Louis  gymnastics      artistic g.                EYSER, George  USA    Men
# 1129  1904  St Louis  gymnastics      artistic g.                 HEIDA, Anton  USA    Men
# 1130  1904  St Louis     fencing          fencing       VAN ZO POST, Albertson  CUB    Men
# 1131  1904  St Louis     fencing          fencing                 FONST, Ramon  CUB    Men
# 1132  1904  St Louis     fencing          fencing              TATHAM, Charles  CUB    Men
#
#                         Event Event Gender   Medal
# 663   + 71.67kg (heavyweight)            M  Bronze
# 664   + 71.67kg (heavyweight)            M    Gold
# 665   + 71.67kg (heavyweight)            M  Silver
# 666   + 71.67kg (heavyweight)            M  Bronze
# 667   + 71.67kg (heavyweight)            M    Gold
# ...                       ...          ...     ...
# 1128                    vault            M    Gold
# 1129                    vault            M    Gold
# 1130          épée individual            M  Bronze
# 1131          épée individual            M    Gold
# 1132          épée individual            M  Silver
#
# [470 rows x 10 columns]
# 1908
#       Year    City      Sport       Discipline               Athlete Name  NOC Gender  \
# 1133  1908  London     boxing           boxing           PARKS, Frederick  GBR    Men
# 1134  1908  London     boxing           boxing     OLDMAN, Albert Leonard  GBR    Men
# 1135  1908  London     boxing           boxing   EVANS, Sydney Charles H.  GBR    Men
# 1136  1908  London  wrestling  wrestling free.     BARRETT, Edward Edmond  GBR    Men
# 1137  1908  London  wrestling  wrestling free.  O'KELLY, George Cornelius  GBR    Men
# ...    ...     ...        ...              ...                        ...  ...    ...
# 1932  1908  London    fencing          fencing     OLIVIER, Eugène Victor  FRA    Men
# 1933  1908  London    fencing          fencing      DANIELL, Charles Leaf  GBR    Men
# 1934  1908  London    fencing          fencing          HAIG, Cecil Henry  GBR    Men
# 1935  1908  London    fencing          fencing      HOLT, Martin Drummond  GBR    Men
# 1936  1908  London    fencing          fencing  MONTGOMERIE, Robert Cecil  GBR    Men
#
#                         Event Event Gender   Medal
# 1133  + 71.67kg (heavyweight)            M  Bronze
# 1134  + 71.67kg (heavyweight)            M    Gold
# 1135  + 71.67kg (heavyweight)            M  Silver
# 1136     + 73kg (heavyweight)            M  Bronze
# 1137     + 73kg (heavyweight)            M    Gold
# ...                       ...          ...     ...
# 1932                épée team            M    Gold
# 1933                épée team            M  Silver
# 1934                épée team            M  Silver
# 1935                épée team            M  Silver
# 1936                épée team            M  Silver
#
# [804 rows x 10 columns]
# 1912
#       Year       City      Sport       Discipline                Athlete Name  NOC Gender  \
# 1937  1912  Stockholm  wrestling  wrestling gre-r        JENSEN, Sören Marius  DEN    Men
# 1938  1912  Stockholm  wrestling  wrestling gre-r   SAARELA, Urjö Erik Mikael  FIN    Men
# 1939  1912  Stockholm  wrestling  wrestling gre-r         OLIN, Johan Fredrik  FIN    Men
# 1940  1912  Stockholm  wrestling  wrestling gre-r               LASANEN, Otto  FIN    Men
# 1941  1912  Stockholm  wrestling  wrestling gre-r             KOSKELO, Kaarlo  FIN    Men
# ...    ...        ...        ...              ...                         ...  ...    ...
# 2817  1912  Stockholm    fencing          fencing  EVERITT, Arthur Francis G.  GBR    Men
# 2818  1912  Stockholm    fencing          fencing       HOLT, Martin Drummond  GBR    Men
# 2819  1912  Stockholm    fencing          fencing           MARTINEAU, Sydney  GBR    Men
# 2820  1912  Stockholm    fencing          fencing   MONTGOMERIE, Robert Cecil  GBR    Men
# 2821  1912  Stockholm    fencing          fencing       SELIGMAN, Edgar Isaac  GBR    Men
#
#                              Event Event Gender   Medal
# 1937  + 82.5kg (super heavyweight)            M  Bronze
# 1938  + 82.5kg (super heavyweight)            M    Gold
# 1939  + 82.5kg (super heavyweight)            M  Silver
# 1940        - 60kg (featherweight)            M  Bronze
# 1941        - 60kg (featherweight)            M    Gold
# ...                            ...          ...     ...
# 2817                     épée team            M  Silver
# 2818                     épée team            M  Silver
# 2819                     épée team            M  Silver
# 2820                     épée team            M  Silver
# 2821                     épée team            M  Silver
#
# [885 rows x 10 columns]
# 1920
#       Year     City      Sport       Discipline                    Athlete Name  NOC Gender  \
# 2822  1920  Antwerp     boxing           boxing           ELUERE, Albert Xavier  FRA    Men
# 2823  1920  Antwerp     boxing           boxing                  RAWSON, Ronald  GBR    Men
# 2824  1920  Antwerp     boxing           boxing                PETEERSEN, Sören  DEN    Men
# 2825  1920  Antwerp  wrestling  wrestling free.         MEYER, Frederick Julius  USA    Men
# 2826  1920  Antwerp  wrestling  wrestling free.                  NILSSON, Ernst  SWE    Men
# ...    ...      ...        ...              ...                             ...  ...    ...
# 4115  1920  Antwerp    fencing          fencing                 DE WEE, Maurice  BEL    Men
# 4116  1920  Antwerp    fencing          fencing                  GEVERS, Ernest  BEL    Men
# 4117  1920  Antwerp    fencing          fencing         GOBLET D'AVIELLA, Félix  BEL    Men
# 4118  1920  Antwerp    fencing          fencing  LE HARDY DE BEAULIEU, Philippe  BEL    Men
# 4119  1920  Antwerp    fencing          fencing                       TOM, Léon  BEL    Men
#
#                         Event Event Gender   Medal
# 2822  + 79.38kg (heavyweight)            M  Bronze
# 2823  + 79.38kg (heavyweight)            M    Gold
# 2824  + 79.38kg (heavyweight)            M  Silver
# 2825     + 80kg (heavyweight)            M  Bronze
# 2826     + 80kg (heavyweight)            M  Bronze
# ...                       ...          ...     ...
# 4115                épée team            M  Silver
# 4116                épée team            M  Silver
# 4117                épée team            M  Silver
# 4118                épée team            M  Silver
# 4119                épée team            M  Silver
#
# [1298 rows x 10 columns]
# 1924
#       Year   City      Sport       Discipline          Athlete Name  NOC Gender  \
# 4120  1924  Paris     boxing           boxing       PORZIO, Alfredo  ARG    Men
# 4121  1924  Paris     boxing           boxing       VON PORAT, Otto  NOR    Men
# 4122  1924  Paris     boxing           boxing       PETERSEN, Sören  DEN    Men
# 4123  1924  Paris  wrestling  wrestling gre-r         BADO, Rajmund  HUN    Men
# 4124  1924  Paris  wrestling  wrestling gre-r        DEGLANE, Henri  FRA    Men
# ...    ...    ...        ...              ...                   ...  ...    ...
# 4999  1924  Paris    fencing          fencing   DE CRAECKER, Joseph  BEL    Men
# 5000  1924  Paris    fencing          fencing  DE MONTIGNY, Fernand  BEL    Men
# 5001  1924  Paris    fencing          fencing     DELPORTE, Charles  BEL    Men
# 5002  1924  Paris    fencing          fencing        GEVERS, Ernest  BEL    Men
# 5003  1924  Paris    fencing          fencing             TOM, Léon  BEL    Men
#
#                              Event Event Gender   Medal
# 4120       + 79.38kg (heavyweight)            M  Bronze
# 4121       + 79.38kg (heavyweight)            M    Gold
# 4122       + 79.38kg (heavyweight)            M  Silver
# 4123  + 82.5kg (super heavyweight)            M  Bronze
# 4124  + 82.5kg (super heavyweight)            M    Gold
# ...                            ...          ...     ...
# 4999                     épée team            M  Silver
# 5000                     épée team            M  Silver
# 5001                     épée team            M  Silver
# 5002                     épée team            M  Silver
# 5003                     épée team            M  Silver
#
# [884 rows x 10 columns]
# 1928
#       Year       City      Sport       Discipline               Athlete Name  NOC Gender  \
# 5004  1928  Amsterdam     boxing           boxing  MICHAELSEN, Michael Jacob  DEN    Men
# 5005  1928  Amsterdam     boxing           boxing   RODRIGUEZ JURADO, Arturo  ARG    Men
# 5006  1928  Amsterdam     boxing           boxing           RAMM, Nils Arvid  SWE    Men
# 5007  1928  Amsterdam  wrestling  wrestling gre-r             GEHRING, Georg  GER    Men
# 5008  1928  Amsterdam  wrestling  wrestling gre-r           SVENSSON, Rudolf  SWE    Men
# ...    ...        ...        ...              ...                        ...  ...    ...
# 5709  1928  Amsterdam   aquatics       water polo             KESERU, Ferenc  HUN    Men
# 5710  1928  Amsterdam   aquatics       water polo            VRABELY, Jozsef  HUN    Men
# 5711  1928  Amsterdam    fencing          fencing     CALNAN, George Charles  USA    Men
# 5712  1928  Amsterdam    fencing          fencing             GAUDIN, Lucien  FRA    Men
# 5713  1928  Amsterdam    fencing          fencing           BUCHARD, Georges  FRA    Men
#
#                              Event Event Gender   Medal
# 5004       + 79.38kg (heavyweight)            M  Bronze
# 5005       + 79.38kg (heavyweight)            M    Gold
# 5006       + 79.38kg (heavyweight)            M  Silver
# 5007  + 82.5kg (super heavyweight)            M  Bronze
# 5008  + 82.5kg (super heavyweight)            M    Gold
# ...                            ...          ...     ...
# 5709                    water polo            M  Silver
# 5710                    water polo            M  Silver
# 5711               épée individual            M  Bronze
# 5712               épée individual            M    Gold
# 5713               épée individual            M  Silver
#
# [710 rows x 10 columns]
# 1932
#       Year         City          Sport     Discipline                    Athlete Name  NOC Gender  \
# 5714  1932  Los Angeles         boxing         boxing                FEARY, Frederick  USA    Men
# 5715  1932  Los Angeles         boxing         boxing        LOVELL, Alberto Santiago  ARG    Men
# 5716  1932  Los Angeles         boxing         boxing                   ROVATI, Luigi  ITA    Men
# 5717  1932  Los Angeles  weightlifting  weightlifting             STRASSBERGER, Josef  GER    Men
# 5718  1932  Los Angeles  weightlifting  weightlifting                SKOBLA, Jaroslav  TCH    Men
# ...    ...          ...            ...            ...                             ...  ...    ...
# 6324  1932  Los Angeles        fencing        fencing                 AGOSTONI, Carlo  ITA    Men
# 6325  1932  Los Angeles        fencing        fencing  CORNAGGIA-MEDICI, Giancarlo C.  ITA    Men
# 6326  1932  Los Angeles        fencing        fencing                   MINOLI, Renzo  ITA    Men
# 6327  1932  Los Angeles        fencing        fencing                  RAGNO, Saverio  ITA    Men
# 6328  1932  Los Angeles        fencing        fencing                RICCARDI, Franco  ITA    Men
#
#                               Event Event Gender   Medal
# 5714        + 79.38kg (heavyweight)            M  Bronze
# 5715        + 79.38kg (heavyweight)            M    Gold
# 5716        + 79.38kg (heavyweight)            M  Silver
# 5717  + 82.5kg, total (heavyweight)            M  Bronze
# 5718  + 82.5kg, total (heavyweight)            M    Gold
# ...                             ...          ...     ...
# 6324                      épée team            M  Silver
# 6325                      épée team            M  Silver
# 6326                      épée team            M  Silver
# 6327                      épée team            M  Silver
# 6328                      épée team            M  Silver
#
# [615 rows x 10 columns]
# 1936
#       Year    City          Sport     Discipline            Athlete Name  NOC Gender  \
# 6329  1936  Berlin         boxing         boxing          NILSEN, Erling  NOR    Men
# 6330  1936  Berlin         boxing         boxing          RUNGE, Herbert  GER    Men
# 6331  1936  Berlin         boxing         boxing  LOVELL, Jose Guillermo  ARG    Men
# 6332  1936  Berlin  weightlifting  weightlifting         LUHAÄÄR, Arnold  EST    Men
# 6333  1936  Berlin  weightlifting  weightlifting           MANGER, Josef  GER    Men
# ...    ...     ...            ...            ...                     ...  ...    ...
# 7199  1936  Berlin        fencing        fencing         CEDERIN, Birger  SWE    Men
# 7200  1936  Berlin        fencing        fencing        DRAKENBERG, Hans  SWE    Men
# 7201  1936  Berlin        fencing        fencing         DYRSSEN, Gustaf  SWE    Men
# 7202  1936  Berlin        fencing        fencing          GRANFELT, Hans  SWE    Men
# 7203  1936  Berlin        fencing        fencing           THOFELT, Sven  SWE    Men
#
#                               Event Event Gender   Medal
# 6329        + 79.38kg (heavyweight)            M  Bronze
# 6330        + 79.38kg (heavyweight)            M    Gold
# 6331        + 79.38kg (heavyweight)            M  Silver
# 6332  + 82.5kg, total (heavyweight)            M  Bronze
# 6333  + 82.5kg, total (heavyweight)            M    Gold
# ...                             ...          ...     ...
# 7199                      épée team            M  Silver
# 7200                      épée team            M  Silver
# 7201                      épée team            M  Silver
# 7202                      épée team            M  Silver
# 7203                      épée team            M  Silver
#
# [875 rows x 10 columns]
# 1948
#       Year    City          Sport     Discipline               Athlete Name  NOC Gender  \
# 7204  1948  London         boxing         boxing               ARTHUR, John  RSA    Men
# 7205  1948  London         boxing         boxing           IGLESIAS, Rafael  ARG    Men
# 7206  1948  London         boxing         boxing            NILSSON, Gunnar  SWE    Men
# 7207  1948  London  weightlifting  weightlifting           CHARITE, Abraham  NED    Men
# 7208  1948  London  weightlifting  weightlifting      DAVIS, John Henry Jr.  USA    Men
# ...    ...     ...            ...            ...                        ...  ...    ...
# 8013  1948  London        fencing        fencing             CANTONE, Luigi  ITA    Men
# 8014  1948  London        fencing        fencing  MANDRUZZATO, Marc Antonio  ITA    Men
# 8015  1948  London        fencing        fencing         MANGIAROTTI, Dario  ITA    Men
# 8016  1948  London        fencing        fencing       MANGIAROTTI, Edoardo  ITA    Men
# 8017  1948  London        fencing        fencing           MARINI, Fiorenzo  ITA    Men
#
#                               Event Event Gender   Medal
# 7204           + 80kg (heavyweight)            M  Bronze
# 7205           + 80kg (heavyweight)            M    Gold
# 7206           + 80kg (heavyweight)            M  Silver
# 7207  + 82.5kg, total (heavyweight)            M  Bronze
# 7208  + 82.5kg, total (heavyweight)            M    Gold
# ...                             ...          ...     ...
# 8013                      épée team            M  Silver
# 8014                      épée team            M  Silver
# 8015                      épée team            M  Silver
# 8016                      épée team            M  Silver
# 8017                      épée team            M  Silver
#
# [814 rows x 10 columns]
# 1952
#       Year      City      Sport       Discipline               Athlete Name  NOC Gender  \
# 8018  1952  Helsinki     boxing           boxing      KOSKI, Ilkka Rickhard  FIN    Men
# 8019  1952  Helsinki     boxing           boxing         NIEMAN, Andries C.  RSA    Men
# 8020  1952  Helsinki     boxing           boxing      SANDERS, Hayes Edward  USA    Men
# 8021  1952  Helsinki     boxing           boxing  JOHANSSON, Ingemar (Ingo)  SWE    Men
# 8022  1952  Helsinki  wrestling  wrestling free.     RICHMOND, Kenneth Alan  GBR    Men
# ...    ...       ...        ...              ...                        ...  ...    ...
# 8902  1952  Helsinki    fencing          fencing              FAHLMAN, Sven  SWE    Men
# 8903  1952  Helsinki    fencing          fencing             FORSSELL, Carl  SWE    Men
# 8904  1952  Helsinki    fencing          fencing          LJUNGQUIST, Bengt  SWE    Men
# 8905  1952  Helsinki    fencing          fencing         MAGNUSSON, Lennart  SWE    Men
# 8906  1952  Helsinki    fencing          fencing     REHBINDER, Berndt-Otto  SWE    Men
#
#                      Event Event Gender   Medal
# 8018  + 81kg (heavyweight)            M  Bronze
# 8019  + 81kg (heavyweight)            M  Bronze
# 8020  + 81kg (heavyweight)            M    Gold
# 8021  + 81kg (heavyweight)            M  Silver
# 8022  + 87kg (heavyweight)            M  Bronze
# ...                    ...          ...     ...
# 8902             épée team            M  Silver
# 8903             épée team            M  Silver
# 8904             épée team            M  Silver
# 8905             épée team            M  Silver
# 8906             épée team            M  Silver
#
# [889 rows x 10 columns]
# 1956
#       Year                   City      Sport       Discipline                Athlete Name  NOC  \
# 8907  1956  Melbourne / Stockholm     boxing           boxing      BEKKER, Daniel Wepener  RSA
# 8908  1956  Melbourne / Stockholm     boxing           boxing            BOZZANO, Giacomo  ITA
# 8909  1956  Melbourne / Stockholm     boxing           boxing    RADEMACHER, Thomas Peter  USA
# 8910  1956  Melbourne / Stockholm     boxing           boxing                 MUKHIN, Lev  URS
# 8911  1956  Melbourne / Stockholm  wrestling  wrestling free.  KANGASNIEMI, Taisto Ilmari  FIN
# ...    ...                    ...        ...              ...                         ...  ...
# 9787  1956  Melbourne / Stockholm    fencing          fencing         BERZSENYI, Barnabas  HUN
# 9788  1956  Melbourne / Stockholm    fencing          fencing              MAROSI, Jozsef  HUN
# 9789  1956  Melbourne / Stockholm    fencing          fencing                NAGY, Ambrus  HUN
# 9790  1956  Melbourne / Stockholm    fencing          fencing               RERRICH, Bela  HUN
# 9791  1956  Melbourne / Stockholm    fencing          fencing            SAKOVICS, Jozsef  HUN
#
#      Gender                 Event Event Gender   Medal
# 8907    Men  + 81kg (heavyweight)            M  Bronze
# 8908    Men  + 81kg (heavyweight)            M  Bronze
# 8909    Men  + 81kg (heavyweight)            M    Gold
# 8910    Men  + 81kg (heavyweight)            M  Silver
# 8911    Men  + 87kg (heavyweight)            M  Bronze
# ...     ...                   ...          ...     ...
# 9787    Men             épée team            M  Silver
# 9788    Men             épée team            M  Silver
# 9789    Men             épée team            M  Silver
# 9790    Men             épée team            M  Silver
# 9791    Men             épée team            M  Silver
#
# [885 rows x 10 columns]
# 1960
#        Year  City      Sport       Discipline                  Athlete Name  NOC Gender  \
# 9792   1960  Rome     boxing           boxing                  NEMEC, Josef  TCH    Men
# 9793   1960  Rome     boxing           boxing              SIEGMUND, Günter  EUA    Men
# 9794   1960  Rome     boxing           boxing         DE PICCOLI, Francesco  ITA    Men
# 9795   1960  Rome     boxing           boxing        BEKKER, Daniel Wepener  RSA    Men
# 9796   1960  Rome  wrestling  wrestling free.              DZARASOV, Savkus  URS    Men
# ...     ...   ...        ...              ...                           ...  ...    ...
# 10669  1960  Rome    fencing          fencing        HARRISON, Raymond Alan  GBR    Men
# 10670  1960  Rome    fencing          fencing  HOSKYNS, Henry William Furse  GBR    Men
# 10671  1960  Rome    fencing          fencing    HOWARD, Michael John Peter  GBR    Men
# 10672  1960  Rome    fencing          fencing      JAY, Allan Louis Neville  GBR    Men
# 10673  1960  Rome    fencing          fencing          PELLING, John Albert  GBR    Men
#
#                       Event Event Gender   Medal
# 9792   + 81kg (heavyweight)            M  Bronze
# 9793   + 81kg (heavyweight)            M  Bronze
# 9794   + 81kg (heavyweight)            M    Gold
# 9795   + 81kg (heavyweight)            M  Silver
# 9796   + 87kg (heavyweight)            M  Bronze
# ...                     ...          ...     ...
# 10669             épée team            M  Silver
# 10670             épée team            M  Silver
# 10671             épée team            M  Silver
# 10672             épée team            M  Silver
# 10673             épée team            M  Silver
#
# [882 rows x 10 columns]
# 1964
#        Year   City    Sport Discipline                   Athlete Name  NOC Gender  \
# 10674  1964  Tokyo     judo       judo           CHIKVILADZE, Parnaos  URS    Men
# 10675  1964  Tokyo     judo       judo                KIKNADZE, Anzor  URS    Men
# 10676  1964  Tokyo     judo       judo                  INOKUMA, Isao  JPN    Men
# 10677  1964  Tokyo     judo       judo  ROGERS, Alfred Harold Douglas  CAN    Men
# 10678  1964  Tokyo   boxing     boxing               EMELYANOV, Vadim  URS    Men
# ...     ...    ...      ...        ...                            ...  ...    ...
# 11679  1964  Tokyo  fencing    fencing       BREDA, Giovanni Battista  ITA    Men
# 11680  1964  Tokyo  fencing    fencing              DELFINO, Giuseppe  ITA    Men
# 11681  1964  Tokyo  fencing    fencing           PAOLUCCI, Gianfranco  ITA    Men
# 11682  1964  Tokyo  fencing    fencing            PELLEGRINO, Alberto  ITA    Men
# 11683  1964  Tokyo  fencing    fencing             SACCARO, Gianluigi  ITA    Men
#
#                       Event Event Gender   Medal
# 10674  + 80kg (heavyweight)            M  Bronze
# 10675  + 80kg (heavyweight)            M  Bronze
# 10676  + 80kg (heavyweight)            M    Gold
# 10677  + 80kg (heavyweight)            M  Silver
# 10678  + 81kg (heavyweight)            M  Bronze
# ...                     ...          ...     ...
# 11679             épée team            M  Silver
# 11680             épée team            M  Silver
# 11681             épée team            M  Silver
# 11682             épée team            M  Silver
# 11683             épée team            M  Silver
#
# [1010 rows x 10 columns]
# 1968
#        Year    City          Sport     Discipline          Athlete Name  NOC Gender  \
# 11684  1968  Mexico         boxing         boxing      BAMBINI, Giorgio  ITA    Men
# 11685  1968  Mexico         boxing         boxing        ROCHA, Joaquin  MEX    Men
# 11686  1968  Mexico         boxing         boxing       FOREMAN, George  USA    Men
# 11687  1968  Mexico         boxing         boxing       CHEPULIS, Ionas  URS    Men
# 11688  1968  Mexico  weightlifting  weightlifting  DUBE, Joseph Douglas  USA    Men
# ...     ...     ...            ...            ...                   ...  ...    ...
# 12710  1968  Mexico        fencing        fencing        KRISS, Grigori  URS    Men
# 12711  1968  Mexico        fencing        fencing   MODZALEVSKY, Viktor  URS    Men
# 12712  1968  Mexico        fencing        fencing  NIKANCHIKOV, Aleksei  URS    Men
# 12713  1968  Mexico        fencing        fencing       SMOLYAKOV, Yuri  URS    Men
# 12714  1968  Mexico        fencing        fencing       VITEBSKY, Iosif  URS    Men
#
#                              Event Event Gender   Medal
# 11684         + 81kg (heavyweight)            M  Bronze
# 11685         + 81kg (heavyweight)            M  Bronze
# 11686         + 81kg (heavyweight)            M    Gold
# 11687         + 81kg (heavyweight)            M  Silver
# 11688  + 90kg, total (heavyweight)            M  Bronze
# ...                            ...          ...     ...
# 12710                    épée team            M  Silver
# 12711                    épée team            M  Silver
# 12712                    épée team            M  Silver
# 12713                    épée team            M  Silver
# 12714                    épée team            M  Silver
#
# [1031 rows x 10 columns]
# 1972
#        Year    City      Sport       Discipline            Athlete Name  NOC Gender  \
# 12715  1972  Munich  wrestling  wrestling free.  TAYLOR, Christopher J.  USA    Men
# 12716  1972  Munich  wrestling  wrestling free.       MEDVED, Aleksandr  URS    Men
# 12717  1972  Munich  wrestling  wrestling free.         DURALIEV, Osman  BUL    Men
# 12718  1972  Munich  wrestling  wrestling gre-r       DOLIPSCHI, Victor  ROU    Men
# 12719  1972  Munich  wrestling  wrestling gre-r       ROSHCHIN, Anatoli  URS    Men
# ...     ...     ...        ...              ...                     ...  ...    ...
# 13895  1972  Munich    fencing          fencing            EVEQUOZ, Guy  SUI    Men
# 13896  1972  Munich    fencing          fencing           GIGER, Daniel  SUI    Men
# 13897  1972  Munich    fencing          fencing       KAUTER, Christian  SUI    Men
# 13898  1972  Munich    fencing          fencing         LÖTSCHER, Peter  SUI    Men
# 13899  1972  Munich    fencing          fencing    SUCHANECKI, Francois  SUI    Men
#
#                              Event Event Gender   Medal
# 12715  + 100kg (super heavyweight)            M  Bronze
# 12716  + 100kg (super heavyweight)            M    Gold
# 12717  + 100kg (super heavyweight)            M  Silver
# 12718  + 100kg (super heavyweight)            M  Bronze
# 12719  + 100kg (super heavyweight)            M    Gold
# ...                            ...          ...     ...
# 13895                    épée team            M  Silver
# 13896                    épée team            M  Silver
# 13897                    épée team            M  Silver
# 13898                    épée team            M  Silver
# 13899                    épée team            M  Silver
#
# [1185 rows x 10 columns]
# 1976
#        Year      City      Sport       Discipline           Athlete Name  NOC Gender  \
# 13900  1976  Montreal  wrestling  wrestling free.        SIMON, Ladislau  ROU    Men
# 13901  1976  Montreal  wrestling  wrestling free.         ANDIEV, Soslan  URS    Men
# 13902  1976  Montreal  wrestling  wrestling free.          BALLA, Jozsef  HUN    Men
# 13903  1976  Montreal  wrestling  wrestling gre-r        CODREANU, Roman  ROU    Men
# 13904  1976  Montreal  wrestling  wrestling gre-r  KOLCHINSKY, Aleksandr  URS    Men
# ...     ...       ...        ...              ...                    ...  ...    ...
# 15200  1976  Montreal    fencing          fencing        VON ESSEN, Carl  SWE    Men
# 15201  1976  Montreal    fencing          fencing         BEHR, Reinhold  FRG    Men
# 15202  1976  Montreal    fencing          fencing        FISCHER, Volker  FRG    Men
# 15203  1976  Montreal    fencing          fencing      HEHN, Hans-Jürgen  FRG    Men
# 15204  1976  Montreal    fencing          fencing       PUSCH, Alexander  FRG    Men
#
#                              Event Event Gender   Medal
# 13900  + 100kg (super heavyweight)            M  Bronze
# 13901  + 100kg (super heavyweight)            M    Gold
# 13902  + 100kg (super heavyweight)            M  Silver
# 13903  + 100kg (super heavyweight)            M  Bronze
# 13904  + 100kg (super heavyweight)            M    Gold
# ...                            ...          ...     ...
# 15200                    épée team            M    Gold
# 15201                    épée team            M  Silver
# 15202                    épée team            M  Silver
# 15203                    épée team            M  Silver
# 15204                    épée team            M  Silver
#
# [1305 rows x 10 columns]
# 1980
#        Year    City      Sport       Discipline           Athlete Name  NOC Gender  \
# 15205  1980  Moscow  wrestling  wrestling free.        SANDURSKI, Adam  POL    Men
# 15206  1980  Moscow  wrestling  wrestling free.         ANDIEV, Soslan  URS    Men
# 15207  1980  Moscow  wrestling  wrestling free.          BALLA, Jozsef  HUN    Men
# 15208  1980  Moscow  wrestling  wrestling gre-r         BCHARA, Hassan  LIB    Men
# 15209  1980  Moscow  wrestling  wrestling gre-r  KOLCHINSKY, Aleksandr  URS    Men
# ...     ...     ...        ...              ...                    ...  ...    ...
# 16587  1980  Moscow    fencing          fencing    CHRONOWSKI, Ludomir  POL    Men
# 16588  1980  Moscow    fencing          fencing      JABLKOWSKI, Piotr  POL    Men
# 16589  1980  Moscow    fencing          fencing           LIS, Andrzej  POL    Men
# 16590  1980  Moscow    fencing          fencing      STRZALKA, Mariusz  POL    Men
# 16591  1980  Moscow    fencing          fencing     SWORNOWSKI, Leszek  POL    Men
#
#                              Event Event Gender   Medal
# 15205  + 100kg (super heavyweight)            M  Bronze
# 15206  + 100kg (super heavyweight)            M    Gold
# 15207  + 100kg (super heavyweight)            M  Silver
# 15208  + 100kg (super heavyweight)            M  Bronze
# 15209  + 100kg (super heavyweight)            M    Gold
# ...                            ...          ...     ...
# 16587                    épée team            M  Silver
# 16588                    épée team            M  Silver
# 16589                    épée team            M  Silver
# 16590                    épée team            M  Silver
# 16591                    épée team            M  Silver
#
# [1387 rows x 10 columns]
# 1984
#        Year         City      Sport       Discipline               Athlete Name  NOC Gender  \
# 16592  1984  Los Angeles  wrestling  wrestling free.              TASKIN, Ayhan  TUR    Men
# 16593  1984  Los Angeles  wrestling  wrestling free.  BAUMGARTNER, Bruce Robert  USA    Men
# 16594  1984  Los Angeles  wrestling  wrestling free.              MOLLE, Robert  CAN    Men
# 16595  1984  Los Angeles  wrestling  wrestling gre-r          DOLIPSCHI, Victor  ROU    Men
# 16596  1984  Los Angeles  wrestling  wrestling gre-r     BLATNICK, Jeffrey Carl  USA    Men
# ...     ...          ...        ...              ...                        ...  ...    ...
# 18046  1984  Los Angeles    fencing          fencing           BOISSE, Philippe  FRA    Men
# 18047  1984  Los Angeles    fencing          fencing         HENRY, Jean-Michel  FRA    Men
# 18048  1984  Los Angeles    fencing          fencing           LENGLET, Olivier  FRA    Men
# 18049  1984  Los Angeles    fencing          fencing           RIBOUD, Philippe  FRA    Men
# 18050  1984  Los Angeles    fencing          fencing            SALESSE, Michel  FRA    Men
#
#                              Event Event Gender   Medal
# 16592  + 100kg (super heavyweight)            M  Bronze
# 16593  + 100kg (super heavyweight)            M    Gold
# 16594  + 100kg (super heavyweight)            M  Silver
# 16595  + 100kg (super heavyweight)            M  Bronze
# 16596  + 100kg (super heavyweight)            M    Gold
# ...                            ...          ...     ...
# 18046                    épée team            M  Silver
# 18047                    épée team            M  Silver
# 18048                    épée team            M  Silver
# 18049                    épée team            M  Silver
# 18050                    épée team            M  Silver
#
# [1459 rows x 10 columns]
# 1988
#        Year   City          Sport     Discipline               Athlete Name  NOC Gender  \
# 18051  1988  Seoul  weightlifting  weightlifting            ZAWIEJA, Martin  FRG    Men
# 18052  1988  Seoul  weightlifting  weightlifting       KURLOVICH, Alexandre  URS    Men
# 18053  1988  Seoul  weightlifting  weightlifting         NERLINGER, Manfred  FRG    Men
# 18054  1988  Seoul         boxing         boxing  MIROSHNICHENKO, Aleksandr  URS    Men
# 18055  1988  Seoul         boxing         boxing       ZARENKIEWICZ, Janusz  POL    Men
# ...     ...    ...            ...            ...                        ...  ...    ...
# 19592  1988  Seoul        fencing        fencing            BORRMANN, Elmar  FRG    Men
# 19593  1988  Seoul        fencing        fencing            FISCHER, Volker  FRG    Men
# 19594  1988  Seoul        fencing        fencing             GERULL, Thomas  FRG    Men
# 19595  1988  Seoul        fencing        fencing           PUSCH, Alexander  FRG    Men
# 19596  1988  Seoul        fencing        fencing      SCHMITT, Arnd Rüdiger  FRG    Men
#
#                                     Event Event Gender   Medal
# 18051  + 110kg, total (super heavyweight)            M  Bronze
# 18052  + 110kg, total (super heavyweight)            M    Gold
# 18053  + 110kg, total (super heavyweight)            M  Silver
# 18054          + 91kg (super heavyweight)            M  Bronze
# 18055          + 91kg (super heavyweight)            M  Bronze
# ...                                   ...          ...     ...
# 19592                           épée team            M  Silver
# 19593                           épée team            M  Silver
# 19594                           épée team            M  Silver
# 19595                           épée team            M  Silver
# 19596                           épée team            M  Silver
#
# [1546 rows x 10 columns]
# 1992
#        Year       City          Sport     Discipline          Athlete Name  NOC Gender  \
# 19597  1992  Barcelona  weightlifting  weightlifting    NERLINGER, Manfred  GER    Men
# 19598  1992  Barcelona  weightlifting  weightlifting  KURLOVICH, Alexandre  EUN    Men
# 19599  1992  Barcelona  weightlifting  weightlifting     TARANENKO, Leonid  EUN    Men
# 19600  1992  Barcelona           judo           judo       LUPINO, Natalia  FRA  Women
# 19601  1992  Barcelona           judo           judo          SAKAUE, Yoko  JPN  Women
# ...     ...        ...            ...            ...                   ...  ...    ...
# 21297  1992  Barcelona        fencing        fencing       HEGEDUS, Ferenc  HUN    Men
# 21298  1992  Barcelona        fencing        fencing       KOLCZONAI, Erno  HUN    Men
# 21299  1992  Barcelona        fencing        fencing          KOVACS, Ivan  HUN    Men
# 21300  1992  Barcelona        fencing        fencing    KULCSAR, Krisztian  HUN    Men
# 21301  1992  Barcelona        fencing        fencing         TOTOLA, Gabor  HUN    Men
#
#                                     Event Event Gender   Medal
# 19597  + 110kg, total (super heavyweight)            M  Bronze
# 19598  + 110kg, total (super heavyweight)            M    Gold
# 19599  + 110kg, total (super heavyweight)            M  Silver
# 19600                + 72kg (heavyweight)            W  Bronze
# 19601                + 72kg (heavyweight)            W  Bronze
# ...                                   ...          ...     ...
# 21297                           épée team            M  Silver
# 21298                           épée team            M  Silver
# 21299                           épée team            M  Silver
# 21300                           épée team            M  Silver
# 21301                           épée team            M  Silver
#
# [1705 rows x 10 columns]
# 1996
#        Year     City          Sport     Discipline            Athlete Name  NOC Gender  \
# 21302  1996  Atlanta           judo           judo          MOELLER, Frank  GER    Men
# 21303  1996  Atlanta           judo           judo    VAN BARNEVELD, Harry  BEL    Men
# 21304  1996  Atlanta           judo           judo         DOUILLET, David  FRA    Men
# 21305  1996  Atlanta           judo           judo     PEREZ LOBO, Ernesto  ESP    Men
# 21306  1996  Atlanta  weightlifting  weightlifting           BOTEV, Stefan  AUS    Men
# ...     ...      ...            ...            ...                     ...  ...    ...
# 23156  1996  Atlanta        fencing        fencing  FLESSEL-COLOVIC, Laura  FRA  Women
# 23157  1996  Atlanta        fencing        fencing  MORESEE-PICHOT, Sophie  FRA  Women
# 23158  1996  Atlanta        fencing        fencing           CHIESA, Laura  ITA  Women
# 23159  1996  Atlanta        fencing        fencing              UGA, Elisa  ITA  Women
# 23160  1996  Atlanta        fencing        fencing     ZALAFFI, Margherita  ITA  Women
#
#                                     Event Event Gender   Medal
# 21302               + 100kg (heavyweight)            M  Bronze
# 21303               + 100kg (heavyweight)            M  Bronze
# 21304               + 100kg (heavyweight)            M    Gold
# 21305               + 100kg (heavyweight)            M  Silver
# 21306  + 108kg, total (super heavyweight)            M  Bronze
# ...                                   ...          ...     ...
# 23156                           épée team            W    Gold
# 23157                           épée team            W    Gold
# 23158                           épée team            W  Silver
# 23159                           épée team            W  Silver
# 23160                           épée team            W  Silver
#
# [1859 rows x 10 columns]
# 2000
#        Year    City          Sport     Discipline         Athlete Name  NOC Gender  \
# 23161  2000  Sydney           judo           judo    PERTELSON, Indrek  EST    Men
# 23162  2000  Sydney           judo           judo     TMENOV, Tamerlan  RUS    Men
# 23163  2000  Sydney           judo           judo      DOUILLET, David  FRA    Men
# 23164  2000  Sydney           judo           judo  SHINOHARA, Shinichi  JPN    Men
# 23165  2000  Sydney  weightlifting  weightlifting    CHEMERKIN, Andrey  RUS    Men
# ...     ...     ...            ...            ...                  ...  ...    ...
# 25171  2000  Sydney        fencing        fencing   LOGOUNOVA, Tatiana  RUS  Women
# 25172  2000  Sydney        fencing        fencing       MAZINA, Mariya  RUS  Women
# 25173  2000  Sydney        fencing        fencing       BUERKI, Gianna  SUI  Women
# 25174  2000  Sydney        fencing        fencing        LAMON, Sophie  SUI  Women
# 25175  2000  Sydney        fencing        fencing     ROMAGNOLI, Diana  SUI  Women
#
#                        Event Event Gender   Medal
# 23161  + 100kg (heavyweight)            M  Bronze
# 23162  + 100kg (heavyweight)            M  Bronze
# 23163  + 100kg (heavyweight)            M    Gold
# 23164  + 100kg (heavyweight)            M  Silver
# 23165                + 105kg            M  Bronze
# ...                      ...          ...     ...
# 25171              épée team            W    Gold
# 25172              épée team            W    Gold
# 25173              épée team            W  Silver
# 25174              épée team            W  Silver
# 25175              épée team            W  Silver
#
# [2015 rows x 10 columns]
# 2004
#        Year    City          Sport     Discipline           Athlete Name  NOC Gender  \
# 25176  2004  Athens           judo           judo      PERTELSON, Indrek  EST    Men
# 25177  2004  Athens           judo           judo  VAN DER GEEST, Dennis  NED    Men
# 25178  2004  Athens           judo           judo          SUZUKI, Keiji  JPN    Men
# 25179  2004  Athens           judo           judo       TMENOV, Tamerlan  RUS    Men
# 25180  2004  Athens  weightlifting  weightlifting     CHOLAKOV, Velichko  BUL    Men
# ...     ...     ...            ...            ...                    ...  ...    ...
# 27169  2004  Athens        fencing        fencing     LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens        fencing        fencing          SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens        fencing        fencing         BOKEL, Claudia  GER  Women
# 27172  2004  Athens        fencing        fencing        DUPLITZER, Imke  GER  Women
# 27173  2004  Athens        fencing        fencing      HEIDEMANN, Britta  GER  Women
#
#                        Event Event Gender   Medal
# 25176  + 100kg (heavyweight)            M  Bronze
# 25177  + 100kg (heavyweight)            M  Bronze
# 25178  + 100kg (heavyweight)            M    Gold
# 25179  + 100kg (heavyweight)            M  Silver
# 25180                + 105kg            M  Bronze
# ...                      ...          ...     ...
# 27169              épée team            W    Gold
# 27170              épée team            W    Gold
# 27171              épée team            W  Silver
# 27172              épée team            W  Silver
# 27173              épée team            W  Silver
#
# [1998 rows x 10 columns]
# 2008
#       Year     City      Sport       Discipline          Athlete Name  NOC Gender         Event  \
# 0     2008  Beijing   aquatics           diving        GALPERIN, Gleb  RUS    Men  10m platform
# 1     2008  Beijing   aquatics           diving      MITCHAM, Matthew  AUS    Men  10m platform
# 2     2008  Beijing   aquatics           diving           ZHOU, Luxin  CHN    Men  10m platform
# 3     2008  Beijing   aquatics           diving             WANG, Xin  CHN  Women  10m platform
# 4     2008  Beijing   aquatics           diving          CHEN, Ruolin  CHN  Women  10m platform
# ...    ...      ...        ...              ...                   ...  ...    ...           ...
# 2048  2008  Beijing  wrestling  wrestling gre-r        ENGLICH, Mirko  GER    Men     84 - 96kg
# 2049  2008  Beijing  wrestling  wrestling gre-r  MIZGAITIS, Mindaugas  LTU    Men    96 - 120kg
# 2050  2008  Beijing  wrestling  wrestling gre-r       PATRIKEEV, Yuri  ARM    Men    96 - 120kg
# 2051  2008  Beijing  wrestling  wrestling gre-r         LOPEZ, Mijain  CUB    Men    96 - 120kg
# 2052  2008  Beijing  wrestling  wrestling gre-r        BAROEV, Khasan  RUS    Men    96 - 120kg
#
#      Event Gender   Medal
# 0               M  Bronze
# 1               M    Gold
# 2               M  Silver
# 3               W  Bronze
# 4               W    Gold
# ...           ...     ...
# 2048            M  Silver
# 2049            M  Bronze
# 2050            M  Bronze
# 2051            M    Gold
# 2052            M  Silver
#
# [2042 rows x 10 columns]

# %%
type(group_value)
# Out:
# pandas.core.frame.DataFrame

# %%
up.groupby(['Year']).count()
# Out:
#       City  Sport  Discipline  Athlete Name   NOC  Gender  Event  Event Gender  Medal
# Year
# 1896   151    151         151           151   151     151    151           151    151
# 1900   512    512         512           512   512     512    512           512    512
# 1904   470    470         470           470   470     470    470           470    470
# 1908   804    804         804           804   804     804    804           804    804
# 1912   885    885         885           885   885     885    885           885    885
# 1920  1298   1298        1298          1298  1298    1298   1298          1298   1298
# 1924   884    884         884           884   884     884    884           884    884
# 1928   710    710         710           710   710     710    710           710    710
# 1932   615    615         615           615   615     615    615           615    615
# 1936   875    875         875           875   875     875    875           875    875
# 1948   814    814         814           814   814     814    814           814    814
# 1952   889    889         889           889   889     889    889           889    889
# 1956   885    885         885           885   885     885    885           885    885
# 1960   882    882         882           882   882     882    882           882    882
# 1964  1010   1010        1010          1010  1010    1010   1010          1010   1010
# 1968  1031   1031        1031          1031  1031    1031   1031          1031   1031
# 1972  1185   1185        1185          1185  1185    1185   1185          1185   1185
# 1976  1305   1305        1305          1305  1305    1305   1305          1305   1305
# 1980  1387   1387        1387          1387  1387    1387   1387          1387   1387
# 1984  1459   1459        1459          1459  1459    1459   1459          1459   1459
# 1988  1546   1546        1546          1546  1546    1546   1546          1546   1546
# 1992  1705   1705        1705          1705  1705    1705   1705          1705   1705
# 1996  1859   1859        1859          1859  1859    1859   1859          1859   1859
# 2000  2015   2015        2015          2015  2015    2015   2015          2015   2015
# 2004  1998   1998        1998          1998  1998    1998   1998          1998   1998
# 2008  2042   2042        2042          2042  2042    2042   2042          2042   2042

# %%
up.groupby("Year").size()
# Out:
# Year
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
up.groupby(['Year','NOC']).count()
# Out:
#           City  Sport  Discipline  Athlete Name  Gender  Event  Event Gender  Medal
# Year NOC
# 1896 AUS     2      2           2             2       2      2             2      2
#      AUT     5      5           5             5       5      5             5      5
#      DEN     6      6           6             6       6      6             6      6
#      FRA    11     11          11            11      11     11            11     11
#      GBR     7      7           7             7       7      7             7      7
# ...        ...    ...         ...           ...     ...    ...           ...    ...
# 2008 USA   315    315         315           315     315    315           315    315
#      UZB     6      6           6             6       6      6             6      6
#      VEN     1      1           1             1       1      1             1      1
#      VIE     1      1           1             1       1      1             1      1
#      ZIM     4      4           4             4       4      4             4      4
#
# [1072 rows x 8 columns]

# %%
up.groupby(['Year','NOC'])['Medal'].count()
# Out:
# Year  NOC
# 1896  AUS      2
#       AUT      5
#       DEN      6
#       FRA     11
#       GBR      7
#             ...
# 2008  USA    315
#       UZB      6
#       VEN      1
#       VIE      1
#       ZIM      4
# Name: Medal, Length: 1072, dtype: int64

# %%
up.groupby(['Year','NOC']).size()
# Out:
# Year  NOC
# 1896  AUS      2
#       AUT      5
#       DEN      6
#       FRA     11
#       GBR      7
#             ...
# 2008  USA    315
#       UZB      6
#       VEN      1
#       VIE      1
#       ZIM      4
# Length: 1072, dtype: int64

# %%
up.groupby(['Year','NOC','Medal']).size()
# Out:
# Year  NOC  Medal
# 1896  AFG  Bronze    0
#            Silver    0
#            Gold      0
#       AHO  Bronze    0
#            Silver    0
#                     ..
# 2008  ZIM  Silver    3
#            Gold      1
#       ZZX  Bronze    0
#            Silver    0
#            Gold      0
# Length: 10764, dtype: int64

# %%
up.groupby(['NOC'])['Year'].min()
# Out:
# NOC
# AFG    2008
# AHO    1988
# ALG    1984
# ANZ    1908
# ARG    1924
#        ...
# VIE    2000
# YUG    1924
# ZAM    1984
# ZIM    1980
# ZZX    1896
# Name: Year, Length: 138, dtype: int64

# %%
up.groupby(['NOC'])['Year'].max()
# Out:
# NOC
# AFG    2008
# AHO    1988
# ALG    2008
# ANZ    1912
# ARG    2008
#        ...
# VIE    2008
# YUG    2000
# ZAM    1996
# ZIM    2008
# ZZX    1904
# Name: Year, Length: 138, dtype: int64

# %%
up.groupby(['NOC'])['Year'].min()
# Out:
# NOC
# AFG    2008
# AHO    1988
# ALG    1984
# ANZ    1908
# ARG    1924
#        ...
# VIE    2000
# YUG    1924
# ZAM    1984
# ZIM    1980
# ZZX    1896
# Name: Year, Length: 138, dtype: int64

# %%
up.groupby(['NOC'])['Year'].agg(['min', 'max', 'count'])
# Out:
#       min   max  count
# NOC
# AFG  2008  2008      1
# AHO  1988  1988      1
# ALG  1984  2008     14
# ANZ  1908  1912     29
# ARG  1924  2008    239
# ..    ...   ...    ...
# VIE  2000  2008      2
# YUG  1924  2000    435
# ZAM  1984  1996      2
# ZIM  1980  2008     23
# ZZX  1896  1904     48
#
# [138 rows x 3 columns]

# %% [markdown]
# ##Reshaping data: Stacking, Unstacking and MultiIndex

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt


if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year   City      Sport       Discipline          Athlete Name  NOC Gender  \
# 9827   1960   Rome   aquatics         swimming  BENNETT, Robert Earl  USA    Men
# 10393  1960   Rome  athletics        athletics          RUT, Tadeusz  POL    Men
# 18523  1988  Seoul  wrestling  wrestling free.        KHABELOV, Yuri  URS    Men
#
#                           Event Event Gender   Medal
# 9827            100m backstroke            M  Bronze
# 10393              hammer throw            M  Bronze
# 18523  90 - 100kg (heavyweight)            M  Silver

# %%
sprints = up[(up.Year == 2008) & ( (up.Event == '100m') | (up.Event == '200m'))]
sprints
# Out:
#      Year     City      Sport Discipline              Athlete Name  NOC Gender Event Event Gender  \
# 388  2008  Beijing  athletics  athletics               DIX, Walter  USA    Men  100m            M
# 389  2008  Beijing  athletics  athletics               BOLT, Usain  JAM    Men  100m            M
# 390  2008  Beijing  athletics  athletics         THOMPSON, Richard  TRI    Men  100m            M
# 391  2008  Beijing  athletics  athletics        FRASER, Shelly-ann  JAM  Women  100m            W
# 392  2008  Beijing  athletics  athletics          SIMPSON, Sherone  JAM  Women  100m            W
# 393  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM  Women  100m            W
# 406  2008  Beijing  athletics  athletics               DIX, Walter  USA    Men  200m            M
# 407  2008  Beijing  athletics  athletics               BOLT, Usain  JAM    Men  200m            M
# 408  2008  Beijing  athletics  athletics           CRAWFORD, Shawn  USA    Men  200m            M
# 409  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM  Women  200m            W
# 410  2008  Beijing  athletics  athletics  CAMPBELL-BROWN, Veronica  JAM  Women  200m            W
# 411  2008  Beijing  athletics  athletics            FELIX, Allyson  USA  Women  200m            W
#
#       Medal
# 388  Bronze
# 389    Gold
# 390  Silver
# 391    Gold
# 392  Silver
# 393  Silver
# 406  Bronze
# 407    Gold
# 408  Silver
# 409  Bronze
# 410    Gold
# 411  Silver

# %%
sp = sprints.groupby(['NOC','Gender','Event']).size()
sp
# Out:
# NOC  Gender  Event
# JAM  Men     100m     1
#              200m     1
#      Women   100m     3
#              200m     2
# TRI  Men     100m     1
#              200m     0
#      Women   100m     0
#              200m     0
# USA  Men     100m     1
#              200m     2
#      Women   100m     0
#              200m     1
# dtype: int64

# %%
sp.unstack?

# %%
sp.unstack('Gender', fill_value=0)
# Out:
# Gender     Men  Women
# NOC Event
# JAM 100m     1      3
#     200m     1      2
# TRI 100m     1      0
#     200m     0      0
# USA 100m     1      0
#     200m     2      1

# %%
(sp
 .unstack('Gender', fill_value=0)
 .unstack('Event', fill_value=0)
)
# Out:
# Gender  Men      Women
# Event  100m 200m  100m 200m
# NOC
# JAM       1    1     3    2
# TRI       1    0     0    0
# USA       1    2     0    1

# %%
sp.unstack?

# %%
sp.unstack(['Gender', 'Event'], fill_value=0)
# Out:
# Gender  Men      Women
# Event  100m 200m  100m 200m
# NOC
# JAM       1    1     3    2
# TRI       1    0     0    0
# USA       1    2     0    1

# %%
sp = sprints.groupby(['NOC','Gender','Event']).size()
sp
# Out:
# NOC  Gender  Event
# JAM  Men     100m     1
#              200m     1
#      Women   100m     3
#              200m     2
# TRI  Men     100m     1
#              200m     0
#      Women   100m     0
#              200m     0
# USA  Men     100m     1
#              200m     2
#      Women   100m     0
#              200m     1
# dtype: int64

# %%
sp.unstack(level=1, fill_value=0)
# Out:
# Gender     Men  Women
# NOC Event
# JAM 100m     1      3
#     200m     1      2
# TRI 100m     1      0
#     200m     0      0
# USA 100m     1      0
#     200m     2      1

# %%
sprints_table = sp.unstack(level=1, fill_value=0).unstack(level=1, fill_value=0)
sprints_table
# Out:
# Gender  Men      Women
# Event  100m 200m  100m 200m
# NOC
# JAM       1    1     3    2
# TRI       1    0     0    0
# USA       1    2     0    1

# %%
sprints_NOC = sprints_table.stack("Gender")
sprints_NOC
# Out:
# Event       100m  200m
# NOC Gender
# JAM Men        1     1
#     Women      3     2
# TRI Men        1     0
#     Women      0     0
# USA Men        1     2
#     Women      0     1

# %%
sprints_NOC.index
# Out:
# MultiIndex([('JAM',   'Men'),
#             ('JAM', 'Women'),
#             ('TRI',   'Men'),
#             ('TRI', 'Women'),
#             ('USA',   'Men'),
#             ('USA', 'Women')],
#            names=['NOC', 'Gender'])

# %%
sprints_NOC.loc[('JAM',   'Men'), :]
# Out:
# Event
# 100m    1
# 200m    1
# Name: (JAM, Men), dtype: int64

# %%
sprints_NOC.loc[('JAM',   'Men'), '100m']
# Out:
# 1

# %%
sprints_NOC.iloc[0, :]
# Out:
# Event
# 100m    1
# 200m    1
# Name: (JAM, Men), dtype: int64

# %%
sprints_NOC.iloc[0, 0]
# Out:
# 1

# %%
sprints_NOC.stack?

# %%
sprints_NOC.unstack?

# %% [markdown]
# ## Challenge

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year       City       Sport Discipline             Athlete Name  NOC Gender  \
# 5594   1928  Amsterdam  equestrian   eventing      ANTONIEWICZ, Michal  POL    Men
# 5287   1928  Amsterdam   athletics  athletics  HOUSER, Lemuel Clarence  USA    Men
# 14509  1976   Montreal      rowing     rowing        KOSTULSKI, Roland  GDR    Men
#
#                           Event Event Gender   Medal
# 5594                       team            X  Bronze
# 5287               discus throw            M    Gold
# 14509  eight with coxswain (8+)            M    Gold

# %% [markdown]
# **Using a line graph, plot the number of gold medals won by the USA male and female Olympians throughout the history of the Olympics?
# Distinguish between the male and female Olympians in the line graph using blue and pink**

# %% [markdown]
# **Using a bar chart, plot the 5 Olympians who have won the most gold medals from the dataset (1896 to 2008). When there is a tie, consider the number of silver medals, then bronze medals.**

# %% [markdown]
# ##Solution

# %% [markdown]
# **Using a line graph, plot the number of gold medals won by the USA male and female Olympians throughout the history of the Olympics?
# Distinguish between the male and female Olympians in the line graph using blue (male) and pink (female)**

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year         City       Sport   Discipline         Athlete Name  NOC Gender  \
# 5430   1928    Amsterdam      rowing       rowing  ORMANOWSKI, Bernard  POL    Men
# 17855  1984  Los Angeles  gymnastics  artistic g.       SOTOMURA, Koji  JPN    Men
# 4521   1924        Paris      tennis       tennis   LACOSTE, Jean René  FRA    Men
#
#                                      Event Event Gender   Medal
# 5430   four-oared shell with coxswain (4-)            M  Bronze
# 17855                     team competition            M  Bronze
# 4521                               doubles            M  Bronze

# %%
usa_gold = up[(up.NOC == 'USA') & (up.Medal == 'Gold')]
usa_gold
# Out:
#       Year     City       Sport       Discipline      Athlete Name  NOC Gender  \
# 4     1896   Athens   athletics        athletics     BURKE, Thomas  USA    Men
# 14    1896   Athens   athletics        athletics    CURTIS, Thomas  USA    Men
# 28    1896   Athens    shooting         shooting       PAINE, John  USA    Men
# 34    1896   Athens   athletics        athletics     BURKE, Thomas  USA    Men
# 40    1896   Athens    shooting         shooting     PAINE, Sumner  USA    Men
# ...    ...      ...         ...              ...               ...  ...    ...
# 1885  2008  Beijing  volleyball       volleyball      ROONEY, Sean  USA    Men
# 1886  2008  Beijing  volleyball       volleyball     SALMON, Riley  USA    Men
# 1887  2008  Beijing  volleyball       volleyball  STANLEY, Clayton  USA    Men
# 1888  2008  Beijing  volleyball       volleyball  TOUZINSKY, Scott  USA    Men
# 1988  2008  Beijing   wrestling  wrestling free.     CEJUDO, Henry  USA    Men
#
#                       Event Event Gender Medal
# 4                      100m            M  Gold
# 14             110m hurdles            M  Gold
# 28          25m army pistol            M  Gold
# 34                     400m            M  Gold
# 40    50m pistol (60 shots)            M  Gold
# ...                     ...          ...   ...
# 1885             volleyball            M  Gold
# 1886             volleyball            M  Gold
# 1887             volleyball            M  Gold
# 1888             volleyball            M  Gold
# 1988                 - 55kg            M  Gold
#
# [2088 rows x 10 columns]

# %%
usa_gold.groupby(['Year', 'Gender']).size()
# Out:
# Year  Gender
# 1896  Men        11
#       Women       0
# 1900  Men        26
#       Women       1
# 1904  Men       140
#       Women       6
# 1908  Men        34
#       Women       0
# 1912  Men        45
#       Women       0
# 1920  Men       103
#       Women       7
# 1924  Men        95
#       Women      15
# 1928  Men        34
#       Women       9
# 1932  Men        61
#       Women      17
# 1936  Men        44
#       Women       7
# 1948  Men        75
#       Women       8
# 1952  Men        72
#       Women       7
# 1956  Men        57
#       Women       4
# 1960  Men        51
#       Women      17
# 1964  Men        63
#       Women      15
# 1968  Men        59
#       Women      24
# 1972  Men        37
#       Women      16
# 1976  Men        56
#       Women       7
# 1984  Men       106
#       Women      62
# 1988  Men        49
#       Women      28
# 1992  Men        57
#       Women      32
# 1996  Men        59
#       Women     101
# 2000  Men        68
#       Women      62
# 2004  Men        51
#       Women      65
# 2008  Men        67
#       Women      58
# dtype: int64

# %%
usa_gold.groupby(['Year', 'Gender']).size().index
# Out:
# MultiIndex([(1896,   'Men'),
#             (1896, 'Women'),
#             (1900,   'Men'),
#             (1900, 'Women'),
#             (1904,   'Men'),
#             (1904, 'Women'),
#             (1908,   'Men'),
#             (1908, 'Women'),
#             (1912,   'Men'),
#             (1912, 'Women'),
#             (1920,   'Men'),
#             (1920, 'Women'),
#             (1924,   'Men'),
#             (1924, 'Women'),
#             (1928,   'Men'),
#             (1928, 'Women'),
#             (1932,   'Men'),
#             (1932, 'Women'),
#             (1936,   'Men'),
#             (1936, 'Women'),
#             (1948,   'Men'),
#             (1948, 'Women'),
#             (1952,   'Men'),
#             (1952, 'Women'),
#             (1956,   'Men'),
#             (1956, 'Women'),
#             (1960,   'Men'),
#             (1960, 'Women'),
#             (1964,   'Men'),
#             (1964, 'Women'),
#             (1968,   'Men'),
#             (1968, 'Women'),
#             (1972,   'Men'),
#             (1972, 'Women'),
#             (1976,   'Men'),
#             (1976, 'Women'),
#             (1984,   'Men'),
#             (1984, 'Women'),
#             (1988,   'Men'),
#             (1988, 'Women'),
#             (1992,   'Men'),
#             (1992, 'Women'),
#             (1996,   'Men'),
#             (1996, 'Women'),
#             (2000,   'Men'),
#             (2000, 'Women'),
#             (2004,   'Men'),
#             (2004, 'Women'),
#             (2008,   'Men'),
#             (2008, 'Women')],
#            names=['Year', 'Gender'])

# %%
usa_gold.groupby(['Year', 'Gender']).size().plot(kind='line')
# Out:
# <Axes: xlabel='Year,Gender'>

# %%
usa_gold.groupby(['Year', 'Gender']).size()
# Out:
# Year  Gender
# 1896  Men        11
#       Women       0
# 1900  Men        26
#       Women       1
# 1904  Men       140
#       Women       6
# 1908  Men        34
#       Women       0
# 1912  Men        45
#       Women       0
# 1920  Men       103
#       Women       7
# 1924  Men        95
#       Women      15
# 1928  Men        34
#       Women       9
# 1932  Men        61
#       Women      17
# 1936  Men        44
#       Women       7
# 1948  Men        75
#       Women       8
# 1952  Men        72
#       Women       7
# 1956  Men        57
#       Women       4
# 1960  Men        51
#       Women      17
# 1964  Men        63
#       Women      15
# 1968  Men        59
#       Women      24
# 1972  Men        37
#       Women      16
# 1976  Men        56
#       Women       7
# 1984  Men       106
#       Women      62
# 1988  Men        49
#       Women      28
# 1992  Men        57
#       Women      32
# 1996  Men        59
#       Women     101
# 2000  Men        68
#       Women      62
# 2004  Men        51
#       Women      65
# 2008  Men        67
#       Women      58
# dtype: int64

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender')
# Out:
# Gender  Men  Women
# Year
# 1896     11      0
# 1900     26      1
# 1904    140      6
# 1908     34      0
# 1912     45      0
# 1920    103      7
# 1924     95     15
# 1928     34      9
# 1932     61     17
# 1936     44      7
# 1948     75      8
# 1952     72      7
# 1956     57      4
# 1960     51     17
# 1964     63     15
# 1968     59     24
# 1972     37     16
# 1976     56      7
# 1984    106     62
# 1988     49     28
# 1992     57     32
# 1996     59    101
# 2000     68     62
# 2004     51     65
# 2008     67     58

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line')
# Out:
# <Axes: xlabel='Year'>

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot?
# Out:
# Object `plot` not found.

# %%
pd.Series.plot?

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line', color=['blue', 'pink'])
# Out:
# <Axes: xlabel='Year'>

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line', color=['pink', 'blue'])
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# **Using a bar chart, plot the 5 Olympians who have won the most gold medals from the dataset (1896 to 2008). When there is a tie, consider the number of silver medals, then bronze medals.**

# %%
up.groupby(['Athlete Name','Medal']).size()
# Out:
# Athlete Name           Medal
# AABYE, Edgar           Bronze    0
#                        Silver    0
#                        Gold      1
# AALTONEN, Arvo Ossian  Bronze    2
#                        Silver    0
#                                 ..
# ÖSTMO, Ole             Silver    2
#                        Gold      0
# ÖSTRAND, Per-Olof      Bronze    1
#                        Silver    0
#                        Gold      0
# Length: 64239, dtype: int64

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
)
# Out:
# Medal                      Bronze  Silver  Gold
# Athlete Name
# AABYE, Edgar                    0       0     1
# AALTONEN, Arvo Ossian           2       0     0
# AALTONEN, Paavo Johannes        2       0     3
# AAMODT, Ragnhild                0       0     1
# AANING, Alf Lied                0       1     0
# ...                           ...     ...   ...
# ÖSTERVOLD, Jan Olsen            0       0     1
# ÖSTERVOLD, Kristian Olsen       0       0     1
# ÖSTERVOLD, Ole Olsen            0       0     1
# ÖSTMO, Ole                      2       2     0
# ÖSTRAND, Per-Olof               1       0     0
#
# [21413 rows x 3 columns]

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)
)
# Out:
# Medal                Bronze  Silver  Gold
# Athlete Name
# PHELPS, Michael           2       0    14
# LATYNINA, Larisa          4       5     9
# NURMI, Paavo              0       3     9
# SPITZ, Mark               1       1     9
# LEWIS, Carl               0       1     9
# ...                     ...     ...   ...
# ZYCH, Boguslaw            1       0     0
# ZÄHRINGER, Klaus          1       0     0
# ZÜHLKE, Steffen           1       0     0
# ÖRSTED, Hans-Henrik       1       0     0
# ÖSTRAND, Per-Olof         1       0     0
#
# [21413 rows x 3 columns]

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
)
# Out:
# Medal                Gold  Silver  Bronze
# Athlete Name
# PHELPS, Michael        14       0       2
# LATYNINA, Larisa        9       5       4
# NURMI, Paavo            9       3       0
# SPITZ, Mark             9       1       1
# LEWIS, Carl             9       1       0
# ...                   ...     ...     ...
# ZYCH, Boguslaw          0       0       1
# ZÄHRINGER, Klaus        0       0       1
# ZÜHLKE, Steffen         0       0       1
# ÖRSTED, Hans-Henrik     0       0       1
# ÖSTRAND, Per-Olof       0       0       1
#
# [21413 rows x 3 columns]

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
.head(5)
)
# Out:
# Medal             Gold  Silver  Bronze
# Athlete Name
# PHELPS, Michael     14       0       2
# LATYNINA, Larisa     9       5       4
# NURMI, Paavo         9       3       0
# SPITZ, Mark          9       1       1
# LEWIS, Carl          9       1       0

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
.head(5)
.plot(kind='bar')
)
# Out:
# <Axes: xlabel='Athlete Name'>

# %% [markdown]
# ##Creating your own colormaps

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year      City     Sport Discipline        Athlete Name  NOC Gender                  Event  \
# 25606  2004    Athens  shooting   shooting        KIM, Jong Su  PRK    Men  50m pistol (60 shots)
# 14955  1976  Montreal   fencing    fencing  NAZLYMOV, Vladimir  URS    Men             sabre team
# 6791   1936    Berlin  football   football    MARCHINI, Libero  ITA    Men               football
#
#       Event Gender   Medal
# 25606            M  Bronze
# 14955            M    Gold
# 6791             M    Gold

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
.head(5)
.plot(kind='bar')
)
# Out:
# <Axes: xlabel='Athlete Name'>

# %%
from matplotlib.colors import ListedColormap

# %%
ListedColormap?

# %%
gold_silver_bronze = ['#dbb40c','#c5c9c7','#a87900']

# %%
colormap = ListedColormap(gold_silver_bronze)
colormap

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
.head(5)
.plot(kind='bar', colormap=colormap)
)
# Out:
# <Axes: xlabel='Athlete Name'>

# %% [markdown]
# ##Final Challenge

# %% [markdown]
# For each Olympic year present in the dataset, show the US Olympian (and their sport) who has won the highest number of medals in that particular year.
#
# - In the case of a tie, Gold > Silver > Bronze
# - Include only one Olympian for each Olympic year i.e. If there are 2 Olympians in one year who have won exactly the same number and type of medals, then show only the first one based on sorting the names alphabetically by surname.
#
# - You should show the the following columns for each Olympic year:
#   - Athlete Name
#   - Sport
#   - Total

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
pd.set_option("display.width", 100)

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year    City          Sport       Discipline       Athlete Name  NOC Gender  \
# 25829  2004  Athens  canoe / kayak  canoe / kayak f   BAGGALEY, Nathan  AUS    Men
# 4162   1924   Paris       aquatics         swimming   EDERLE, Gertrude  USA  Women
# 13030  1972  Munich      wrestling  wrestling free.  YANAGIDA, Hideaki  JPN    Men
#
#                           Event Event Gender   Medal
# 25829   k-1 500m (kayak single)            M  Silver
# 4162             100m freestyle            W  Bronze
# 13030  52 - 57kg (bantamweight)            M    Gold

# %% [markdown]
# ##Solution

# %% [markdown]
# For each Olympic year present in the dataset, show the US Olympian (and their sport) who has won the highest number of medals in that particular year.
#
# - In the case of a tie, Gold > Silver > Bronze
# - Include only one Olympian for each Olympic year i.e. If there are 2 Olympians in one year who have won exactly the same number and type of medals, then show only the first one based on sorting the names alphabetically by surname.
#
# - You should show the the following columns for each Olympic year:
#   - Athlete Name
#   - Sport
#   - Total

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
pd.set_option("display.width", 100)

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year      City      Sport  Discipline      Athlete Name  NOC Gender       Event  \
# 15186  1976  Montreal   aquatics  water polo  PANERAI, Umberto  ITA    Men  water polo
# 26774  2004    Athens     tennis      tennis    MASSU, Nicolas  CHI    Men     singles
# 1811   2008   Beijing  taekwondo   taekwondo      CHA, Dongmin  KOR    Men     + 80 kg
#
#       Event Gender   Medal
# 15186            M  Silver
# 26774            M    Gold
# 1811             M    Gold

# %%
usa_olympian = up[up.NOC == 'USA']
usa_olympian
# Out:
#       Year     City       Sport       Discipline     Athlete Name  NOC Gender            Event  \
# 2     1896   Athens   athletics        athletics    LANE, Francis  USA    Men             100m
# 4     1896   Athens   athletics        athletics    BURKE, Thomas  USA    Men             100m
# 14    1896   Athens   athletics        athletics   CURTIS, Thomas  USA    Men     110m hurdles
# 23    1896   Athens   athletics        athletics    BLAKE, Arthur  USA    Men            1500m
# 28    1896   Athens    shooting         shooting      PAINE, John  USA    Men  25m army pistol
# ...    ...      ...         ...              ...              ...  ...    ...              ...
# 1935  2008  Beijing  volleyball       volleyball       TOM, Logan  USA  Women       volleyball
# 1936  2008  Beijing  volleyball       volleyball  WILLOUGHBY, Kim  USA  Women       volleyball
# 1988  2008  Beijing   wrestling  wrestling free.    CEJUDO, Henry  USA    Men           - 55kg
# 1998  2008  Beijing   wrestling  wrestling free.    MILLER, Randi  USA  Women        55 - 63kg
# 2046  2008  Beijing   wrestling  wrestling gre-r    WHEELER, Adam  USA    Men        84 - 96kg
#
#      Event Gender   Medal
# 2               M  Bronze
# 4               M    Gold
# 14              M    Gold
# 23              M  Silver
# 28              M    Gold
# ...           ...     ...
# 1935            W  Silver
# 1936            W  Silver
# 1988            M    Gold
# 1998            W  Bronze
# 2046            M  Bronze
#
# [4335 rows x 10 columns]

# %%
usa_olympian.groupby(['Year', 'Athlete Name', 'Medal', 'Sport']).size()
# Out:
# Year  Athlete Name   Medal   Sport
# 1896  ABAS, Stephen  Bronze  aquatics         0
#                              archery          0
#                              athletics        0
#                              baseball         0
#                              basketball       0
#                                              ..
# 2008  ZORN, Zachary  Gold    triathlon        0
#                              tug of war       0
#                              volleyball       0
#                              weightlifting    0
#                              wrestling        0
# Length: 7680600, dtype: int64

# %%
(usa_olympian.groupby(['Year', 'Athlete Name', 'Medal', 'Sport'])
.size()
.unstack('Medal', fill_value=0)
)
# Out:
# Medal                             Bronze  Silver  Gold
# Year Athlete Name  Sport
# 1896 ABAS, Stephen aquatics            0       0     0
#                    archery             0       0     0
#                    athletics           0       0     0
#                    baseball            0       0     0
#                    basketball          0       0     0
# ...                                  ...     ...   ...
# 2008 ZORN, Zachary triathlon           0       0     0
#                    tug of war          0       0     0
#                    volleyball          0       0     0
#                    weightlifting       0       0     0
#                    wrestling           0       0     0
#
# [2560200 rows x 3 columns]

# %%
table = (usa_olympian.groupby(['Year', 'Athlete Name', 'Sport', 'Medal'])
.size()
.unstack('Medal', fill_value=0)
)
table
# Out:
# Medal                             Bronze  Silver  Gold
# Year Athlete Name  Sport
# 1896 ABAS, Stephen aquatics            0       0     0
#                    archery             0       0     0
#                    athletics           0       0     0
#                    baseball            0       0     0
#                    basketball          0       0     0
# ...                                  ...     ...   ...
# 2008 ZORN, Zachary triathlon           0       0     0
#                    tug of war          0       0     0
#                    volleyball          0       0     0
#                    weightlifting       0       0     0
#                    wrestling           0       0     0
#
# [2560200 rows x 3 columns]

# %%
table = (usa_olympian.groupby(['Year', 'Athlete Name', 'Sport', 'Medal'])
.size()
.unstack('Medal', fill_value=0)
.assign(Total=table['Gold']+table['Silver']+table['Bronze'])
)
table
# Out:
# Medal                             Bronze  Silver  Gold  Total
# Year Athlete Name  Sport
# 1896 ABAS, Stephen aquatics            0       0     0      0
#                    archery             0       0     0      0
#                    athletics           0       0     0      0
#                    baseball            0       0     0      0
#                    basketball          0       0     0      0
# ...                                  ...     ...   ...    ...
# 2008 ZORN, Zachary triathlon           0       0     0      0
#                    tug of war          0       0     0      0
#                    volleyball          0       0     0      0
#                    weightlifting       0       0     0      0
#                    wrestling           0       0     0      0
#
# [2560200 rows x 4 columns]

# %%
table = (usa_olympian.groupby(['Year', 'Athlete Name', 'Sport', 'Medal'])
.size()
.unstack('Medal', fill_value=0)
.assign(Total=table['Gold']+table['Silver']+table['Bronze'])
.reset_index()
)
table
# Out:
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 0        1896  ABAS, Stephen       aquatics       0       0     0      0
# 1        1896  ABAS, Stephen        archery       0       0     0      0
# 2        1896  ABAS, Stephen      athletics       0       0     0      0
# 3        1896  ABAS, Stephen       baseball       0       0     0      0
# 4        1896  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2560195  2008  ZORN, Zachary      triathlon       0       0     0      0
# 2560196  2008  ZORN, Zachary     tug of war       0       0     0      0
# 2560197  2008  ZORN, Zachary     volleyball       0       0     0      0
# 2560198  2008  ZORN, Zachary  weightlifting       0       0     0      0
# 2560199  2008  ZORN, Zachary      wrestling       0       0     0      0
#
# [2560200 rows x 7 columns]

# %%
for year, group in table.groupby('Year'):
  print(group)
# Out:
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 0       1896  ABAS, Stephen       aquatics       0       0     0      0
# 1       1896  ABAS, Stephen        archery       0       0     0      0
# 2       1896  ABAS, Stephen      athletics       0       0     0      0
# 3       1896  ABAS, Stephen       baseball       0       0     0      0
# 4       1896  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 102403  1896  ZORN, Zachary      triathlon       0       0     0      0
# 102404  1896  ZORN, Zachary     tug of war       0       0     0      0
# 102405  1896  ZORN, Zachary     volleyball       0       0     0      0
# 102406  1896  ZORN, Zachary  weightlifting       0       0     0      0
# 102407  1896  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 102408  1900  ABAS, Stephen       aquatics       0       0     0      0
# 102409  1900  ABAS, Stephen        archery       0       0     0      0
# 102410  1900  ABAS, Stephen      athletics       0       0     0      0
# 102411  1900  ABAS, Stephen       baseball       0       0     0      0
# 102412  1900  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 204811  1900  ZORN, Zachary      triathlon       0       0     0      0
# 204812  1900  ZORN, Zachary     tug of war       0       0     0      0
# 204813  1900  ZORN, Zachary     volleyball       0       0     0      0
# 204814  1900  ZORN, Zachary  weightlifting       0       0     0      0
# 204815  1900  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 204816  1904  ABAS, Stephen       aquatics       0       0     0      0
# 204817  1904  ABAS, Stephen        archery       0       0     0      0
# 204818  1904  ABAS, Stephen      athletics       0       0     0      0
# 204819  1904  ABAS, Stephen       baseball       0       0     0      0
# 204820  1904  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 307219  1904  ZORN, Zachary      triathlon       0       0     0      0
# 307220  1904  ZORN, Zachary     tug of war       0       0     0      0
# 307221  1904  ZORN, Zachary     volleyball       0       0     0      0
# 307222  1904  ZORN, Zachary  weightlifting       0       0     0      0
# 307223  1904  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 307224  1908  ABAS, Stephen       aquatics       0       0     0      0
# 307225  1908  ABAS, Stephen        archery       0       0     0      0
# 307226  1908  ABAS, Stephen      athletics       0       0     0      0
# 307227  1908  ABAS, Stephen       baseball       0       0     0      0
# 307228  1908  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 409627  1908  ZORN, Zachary      triathlon       0       0     0      0
# 409628  1908  ZORN, Zachary     tug of war       0       0     0      0
# 409629  1908  ZORN, Zachary     volleyball       0       0     0      0
# 409630  1908  ZORN, Zachary  weightlifting       0       0     0      0
# 409631  1908  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 409632  1912  ABAS, Stephen       aquatics       0       0     0      0
# 409633  1912  ABAS, Stephen        archery       0       0     0      0
# 409634  1912  ABAS, Stephen      athletics       0       0     0      0
# 409635  1912  ABAS, Stephen       baseball       0       0     0      0
# 409636  1912  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 512035  1912  ZORN, Zachary      triathlon       0       0     0      0
# 512036  1912  ZORN, Zachary     tug of war       0       0     0      0
# 512037  1912  ZORN, Zachary     volleyball       0       0     0      0
# 512038  1912  ZORN, Zachary  weightlifting       0       0     0      0
# 512039  1912  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 512040  1920  ABAS, Stephen       aquatics       0       0     0      0
# 512041  1920  ABAS, Stephen        archery       0       0     0      0
# 512042  1920  ABAS, Stephen      athletics       0       0     0      0
# 512043  1920  ABAS, Stephen       baseball       0       0     0      0
# 512044  1920  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 614443  1920  ZORN, Zachary      triathlon       0       0     0      0
# 614444  1920  ZORN, Zachary     tug of war       0       0     0      0
# 614445  1920  ZORN, Zachary     volleyball       0       0     0      0
# 614446  1920  ZORN, Zachary  weightlifting       0       0     0      0
# 614447  1920  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 614448  1924  ABAS, Stephen       aquatics       0       0     0      0
# 614449  1924  ABAS, Stephen        archery       0       0     0      0
# 614450  1924  ABAS, Stephen      athletics       0       0     0      0
# 614451  1924  ABAS, Stephen       baseball       0       0     0      0
# 614452  1924  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 716851  1924  ZORN, Zachary      triathlon       0       0     0      0
# 716852  1924  ZORN, Zachary     tug of war       0       0     0      0
# 716853  1924  ZORN, Zachary     volleyball       0       0     0      0
# 716854  1924  ZORN, Zachary  weightlifting       0       0     0      0
# 716855  1924  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 716856  1928  ABAS, Stephen       aquatics       0       0     0      0
# 716857  1928  ABAS, Stephen        archery       0       0     0      0
# 716858  1928  ABAS, Stephen      athletics       0       0     0      0
# 716859  1928  ABAS, Stephen       baseball       0       0     0      0
# 716860  1928  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 819259  1928  ZORN, Zachary      triathlon       0       0     0      0
# 819260  1928  ZORN, Zachary     tug of war       0       0     0      0
# 819261  1928  ZORN, Zachary     volleyball       0       0     0      0
# 819262  1928  ZORN, Zachary  weightlifting       0       0     0      0
# 819263  1928  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 819264  1932  ABAS, Stephen       aquatics       0       0     0      0
# 819265  1932  ABAS, Stephen        archery       0       0     0      0
# 819266  1932  ABAS, Stephen      athletics       0       0     0      0
# 819267  1932  ABAS, Stephen       baseball       0       0     0      0
# 819268  1932  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 921667  1932  ZORN, Zachary      triathlon       0       0     0      0
# 921668  1932  ZORN, Zachary     tug of war       0       0     0      0
# 921669  1932  ZORN, Zachary     volleyball       0       0     0      0
# 921670  1932  ZORN, Zachary  weightlifting       0       0     0      0
# 921671  1932  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 921672   1936  ABAS, Stephen       aquatics       0       0     0      0
# 921673   1936  ABAS, Stephen        archery       0       0     0      0
# 921674   1936  ABAS, Stephen      athletics       0       0     0      0
# 921675   1936  ABAS, Stephen       baseball       0       0     0      0
# 921676   1936  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1024075  1936  ZORN, Zachary      triathlon       0       0     0      0
# 1024076  1936  ZORN, Zachary     tug of war       0       0     0      0
# 1024077  1936  ZORN, Zachary     volleyball       0       0     0      0
# 1024078  1936  ZORN, Zachary  weightlifting       0       0     0      0
# 1024079  1936  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1024080  1948  ABAS, Stephen       aquatics       0       0     0      0
# 1024081  1948  ABAS, Stephen        archery       0       0     0      0
# 1024082  1948  ABAS, Stephen      athletics       0       0     0      0
# 1024083  1948  ABAS, Stephen       baseball       0       0     0      0
# 1024084  1948  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1126483  1948  ZORN, Zachary      triathlon       0       0     0      0
# 1126484  1948  ZORN, Zachary     tug of war       0       0     0      0
# 1126485  1948  ZORN, Zachary     volleyball       0       0     0      0
# 1126486  1948  ZORN, Zachary  weightlifting       0       0     0      0
# 1126487  1948  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1126488  1952  ABAS, Stephen       aquatics       0       0     0      0
# 1126489  1952  ABAS, Stephen        archery       0       0     0      0
# 1126490  1952  ABAS, Stephen      athletics       0       0     0      0
# 1126491  1952  ABAS, Stephen       baseball       0       0     0      0
# 1126492  1952  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1228891  1952  ZORN, Zachary      triathlon       0       0     0      0
# 1228892  1952  ZORN, Zachary     tug of war       0       0     0      0
# 1228893  1952  ZORN, Zachary     volleyball       0       0     0      0
# 1228894  1952  ZORN, Zachary  weightlifting       0       0     0      0
# 1228895  1952  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1228896  1956  ABAS, Stephen       aquatics       0       0     0      0
# 1228897  1956  ABAS, Stephen        archery       0       0     0      0
# 1228898  1956  ABAS, Stephen      athletics       0       0     0      0
# 1228899  1956  ABAS, Stephen       baseball       0       0     0      0
# 1228900  1956  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1331299  1956  ZORN, Zachary      triathlon       0       0     0      0
# 1331300  1956  ZORN, Zachary     tug of war       0       0     0      0
# 1331301  1956  ZORN, Zachary     volleyball       0       0     0      0
# 1331302  1956  ZORN, Zachary  weightlifting       0       0     0      0
# 1331303  1956  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1331304  1960  ABAS, Stephen       aquatics       0       0     0      0
# 1331305  1960  ABAS, Stephen        archery       0       0     0      0
# 1331306  1960  ABAS, Stephen      athletics       0       0     0      0
# 1331307  1960  ABAS, Stephen       baseball       0       0     0      0
# 1331308  1960  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1433707  1960  ZORN, Zachary      triathlon       0       0     0      0
# 1433708  1960  ZORN, Zachary     tug of war       0       0     0      0
# 1433709  1960  ZORN, Zachary     volleyball       0       0     0      0
# 1433710  1960  ZORN, Zachary  weightlifting       0       0     0      0
# 1433711  1960  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1433712  1964  ABAS, Stephen       aquatics       0       0     0      0
# 1433713  1964  ABAS, Stephen        archery       0       0     0      0
# 1433714  1964  ABAS, Stephen      athletics       0       0     0      0
# 1433715  1964  ABAS, Stephen       baseball       0       0     0      0
# 1433716  1964  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1536115  1964  ZORN, Zachary      triathlon       0       0     0      0
# 1536116  1964  ZORN, Zachary     tug of war       0       0     0      0
# 1536117  1964  ZORN, Zachary     volleyball       0       0     0      0
# 1536118  1964  ZORN, Zachary  weightlifting       0       0     0      0
# 1536119  1964  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1536120  1968  ABAS, Stephen       aquatics       0       0     0      0
# 1536121  1968  ABAS, Stephen        archery       0       0     0      0
# 1536122  1968  ABAS, Stephen      athletics       0       0     0      0
# 1536123  1968  ABAS, Stephen       baseball       0       0     0      0
# 1536124  1968  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1638523  1968  ZORN, Zachary      triathlon       0       0     0      0
# 1638524  1968  ZORN, Zachary     tug of war       0       0     0      0
# 1638525  1968  ZORN, Zachary     volleyball       0       0     0      0
# 1638526  1968  ZORN, Zachary  weightlifting       0       0     0      0
# 1638527  1968  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1638528  1972  ABAS, Stephen       aquatics       0       0     0      0
# 1638529  1972  ABAS, Stephen        archery       0       0     0      0
# 1638530  1972  ABAS, Stephen      athletics       0       0     0      0
# 1638531  1972  ABAS, Stephen       baseball       0       0     0      0
# 1638532  1972  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1740931  1972  ZORN, Zachary      triathlon       0       0     0      0
# 1740932  1972  ZORN, Zachary     tug of war       0       0     0      0
# 1740933  1972  ZORN, Zachary     volleyball       0       0     0      0
# 1740934  1972  ZORN, Zachary  weightlifting       0       0     0      0
# 1740935  1972  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1740936  1976  ABAS, Stephen       aquatics       0       0     0      0
# 1740937  1976  ABAS, Stephen        archery       0       0     0      0
# 1740938  1976  ABAS, Stephen      athletics       0       0     0      0
# 1740939  1976  ABAS, Stephen       baseball       0       0     0      0
# 1740940  1976  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1843339  1976  ZORN, Zachary      triathlon       0       0     0      0
# 1843340  1976  ZORN, Zachary     tug of war       0       0     0      0
# 1843341  1976  ZORN, Zachary     volleyball       0       0     0      0
# 1843342  1976  ZORN, Zachary  weightlifting       0       0     0      0
# 1843343  1976  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1843344  1984  ABAS, Stephen       aquatics       0       0     0      0
# 1843345  1984  ABAS, Stephen        archery       0       0     0      0
# 1843346  1984  ABAS, Stephen      athletics       0       0     0      0
# 1843347  1984  ABAS, Stephen       baseball       0       0     0      0
# 1843348  1984  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1945747  1984  ZORN, Zachary      triathlon       0       0     0      0
# 1945748  1984  ZORN, Zachary     tug of war       0       0     0      0
# 1945749  1984  ZORN, Zachary     volleyball       0       0     0      0
# 1945750  1984  ZORN, Zachary  weightlifting       0       0     0      0
# 1945751  1984  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1945752  1988  ABAS, Stephen       aquatics       0       0     0      0
# 1945753  1988  ABAS, Stephen        archery       0       0     0      0
# 1945754  1988  ABAS, Stephen      athletics       0       0     0      0
# 1945755  1988  ABAS, Stephen       baseball       0       0     0      0
# 1945756  1988  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2048155  1988  ZORN, Zachary      triathlon       0       0     0      0
# 2048156  1988  ZORN, Zachary     tug of war       0       0     0      0
# 2048157  1988  ZORN, Zachary     volleyball       0       0     0      0
# 2048158  1988  ZORN, Zachary  weightlifting       0       0     0      0
# 2048159  1988  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2048160  1992  ABAS, Stephen       aquatics       0       0     0      0
# 2048161  1992  ABAS, Stephen        archery       0       0     0      0
# 2048162  1992  ABAS, Stephen      athletics       0       0     0      0
# 2048163  1992  ABAS, Stephen       baseball       0       0     0      0
# 2048164  1992  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2150563  1992  ZORN, Zachary      triathlon       0       0     0      0
# 2150564  1992  ZORN, Zachary     tug of war       0       0     0      0
# 2150565  1992  ZORN, Zachary     volleyball       0       0     0      0
# 2150566  1992  ZORN, Zachary  weightlifting       0       0     0      0
# 2150567  1992  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2150568  1996  ABAS, Stephen       aquatics       0       0     0      0
# 2150569  1996  ABAS, Stephen        archery       0       0     0      0
# 2150570  1996  ABAS, Stephen      athletics       0       0     0      0
# 2150571  1996  ABAS, Stephen       baseball       0       0     0      0
# 2150572  1996  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2252971  1996  ZORN, Zachary      triathlon       0       0     0      0
# 2252972  1996  ZORN, Zachary     tug of war       0       0     0      0
# 2252973  1996  ZORN, Zachary     volleyball       0       0     0      0
# 2252974  1996  ZORN, Zachary  weightlifting       0       0     0      0
# 2252975  1996  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2252976  2000  ABAS, Stephen       aquatics       0       0     0      0
# 2252977  2000  ABAS, Stephen        archery       0       0     0      0
# 2252978  2000  ABAS, Stephen      athletics       0       0     0      0
# 2252979  2000  ABAS, Stephen       baseball       0       0     0      0
# 2252980  2000  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2355379  2000  ZORN, Zachary      triathlon       0       0     0      0
# 2355380  2000  ZORN, Zachary     tug of war       0       0     0      0
# 2355381  2000  ZORN, Zachary     volleyball       0       0     0      0
# 2355382  2000  ZORN, Zachary  weightlifting       0       0     0      0
# 2355383  2000  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2355384  2004  ABAS, Stephen       aquatics       0       0     0      0
# 2355385  2004  ABAS, Stephen        archery       0       0     0      0
# 2355386  2004  ABAS, Stephen      athletics       0       0     0      0
# 2355387  2004  ABAS, Stephen       baseball       0       0     0      0
# 2355388  2004  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2457787  2004  ZORN, Zachary      triathlon       0       0     0      0
# 2457788  2004  ZORN, Zachary     tug of war       0       0     0      0
# 2457789  2004  ZORN, Zachary     volleyball       0       0     0      0
# 2457790  2004  ZORN, Zachary  weightlifting       0       0     0      0
# 2457791  2004  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2457792  2008  ABAS, Stephen       aquatics       0       0     0      0
# 2457793  2008  ABAS, Stephen        archery       0       0     0      0
# 2457794  2008  ABAS, Stephen      athletics       0       0     0      0
# 2457795  2008  ABAS, Stephen       baseball       0       0     0      0
# 2457796  2008  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2560195  2008  ZORN, Zachary      triathlon       0       0     0      0
# 2560196  2008  ZORN, Zachary     tug of war       0       0     0      0
# 2560197  2008  ZORN, Zachary     volleyball       0       0     0      0
# 2560198  2008  ZORN, Zachary  weightlifting       0       0     0      0
# 2560199  2008  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]

# %%
for year, group in table.groupby('Year'):
  print(group.sort_values('Total', ascending=False))
# Out:
# Medal   Year                  Athlete Name          Sport  Bronze  Silver  Gold  Total
# 32642   1896               GARRETT, Robert      athletics       0       2     2      4
# 17988   1896               CONNOLLY, James      athletics       1       1     1      3
# 12616   1896                 BURKE, Thomas      athletics       0       0     2      2
# 16186   1896                 CLARK, Ellery      athletics       0       0     2      2
# 71118   1896                 PAINE, Sumner       shooting       0       1     1      2
# ...      ...                           ...            ...     ...     ...   ...    ...
# 34136   1896                GLASS, Hermann       aquatics       0       0     0      0
# 34135   1896  GLASGOW, Walter Merrill, Jr.      wrestling       0       0     0      0
# 34134   1896  GLASGOW, Walter Merrill, Jr.  weightlifting       0       0     0      0
# 34133   1896  GLASGOW, Walter Merrill, Jr.     volleyball       0       0     0      0
# 102407  1896                 ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year               Athlete Name       Sport  Bronze  Silver  Gold  Total
# 193156  1900  TEWKSBURY, Walter B. John   athletics       1       2     2      5
# 107612  1900             BAXTER, Irving   athletics       0       3     2      5
# 154838  1900          KRAENZLEIN, Alvin   athletics       0       0     4      4
# 130154  1900                  EWRY, Ray   athletics       0       0     3      3
# 135050  1900            GARRETT, Robert   athletics       2       0     0      2
# ...      ...                        ...         ...     ...     ...   ...    ...
# 136548  1900             GLASS, Hermann  basketball       0       0     0      0
# 136547  1900             GLASS, Hermann    baseball       0       0     0      0
# 136546  1900             GLASS, Hermann   athletics       0       0     0      0
# 136545  1900             GLASS, Hermann     archery       0       0     0      0
# 204815  1900              ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year      Athlete Name       Sport  Bronze  Silver  Gold  Total
# 245424  1904      HEIDA, Anton  gymnastics       0       1     5      6
# 232640  1904     EYSER, George  gymnastics       1       2     3      6
# 229541  1904   DOWNING, Burton     cycling       1       3     2      6
# 249159  1904    HURLEY, Marcus     cycling       1       0     4      5
# 225454  1904  DANIELS, Charles    aquatics       1       1     3      5
# ...      ...               ...         ...     ...     ...   ...    ...
# 238991  1904   GLASS, Kimberly      boxing       0       0     0      0
# 238990  1904   GLASS, Kimberly  basketball       0       0     0      0
# 238989  1904   GLASS, Kimberly    baseball       0       0     0      0
# 238988  1904   GLASS, Kimberly   athletics       0       0     0      0
# 307223  1904     ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year           Athlete Name          Sport  Bronze  Silver  Gold  Total
# 390390  1908       SHEPPARD, Melvin      athletics       0       0     3      3
# 390458  1908       SHERIDAN, Martin      athletics       1       0     2      3
# 342098  1908   GORMAN, James Edward       shooting       1       0     1      2
# 327862  1908       DANIELS, Charles       aquatics       1       0     1      2
# 339832  1908  GARRELS, John Carlyle      athletics       1       1     0      2
# ...      ...                    ...            ...     ...     ...   ...    ...
# 341369  1908         GLASS, Hermann        fencing       0       0     0      0
# 341368  1908         GLASS, Hermann     equestrian       0       0     0      0
# 341367  1908         GLASS, Hermann        cycling       0       0     0      0
# 341366  1908         GLASS, Hermann  canoe / kayak       0       0     0      0
# 409631  1908          ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year           Athlete Name       Sport  Bronze  Silver  Gold  Total
# 480240  1912  OSBURN, Carl Townsend    shooting       1       2     1      4
# 496186  1912      SPROUT, Warren A.    shooting       2       0     1      3
# 463342  1912        LANE, Alfred P.    shooting       0       0     3      3
# 464974  1912   LEUSHNER, William F.    shooting       2       1     0      3
# 451884  1912     HIRD, Frederick S.    shooting       2       0     1      3
# ...      ...                    ...         ...     ...     ...   ...    ...
# 443772  1912         GLASS, Hermann  basketball       0       0     0      0
# 443771  1912         GLASS, Hermann    baseball       0       0     0      0
# 443770  1912         GLASS, Hermann   athletics       0       0     0      0
# 443769  1912         GLASS, Hermann     archery       0       0     0      0
# 512039  1912          ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year              Athlete Name         Sport  Bronze  Silver  Gold  Total
# 598424  1920    SPOONER, Lloyd Spencer      shooting       2       1     4      7
# 566940  1920               LEE, Willis      shooting       1       1     5      7
# 582648  1920     OSBURN, Carl Townsend      shooting       1       1     4      6
# 581186  1920  NUESSLEIN, Lawrence Adam      shooting       2       1     2      5
# 540522  1920            FENTON, Dennis      shooting       1       0     3      4
# ...      ...                       ...           ...     ...     ...   ...    ...
# 546192  1920            GLASS, Hermann          judo       0       0     0      0
# 546191  1920            GLASS, Hermann  jeu de paume       0       0     0      0
# 546190  1920            GLASS, Hermann    ice hockey       0       0     0      0
# 546189  1920            GLASS, Hermann        hockey       0       0     0      0
# 614447  1920             ZORN, Zachary     wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year              Athlete Name      Sport  Bronze  Silver  Gold  Total
# 710940  1924       WEISSMULLER, Johnny   aquatics       1       0     3      4
# 640662  1924          EDERLE, Gertrude   aquatics       2       0     1      3
# 690602  1924         RICHARDS, Vincent     tennis       0       1     2      3
# 633342  1924  COULTER, Raymond Orville   shooting       1       0     1      2
# 695336  1924           SCHOLZ, Jackson  athletics       0       1     1      2
# ...      ...                       ...        ...     ...     ...   ...    ...
# 648606  1924            GLASS, Hermann      rugby       0       0     0      0
# 648605  1924            GLASS, Hermann     rowing       0       0     0      0
# 648604  1924            GLASS, Hermann      roque       0       0     0      0
# 648603  1924            GLASS, Hermann       polo       0       0     0      0
# 716855  1924             ZORN, Zachary  wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year                      Athlete Name              Sport  Bronze  Silver  Gold  Total
# 787508  1928            OSIPOWICH, Albina Lucy           aquatics       0       0     2      2
# 739704  1928  DESJARDINS, Ulise Joseph "Peter"           aquatics       0       0     2      2
# 734230  1928               COLEMAN, Georgia V.           aquatics       1       1     0      2
# 749088  1928           GALITZEN, Michael Riley           aquatics       1       1     0      2
# 794072  1928               ROBINSON, Elizabeth          athletics       0       1     1      2
# ...      ...                               ...                ...     ...     ...   ...    ...
# 751010  1928                    GLASS, Hermann  modern pentathlon       0       0     0      0
# 751009  1928                    GLASS, Hermann           lacrosse       0       0     0      0
# 751008  1928                    GLASS, Hermann               judo       0       0     0      0
# 751007  1928                    GLASS, Hermann       jeu de paume       0       0     0      0
# 819263  1928                     ZORN, Zachary          wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year            Athlete Name          Sport  Bronze  Silver  Gold  Total
# 877370  1932         MADISON, Helene       aquatics       0       0     3      3
# 842454  1932      DIDRIKSON, Mildred      athletics       0       1     2      3
# 836638  1932     COLEMAN, Georgia V.       aquatics       0       1     1      2
# 913922  1932  VON BREMEN, Wilhelmina      athletics       1       0     1      2
# 833818  1932    CARR, William Arthur      athletics       0       0     2      2
# ...      ...                     ...            ...     ...     ...   ...    ...
# 853432  1932          GLASS, Hermann  weightlifting       0       0     0      0
# 853431  1932          GLASS, Hermann     volleyball       0       0     0      0
# 853430  1932          GLASS, Hermann     tug of war       0       0     0      0
# 853429  1932          GLASS, Hermann      triathlon       0       0     0      0
# 921671  1932           ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year             Athlete Name       Sport  Bronze  Silver  Gold  Total
# 992530   1936             OWENS, Jesse   athletics       0       0     4      4
# 984674   1936          MEDICA, Jack C.    aquatics       0       2     1      3
# 985322   1936          METCALFE, Ralph   athletics       0       1     1      2
# 996710   1936  RAWLS, Katherine Louise    aquatics       1       1     0      2
# 995724   1936    POYNTON-HILL, Dorothy    aquatics       1       0     1      2
# ...       ...                      ...         ...     ...     ...   ...    ...
# 955819   1936           GLASS, Hermann        golf       0       0     0      0
# 955818   1936           GLASS, Hermann    football       0       0     0      0
# 955817   1936           GLASS, Hermann     fencing       0       0     0      0
# 955816   1936           GLASS, Hermann  equestrian       0       0     0      0
# 1024079  1936            ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name       Sport  Bronze  Silver  Gold  Total
# 1065364  1948       HENRY, Frank Sherman  equestrian       0       2     1      3
# 1121560  1948  WHITFIELD, Malvin Groston   athletics       1       0     2      3
# 1086402  1948    MCLANE, James Price Jr.    aquatics       0       1     2      3
# 1051724  1948      EWELL, Harold Norwood   athletics       0       2     1      3
# 1044310  1948      CURTIS, Ann Elisabeth    aquatics       0       1     2      3
# ...       ...                        ...         ...     ...     ...   ...    ...
# 1058240  1948             GLASS, Hermann    shooting       0       0     0      0
# 1058239  1948             GLASS, Hermann     sailing       0       0     0      0
# 1058238  1948             GLASS, Hermann       rugby       0       0     0      0
# 1058237  1948             GLASS, Hermann      rowing       0       0     0      0
# 1126487  1948              ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name       Sport  Bronze  Silver  Gold  Total
# 1178576  1952        KONNO, Ford Hiroshi    aquatics       0       1     2      3
# 1213428  1952  STANFIELD, Andrew William   athletics       0       0     2      2
# 1192212  1952   MOORE, Charles Hewes Jr.   athletics       0       1     1      2
# 1186228  1952      MATSON, Oliver Adrian   athletics       1       1     0      2
# 1176094  1952     KAWAMOTO, Evelyn Tokue    aquatics       2       0     0      2
# ...       ...                        ...         ...     ...     ...   ...    ...
# 1160638  1952             GLASS, Hermann  ice hockey       0       0     0      0
# 1160637  1952             GLASS, Hermann      hockey       0       0     0      0
# 1160636  1952             GLASS, Hermann  gymnastics       0       0     0      0
# 1160635  1952             GLASS, Hermann        golf       0       0     0      0
# 1228895  1952              ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year           Athlete Name              Sport  Bronze  Silver  Gold  Total
# 1295504  1956  MORROW, Robert Joseph          athletics       0       0     3      3
# 1239198  1956   BREEN, George Thomas           aquatics       2       1     0      3
# 1232536  1956    BAKER, Walter Thane          athletics       1       1     1      3
# 1289858  1956    MCCORMICK, Patricia           aquatics       0       0     2      2
# 1287580  1956   MANN, Shelley Isabel           aquatics       0       1     1      2
# ...       ...                    ...                ...     ...     ...   ...    ...
# 1263051  1956         GLASS, Hermann               polo       0       0     0      0
# 1263050  1956         GLASS, Hermann  modern pentathlon       0       0     0      0
# 1263049  1956         GLASS, Hermann           lacrosse       0       0     0      0
# 1263048  1956         GLASS, Hermann               judo       0       0     0      0
# 1331303  1956          ZORN, Zachary          wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year                 Athlete Name         Sport  Bronze  Silver  Gold  Total
# 1425994  1960  VON SALTZA, Susan Christina      aquatics       0       1     3      4
# 1409914  1960               RUDOLPH, Wilma     athletics       0       0     3      3
# 1359388  1960      FARRELL, Felix Geoffrey      aquatics       0       0     2      2
# 1385364  1960         LARSON, Lance Melvin      aquatics       0       1     1      2
# 1423886  1960        TROY, Michael Francis      aquatics       0       0     2      2
# ...       ...                          ...           ...     ...     ...   ...    ...
# 1365455  1960               GLASS, Hermann  jeu de paume       0       0     0      0
# 1365454  1960               GLASS, Hermann    ice hockey       0       0     0      0
# 1365453  1960               GLASS, Hermann        hockey       0       0     0      0
# 1365452  1960               GLASS, Hermann    gymnastics       0       0     0      0
# 1433711  1960                ZORN, Zachary     wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year                Athlete Name      Sport  Bronze  Silver  Gold  Total
# 1514564  1964  SCHOLLANDER, Donald Arthur   aquatics       0       0     4      4
# 1460232  1964             ELLIS, Kathleen   aquatics       2       0     2      4
# 1522282  1964       STOUDER, Sharon Marie   aquatics       0       1     3      4
# 1495424  1964        MCGUIRE, Edith Marie  athletics       0       2     1      3
# 1450100  1964       CLARK, Stephen Edward   aquatics       0       0     3      3
# ...       ...                         ...        ...     ...     ...   ...    ...
# 1467873  1964              GLASS, Hermann    skating       0       0     0      0
# 1467872  1964              GLASS, Hermann   shooting       0       0     0      0
# 1467871  1964              GLASS, Hermann    sailing       0       0     0      0
# 1467870  1964              GLASS, Hermann      rugby       0       0     0      0
# 1536119  1964               ZORN, Zachary  wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1622412  1968                SPITZ, Mark       aquatics       1       1     2      4
# 1577294  1968          HENNE, Jane Margo       aquatics       1       1     2      4
# 1608234  1968       PEDERSEN, Susan Jane       aquatics       0       2     2      4
# 1577804  1968  HICKCOX, Charles Buchanan       aquatics       0       1     3      4
# 1556724  1968    DANIEL, Eleanor Suzanne       aquatics       1       1     1      3
# ...       ...                        ...            ...     ...     ...   ...    ...
# 1570264  1968             GLASS, Hermann     equestrian       0       0     0      0
# 1570263  1968             GLASS, Hermann        cycling       0       0     0      0
# 1570262  1968             GLASS, Hermann  canoe / kayak       0       0     0      0
# 1570261  1968             GLASS, Hermann         boxing       0       0     0      0
# 1638527  1968              ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name              Sport  Bronze  Silver  Gold  Total
# 1724820  1972                SPITZ, Mark           aquatics       0       0     7      7
# 1679158  1972    HEIDENREICH, Jerry Alan           aquatics       1       1     2      4
# 1641656  1972  BABASHOFF, Shirley Farber           aquatics       0       2     1      3
# 1725398  1972      STAMM, Michael Eugene           aquatics       0       2     1      3
# 1644818  1972     BELOTE, Melissa Louise           aquatics       0       0     3      3
# ...       ...                        ...                ...     ...     ...   ...    ...
# 1672682  1972             GLASS, Hermann  modern pentathlon       0       0     0      0
# 1672681  1972             GLASS, Hermann           lacrosse       0       0     0      0
# 1672680  1972             GLASS, Hermann               judo       0       0     0      0
# 1672679  1972             GLASS, Hermann       jeu de paume       0       0     0      0
# 1740935  1972              ZORN, Zachary          wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name         Sport  Bronze  Silver  Gold  Total
# 1744064  1976  BABASHOFF, Shirley Farber      aquatics       0       4     1      5
# 1808732  1976       NABER, John Phillips      aquatics       0       1     4      5
# 1806420  1976     MONTGOMERY, James Paul      aquatics       1       0     3      4
# 1781838  1976    HENCKEN, John Frederick      aquatics       0       1     2      3
# 1772760  1976  FURNISS, Bruce Macfarlane      aquatics       0       0     2      2
# ...       ...                        ...           ...     ...     ...   ...    ...
# 1775087  1976             GLASS, Hermann  jeu de paume       0       0     0      0
# 1775086  1976             GLASS, Hermann    ice hockey       0       0     0      0
# 1775085  1976             GLASS, Hermann        hockey       0       0     0      0
# 1775084  1976             GLASS, Hermann    gymnastics       0       0     0      0
# 1843343  1976              ZORN, Zachary     wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year            Athlete Name         Sport  Bronze  Silver  Gold  Total
# 1919142  1984        RETTON, Mary-Lou    gymnastics       2       2     1      5
# 1898800  1984             LEWIS, Carl     athletics       0       0     4      4
# 1886014  1984    HOGSHEAD, Nancy Lynn      aquatics       0       1     3      4
# 1876234  1984   GAYLORD, Mitchell Jay    gymnastics       2       1     1      4
# 1906120  1984  MCNAMARA, Julianne Lyn    gymnastics       0       2     1      3
# ...       ...                     ...           ...     ...     ...   ...    ...
# 1877530  1984         GLASS, Kimberly          judo       0       0     0      0
# 1877529  1984         GLASS, Kimberly  jeu de paume       0       0     0      0
# 1877528  1984         GLASS, Kimberly    ice hockey       0       0     0      0
# 1877527  1984         GLASS, Kimberly        hockey       0       0     0      0
# 1945751  1984           ZORN, Zachary     wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year                 Athlete Name       Sport  Bronze  Silver  Gold  Total
# 1953334  1988              BIONDI, Matthew    aquatics       1       1     5      7
# 1982168  1988    GRIFFITH-JOYNER, Florence   athletics       0       1     3      4
# 1991142  1988  JACOBS, Christopher Charles    aquatics       0       1     2      3
# 1973088  1988                 EVANS, Janet    aquatics       0       0     3      3
# 2001208  1988                  LEWIS, Carl   athletics       0       1     2      3
# ...       ...                          ...         ...     ...     ...   ...    ...
# 1979919  1988               GLASS, Hermann  volleyball       0       0     0      0
# 1979918  1988               GLASS, Hermann  tug of war       0       0     0      0
# 1979917  1988               GLASS, Hermann   triathlon       0       0     0      0
# 1979916  1988               GLASS, Hermann      tennis       0       0     0      0
# 2048159  1988                ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year     Athlete Name       Sport  Bronze  Silver  Gold  Total
# 2112636  1992  MILLER, Shannon  gymnastics       3       2     0      5
# 2127856  1992  SANDERS, Summer    aquatics       1       1     2      4
# 2118506  1992       OLSEN, Jon    aquatics       1       0     2      3
# 2115990  1992      NALL, Anita    aquatics       1       1     1      3
# 2140166  1992   TORRENCE, Gwen   athletics       0       1     2      3
# ...       ...              ...         ...     ...     ...   ...    ...
# 2082326  1992   GLASS, Hermann  tug of war       0       0     0      0
# 2082325  1992   GLASS, Hermann   triathlon       0       0     0      0
# 2082324  1992   GLASS, Hermann      tennis       0       0     0      0
# 2082323  1992   GLASS, Hermann   taekwondo       0       0     0      0
# 2150567  1992    ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year    Athlete Name       Sport  Bronze  Silver  Gold  Total
# 2188206  1996  HALL, Gary Jr.    aquatics       0       2     2      4
# 2210068  1996  MARTINO, Angel    aquatics       2       0     2      4
# 2244204  1996  VAN DYKEN, Amy    aquatics       0       0     4      4
# 2155940  1996   BEARD, Amanda    aquatics       0       2     1      3
# 2172022  1996     DAVIS, Josh    aquatics       0       0     3      3
# ...       ...             ...         ...     ...     ...   ...    ...
# 2184734  1996  GLASS, Hermann  tug of war       0       0     0      0
# 2184733  1996  GLASS, Hermann   triathlon       0       0     0      0
# 2184732  1996  GLASS, Hermann      tennis       0       0     0      0
# 2184731  1996  GLASS, Hermann   taekwondo       0       0     0      0
# 2252975  1996   ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year        Athlete Name       Sport  Bronze  Silver  Gold  Total
# 2345014  2000        TORRES, Dara    aquatics       3       0     2      5
# 2290614  2000      HALL, Gary Jr.    aquatics       1       1     2      4
# 2343994  2000     THOMPSON, Jenny    aquatics       1       0     3      4
# 2305540  2000  KRAYZELBURG, Lenny    aquatics       0       0     3      3
# 2320296  2000         MUNZ, Diana    aquatics       0       1     1      2
# ...       ...                 ...         ...     ...     ...   ...    ...
# 2287143  2000      GLASS, Hermann  volleyball       0       0     0      0
# 2287142  2000      GLASS, Hermann  tug of war       0       0     0      0
# 2287141  2000      GLASS, Hermann   triathlon       0       0     0      0
# 2287140  2000      GLASS, Hermann      tennis       0       0     0      0
# 2355383  2000       ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year       Athlete Name       Sport  Bronze  Silver  Gold  Total
# 2428246  2004    PHELPS, Michael    aquatics       2       0     6      8
# 2374220  2004  COUGHLIN, Natalie    aquatics       1       2     2      5
# 2427000  2004   PATTERSON, Carly  gymnastics       0       2     1      3
# 2360756  2004      BEARD, Amanda    aquatics       0       2     1      3
# 2393872  2004    HANSEN, Brendan    aquatics       1       1     1      3
# ...       ...                ...         ...     ...     ...   ...    ...
# 2389545  2004     GLASS, Hermann     skating       0       0     0      0
# 2389544  2004     GLASS, Hermann    shooting       0       0     0      0
# 2389543  2004     GLASS, Hermann     sailing       0       0     0      0
# 2389542  2004     GLASS, Hermann       rugby       0       0     0      0
# 2457791  2004      ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year       Athlete Name       Sport  Bronze  Silver  Gold  Total
# 2530654  2008    PHELPS, Michael    aquatics       0       0     8      8
# 2476628  2008  COUGHLIN, Natalie    aquatics       3       2     1      6
# 2514142  2008     LIUKIN, Nastia  gymnastics       1       3     1      5
# 2514368  2008       LOCHTE, Ryan    aquatics       2       0     2      4
# 2505642  2008     JOHNSON, Shawn  gymnastics       0       3     1      4
# ...       ...                ...         ...     ...     ...   ...    ...
# 2491964  2008    GLASS, Kimberly   athletics       0       0     0      0
# 2491963  2008    GLASS, Kimberly     archery       0       0     0      0
# 2491962  2008    GLASS, Kimberly    aquatics       0       0     0      0
# 2491961  2008     GLASS, Hermann   wrestling       0       0     0      0
# 2560199  2008      ZORN, Zachary   wrestling       0       0     0      0
#
# [102408 rows x 7 columns]

# %%
for year, group in table.groupby('Year'):
  print(group.sort_values(['Total', 'Gold', 'Silver', 'Bronze', 'Athlete Name'], ascending=False))
# Out:
# Medal  Year     Athlete Name          Sport  Bronze  Silver  Gold  Total
# 32642  1896  GARRETT, Robert      athletics       0       2     2      4
# 17988  1896  CONNOLLY, James      athletics       1       1     1      3
# 16186  1896    CLARK, Ellery      athletics       0       0     2      2
# 12616  1896    BURKE, Thomas      athletics       0       0     2      2
# 71118  1896    PAINE, Sumner       shooting       0       1     1      2
# ...     ...              ...            ...     ...     ...   ...    ...
# 29     1896    ABAS, Stephen      triathlon       0       0     0      0
# 30     1896    ABAS, Stephen     tug of war       0       0     0      0
# 31     1896    ABAS, Stephen     volleyball       0       0     0      0
# 32     1896    ABAS, Stephen  weightlifting       0       0     0      0
# 33     1896    ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year               Athlete Name          Sport  Bronze  Silver  Gold  Total
# 107612  1900             BAXTER, Irving      athletics       0       3     2      5
# 193156  1900  TEWKSBURY, Walter B. John      athletics       1       2     2      5
# 154838  1900          KRAENZLEIN, Alvin      athletics       0       0     4      4
# 130154  1900                  EWRY, Ray      athletics       0       0     3      3
# 176700  1900           PRINSTEIN, Meyer      athletics       0       1     1      2
# ...      ...                        ...            ...     ...     ...   ...    ...
# 102437  1900              ABAS, Stephen      triathlon       0       0     0      0
# 102438  1900              ABAS, Stephen     tug of war       0       0     0      0
# 102439  1900              ABAS, Stephen     volleyball       0       0     0      0
# 102440  1900              ABAS, Stephen  weightlifting       0       0     0      0
# 102441  1900              ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year      Athlete Name          Sport  Bronze  Silver  Gold  Total
# 245424  1904      HEIDA, Anton     gymnastics       0       1     5      6
# 232640  1904     EYSER, George     gymnastics       1       2     3      6
# 229541  1904   DOWNING, Burton        cycling       1       3     2      6
# 249159  1904    HURLEY, Marcus        cycling       1       0     4      5
# 225454  1904  DANIELS, Charles       aquatics       1       1     3      5
# ...      ...               ...            ...     ...     ...   ...    ...
# 204845  1904     ABAS, Stephen      triathlon       0       0     0      0
# 204846  1904     ABAS, Stephen     tug of war       0       0     0      0
# 204847  1904     ABAS, Stephen     volleyball       0       0     0      0
# 204848  1904     ABAS, Stephen  weightlifting       0       0     0      0
# 204849  1904     ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year                  Athlete Name          Sport  Bronze  Silver  Gold  Total
# 390390  1908              SHEPPARD, Melvin      athletics       0       0     3      3
# 390458  1908              SHERIDAN, Martin      athletics       1       0     2      3
# 334970  1908                     EWRY, Ray      athletics       0       0     2      2
# 322140  1908  CASEY, Kellog Kennon Venable       shooting       0       1     1      2
# 342098  1908          GORMAN, James Edward       shooting       1       0     1      2
# ...      ...                           ...            ...     ...     ...   ...    ...
# 307253  1908                 ABAS, Stephen      triathlon       0       0     0      0
# 307254  1908                 ABAS, Stephen     tug of war       0       0     0      0
# 307255  1908                 ABAS, Stephen     volleyball       0       0     0      0
# 307256  1908                 ABAS, Stephen  weightlifting       0       0     0      0
# 307257  1908                 ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year           Athlete Name          Sport  Bronze  Silver  Gold  Total
# 480240  1912  OSBURN, Carl Townsend       shooting       1       2     1      4
# 463342  1912        LANE, Alfred P.       shooting       0       0     3      3
# 496186  1912      SPROUT, Warren A.       shooting       2       0     1      3
# 451884  1912     HIRD, Frederick S.       shooting       2       0     1      3
# 464974  1912   LEUSHNER, William F.       shooting       2       1     0      3
# ...      ...                    ...            ...     ...     ...   ...    ...
# 409661  1912          ABAS, Stephen      triathlon       0       0     0      0
# 409662  1912          ABAS, Stephen     tug of war       0       0     0      0
# 409663  1912          ABAS, Stephen     volleyball       0       0     0      0
# 409664  1912          ABAS, Stephen  weightlifting       0       0     0      0
# 409665  1912          ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year              Athlete Name          Sport  Bronze  Silver  Gold  Total
# 566940  1920               LEE, Willis       shooting       1       1     5      7
# 598424  1920    SPOONER, Lloyd Spencer       shooting       2       1     4      7
# 582648  1920     OSBURN, Carl Townsend       shooting       1       1     4      6
# 581186  1920  NUESSLEIN, Lawrence Adam       shooting       2       1     2      5
# 540522  1920            FENTON, Dennis       shooting       1       0     3      4
# ...      ...                       ...            ...     ...     ...   ...    ...
# 512069  1920             ABAS, Stephen      triathlon       0       0     0      0
# 512070  1920             ABAS, Stephen     tug of war       0       0     0      0
# 512071  1920             ABAS, Stephen     volleyball       0       0     0      0
# 512072  1920             ABAS, Stephen  weightlifting       0       0     0      0
# 512073  1920             ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year              Athlete Name          Sport  Bronze  Silver  Gold  Total
# 710940  1924       WEISSMULLER, Johnny       aquatics       1       0     3      4
# 690602  1924         RICHARDS, Vincent         tennis       0       1     2      3
# 640662  1924          EDERLE, Gertrude       aquatics       2       0     1      3
# 713858  1924        WILLS-MOODY, Helen         tennis       0       0     2      2
# 712362  1924  WIGHTMAN, Hazel Virginia         tennis       0       0     2      2
# ...      ...                       ...            ...     ...     ...   ...    ...
# 614477  1924             ABAS, Stephen      triathlon       0       0     0      0
# 614478  1924             ABAS, Stephen     tug of war       0       0     0      0
# 614479  1924             ABAS, Stephen     volleyball       0       0     0      0
# 614480  1924             ABAS, Stephen  weightlifting       0       0     0      0
# 614481  1924             ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year                      Athlete Name          Sport  Bronze  Silver  Gold  Total
# 813348  1928               WEISSMULLER, Johnny       aquatics       0       0     2      2
# 787508  1928            OSIPOWICH, Albina Lucy       aquatics       0       0     2      2
# 785672  1928                  NORELIUS, Martha       aquatics       0       0     2      2
# 768774  1928              KOJAC, George Harold       aquatics       0       0     2      2
# 739704  1928  DESJARDINS, Ulise Joseph "Peter"       aquatics       0       0     2      2
# ...      ...                               ...            ...     ...     ...   ...    ...
# 716885  1928                     ABAS, Stephen      triathlon       0       0     0      0
# 716886  1928                     ABAS, Stephen     tug of war       0       0     0      0
# 716887  1928                     ABAS, Stephen     volleyball       0       0     0      0
# 716888  1928                     ABAS, Stephen  weightlifting       0       0     0      0
# 716889  1928                     ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year          Athlete Name          Sport  Bronze  Silver  Gold  Total
# 877370  1932       MADISON, Helene       aquatics       0       0     3      3
# 842454  1932    DIDRIKSON, Mildred      athletics       0       1     2      3
# 910964  1932          TOLAN, Eddie      athletics       0       0     2      2
# 833818  1932  CARR, William Arthur      athletics       0       0     2      2
# 910494  1932  THOMSON, Earl Foster     equestrian       0       1     1      2
# ...      ...                   ...            ...     ...     ...   ...    ...
# 819293  1932         ABAS, Stephen      triathlon       0       0     0      0
# 819294  1932         ABAS, Stephen     tug of war       0       0     0      0
# 819295  1932         ABAS, Stephen     volleyball       0       0     0      0
# 819296  1932         ABAS, Stephen  weightlifting       0       0     0      0
# 819297  1932         ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year             Athlete Name          Sport  Bronze  Silver  Gold  Total
# 992530   1936             OWENS, Jesse      athletics       0       0     4      4
# 984674   1936          MEDICA, Jack C.       aquatics       0       2     1      3
# 1009360  1936  STEPHENS, Helen Herring      athletics       0       0     2      2
# 1017484  1936          WAYNE, Marshall       aquatics       0       1     1      2
# 985322   1936          METCALFE, Ralph      athletics       0       1     1      2
# ...       ...                      ...            ...     ...     ...   ...    ...
# 921701   1936            ABAS, Stephen      triathlon       0       0     0      0
# 921702   1936            ABAS, Stephen     tug of war       0       0     0      0
# 921703   1936            ABAS, Stephen     volleyball       0       0     0      0
# 921704   1936            ABAS, Stephen  weightlifting       0       0     0      0
# 921705   1936            ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1086402  1948    MCLANE, James Price Jr.       aquatics       0       1     2      3
# 1044310  1948      CURTIS, Ann Elisabeth       aquatics       0       1     2      3
# 1121560  1948  WHITFIELD, Malvin Groston      athletics       1       0     2      3
# 1065364  1948       HENRY, Frank Sherman     equestrian       0       2     1      3
# 1051724  1948      EWELL, Harold Norwood      athletics       0       2     1      3
# ...       ...                        ...            ...     ...     ...   ...    ...
# 1024109  1948              ABAS, Stephen      triathlon       0       0     0      0
# 1024110  1948              ABAS, Stephen     tug of war       0       0     0      0
# 1024111  1948              ABAS, Stephen     volleyball       0       0     0      0
# 1024112  1948              ABAS, Stephen  weightlifting       0       0     0      0
# 1024113  1948              ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1178576  1952        KONNO, Ford Hiroshi       aquatics       0       1     2      3
# 1213428  1952  STANFIELD, Andrew William      athletics       0       0     2      2
# 1202174  1952            REMIGINO, Lindy      athletics       0       0     2      2
# 1187450  1952        MCCORMICK, Patricia       aquatics       0       0     2      2
# 1149882  1952          DILLARD, Harrison      athletics       0       0     2      2
# ...       ...                        ...            ...     ...     ...   ...    ...
# 1126517  1952              ABAS, Stephen      triathlon       0       0     0      0
# 1126518  1952              ABAS, Stephen     tug of war       0       0     0      0
# 1126519  1952              ABAS, Stephen     volleyball       0       0     0      0
# 1126520  1952              ABAS, Stephen  weightlifting       0       0     0      0
# 1126521  1952              ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year             Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1295504  1956    MORROW, Robert Joseph      athletics       0       0     3      3
# 1232536  1956      BAKER, Walter Thane      athletics       1       1     1      3
# 1239198  1956     BREEN, George Thomas       aquatics       2       1     0      3
# 1289858  1956      MCCORMICK, Patricia       aquatics       0       0     2      2
# 1275410  1956  JENKINS, Charles Lamont      athletics       0       0     2      2
# ...       ...                      ...            ...     ...     ...   ...    ...
# 1228925  1956            ABAS, Stephen      triathlon       0       0     0      0
# 1228926  1956            ABAS, Stephen     tug of war       0       0     0      0
# 1228927  1956            ABAS, Stephen     volleyball       0       0     0      0
# 1228928  1956            ABAS, Stephen  weightlifting       0       0     0      0
# 1228929  1956            ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year                 Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1425994  1960  VON SALTZA, Susan Christina       aquatics       0       1     3      4
# 1409914  1960               RUDOLPH, Wilma      athletics       0       0     3      3
# 1423886  1960        TROY, Michael Francis       aquatics       0       0     2      2
# 1412564  1960        SCHULER, Carolyn Jane       aquatics       0       0     2      2
# 1359388  1960      FARRELL, Felix Geoffrey       aquatics       0       0     2      2
# ...       ...                          ...            ...     ...     ...   ...    ...
# 1331333  1960                ABAS, Stephen      triathlon       0       0     0      0
# 1331334  1960                ABAS, Stephen     tug of war       0       0     0      0
# 1331335  1960                ABAS, Stephen     volleyball       0       0     0      0
# 1331336  1960                ABAS, Stephen  weightlifting       0       0     0      0
# 1331337  1960                ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year                Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1514564  1964  SCHOLLANDER, Donald Arthur       aquatics       0       0     4      4
# 1522282  1964       STOUDER, Sharon Marie       aquatics       0       1     3      4
# 1460232  1964             ELLIS, Kathleen       aquatics       2       0     2      4
# 1450100  1964       CLARK, Stephen Edward       aquatics       0       0     3      3
# 1495424  1964        MCGUIRE, Edith Marie      athletics       0       2     1      3
# ...       ...                         ...            ...     ...     ...   ...    ...
# 1433741  1964               ABAS, Stephen      triathlon       0       0     0      0
# 1433742  1964               ABAS, Stephen     tug of war       0       0     0      0
# 1433743  1964               ABAS, Stephen     volleyball       0       0     0      0
# 1433744  1964               ABAS, Stephen  weightlifting       0       0     0      0
# 1433745  1964               ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1577804  1968  HICKCOX, Charles Buchanan       aquatics       0       1     3      4
# 1608234  1968       PEDERSEN, Susan Jane       aquatics       0       2     2      4
# 1622412  1968                SPITZ, Mark       aquatics       1       1     2      4
# 1577294  1968          HENNE, Jane Margo       aquatics       1       1     2      4
# 1599802  1968             MEYER, Deborah       aquatics       0       0     3      3
# ...       ...                        ...            ...     ...     ...   ...    ...
# 1536149  1968              ABAS, Stephen      triathlon       0       0     0      0
# 1536150  1968              ABAS, Stephen     tug of war       0       0     0      0
# 1536151  1968              ABAS, Stephen     volleyball       0       0     0      0
# 1536152  1968              ABAS, Stephen  weightlifting       0       0     0      0
# 1536153  1968              ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year             Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1724820  1972              SPITZ, Mark       aquatics       0       0     7      7
# 1679158  1972  HEIDENREICH, Jerry Alan       aquatics       1       1     2      4
# 1706562  1972  NEILSON, Alexandra Lynn       aquatics       0       0     3      3
# 1644818  1972   BELOTE, Melissa Louise       aquatics       0       0     3      3
# 1725398  1972    STAMM, Michael Eugene       aquatics       0       2     1      3
# ...       ...                      ...            ...     ...     ...   ...    ...
# 1638557  1972            ABAS, Stephen      triathlon       0       0     0      0
# 1638558  1972            ABAS, Stephen     tug of war       0       0     0      0
# 1638559  1972            ABAS, Stephen     volleyball       0       0     0      0
# 1638560  1972            ABAS, Stephen  weightlifting       0       0     0      0
# 1638561  1972            ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1808732  1976       NABER, John Phillips       aquatics       0       1     4      5
# 1744064  1976  BABASHOFF, Shirley Farber       aquatics       0       4     1      5
# 1806420  1976     MONTGOMERY, James Paul       aquatics       1       0     3      4
# 1781838  1976    HENCKEN, John Frederick       aquatics       0       1     2      3
# 1835354  1976      VOGEL, Matthew Haynes       aquatics       0       0     2      2
# ...       ...                        ...            ...     ...     ...   ...    ...
# 1740965  1976              ABAS, Stephen      triathlon       0       0     0      0
# 1740966  1976              ABAS, Stephen     tug of war       0       0     0      0
# 1740967  1976              ABAS, Stephen     volleyball       0       0     0      0
# 1740968  1976              ABAS, Stephen  weightlifting       0       0     0      0
# 1740969  1976              ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year           Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1919142  1984       RETTON, Mary-Lou     gymnastics       2       2     1      5
# 1898800  1984            LEWIS, Carl      athletics       0       0     4      4
# 1886014  1984   HOGSHEAD, Nancy Lynn       aquatics       0       1     3      4
# 1876234  1984  GAYLORD, Mitchell Jay     gymnastics       2       1     1      4
# 1906278  1984       MEAGHER, Mary T.       aquatics       0       0     3      3
# ...       ...                    ...            ...     ...     ...   ...    ...
# 1843373  1984          ABAS, Stephen      triathlon       0       0     0      0
# 1843374  1984          ABAS, Stephen     tug of war       0       0     0      0
# 1843375  1984          ABAS, Stephen     volleyball       0       0     0      0
# 1843376  1984          ABAS, Stephen  weightlifting       0       0     0      0
# 1843377  1984          ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year                 Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1953334  1988              BIONDI, Matthew       aquatics       1       1     5      7
# 1982168  1988    GRIFFITH-JOYNER, Florence      athletics       0       1     3      4
# 1973088  1988                 EVANS, Janet       aquatics       0       0     3      3
# 2001208  1988                  LEWIS, Carl      athletics       0       1     2      3
# 1991142  1988  JACOBS, Christopher Charles       aquatics       0       1     2      3
# ...       ...                          ...            ...     ...     ...   ...    ...
# 1945781  1988                ABAS, Stephen      triathlon       0       0     0      0
# 1945782  1988                ABAS, Stephen     tug of war       0       0     0      0
# 1945783  1988                ABAS, Stephen     volleyball       0       0     0      0
# 1945784  1988                ABAS, Stephen  weightlifting       0       0     0      0
# 1945785  1988                ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year          Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2112636  1992       MILLER, Shannon     gymnastics       3       2     0      5
# 2127856  1992       SANDERS, Summer       aquatics       1       1     2      4
# 2085424  1992  HAISLETT, Nicole Lee       aquatics       0       0     3      3
# 2140166  1992        TORRENCE, Gwen      athletics       0       1     2      3
# 2139178  1992       THOMPSON, Jenny       aquatics       0       1     2      3
# ...       ...                   ...            ...     ...     ...   ...    ...
# 2048189  1992         ABAS, Stephen      triathlon       0       0     0      0
# 2048190  1992         ABAS, Stephen     tug of war       0       0     0      0
# 2048191  1992         ABAS, Stephen     volleyball       0       0     0      0
# 2048192  1992         ABAS, Stephen  weightlifting       0       0     0      0
# 2048193  1992         ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year     Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2244204  1996   VAN DYKEN, Amy       aquatics       0       0     4      4
# 2188206  1996   HALL, Gary Jr.       aquatics       0       2     2      4
# 2210068  1996   MARTINO, Angel       aquatics       2       0     2      4
# 2241586  1996  THOMPSON, Jenny       aquatics       0       0     3      3
# 2172022  1996      DAVIS, Josh       aquatics       0       0     3      3
# ...       ...              ...            ...     ...     ...   ...    ...
# 2150597  1996    ABAS, Stephen      triathlon       0       0     0      0
# 2150598  1996    ABAS, Stephen     tug of war       0       0     0      0
# 2150599  1996    ABAS, Stephen     volleyball       0       0     0      0
# 2150600  1996    ABAS, Stephen  weightlifting       0       0     0      0
# 2150601  1996    ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year        Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2345014  2000        TORRES, Dara       aquatics       3       0     2      5
# 2343994  2000     THOMPSON, Jenny       aquatics       1       0     3      4
# 2290614  2000      HALL, Gary Jr.       aquatics       1       1     2      4
# 2305540  2000  KRAYZELBURG, Lenny       aquatics       0       0     3      3
# 2352250  2000     WILLIAMS, Venus         tennis       0       0     2      2
# ...       ...                 ...            ...     ...     ...   ...    ...
# 2253005  2000       ABAS, Stephen      triathlon       0       0     0      0
# 2253006  2000       ABAS, Stephen     tug of war       0       0     0      0
# 2253007  2000       ABAS, Stephen     volleyball       0       0     0      0
# 2253008  2000       ABAS, Stephen  weightlifting       0       0     0      0
# 2253009  2000       ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year       Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2428246  2004    PHELPS, Michael       aquatics       2       0     6      8
# 2374220  2004  COUGHLIN, Natalie       aquatics       1       2     2      5
# 2427566  2004     PEIRSOL, Aaron       aquatics       0       0     3      3
# 2427000  2004   PATTERSON, Carly     gymnastics       0       2     1      3
# 2393476  2004         HAMM, Paul     gymnastics       0       2     1      3
# ...       ...                ...            ...     ...     ...   ...    ...
# 2355412  2004      ABAS, Stephen         tennis       0       0     0      0
# 2355413  2004      ABAS, Stephen      triathlon       0       0     0      0
# 2355414  2004      ABAS, Stephen     tug of war       0       0     0      0
# 2355415  2004      ABAS, Stephen     volleyball       0       0     0      0
# 2355416  2004      ABAS, Stephen  weightlifting       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year       Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2530654  2008    PHELPS, Michael       aquatics       0       0     8      8
# 2476628  2008  COUGHLIN, Natalie       aquatics       3       2     1      6
# 2514142  2008     LIUKIN, Nastia     gymnastics       1       3     1      5
# 2514368  2008       LOCHTE, Ryan       aquatics       2       0     2      4
# 2505642  2008     JOHNSON, Shawn     gymnastics       0       3     1      4
# ...       ...                ...            ...     ...     ...   ...    ...
# 2457821  2008      ABAS, Stephen      triathlon       0       0     0      0
# 2457822  2008      ABAS, Stephen     tug of war       0       0     0      0
# 2457823  2008      ABAS, Stephen     volleyball       0       0     0      0
# 2457824  2008      ABAS, Stephen  weightlifting       0       0     0      0
# 2457825  2008      ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]

# %%
for year, group in table.groupby('Year'):
  print(group.sort_values(['Total', 'Gold', 'Silver', 'Bronze', 'Athlete Name'], ascending=False).head(1))
# Out:
# Medal  Year     Athlete Name      Sport  Bronze  Silver  Gold  Total
# 32642  1896  GARRETT, Robert  athletics       0       2     2      4
# Medal   Year    Athlete Name      Sport  Bronze  Silver  Gold  Total
# 107612  1900  BAXTER, Irving  athletics       0       3     2      5
# Medal   Year  Athlete Name       Sport  Bronze  Silver  Gold  Total
# 245424  1904  HEIDA, Anton  gymnastics       0       1     5      6
# Medal   Year      Athlete Name      Sport  Bronze  Silver  Gold  Total
# 390390  1908  SHEPPARD, Melvin  athletics       0       0     3      3
# Medal   Year           Athlete Name     Sport  Bronze  Silver  Gold  Total
# 480240  1912  OSBURN, Carl Townsend  shooting       1       2     1      4
# Medal   Year Athlete Name     Sport  Bronze  Silver  Gold  Total
# 566940  1920  LEE, Willis  shooting       1       1     5      7
# Medal   Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
# 710940  1924  WEISSMULLER, Johnny  aquatics       1       0     3      4
# Medal   Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
# 813348  1928  WEISSMULLER, Johnny  aquatics       0       0     2      2
# Medal   Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
# 877370  1932  MADISON, Helene  aquatics       0       0     3      3
# Medal   Year  Athlete Name      Sport  Bronze  Silver  Gold  Total
# 992530  1936  OWENS, Jesse  athletics       0       0     4      4
# Medal    Year             Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1086402  1948  MCLANE, James Price Jr.  aquatics       0       1     2      3
# Medal    Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1178576  1952  KONNO, Ford Hiroshi  aquatics       0       1     2      3
# Medal    Year           Athlete Name      Sport  Bronze  Silver  Gold  Total
# 1295504  1956  MORROW, Robert Joseph  athletics       0       0     3      3
# Medal    Year                 Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1425994  1960  VON SALTZA, Susan Christina  aquatics       0       1     3      4
# Medal    Year                Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1514564  1964  SCHOLLANDER, Donald Arthur  aquatics       0       0     4      4
# Medal    Year               Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1577804  1968  HICKCOX, Charles Buchanan  aquatics       0       1     3      4
# Medal    Year Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1724820  1972  SPITZ, Mark  aquatics       0       0     7      7
# Medal    Year          Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1808732  1976  NABER, John Phillips  aquatics       0       1     4      5
# Medal    Year      Athlete Name       Sport  Bronze  Silver  Gold  Total
# 1919142  1984  RETTON, Mary-Lou  gymnastics       2       2     1      5
# Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1953334  1988  BIONDI, Matthew  aquatics       1       1     5      7
# Medal    Year     Athlete Name       Sport  Bronze  Silver  Gold  Total
# 2112636  1992  MILLER, Shannon  gymnastics       3       2     0      5
# Medal    Year    Athlete Name     Sport  Bronze  Silver  Gold  Total
# 2244204  1996  VAN DYKEN, Amy  aquatics       0       0     4      4
# Medal    Year  Athlete Name     Sport  Bronze  Silver  Gold  Total
# 2345014  2000  TORRES, Dara  aquatics       3       0     2      5
# Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
# 2428246  2004  PHELPS, Michael  aquatics       2       0     6      8
# Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
# 2530654  2008  PHELPS, Michael  aquatics       0       0     8      8

# %%
winners = [
    group.sort_values(['Total', 'Gold', 'Silver', 'Bronze', 'Athlete Name'], ascending=False).head(1)
    for year, group in table.groupby('Year')
]
winners
# Out:
# [Medal  Year     Athlete Name      Sport  Bronze  Silver  Gold  Total
#  32642  1896  GARRETT, Robert  athletics       0       2     2      4,
#  Medal   Year    Athlete Name      Sport  Bronze  Silver  Gold  Total
#  107612  1900  BAXTER, Irving  athletics       0       3     2      5,
#  Medal   Year  Athlete Name       Sport  Bronze  Silver  Gold  Total
#  245424  1904  HEIDA, Anton  gymnastics       0       1     5      6,
#  Medal   Year      Athlete Name      Sport  Bronze  Silver  Gold  Total
#  390390  1908  SHEPPARD, Melvin  athletics       0       0     3      3,
#  Medal   Year           Athlete Name     Sport  Bronze  Silver  Gold  Total
#  480240  1912  OSBURN, Carl Townsend  shooting       1       2     1      4,
#  Medal   Year Athlete Name     Sport  Bronze  Silver  Gold  Total
#  566940  1920  LEE, Willis  shooting       1       1     5      7,
#  Medal   Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
#  710940  1924  WEISSMULLER, Johnny  aquatics       1       0     3      4,
#  Medal   Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
#  813348  1928  WEISSMULLER, Johnny  aquatics       0       0     2      2,
#  Medal   Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
#  877370  1932  MADISON, Helene  aquatics       0       0     3      3,
#  Medal   Year  Athlete Name      Sport  Bronze  Silver  Gold  Total
#  992530  1936  OWENS, Jesse  athletics       0       0     4      4,
#  Medal    Year             Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1086402  1948  MCLANE, James Price Jr.  aquatics       0       1     2      3,
#  Medal    Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1178576  1952  KONNO, Ford Hiroshi  aquatics       0       1     2      3,
#  Medal    Year           Athlete Name      Sport  Bronze  Silver  Gold  Total
#  1295504  1956  MORROW, Robert Joseph  athletics       0       0     3      3,
#  Medal    Year                 Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1425994  1960  VON SALTZA, Susan Christina  aquatics       0       1     3      4,
#  Medal    Year                Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1514564  1964  SCHOLLANDER, Donald Arthur  aquatics       0       0     4      4,
#  Medal    Year               Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1577804  1968  HICKCOX, Charles Buchanan  aquatics       0       1     3      4,
#  Medal    Year Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1724820  1972  SPITZ, Mark  aquatics       0       0     7      7,
#  Medal    Year          Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1808732  1976  NABER, John Phillips  aquatics       0       1     4      5,
#  Medal    Year      Athlete Name       Sport  Bronze  Silver  Gold  Total
#  1919142  1984  RETTON, Mary-Lou  gymnastics       2       2     1      5,
#  Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1953334  1988  BIONDI, Matthew  aquatics       1       1     5      7,
#  Medal    Year     Athlete Name       Sport  Bronze  Silver  Gold  Total
#  2112636  1992  MILLER, Shannon  gymnastics       3       2     0      5,
#  Medal    Year    Athlete Name     Sport  Bronze  Silver  Gold  Total
#  2244204  1996  VAN DYKEN, Amy  aquatics       0       0     4      4,
#  Medal    Year  Athlete Name     Sport  Bronze  Silver  Gold  Total
#  2345014  2000  TORRES, Dara  aquatics       3       0     2      5,
#  Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
#  2428246  2004  PHELPS, Michael  aquatics       2       0     6      8,
#  Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
#  2530654  2008  PHELPS, Michael  aquatics       0       0     8      8]

# %%
winners[0]
# Out:
# Medal  Year     Athlete Name      Sport  Bronze  Silver  Gold  Total
# 32642  1896  GARRETT, Robert  athletics       0       2     2      4

# %%
type(winners[0])
# Out:
# pandas.core.frame.DataFrame

# %%
pd.concat(winners)
# Out:
# Medal    Year                 Athlete Name       Sport  Bronze  Silver  Gold  Total
# 32642    1896              GARRETT, Robert   athletics       0       2     2      4
# 107612   1900               BAXTER, Irving   athletics       0       3     2      5
# 245424   1904                 HEIDA, Anton  gymnastics       0       1     5      6
# 390390   1908             SHEPPARD, Melvin   athletics       0       0     3      3
# 480240   1912        OSBURN, Carl Townsend    shooting       1       2     1      4
# 566940   1920                  LEE, Willis    shooting       1       1     5      7
# 710940   1924          WEISSMULLER, Johnny    aquatics       1       0     3      4
# 813348   1928          WEISSMULLER, Johnny    aquatics       0       0     2      2
# 877370   1932              MADISON, Helene    aquatics       0       0     3      3
# 992530   1936                 OWENS, Jesse   athletics       0       0     4      4
# 1086402  1948      MCLANE, James Price Jr.    aquatics       0       1     2      3
# 1178576  1952          KONNO, Ford Hiroshi    aquatics       0       1     2      3
# 1295504  1956        MORROW, Robert Joseph   athletics       0       0     3      3
# 1425994  1960  VON SALTZA, Susan Christina    aquatics       0       1     3      4
# 1514564  1964   SCHOLLANDER, Donald Arthur    aquatics       0       0     4      4
# 1577804  1968    HICKCOX, Charles Buchanan    aquatics       0       1     3      4
# 1724820  1972                  SPITZ, Mark    aquatics       0       0     7      7
# 1808732  1976         NABER, John Phillips    aquatics       0       1     4      5
# 1919142  1984             RETTON, Mary-Lou  gymnastics       2       2     1      5
# 1953334  1988              BIONDI, Matthew    aquatics       1       1     5      7
# 2112636  1992              MILLER, Shannon  gymnastics       3       2     0      5
# 2244204  1996               VAN DYKEN, Amy    aquatics       0       0     4      4
# 2345014  2000                 TORRES, Dara    aquatics       3       0     2      5
# 2428246  2004              PHELPS, Michael    aquatics       2       0     6      8
# 2530654  2008              PHELPS, Michael    aquatics       0       0     8      8

# %%
pd.concat(winners)[["Year",	"Athlete Name",	"Sport", "Total"]]
# Out:
# Medal    Year                 Athlete Name       Sport  Total
# 32642    1896              GARRETT, Robert   athletics      4
# 107612   1900               BAXTER, Irving   athletics      5
# 245424   1904                 HEIDA, Anton  gymnastics      6
# 390390   1908             SHEPPARD, Melvin   athletics      3
# 480240   1912        OSBURN, Carl Townsend    shooting      4
# 566940   1920                  LEE, Willis    shooting      7
# 710940   1924          WEISSMULLER, Johnny    aquatics      4
# 813348   1928          WEISSMULLER, Johnny    aquatics      2
# 877370   1932              MADISON, Helene    aquatics      3
# 992530   1936                 OWENS, Jesse   athletics      4
# 1086402  1948      MCLANE, James Price Jr.    aquatics      3
# 1178576  1952          KONNO, Ford Hiroshi    aquatics      3
# 1295504  1956        MORROW, Robert Joseph   athletics      3
# 1425994  1960  VON SALTZA, Susan Christina    aquatics      4
# 1514564  1964   SCHOLLANDER, Donald Arthur    aquatics      4
# 1577804  1968    HICKCOX, Charles Buchanan    aquatics      4
# 1724820  1972                  SPITZ, Mark    aquatics      7
# 1808732  1976         NABER, John Phillips    aquatics      5
# 1919142  1984             RETTON, Mary-Lou  gymnastics      5
# 1953334  1988              BIONDI, Matthew    aquatics      7
# 2112636  1992              MILLER, Shannon  gymnastics      5
# 2244204  1996               VAN DYKEN, Amy    aquatics      4
# 2345014  2000                 TORRES, Dara    aquatics      5
# 2428246  2004              PHELPS, Michael    aquatics      8
# 2530654  2008              PHELPS, Michael    aquatics      8

# %%
pd.concat(winners)[["Year",	"Athlete Name",	"Sport", "Total"]].reset_index()
# Out:
# Medal    index  Year                 Athlete Name       Sport  Total
# 0        32642  1896              GARRETT, Robert   athletics      4
# 1       107612  1900               BAXTER, Irving   athletics      5
# 2       245424  1904                 HEIDA, Anton  gymnastics      6
# 3       390390  1908             SHEPPARD, Melvin   athletics      3
# 4       480240  1912        OSBURN, Carl Townsend    shooting      4
# 5       566940  1920                  LEE, Willis    shooting      7
# 6       710940  1924          WEISSMULLER, Johnny    aquatics      4
# 7       813348  1928          WEISSMULLER, Johnny    aquatics      2
# 8       877370  1932              MADISON, Helene    aquatics      3
# 9       992530  1936                 OWENS, Jesse   athletics      4
# 10     1086402  1948      MCLANE, James Price Jr.    aquatics      3
# 11     1178576  1952          KONNO, Ford Hiroshi    aquatics      3
# 12     1295504  1956        MORROW, Robert Joseph   athletics      3
# 13     1425994  1960  VON SALTZA, Susan Christina    aquatics      4
# 14     1514564  1964   SCHOLLANDER, Donald Arthur    aquatics      4
# 15     1577804  1968    HICKCOX, Charles Buchanan    aquatics      4
# 16     1724820  1972                  SPITZ, Mark    aquatics      7
# 17     1808732  1976         NABER, John Phillips    aquatics      5
# 18     1919142  1984             RETTON, Mary-Lou  gymnastics      5
# 19     1953334  1988              BIONDI, Matthew    aquatics      7
# 20     2112636  1992              MILLER, Shannon  gymnastics      5
# 21     2244204  1996               VAN DYKEN, Amy    aquatics      4
# 22     2345014  2000                 TORRES, Dara    aquatics      5
# 23     2428246  2004              PHELPS, Michael    aquatics      8
# 24     2530654  2008              PHELPS, Michael    aquatics      8

# %%
pd.concat(winners)[["Year",	"Athlete Name",	"Sport", "Total"]].reset_index?
# Out:
# Object `reset_index` not found.

# %%
pd.DataFrame.reset_index?

# %%
pd.concat(winners)[["Year",	"Athlete Name",	"Sport", "Total"]].reset_index(drop=True)
# Out:
# Medal  Year                 Athlete Name       Sport  Total
# 0      1896              GARRETT, Robert   athletics      4
# 1      1900               BAXTER, Irving   athletics      5
# 2      1904                 HEIDA, Anton  gymnastics      6
# 3      1908             SHEPPARD, Melvin   athletics      3
# 4      1912        OSBURN, Carl Townsend    shooting      4
# 5      1920                  LEE, Willis    shooting      7
# 6      1924          WEISSMULLER, Johnny    aquatics      4
# 7      1928          WEISSMULLER, Johnny    aquatics      2
# 8      1932              MADISON, Helene    aquatics      3
# 9      1936                 OWENS, Jesse   athletics      4
# 10     1948      MCLANE, James Price Jr.    aquatics      3
# 11     1952          KONNO, Ford Hiroshi    aquatics      3
# 12     1956        MORROW, Robert Joseph   athletics      3
# 13     1960  VON SALTZA, Susan Christina    aquatics      4
# 14     1964   SCHOLLANDER, Donald Arthur    aquatics      4
# 15     1968    HICKCOX, Charles Buchanan    aquatics      4
# 16     1972                  SPITZ, Mark    aquatics      7
# 17     1976         NABER, John Phillips    aquatics      5
# 18     1984             RETTON, Mary-Lou  gymnastics      5
# 19     1988              BIONDI, Matthew    aquatics      7
# 20     1992              MILLER, Shannon  gymnastics      5
# 21     1996               VAN DYKEN, Amy    aquatics      4
# 22     2000                 TORRES, Dara    aquatics      5
# 23     2004              PHELPS, Michael    aquatics      8
# 24     2008              PHELPS, Michael    aquatics      8

# %%
#SDG
