# %% [markdown]
# # Getting Tweets with Tweepy

# %%
import tweepy
import configparser

# %%
# read configs
config = configparser.ConfigParser()
config.read('config.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 7
#       4 config = configparser.ConfigParser()
#       5 config.read('config.ini')
# ----> 7 api_key = config['twitter']['api_key']
#       8 api_key_secret = config['twitter']['api_key_secret']
#      10 access_token = config['twitter']['access_token']
#
# File /opt/anaconda3/lib/python3.12/configparser.py:941, in RawConfigParser.__getitem__(self, key)
#     939 def __getitem__(self, key):
#     940     if key != self.default_section and not self.has_section(key):
# --> 941         raise KeyError(key)
#     942     return self._proxies[key]
#
# KeyError: 'twitter'

# %%
# authentication
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # authentication
# ----> 2 auth = tweepy.OAuthHandler(api_key, api_key_secret)
#       3 auth.set_access_token(access_token, access_token_secret)
#
# NameError: name 'api_key' is not defined
